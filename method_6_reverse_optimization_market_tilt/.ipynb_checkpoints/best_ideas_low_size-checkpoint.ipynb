# %% [markdown]
# # Method 6 - Best Ideas Low Size

# %%
# %matplotlib inline
import pandas as pd
import warnings
from statsmodels import api as sm

from eptooling import crsp, epd, fs, hfu, crsp, db, bi
from eptooling.bm import bmdb, iso
from epquant.engine import weights, portfolio
from epquant.gen import returns
from epquant.perf import relative_performance

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Fetch Holdings and Benchmark Data

# %%
# Get HFU Data

# %store -r inst_data
inst_data = inst_data[inst_data['datadate'] >= '1999-06-30']

# Size

size = inst_data.groupby(['datadate', 'institution_id'])['pos_val'].sum().rename('size').reset_index()

# Count number of positions per manager

inst_data['num_pos'] = inst_data.groupby(['datadate', 'institution_id'])[
    'fsym_id'].transform(lambda s: s.nunique())

# Remove less than 20 holdings and less than $5mm per CSP

valid_data = inst_data[inst_data['num_pos'] >= 20]
valid_data = valid_data[valid_data['public_aum'] >= 5e6]

# Add Expected Returns from Market Relative Weight per Shumway, Szefler, Yuan 2009

# %store -r mkt_exp_ret

valid_data = valid_data.merge(mkt_exp_ret, on=['datadate', 'institution_id', 'fsym_id'], how='left')

# Calculate CSP Weight per Market Tilt

valid_data['adj_target'] = valid_data['expected_return']

# %% [markdown]
# ## Calculate Best Ideas

# %%
# Extract Best Ideas

valid_data['pos_rank'] = valid_data\
    .groupby(['datadate', 'institution_id'])['adj_target'].rank(ascending=False)

best_ideas = valid_data[valid_data['pos_rank'] == 1].copy()

# Add Size

best_ideas = best_ideas.merge(size)
best_ideas['size_pct'] = best_ideas.groupby('datadate')['size'].rank(pct=True)
best_ideas = best_ideas[best_ideas['size_pct'] < (1 / 3)]

# Weight the best ideas equally

best_ideas['target'] = 1 / best_ideas.groupby('datadate')['institution_id'].transform('count')

# %% [markdown]
# ## Backtest Portfolio

# %%
w = weights.Weights(best_ideas)

# %store -r r

p = portfolio.DailyPortfolio(w, r, end_date='2018-12-31')

rf = bi.get_risk_free_rate()
monthly_return = p.port_return.loc['1999-07-01':].resample('M').apply(epd.prod_red)
monthly_return = (monthly_return - rf).dropna()
monthly_return.name = 'port_return'

# %% [markdown]
# ## Plot Performance

# %%
epd.nav(monthly_return).plot()

# %%
monthly_return.resample('A').apply(epd.prod_red)
# Out:
# datadate
# 1999-12-31    0.230194
# 2000-12-31   -0.128224
# 2001-12-31   -0.013607
# 2002-12-31   -0.287841
# 2003-12-31    0.912568
# 2004-12-31    0.220809
# 2005-12-31    0.019116
# 2006-12-31    0.189040
# 2007-12-31   -0.086567
# 2008-12-31   -0.495268
# 2009-12-31    0.908287
# 2010-12-31    0.264609
# 2011-12-31   -0.157487
# 2012-12-31    0.138631
# 2013-12-31    0.491325
# 2014-12-31   -0.005505
# 2015-12-31   -0.098921
# 2016-12-31    0.181179
# 2017-12-31    0.163966
# 2018-12-31   -0.138856
# Freq: A-DEC, Name: port_return, dtype: float64

# %% [markdown]
# ## Fetch Factor Models

# %%
# Get Factor Models
q_factor_model = bi.get_q_factor_model()
fama_french_five_factor_model = bi.get_fama_french_five_factor_model()
four_factor_model = bi.get_four_factor_model()

# Concat Portfolio Return
q_factor = pd.concat([monthly_return, q_factor_model], axis=1)
fama_french_five = pd.concat([monthly_return, fama_french_five_factor_model], axis=1)
four_factor = pd.concat([monthly_return, four_factor_model], axis=1)

# Add Constants
q_factor.insert(1, 'const', 1)
fama_french_five.insert(1, 'const', 1)
four_factor.insert(1, 'const', 1)

# Split Period into Pre and Post Crisis
q_factor_pre, q_factor_post = q_factor.loc[:'2009-06-30'], q_factor.loc['2009-07-31':]
fama_french_five_pre, fama_french_five_post = fama_french_five.loc[:'2009-06-30'], fama_french_five.loc['2009-07-31':] 
four_factor_pre, four_factor_post = four_factor.loc[:'2009-06-30'], four_factor.loc['2009-07-31':]

# %% [markdown]
# ## Full Time Period Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.890
# Model:                            OLS   Adj. R-squared:                  0.888
# Method:                 Least Squares   F-statistic:                     463.1
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):          1.83e-108
# Time:                        13:31:15   Log-Likelihood:                 533.92
# No. Observations:                 234   AIC:                            -1058.
# Df Residuals:                     229   BIC:                            -1041.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0041      0.002      2.431      0.016       0.001       0.007
# mktrf          1.0359      0.047     22.239      0.000       0.944       1.128
# me             0.6211      0.054     11.463      0.000       0.514       0.728
# ia             0.1268      0.082      1.540      0.125      -0.035       0.289
# roe           -0.7518      0.070    -10.665      0.000      -0.891      -0.613
# ==============================================================================
# Omnibus:                       55.126   Durbin-Watson:                   2.189
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              331.664
# Skew:                           0.736   Prob(JB):                     9.55e-73
# Kurtosis:                       8.644   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.890
# Model:                            OLS   Adj. R-squared:                  0.888
# Method:                 Least Squares   F-statistic:                     245.6
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.38e-81
# Time:                        13:31:15   Log-Likelihood:                 533.92
# No. Observations:                 234   AIC:                            -1058.
# Df Residuals:                     229   BIC:                            -1041.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0041      0.002      2.267      0.023       0.001       0.008
# mktrf          1.0359      0.045     22.952      0.000       0.947       1.124
# me             0.6211      0.050     12.459      0.000       0.523       0.719
# ia             0.1268      0.134      0.944      0.345      -0.137       0.390
# roe           -0.7518      0.134     -5.607      0.000      -1.015      -0.489
# ==============================================================================
# Omnibus:                       55.126   Durbin-Watson:                   2.189
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              331.664
# Skew:                           0.736   Prob(JB):                     9.55e-73
# Kurtosis:                       8.644   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.890
# Model:                            OLS   Adj. R-squared:                  0.888
# Method:                 Least Squares   F-statistic:                     353.9
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           9.19e-97
# Time:                        13:31:15   Log-Likelihood:                 533.92
# No. Observations:                 234   AIC:                            -1058.
# Df Residuals:                     229   BIC:                            -1041.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0041      0.002      2.235      0.025       0.001       0.008
# mktrf          1.0359      0.042     24.471      0.000       0.953       1.119
# me             0.6211      0.053     11.826      0.000       0.518       0.724
# ia             0.1268      0.121      1.048      0.295      -0.110       0.364
# roe           -0.7518      0.143     -5.260      0.000      -1.032      -0.472
# ==============================================================================
# Omnibus:                       55.126   Durbin-Watson:                   2.189
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              331.664
# Skew:                           0.736   Prob(JB):                     9.55e-73
# Kurtosis:                       8.644   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.856
# Model:                            OLS   Adj. R-squared:                  0.853
# Method:                 Least Squares   F-statistic:                     339.9
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           4.74e-95
# Time:                        13:31:15   Log-Likelihood:                 502.32
# No. Observations:                 234   AIC:                            -994.6
# Df Residuals:                     229   BIC:                            -977.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0016      0.002      0.858      0.392      -0.002       0.005
# mktrf          1.1787      0.049     24.011      0.000       1.082       1.275
# smb            0.9063      0.061     14.791      0.000       0.786       1.027
# hml            0.0858      0.061      1.409      0.160      -0.034       0.206
# umd           -0.2135      0.040     -5.347      0.000      -0.292      -0.135
# ==============================================================================
# Omnibus:                       67.717   Durbin-Watson:                   2.142
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              345.047
# Skew:                           1.027   Prob(JB):                     1.19e-75
# Kurtosis:                       8.583   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.856
# Model:                            OLS   Adj. R-squared:                  0.853
# Method:                 Least Squares   F-statistic:                     235.7
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           6.20e-80
# Time:                        13:31:15   Log-Likelihood:                 502.32
# No. Observations:                 234   AIC:                            -994.6
# Df Residuals:                     229   BIC:                            -977.4
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0016      0.002      0.896      0.370      -0.002       0.005
# mktrf          1.1787      0.041     28.869      0.000       1.099       1.259
# smb            0.9063      0.074     12.318      0.000       0.762       1.051
# hml            0.0858      0.096      0.890      0.374      -0.103       0.275
# umd           -0.2135      0.081     -2.634      0.008      -0.372      -0.055
# ==============================================================================
# Omnibus:                       67.717   Durbin-Watson:                   2.142
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              345.047
# Skew:                           1.027   Prob(JB):                     1.19e-75
# Kurtosis:                       8.583   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.856
# Model:                            OLS   Adj. R-squared:                  0.853
# Method:                 Least Squares   F-statistic:                     319.7
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.85e-92
# Time:                        13:31:15   Log-Likelihood:                 502.32
# No. Observations:                 234   AIC:                            -994.6
# Df Residuals:                     229   BIC:                            -977.4
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0016      0.002      0.912      0.362      -0.002       0.005
# mktrf          1.1787      0.033     35.455      0.000       1.114       1.244
# smb            0.9063      0.070     12.956      0.000       0.769       1.043
# hml            0.0858      0.092      0.935      0.350      -0.094       0.265
# umd           -0.2135      0.078     -2.745      0.006      -0.366      -0.061
# ==============================================================================
# Omnibus:                       67.717   Durbin-Watson:                   2.142
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              345.047
# Skew:                           1.027   Prob(JB):                     1.19e-75
# Kurtosis:                       8.583   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.856
# Model:                            OLS   Adj. R-squared:                  0.853
# Method:                 Least Squares   F-statistic:                     339.9
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           4.74e-95
# Time:                        13:31:15   Log-Likelihood:                 502.32
# No. Observations:                 234   AIC:                            -994.6
# Df Residuals:                     229   BIC:                            -977.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0016      0.002      0.858      0.392      -0.002       0.005
# mktrf          1.1787      0.049     24.011      0.000       1.082       1.275
# smb            0.9063      0.061     14.791      0.000       0.786       1.027
# hml            0.0858      0.061      1.409      0.160      -0.034       0.206
# umd           -0.2135      0.040     -5.347      0.000      -0.292      -0.135
# ==============================================================================
# Omnibus:                       67.717   Durbin-Watson:                   2.142
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              345.047
# Skew:                           1.027   Prob(JB):                     1.19e-75
# Kurtosis:                       8.583   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.856
# Model:                            OLS   Adj. R-squared:                  0.853
# Method:                 Least Squares   F-statistic:                     235.7
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           6.20e-80
# Time:                        13:31:15   Log-Likelihood:                 502.32
# No. Observations:                 234   AIC:                            -994.6
# Df Residuals:                     229   BIC:                            -977.4
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0016      0.002      0.896      0.370      -0.002       0.005
# mktrf          1.1787      0.041     28.869      0.000       1.099       1.259
# smb            0.9063      0.074     12.318      0.000       0.762       1.051
# hml            0.0858      0.096      0.890      0.374      -0.103       0.275
# umd           -0.2135      0.081     -2.634      0.008      -0.372      -0.055
# ==============================================================================
# Omnibus:                       67.717   Durbin-Watson:                   2.142
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              345.047
# Skew:                           1.027   Prob(JB):                     1.19e-75
# Kurtosis:                       8.583   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.856
# Model:                            OLS   Adj. R-squared:                  0.853
# Method:                 Least Squares   F-statistic:                     319.7
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.85e-92
# Time:                        13:31:15   Log-Likelihood:                 502.32
# No. Observations:                 234   AIC:                            -994.6
# Df Residuals:                     229   BIC:                            -977.4
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0016      0.002      0.912      0.362      -0.002       0.005
# mktrf          1.1787      0.033     35.455      0.000       1.114       1.244
# smb            0.9063      0.070     12.956      0.000       0.769       1.043
# hml            0.0858      0.092      0.935      0.350      -0.094       0.265
# umd           -0.2135      0.078     -2.745      0.006      -0.366      -0.061
# ==============================================================================
# Omnibus:                       67.717   Durbin-Watson:                   2.142
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              345.047
# Skew:                           1.027   Prob(JB):                     1.19e-75
# Kurtosis:                       8.583   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Pre-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.882
# Model:                            OLS   Adj. R-squared:                  0.878
# Method:                 Least Squares   F-statistic:                     215.8
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.78e-52
# Time:                        13:31:16   Log-Likelihood:                 251.44
# No. Observations:                 120   AIC:                            -492.9
# Df Residuals:                     115   BIC:                            -478.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0067      0.003      2.308      0.023       0.001       0.012
# mktrf          1.0360      0.078     13.217      0.000       0.881       1.191
# me             0.6121      0.077      7.907      0.000       0.459       0.765
# ia             0.1951      0.121      1.610      0.110      -0.045       0.435
# roe           -0.7556      0.107     -7.042      0.000      -0.968      -0.543
# ==============================================================================
# Omnibus:                       23.221   Durbin-Watson:                   2.359
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               82.459
# Skew:                           0.552   Prob(JB):                     1.24e-18
# Kurtosis:                       6.908   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.882
# Model:                            OLS   Adj. R-squared:                  0.878
# Method:                 Least Squares   F-statistic:                     156.0
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.72e-45
# Time:                        13:31:16   Log-Likelihood:                 251.44
# No. Observations:                 120   AIC:                            -492.9
# Df Residuals:                     115   BIC:                            -478.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0067      0.003      2.470      0.014       0.001       0.012
# mktrf          1.0360      0.079     13.176      0.000       0.882       1.190
# me             0.6121      0.074      8.315      0.000       0.468       0.756
# ia             0.1951      0.177      1.103      0.270      -0.152       0.542
# roe           -0.7556      0.183     -4.140      0.000      -1.113      -0.398
# ==============================================================================
# Omnibus:                       23.221   Durbin-Watson:                   2.359
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               82.459
# Skew:                           0.552   Prob(JB):                     1.24e-18
# Kurtosis:                       6.908   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.882
# Model:                            OLS   Adj. R-squared:                  0.878
# Method:                 Least Squares   F-statistic:                     247.6
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.61e-55
# Time:                        13:31:16   Log-Likelihood:                 251.44
# No. Observations:                 120   AIC:                            -492.9
# Df Residuals:                     115   BIC:                            -478.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0067      0.003      2.621      0.009       0.002       0.012
# mktrf          1.0360      0.077     13.474      0.000       0.885       1.187
# me             0.6121      0.079      7.787      0.000       0.458       0.766
# ia             0.1951      0.155      1.255      0.210      -0.110       0.500
# roe           -0.7556      0.194     -3.904      0.000      -1.135      -0.376
# ==============================================================================
# Omnibus:                       23.221   Durbin-Watson:                   2.359
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               82.459
# Skew:                           0.552   Prob(JB):                     1.24e-18
# Kurtosis:                       6.908   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.855
# Model:                            OLS   Adj. R-squared:                  0.850
# Method:                 Least Squares   F-statistic:                     169.8
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.79e-47
# Time:                        13:31:16   Log-Likelihood:                 238.93
# No. Observations:                 120   AIC:                            -467.9
# Df Residuals:                     115   BIC:                            -453.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0050      0.003      1.595      0.113      -0.001       0.011
# mktrf          1.2235      0.077     15.964      0.000       1.072       1.375
# smb            0.9301      0.087     10.659      0.000       0.757       1.103
# hml            0.0938      0.087      1.074      0.285      -0.079       0.267
# umd           -0.2110      0.054     -3.916      0.000      -0.318      -0.104
# ==============================================================================
# Omnibus:                       34.639   Durbin-Watson:                   2.361
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              124.494
# Skew:                           0.938   Prob(JB):                     9.26e-28
# Kurtosis:                       7.623   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.855
# Model:                            OLS   Adj. R-squared:                  0.850
# Method:                 Least Squares   F-statistic:                     117.2
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.26e-39
# Time:                        13:31:16   Log-Likelihood:                 238.93
# No. Observations:                 120   AIC:                            -467.9
# Df Residuals:                     115   BIC:                            -453.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0050      0.002      2.027      0.043       0.000       0.010
# mktrf          1.2235      0.062     19.830      0.000       1.103       1.344
# smb            0.9301      0.096      9.687      0.000       0.742       1.118
# hml            0.0938      0.125      0.749      0.454      -0.152       0.339
# umd           -0.2110      0.093     -2.274      0.023      -0.393      -0.029
# ==============================================================================
# Omnibus:                       34.639   Durbin-Watson:                   2.361
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              124.494
# Skew:                           0.938   Prob(JB):                     9.26e-28
# Kurtosis:                       7.623   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.855
# Model:                            OLS   Adj. R-squared:                  0.850
# Method:                 Least Squares   F-statistic:                     159.1
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           6.66e-46
# Time:                        13:31:16   Log-Likelihood:                 238.93
# No. Observations:                 120   AIC:                            -467.9
# Df Residuals:                     115   BIC:                            -453.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0050      0.002      2.274      0.023       0.001       0.009
# mktrf          1.2235      0.051     24.005      0.000       1.124       1.323
# smb            0.9301      0.094      9.876      0.000       0.746       1.115
# hml            0.0938      0.128      0.731      0.465      -0.158       0.345
# umd           -0.2110      0.086     -2.445      0.014      -0.380      -0.042
# ==============================================================================
# Omnibus:                       34.639   Durbin-Watson:                   2.361
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              124.494
# Skew:                           0.938   Prob(JB):                     9.26e-28
# Kurtosis:                       7.623   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.855
# Model:                            OLS   Adj. R-squared:                  0.850
# Method:                 Least Squares   F-statistic:                     169.8
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.79e-47
# Time:                        13:31:16   Log-Likelihood:                 238.93
# No. Observations:                 120   AIC:                            -467.9
# Df Residuals:                     115   BIC:                            -453.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0050      0.003      1.595      0.113      -0.001       0.011
# mktrf          1.2235      0.077     15.964      0.000       1.072       1.375
# smb            0.9301      0.087     10.659      0.000       0.757       1.103
# hml            0.0938      0.087      1.074      0.285      -0.079       0.267
# umd           -0.2110      0.054     -3.916      0.000      -0.318      -0.104
# ==============================================================================
# Omnibus:                       34.639   Durbin-Watson:                   2.361
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              124.494
# Skew:                           0.938   Prob(JB):                     9.26e-28
# Kurtosis:                       7.623   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.855
# Model:                            OLS   Adj. R-squared:                  0.850
# Method:                 Least Squares   F-statistic:                     117.2
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.26e-39
# Time:                        13:31:16   Log-Likelihood:                 238.93
# No. Observations:                 120   AIC:                            -467.9
# Df Residuals:                     115   BIC:                            -453.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0050      0.002      2.027      0.043       0.000       0.010
# mktrf          1.2235      0.062     19.830      0.000       1.103       1.344
# smb            0.9301      0.096      9.687      0.000       0.742       1.118
# hml            0.0938      0.125      0.749      0.454      -0.152       0.339
# umd           -0.2110      0.093     -2.274      0.023      -0.393      -0.029
# ==============================================================================
# Omnibus:                       34.639   Durbin-Watson:                   2.361
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              124.494
# Skew:                           0.938   Prob(JB):                     9.26e-28
# Kurtosis:                       7.623   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.855
# Model:                            OLS   Adj. R-squared:                  0.850
# Method:                 Least Squares   F-statistic:                     159.1
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           6.66e-46
# Time:                        13:31:16   Log-Likelihood:                 238.93
# No. Observations:                 120   AIC:                            -467.9
# Df Residuals:                     115   BIC:                            -453.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0050      0.002      2.274      0.023       0.001       0.009
# mktrf          1.2235      0.051     24.005      0.000       1.124       1.323
# smb            0.9301      0.094      9.876      0.000       0.746       1.115
# hml            0.0938      0.128      0.731      0.465      -0.158       0.345
# umd           -0.2110      0.086     -2.445      0.014      -0.380      -0.042
# ==============================================================================
# Omnibus:                       34.639   Durbin-Watson:                   2.361
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              124.494
# Skew:                           0.938   Prob(JB):                     9.26e-28
# Kurtosis:                       7.623   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Post-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.918
# Model:                            OLS   Adj. R-squared:                  0.915
# Method:                 Least Squares   F-statistic:                     306.4
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.61e-58
# Time:                        13:31:16   Log-Likelihood:                 304.34
# No. Observations:                 114   AIC:                            -598.7
# Df Residuals:                     109   BIC:                            -585.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0012      0.002      0.699      0.486      -0.002       0.005
# mktrf          1.0806      0.050     21.439      0.000       0.981       1.180
# me             0.5712      0.078      7.340      0.000       0.417       0.725
# ia            -0.1207      0.108     -1.119      0.266      -0.335       0.093
# roe           -0.8607      0.095     -9.074      0.000      -1.049      -0.673
# ==============================================================================
# Omnibus:                        5.862   Durbin-Watson:                   1.917
# Prob(Omnibus):                  0.053   Jarque-Bera (JB):                9.042
# Skew:                           0.087   Prob(JB):                       0.0109
# Kurtosis:                       4.369   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.918
# Model:                            OLS   Adj. R-squared:                  0.915
# Method:                 Least Squares   F-statistic:                     453.3
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           6.17e-67
# Time:                        13:31:16   Log-Likelihood:                 304.34
# No. Observations:                 114   AIC:                            -598.7
# Df Residuals:                     109   BIC:                            -585.0
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0012      0.002      0.708      0.479      -0.002       0.004
# mktrf          1.0806      0.041     26.259      0.000       1.000       1.161
# me             0.5712      0.048     12.022      0.000       0.478       0.664
# ia            -0.1207      0.103     -1.171      0.242      -0.323       0.081
# roe           -0.8607      0.114     -7.539      0.000      -1.084      -0.637
# ==============================================================================
# Omnibus:                        5.862   Durbin-Watson:                   1.917
# Prob(Omnibus):                  0.053   Jarque-Bera (JB):                9.042
# Skew:                           0.087   Prob(JB):                       0.0109
# Kurtosis:                       4.369   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.918
# Model:                            OLS   Adj. R-squared:                  0.915
# Method:                 Least Squares   F-statistic:                     635.7
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.52e-74
# Time:                        13:31:16   Log-Likelihood:                 304.34
# No. Observations:                 114   AIC:                            -598.7
# Df Residuals:                     109   BIC:                            -585.0
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0012      0.002      0.757      0.449      -0.002       0.004
# mktrf          1.0806      0.038     28.658      0.000       1.007       1.154
# me             0.5712      0.040     14.189      0.000       0.492       0.650
# ia            -0.1207      0.098     -1.227      0.220      -0.314       0.072
# roe           -0.8607      0.112     -7.704      0.000      -1.080      -0.642
# ==============================================================================
# Omnibus:                        5.862   Durbin-Watson:                   1.917
# Prob(Omnibus):                  0.053   Jarque-Bera (JB):                9.042
# Skew:                           0.087   Prob(JB):                       0.0109
# Kurtosis:                       4.369   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.870
# Model:                            OLS   Adj. R-squared:                  0.865
# Method:                 Least Squares   F-statistic:                     182.1
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.64e-47
# Time:                        13:31:16   Log-Likelihood:                 277.78
# No. Observations:                 114   AIC:                            -545.6
# Df Residuals:                     109   BIC:                            -531.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0019      0.002     -0.876      0.383      -0.006       0.002
# mktrf          1.1653      0.060     19.328      0.000       1.046       1.285
# smb            0.7689      0.094      8.179      0.000       0.583       0.955
# hml            0.1277      0.097      1.319      0.190      -0.064       0.320
# umd           -0.1819      0.073     -2.491      0.014      -0.327      -0.037
# ==============================================================================
# Omnibus:                       11.155   Durbin-Watson:                   1.738
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               17.829
# Skew:                           0.432   Prob(JB):                     0.000134
# Kurtosis:                       4.734   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.870
# Model:                            OLS   Adj. R-squared:                  0.865
# Method:                 Least Squares   F-statistic:                     207.2
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           5.58e-50
# Time:                        13:31:16   Log-Likelihood:                 277.78
# No. Observations:                 114   AIC:                            -545.6
# Df Residuals:                     109   BIC:                            -531.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0019      0.002     -1.015      0.310      -0.006       0.002
# mktrf          1.1653      0.048     24.285      0.000       1.071       1.259
# smb            0.7689      0.086      8.910      0.000       0.600       0.938
# hml            0.1277      0.152      0.842      0.400      -0.170       0.425
# umd           -0.1819      0.061     -2.958      0.003      -0.302      -0.061
# ==============================================================================
# Omnibus:                       11.155   Durbin-Watson:                   1.738
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               17.829
# Skew:                           0.432   Prob(JB):                     0.000134
# Kurtosis:                       4.734   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.870
# Model:                            OLS   Adj. R-squared:                  0.865
# Method:                 Least Squares   F-statistic:                     240.5
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           4.12e-53
# Time:                        13:31:16   Log-Likelihood:                 277.78
# No. Observations:                 114   AIC:                            -545.6
# Df Residuals:                     109   BIC:                            -531.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0019      0.002     -1.033      0.302      -0.005       0.002
# mktrf          1.1653      0.045     25.805      0.000       1.077       1.254
# smb            0.7689      0.067     11.499      0.000       0.638       0.900
# hml            0.1277      0.161      0.794      0.427      -0.187       0.443
# umd           -0.1819      0.056     -3.247      0.001      -0.292      -0.072
# ==============================================================================
# Omnibus:                       11.155   Durbin-Watson:                   1.738
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               17.829
# Skew:                           0.432   Prob(JB):                     0.000134
# Kurtosis:                       4.734   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.870
# Model:                            OLS   Adj. R-squared:                  0.865
# Method:                 Least Squares   F-statistic:                     182.1
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.64e-47
# Time:                        13:31:16   Log-Likelihood:                 277.78
# No. Observations:                 114   AIC:                            -545.6
# Df Residuals:                     109   BIC:                            -531.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0019      0.002     -0.876      0.383      -0.006       0.002
# mktrf          1.1653      0.060     19.328      0.000       1.046       1.285
# smb            0.7689      0.094      8.179      0.000       0.583       0.955
# hml            0.1277      0.097      1.319      0.190      -0.064       0.320
# umd           -0.1819      0.073     -2.491      0.014      -0.327      -0.037
# ==============================================================================
# Omnibus:                       11.155   Durbin-Watson:                   1.738
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               17.829
# Skew:                           0.432   Prob(JB):                     0.000134
# Kurtosis:                       4.734   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.870
# Model:                            OLS   Adj. R-squared:                  0.865
# Method:                 Least Squares   F-statistic:                     207.2
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           5.58e-50
# Time:                        13:31:16   Log-Likelihood:                 277.78
# No. Observations:                 114   AIC:                            -545.6
# Df Residuals:                     109   BIC:                            -531.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0019      0.002     -1.015      0.310      -0.006       0.002
# mktrf          1.1653      0.048     24.285      0.000       1.071       1.259
# smb            0.7689      0.086      8.910      0.000       0.600       0.938
# hml            0.1277      0.152      0.842      0.400      -0.170       0.425
# umd           -0.1819      0.061     -2.958      0.003      -0.302      -0.061
# ==============================================================================
# Omnibus:                       11.155   Durbin-Watson:                   1.738
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               17.829
# Skew:                           0.432   Prob(JB):                     0.000134
# Kurtosis:                       4.734   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.870
# Model:                            OLS   Adj. R-squared:                  0.865
# Method:                 Least Squares   F-statistic:                     240.5
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           4.12e-53
# Time:                        13:31:16   Log-Likelihood:                 277.78
# No. Observations:                 114   AIC:                            -545.6
# Df Residuals:                     109   BIC:                            -531.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0019      0.002     -1.033      0.302      -0.005       0.002
# mktrf          1.1653      0.045     25.805      0.000       1.077       1.254
# smb            0.7689      0.067     11.499      0.000       0.638       0.900
# hml            0.1277      0.161      0.794      0.427      -0.187       0.443
# umd           -0.1819      0.056     -3.247      0.001      -0.292      -0.072
# ==============================================================================
# Omnibus:                       11.155   Durbin-Watson:                   1.738
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               17.829
# Skew:                           0.432   Prob(JB):                     0.000134
# Kurtosis:                       4.734   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """
