# %% [markdown]
# # Method 2 - Best Ideas High Focus

# %%
# %matplotlib inline
import pandas as pd
import warnings
from statsmodels import api as sm

from eptooling import crsp, epd, fs, hfu, crsp, db, bi
from eptooling.bm import bmdb, iso
from epquant.engine import weights, portfolio
from epquant.gen import returns
from epquant.perf import relative_performance

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Fetch Holdings and Benchmark Data

# %%
# Get HFU Data

# %store -r inst_data
inst_data = inst_data[inst_data['datadate'] >= '1999-06-30']

# Focus

focus = inst_data.groupby(['datadate', 'institution_id'])['fsym_id'].count().rename('focus').reset_index()

# Count number of positions per manager

inst_data['num_pos'] = inst_data.groupby(['datadate', 'institution_id'])[
    'fsym_id'].transform(lambda s: s.nunique())

# Remove less than 20 holdings and less than $5mm per CSP

valid_data = inst_data[inst_data['num_pos'] >= 20]
valid_data = valid_data[valid_data['public_aum'] >= 5e6]

# Get Benchmark Weights

bm = crsp.get_crsp_market_portfolio()

# Merge Benchmark Weights onto Holdings

valid_data = valid_data.merge(bm, how='left', on=['datadate', 'fsym_id'])

# Grab Idiosyncratic Volatility

capm_var = crsp.get_capm_variance()

# Merge Idiosyncratic Volatility

valid_data = valid_data.merge(capm_var, how='left')

# Calculate Variance-Adjusted Market Tilt

valid_data['adj_target'] = (valid_data['target'] - valid_data['weight'].fillna(0)) * valid_data['capm_var']

# %% [markdown]
# ## Calculate Best Ideas

# %%
# Extract Best Ideas

valid_data['pos_rank'] = valid_data\
    .groupby(['datadate', 'institution_id'])['adj_target'].rank(ascending=False)

best_ideas = valid_data[valid_data['pos_rank'] == 1].copy()

# Add Focus

best_ideas = best_ideas.merge(focus)
best_ideas['focus_pct'] = best_ideas.groupby('datadate')['focus'].rank(pct=True)
best_ideas = best_ideas[best_ideas['focus_pct'] > (2 / 3)]

# Weight the best ideas equally

best_ideas['target'] = 1 / best_ideas.groupby('datadate')['institution_id'].transform('count')

# %% [markdown]
# ## Backtest Portfolio

# %%
w = weights.Weights(best_ideas)

# %store -r r

p = portfolio.DailyPortfolio(w, r, end_date='2018-12-31')

rf = bi.get_risk_free_rate()
monthly_return = p.port_return.loc['1999-07-01':].resample('M').apply(epd.prod_red)
monthly_return = (monthly_return - rf).dropna()
monthly_return.name = 'port_return'

# %% [markdown]
# ## Plot Performance

# %%
epd.nav(monthly_return).plot()

# %%
monthly_return.resample('A').apply(epd.prod_red)
# Out:
# datadate
# 1999-12-31    0.320253
# 2000-12-31   -0.242499
# 2001-12-31   -0.187461
# 2002-12-31   -0.180902
# 2003-12-31    0.373479
# 2004-12-31    0.137333
# 2005-12-31    0.064268
# 2006-12-31    0.102334
# 2007-12-31    0.069978
# 2008-12-31   -0.410232
# 2009-12-31    0.287298
# 2010-12-31    0.226429
# 2011-12-31   -0.027131
# 2012-12-31    0.183217
# 2013-12-31    0.455797
# 2014-12-31    0.119574
# 2015-12-31    0.000644
# 2016-12-31    0.085796
# 2017-12-31    0.165675
# 2018-12-31   -0.084418
# Freq: A-DEC, Name: port_return, dtype: float64

# %% [markdown]
# ## Fetch Factor Models

# %%
# Get Factor Models
q_factor_model = bi.get_q_factor_model()
fama_french_five_factor_model = bi.get_fama_french_five_factor_model()
four_factor_model = bi.get_four_factor_model()

# Concat Portfolio Return
q_factor = pd.concat([monthly_return, q_factor_model], axis=1)
fama_french_five = pd.concat([monthly_return, fama_french_five_factor_model], axis=1)
four_factor = pd.concat([monthly_return, four_factor_model], axis=1)

# Add Constants
q_factor.insert(1, 'const', 1)
fama_french_five.insert(1, 'const', 1)
four_factor.insert(1, 'const', 1)

# Split Period into Pre and Post Crisis
q_factor_pre, q_factor_post = q_factor.loc[:'2009-06-30'], q_factor.loc['2009-07-31':]
fama_french_five_pre, fama_french_five_post = fama_french_five.loc[:'2009-06-30'], fama_french_five.loc['2009-07-31':] 
four_factor_pre, four_factor_post = four_factor.loc[:'2009-06-30'], four_factor.loc['2009-07-31':]

# %% [markdown]
# ## Full Time Period Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.892
# Model:                            OLS   Adj. R-squared:                  0.890
# Method:                 Least Squares   F-statistic:                     474.2
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):          1.64e-109
# Time:                        17:53:37   Log-Likelihood:                 641.16
# No. Observations:                 234   AIC:                            -1272.
# Df Residuals:                     229   BIC:                            -1255.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0002      0.001     -0.203      0.839      -0.002       0.002
# mktrf          0.9833      0.029     33.383      0.000       0.925       1.041
# me             0.3414      0.034      9.964      0.000       0.274       0.409
# ia            -0.2565      0.052     -4.925      0.000      -0.359      -0.154
# roe            0.2149      0.045      4.822      0.000       0.127       0.303
# ==============================================================================
# Omnibus:                       53.696   Durbin-Watson:                   1.809
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              443.136
# Skew:                           0.587   Prob(JB):                     5.95e-97
# Kurtosis:                       9.639   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.892
# Model:                            OLS   Adj. R-squared:                  0.890
# Method:                 Least Squares   F-statistic:                     245.3
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           1.56e-81
# Time:                        17:53:37   Log-Likelihood:                 641.16
# No. Observations:                 234   AIC:                            -1272.
# Df Residuals:                     229   BIC:                            -1255.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0002      0.001     -0.192      0.848      -0.002       0.002
# mktrf          0.9833      0.037     26.606      0.000       0.911       1.056
# me             0.3414      0.036      9.444      0.000       0.271       0.412
# ia            -0.2565      0.103     -2.500      0.012      -0.458      -0.055
# roe            0.2149      0.056      3.870      0.000       0.106       0.324
# ==============================================================================
# Omnibus:                       53.696   Durbin-Watson:                   1.809
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              443.136
# Skew:                           0.587   Prob(JB):                     5.95e-97
# Kurtosis:                       9.639   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.892
# Model:                            OLS   Adj. R-squared:                  0.890
# Method:                 Least Squares   F-statistic:                     235.5
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           6.71e-80
# Time:                        17:53:38   Log-Likelihood:                 641.16
# No. Observations:                 234   AIC:                            -1272.
# Df Residuals:                     229   BIC:                            -1255.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0002      0.001     -0.187      0.851      -0.003       0.002
# mktrf          0.9833      0.035     28.331      0.000       0.915       1.051
# me             0.3414      0.033     10.470      0.000       0.278       0.405
# ia            -0.2565      0.100     -2.565      0.010      -0.453      -0.060
# roe            0.2149      0.055      3.940      0.000       0.108       0.322
# ==============================================================================
# Omnibus:                       53.696   Durbin-Watson:                   1.809
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              443.136
# Skew:                           0.587   Prob(JB):                     5.95e-97
# Kurtosis:                       9.639   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.913
# Model:                            OLS   Adj. R-squared:                  0.911
# Method:                 Least Squares   F-statistic:                     599.7
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):          4.78e-120
# Time:                        17:53:38   Log-Likelihood:                 665.97
# No. Observations:                 234   AIC:                            -1322.
# Df Residuals:                     229   BIC:                            -1305.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0005      0.001     -0.499      0.618      -0.002       0.001
# mktrf          1.0347      0.024     42.417      0.000       0.987       1.083
# smb            0.2165      0.030      7.111      0.000       0.157       0.277
# hml           -0.0396      0.030     -1.308      0.192      -0.099       0.020
# umd            0.1999      0.020     10.071      0.000       0.161       0.239
# ==============================================================================
# Omnibus:                       23.987   Durbin-Watson:                   1.840
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              101.262
# Skew:                           0.154   Prob(JB):                     1.03e-22
# Kurtosis:                       6.208   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.913
# Model:                            OLS   Adj. R-squared:                  0.911
# Method:                 Least Squares   F-statistic:                     566.3
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):          1.89e-117
# Time:                        17:53:38   Log-Likelihood:                 665.97
# No. Observations:                 234   AIC:                            -1322.
# Df Residuals:                     229   BIC:                            -1305.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0005      0.001     -0.567      0.571      -0.002       0.001
# mktrf          1.0347      0.042     24.552      0.000       0.952       1.117
# smb            0.2165      0.043      5.026      0.000       0.132       0.301
# hml           -0.0396      0.039     -1.025      0.305      -0.115       0.036
# umd            0.1999      0.039      5.185      0.000       0.124       0.275
# ==============================================================================
# Omnibus:                       23.987   Durbin-Watson:                   1.840
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              101.262
# Skew:                           0.154   Prob(JB):                     1.03e-22
# Kurtosis:                       6.208   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.913
# Model:                            OLS   Adj. R-squared:                  0.911
# Method:                 Least Squares   F-statistic:                     745.6
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):          5.17e-130
# Time:                        17:53:38   Log-Likelihood:                 665.97
# No. Observations:                 234   AIC:                            -1322.
# Df Residuals:                     229   BIC:                            -1305.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0005      0.001     -0.551      0.582      -0.002       0.001
# mktrf          1.0347      0.043     24.003      0.000       0.950       1.119
# smb            0.2165      0.047      4.599      0.000       0.124       0.309
# hml           -0.0396      0.035     -1.115      0.265      -0.109       0.030
# umd            0.1999      0.038      5.327      0.000       0.126       0.273
# ==============================================================================
# Omnibus:                       23.987   Durbin-Watson:                   1.840
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              101.262
# Skew:                           0.154   Prob(JB):                     1.03e-22
# Kurtosis:                       6.208   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.913
# Model:                            OLS   Adj. R-squared:                  0.911
# Method:                 Least Squares   F-statistic:                     599.7
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):          4.78e-120
# Time:                        17:53:38   Log-Likelihood:                 665.97
# No. Observations:                 234   AIC:                            -1322.
# Df Residuals:                     229   BIC:                            -1305.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0005      0.001     -0.499      0.618      -0.002       0.001
# mktrf          1.0347      0.024     42.417      0.000       0.987       1.083
# smb            0.2165      0.030      7.111      0.000       0.157       0.277
# hml           -0.0396      0.030     -1.308      0.192      -0.099       0.020
# umd            0.1999      0.020     10.071      0.000       0.161       0.239
# ==============================================================================
# Omnibus:                       23.987   Durbin-Watson:                   1.840
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              101.262
# Skew:                           0.154   Prob(JB):                     1.03e-22
# Kurtosis:                       6.208   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.913
# Model:                            OLS   Adj. R-squared:                  0.911
# Method:                 Least Squares   F-statistic:                     566.3
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):          1.89e-117
# Time:                        17:53:38   Log-Likelihood:                 665.97
# No. Observations:                 234   AIC:                            -1322.
# Df Residuals:                     229   BIC:                            -1305.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0005      0.001     -0.567      0.571      -0.002       0.001
# mktrf          1.0347      0.042     24.552      0.000       0.952       1.117
# smb            0.2165      0.043      5.026      0.000       0.132       0.301
# hml           -0.0396      0.039     -1.025      0.305      -0.115       0.036
# umd            0.1999      0.039      5.185      0.000       0.124       0.275
# ==============================================================================
# Omnibus:                       23.987   Durbin-Watson:                   1.840
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              101.262
# Skew:                           0.154   Prob(JB):                     1.03e-22
# Kurtosis:                       6.208   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.913
# Model:                            OLS   Adj. R-squared:                  0.911
# Method:                 Least Squares   F-statistic:                     745.6
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):          5.17e-130
# Time:                        17:53:38   Log-Likelihood:                 665.97
# No. Observations:                 234   AIC:                            -1322.
# Df Residuals:                     229   BIC:                            -1305.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0005      0.001     -0.551      0.582      -0.002       0.001
# mktrf          1.0347      0.043     24.003      0.000       0.950       1.119
# smb            0.2165      0.047      4.599      0.000       0.124       0.309
# hml           -0.0396      0.035     -1.115      0.265      -0.109       0.030
# umd            0.1999      0.038      5.327      0.000       0.126       0.273
# ==============================================================================
# Omnibus:                       23.987   Durbin-Watson:                   1.840
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              101.262
# Skew:                           0.154   Prob(JB):                     1.03e-22
# Kurtosis:                       6.208   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Pre-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.866
# Model:                            OLS   Adj. R-squared:                  0.861
# Method:                 Least Squares   F-statistic:                     185.8
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           3.28e-49
# Time:                        17:53:38   Log-Likelihood:                 301.08
# No. Observations:                 120   AIC:                            -592.2
# Df Residuals:                     115   BIC:                            -578.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0016      0.002     -0.833      0.407      -0.005       0.002
# mktrf          1.0162      0.052     19.608      0.000       0.914       1.119
# me             0.3724      0.051      7.274      0.000       0.271       0.474
# ia            -0.3266      0.080     -4.074      0.000      -0.485      -0.168
# roe            0.3116      0.071      4.392      0.000       0.171       0.452
# ==============================================================================
# Omnibus:                       25.798   Durbin-Watson:                   1.811
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               93.288
# Skew:                           0.638   Prob(JB):                     5.53e-21
# Kurtosis:                       7.127   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.866
# Model:                            OLS   Adj. R-squared:                  0.861
# Method:                 Least Squares   F-statistic:                     101.3
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           9.23e-37
# Time:                        17:53:38   Log-Likelihood:                 301.08
# No. Observations:                 120   AIC:                            -592.2
# Df Residuals:                     115   BIC:                            -578.2
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0016      0.002     -0.801      0.423      -0.006       0.002
# mktrf          1.0162      0.062     16.456      0.000       0.895       1.137
# me             0.3724      0.042      8.877      0.000       0.290       0.455
# ia            -0.3266      0.138     -2.366      0.018      -0.597      -0.056
# roe            0.3116      0.063      4.978      0.000       0.189       0.434
# ==============================================================================
# Omnibus:                       25.798   Durbin-Watson:                   1.811
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               93.288
# Skew:                           0.638   Prob(JB):                     5.53e-21
# Kurtosis:                       7.127   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.866
# Model:                            OLS   Adj. R-squared:                  0.861
# Method:                 Least Squares   F-statistic:                     101.8
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           7.39e-37
# Time:                        17:53:38   Log-Likelihood:                 301.08
# No. Observations:                 120   AIC:                            -592.2
# Df Residuals:                     115   BIC:                            -578.2
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0016      0.002     -0.843      0.399      -0.005       0.002
# mktrf          1.0162      0.054     18.808      0.000       0.910       1.122
# me             0.3724      0.038      9.879      0.000       0.298       0.446
# ia            -0.3266      0.136     -2.401      0.016      -0.593      -0.060
# roe            0.3116      0.046      6.814      0.000       0.222       0.401
# ==============================================================================
# Omnibus:                       25.798   Durbin-Watson:                   1.811
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               93.288
# Skew:                           0.638   Prob(JB):                     5.53e-21
# Kurtosis:                       7.127   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.899
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     257.3
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           2.23e-56
# Time:                        17:53:38   Log-Likelihood:                 318.34
# No. Observations:                 120   AIC:                            -626.7
# Df Residuals:                     115   BIC:                            -612.7
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -6.659e-06      0.002     -0.004      0.997      -0.003       0.003
# mktrf          1.0877      0.040     27.507      0.000       1.009       1.166
# smb            0.1706      0.045      3.789      0.000       0.081       0.260
# hml           -0.0510      0.045     -1.131      0.260      -0.140       0.038
# umd            0.2480      0.028      8.919      0.000       0.193       0.303
# ==============================================================================
# Omnibus:                        7.222   Durbin-Watson:                   1.813
# Prob(Omnibus):                  0.027   Jarque-Bera (JB):               12.697
# Skew:                          -0.116   Prob(JB):                      0.00175
# Kurtosis:                       4.577   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.899
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     296.6
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           1.37e-59
# Time:                        17:53:38   Log-Likelihood:                 318.34
# No. Observations:                 120   AIC:                            -626.7
# Df Residuals:                     115   BIC:                            -612.7
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -6.659e-06      0.001     -0.005      0.996      -0.003       0.003
# mktrf          1.0877      0.058     18.823      0.000       0.974       1.201
# smb            0.1706      0.052      3.251      0.001       0.068       0.273
# hml           -0.0510      0.046     -1.116      0.265      -0.141       0.039
# umd            0.2480      0.046      5.435      0.000       0.159       0.337
# ==============================================================================
# Omnibus:                        7.222   Durbin-Watson:                   1.813
# Prob(Omnibus):                  0.027   Jarque-Bera (JB):               12.697
# Skew:                          -0.116   Prob(JB):                      0.00175
# Kurtosis:                       4.577   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.899
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     472.2
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           2.37e-70
# Time:                        17:53:38   Log-Likelihood:                 318.34
# No. Observations:                 120   AIC:                            -626.7
# Df Residuals:                     115   BIC:                            -612.7
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -6.659e-06      0.001     -0.005      0.996      -0.002       0.002
# mktrf          1.0877      0.051     21.413      0.000       0.988       1.187
# smb            0.1706      0.056      3.073      0.002       0.062       0.279
# hml           -0.0510      0.039     -1.323      0.186      -0.127       0.025
# umd            0.2480      0.038      6.553      0.000       0.174       0.322
# ==============================================================================
# Omnibus:                        7.222   Durbin-Watson:                   1.813
# Prob(Omnibus):                  0.027   Jarque-Bera (JB):               12.697
# Skew:                          -0.116   Prob(JB):                      0.00175
# Kurtosis:                       4.577   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.899
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     257.3
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           2.23e-56
# Time:                        17:53:38   Log-Likelihood:                 318.34
# No. Observations:                 120   AIC:                            -626.7
# Df Residuals:                     115   BIC:                            -612.7
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -6.659e-06      0.002     -0.004      0.997      -0.003       0.003
# mktrf          1.0877      0.040     27.507      0.000       1.009       1.166
# smb            0.1706      0.045      3.789      0.000       0.081       0.260
# hml           -0.0510      0.045     -1.131      0.260      -0.140       0.038
# umd            0.2480      0.028      8.919      0.000       0.193       0.303
# ==============================================================================
# Omnibus:                        7.222   Durbin-Watson:                   1.813
# Prob(Omnibus):                  0.027   Jarque-Bera (JB):               12.697
# Skew:                          -0.116   Prob(JB):                      0.00175
# Kurtosis:                       4.577   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.899
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     296.6
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           1.37e-59
# Time:                        17:53:38   Log-Likelihood:                 318.34
# No. Observations:                 120   AIC:                            -626.7
# Df Residuals:                     115   BIC:                            -612.7
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -6.659e-06      0.001     -0.005      0.996      -0.003       0.003
# mktrf          1.0877      0.058     18.823      0.000       0.974       1.201
# smb            0.1706      0.052      3.251      0.001       0.068       0.273
# hml           -0.0510      0.046     -1.116      0.265      -0.141       0.039
# umd            0.2480      0.046      5.435      0.000       0.159       0.337
# ==============================================================================
# Omnibus:                        7.222   Durbin-Watson:                   1.813
# Prob(Omnibus):                  0.027   Jarque-Bera (JB):               12.697
# Skew:                          -0.116   Prob(JB):                      0.00175
# Kurtosis:                       4.577   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.899
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     472.2
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           2.37e-70
# Time:                        17:53:38   Log-Likelihood:                 318.34
# No. Observations:                 120   AIC:                            -626.7
# Df Residuals:                     115   BIC:                            -612.7
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -6.659e-06      0.001     -0.005      0.996      -0.002       0.002
# mktrf          1.0877      0.051     21.413      0.000       0.988       1.187
# smb            0.1706      0.056      3.073      0.002       0.062       0.279
# hml           -0.0510      0.039     -1.323      0.186      -0.127       0.025
# umd            0.2480      0.038      6.553      0.000       0.174       0.322
# ==============================================================================
# Omnibus:                        7.222   Durbin-Watson:                   1.813
# Prob(Omnibus):                  0.027   Jarque-Bera (JB):               12.697
# Skew:                          -0.116   Prob(JB):                      0.00175
# Kurtosis:                       4.577   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Post-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.956
# Model:                            OLS   Adj. R-squared:                  0.954
# Method:                 Least Squares   F-statistic:                     588.6
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           8.42e-73
# Time:                        17:53:38   Log-Likelihood:                 385.15
# No. Observations:                 114   AIC:                            -760.3
# Df Residuals:                     109   BIC:                            -746.6
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0015      0.001      1.750      0.083      -0.000       0.003
# mktrf          0.9524      0.025     38.393      0.000       0.903       1.002
# me             0.2839      0.038      7.412      0.000       0.208       0.360
# ia            -0.1329      0.053     -2.502      0.014      -0.238      -0.028
# roe            0.0206      0.047      0.440      0.661      -0.072       0.113
# ==============================================================================
# Omnibus:                        0.175   Durbin-Watson:                   1.817
# Prob(Omnibus):                  0.916   Jarque-Bera (JB):                0.024
# Skew:                          -0.029   Prob(JB):                        0.988
# Kurtosis:                       3.039   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.956
# Model:                            OLS   Adj. R-squared:                  0.954
# Method:                 Least Squares   F-statistic:                     868.9
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           1.13e-81
# Time:                        17:53:38   Log-Likelihood:                 385.15
# No. Observations:                 114   AIC:                            -760.3
# Df Residuals:                     109   BIC:                            -746.6
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0015      0.001      1.588      0.112      -0.000       0.003
# mktrf          0.9524      0.021     44.935      0.000       0.911       0.994
# me             0.2839      0.051      5.595      0.000       0.184       0.383
# ia            -0.1329      0.047     -2.820      0.005      -0.225      -0.041
# roe            0.0206      0.041      0.507      0.612      -0.059       0.100
# ==============================================================================
# Omnibus:                        0.175   Durbin-Watson:                   1.817
# Prob(Omnibus):                  0.916   Jarque-Bera (JB):                0.024
# Skew:                          -0.029   Prob(JB):                        0.988
# Kurtosis:                       3.039   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.956
# Model:                            OLS   Adj. R-squared:                  0.954
# Method:                 Least Squares   F-statistic:                     820.7
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           2.31e-80
# Time:                        17:53:38   Log-Likelihood:                 385.15
# No. Observations:                 114   AIC:                            -760.3
# Df Residuals:                     109   BIC:                            -746.6
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0015      0.001      1.394      0.163      -0.001       0.004
# mktrf          0.9524      0.022     43.903      0.000       0.910       0.995
# me             0.2839      0.051      5.548      0.000       0.184       0.384
# ia            -0.1329      0.040     -3.357      0.001      -0.211      -0.055
# roe            0.0206      0.037      0.562      0.574      -0.051       0.092
# ==============================================================================
# Omnibus:                        0.175   Durbin-Watson:                   1.817
# Prob(Omnibus):                  0.916   Jarque-Bera (JB):                0.024
# Skew:                          -0.029   Prob(JB):                        0.988
# Kurtosis:                       3.039   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.958
# Model:                            OLS   Adj. R-squared:                  0.956
# Method:                 Least Squares   F-statistic:                     622.2
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           4.69e-74
# Time:                        17:53:38   Log-Likelihood:                 388.17
# No. Observations:                 114   AIC:                            -766.3
# Df Residuals:                     109   BIC:                            -752.7
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0003      0.001      0.365      0.716      -0.001       0.002
# mktrf          0.9674      0.023     42.256      0.000       0.922       1.013
# smb            0.2842      0.036      7.961      0.000       0.213       0.355
# hml           -0.0825      0.037     -2.244      0.027      -0.155      -0.010
# umd            0.0326      0.028      1.176      0.242      -0.022       0.088
# ==============================================================================
# Omnibus:                        0.301   Durbin-Watson:                   1.910
# Prob(Omnibus):                  0.860   Jarque-Bera (JB):                0.143
# Skew:                           0.085   Prob(JB):                        0.931
# Kurtosis:                       3.034   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.958
# Model:                            OLS   Adj. R-squared:                  0.956
# Method:                 Least Squares   F-statistic:                     780.0
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           3.35e-79
# Time:                        17:53:38   Log-Likelihood:                 388.17
# No. Observations:                 114   AIC:                            -766.3
# Df Residuals:                     109   BIC:                            -752.7
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0003      0.001      0.339      0.735      -0.001       0.002
# mktrf          0.9674      0.026     37.062      0.000       0.916       1.019
# smb            0.2842      0.042      6.819      0.000       0.203       0.366
# hml           -0.0825      0.042     -1.943      0.052      -0.166       0.001
# umd            0.0326      0.026      1.267      0.205      -0.018       0.083
# ==============================================================================
# Omnibus:                        0.301   Durbin-Watson:                   1.910
# Prob(Omnibus):                  0.860   Jarque-Bera (JB):                0.143
# Skew:                           0.085   Prob(JB):                        0.931
# Kurtosis:                       3.034   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.958
# Model:                            OLS   Adj. R-squared:                  0.956
# Method:                 Least Squares   F-statistic:                     886.2
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           4.00e-82
# Time:                        17:53:38   Log-Likelihood:                 388.17
# No. Observations:                 114   AIC:                            -766.3
# Df Residuals:                     109   BIC:                            -752.7
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0003      0.001      0.306      0.759      -0.002       0.002
# mktrf          0.9674      0.026     37.404      0.000       0.917       1.018
# smb            0.2842      0.038      7.443      0.000       0.209       0.359
# hml           -0.0825      0.036     -2.262      0.024      -0.154      -0.011
# umd            0.0326      0.024      1.345      0.179      -0.015       0.080
# ==============================================================================
# Omnibus:                        0.301   Durbin-Watson:                   1.910
# Prob(Omnibus):                  0.860   Jarque-Bera (JB):                0.143
# Skew:                           0.085   Prob(JB):                        0.931
# Kurtosis:                       3.034   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.958
# Model:                            OLS   Adj. R-squared:                  0.956
# Method:                 Least Squares   F-statistic:                     622.2
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           4.69e-74
# Time:                        17:53:38   Log-Likelihood:                 388.17
# No. Observations:                 114   AIC:                            -766.3
# Df Residuals:                     109   BIC:                            -752.7
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0003      0.001      0.365      0.716      -0.001       0.002
# mktrf          0.9674      0.023     42.256      0.000       0.922       1.013
# smb            0.2842      0.036      7.961      0.000       0.213       0.355
# hml           -0.0825      0.037     -2.244      0.027      -0.155      -0.010
# umd            0.0326      0.028      1.176      0.242      -0.022       0.088
# ==============================================================================
# Omnibus:                        0.301   Durbin-Watson:                   1.910
# Prob(Omnibus):                  0.860   Jarque-Bera (JB):                0.143
# Skew:                           0.085   Prob(JB):                        0.931
# Kurtosis:                       3.034   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.958
# Model:                            OLS   Adj. R-squared:                  0.956
# Method:                 Least Squares   F-statistic:                     780.0
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           3.35e-79
# Time:                        17:53:38   Log-Likelihood:                 388.17
# No. Observations:                 114   AIC:                            -766.3
# Df Residuals:                     109   BIC:                            -752.7
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0003      0.001      0.339      0.735      -0.001       0.002
# mktrf          0.9674      0.026     37.062      0.000       0.916       1.019
# smb            0.2842      0.042      6.819      0.000       0.203       0.366
# hml           -0.0825      0.042     -1.943      0.052      -0.166       0.001
# umd            0.0326      0.026      1.267      0.205      -0.018       0.083
# ==============================================================================
# Omnibus:                        0.301   Durbin-Watson:                   1.910
# Prob(Omnibus):                  0.860   Jarque-Bera (JB):                0.143
# Skew:                           0.085   Prob(JB):                        0.931
# Kurtosis:                       3.034   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.958
# Model:                            OLS   Adj. R-squared:                  0.956
# Method:                 Least Squares   F-statistic:                     886.2
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           4.00e-82
# Time:                        17:53:38   Log-Likelihood:                 388.17
# No. Observations:                 114   AIC:                            -766.3
# Df Residuals:                     109   BIC:                            -752.7
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0003      0.001      0.306      0.759      -0.002       0.002
# mktrf          0.9674      0.026     37.404      0.000       0.917       1.018
# smb            0.2842      0.038      7.443      0.000       0.209       0.359
# hml           -0.0825      0.036     -2.262      0.024      -0.154      -0.011
# umd            0.0326      0.024      1.345      0.179      -0.015       0.080
# ==============================================================================
# Omnibus:                        0.301   Durbin-Watson:                   1.910
# Prob(Omnibus):                  0.860   Jarque-Bera (JB):                0.143
# Skew:                           0.085   Prob(JB):                        0.931
# Kurtosis:                       3.034   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """
