# %% [markdown]
# # Method 2 - Best Ideas Low Focus

# %%
# %matplotlib inline
import pandas as pd
import warnings
from statsmodels import api as sm

from eptooling import crsp, epd, fs, hfu, crsp, db, bi
from eptooling.bm import bmdb, iso
from epquant.engine import weights, portfolio
from epquant.gen import returns
from epquant.perf import relative_performance

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Fetch Holdings and Benchmark Data

# %%
# Get HFU Data

# %store -r inst_data
inst_data = inst_data[inst_data['datadate'] >= '1999-06-30']

# Focus

focus = inst_data.groupby(['datadate', 'institution_id'])['fsym_id'].count().rename('focus').reset_index()

# Count number of positions per manager

inst_data['num_pos'] = inst_data.groupby(['datadate', 'institution_id'])[
    'fsym_id'].transform(lambda s: s.nunique())

# Remove less than 20 holdings and less than $5mm per CSP

valid_data = inst_data[inst_data['num_pos'] >= 20]
valid_data = valid_data[valid_data['public_aum'] >= 5e6]

# Get Benchmark Weights

bm = crsp.get_crsp_market_portfolio()

# Merge Benchmark Weights onto Holdings

valid_data = valid_data.merge(bm, how='left', on=['datadate', 'fsym_id'])

# Grab Idiosyncratic Volatility

capm_var = crsp.get_capm_variance()

# Merge Idiosyncratic Volatility

valid_data = valid_data.merge(capm_var, how='left')

# Calculate Variance-Adjusted Market Tilt

valid_data['adj_target'] = (valid_data['target'] - valid_data['weight'].fillna(0)) * valid_data['capm_var']

# %% [markdown]
# ## Calculate Best Ideas

# %%
# Extract Best Ideas

valid_data['pos_rank'] = valid_data\
    .groupby(['datadate', 'institution_id'])['adj_target'].rank(ascending=False)

best_ideas = valid_data[valid_data['pos_rank'] == 1].copy()

# Add Focus

best_ideas = best_ideas.merge(focus)
best_ideas['focus_pct'] = best_ideas.groupby('datadate')['focus'].rank(pct=True)
best_ideas = best_ideas[best_ideas['focus_pct'] < (1 / 3)]

# Weight the best ideas equally

best_ideas['target'] = 1 / best_ideas.groupby('datadate')['institution_id'].transform('count')

# %% [markdown]
# ## Backtest Portfolio

# %%
w = weights.Weights(best_ideas)

# %store -r r

p = portfolio.DailyPortfolio(w, r, end_date='2018-12-31')

rf = bi.get_risk_free_rate()
monthly_return = p.port_return.loc['1999-07-01':].resample('M').apply(epd.prod_red)
monthly_return = (monthly_return - rf).dropna()
monthly_return.name = 'port_return'

# %% [markdown]
# ## Plot Performance

# %%
epd.nav(monthly_return).plot()

# %%
monthly_return.resample('A').apply(epd.prod_red)
# Out:
# datadate
# 1999-12-31    0.124711
# 2000-12-31   -0.067610
# 2001-12-31   -0.010060
# 2002-12-31   -0.231585
# 2003-12-31    0.409914
# 2004-12-31    0.268798
# 2005-12-31    0.179592
# 2006-12-31    0.167695
# 2007-12-31    0.038639
# 2008-12-31   -0.413592
# 2009-12-31    0.391806
# 2010-12-31    0.184624
# 2011-12-31    0.010914
# 2012-12-31    0.204833
# 2013-12-31    0.494687
# 2014-12-31    0.087818
# 2015-12-31   -0.043692
# 2016-12-31    0.095877
# 2017-12-31    0.240603
# 2018-12-31   -0.027789
# Freq: A-DEC, Name: port_return, dtype: float64

# %% [markdown]
# ## Fetch Factor Models

# %%
# Get Factor Models
q_factor_model = bi.get_q_factor_model()
fama_french_five_factor_model = bi.get_fama_french_five_factor_model()
four_factor_model = bi.get_four_factor_model()

# Concat Portfolio Return
q_factor = pd.concat([monthly_return, q_factor_model], axis=1)
fama_french_five = pd.concat([monthly_return, fama_french_five_factor_model], axis=1)
four_factor = pd.concat([monthly_return, four_factor_model], axis=1)

# Add Constants
q_factor.insert(1, 'const', 1)
fama_french_five.insert(1, 'const', 1)
four_factor.insert(1, 'const', 1)

# Split Period into Pre and Post Crisis
q_factor_pre, q_factor_post = q_factor.loc[:'2009-06-30'], q_factor.loc['2009-07-31':]
fama_french_five_pre, fama_french_five_post = fama_french_five.loc[:'2009-06-30'], fama_french_five.loc['2009-07-31':] 
four_factor_pre, four_factor_post = four_factor.loc[:'2009-06-30'], four_factor.loc['2009-07-31':]

# %% [markdown]
# ## Full Time Period Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.916
# Model:                            OLS   Adj. R-squared:                  0.914
# Method:                 Least Squares   F-statistic:                     621.1
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):          1.22e-121
# Time:                        18:50:32   Log-Likelihood:                 676.26
# No. Observations:                 234   AIC:                            -1343.
# Df Residuals:                     229   BIC:                            -1325.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0028      0.001      2.978      0.003       0.001       0.005
# mktrf          0.9608      0.025     37.898      0.000       0.911       1.011
# me             0.2906      0.029      9.855      0.000       0.233       0.349
# ia            -0.0341      0.045     -0.762      0.447      -0.122       0.054
# roe            0.0751      0.038      1.957      0.052      -0.001       0.151
# ==============================================================================
# Omnibus:                       16.452   Durbin-Watson:                   1.668
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               40.041
# Skew:                          -0.245   Prob(JB):                     2.02e-09
# Kurtosis:                       4.967   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.916
# Model:                            OLS   Adj. R-squared:                  0.914
# Method:                 Least Squares   F-statistic:                     564.2
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):          2.78e-117
# Time:                        18:50:32   Log-Likelihood:                 676.26
# No. Observations:                 234   AIC:                            -1343.
# Df Residuals:                     229   BIC:                            -1325.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0028      0.001      2.723      0.006       0.001       0.005
# mktrf          0.9608      0.027     35.899      0.000       0.908       1.013
# me             0.2906      0.035      8.272      0.000       0.222       0.359
# ia            -0.0341      0.076     -0.447      0.655      -0.184       0.116
# roe            0.0751      0.042      1.792      0.073      -0.007       0.157
# ==============================================================================
# Omnibus:                       16.452   Durbin-Watson:                   1.668
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               40.041
# Skew:                          -0.245   Prob(JB):                     2.02e-09
# Kurtosis:                       4.967   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.916
# Model:                            OLS   Adj. R-squared:                  0.914
# Method:                 Least Squares   F-statistic:                     730.5
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):          4.55e-129
# Time:                        18:50:32   Log-Likelihood:                 676.26
# No. Observations:                 234   AIC:                            -1343.
# Df Residuals:                     229   BIC:                            -1325.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0028      0.001      2.600      0.009       0.001       0.005
# mktrf          0.9608      0.023     41.780      0.000       0.916       1.006
# me             0.2906      0.034      8.593      0.000       0.224       0.357
# ia            -0.0341      0.085     -0.403      0.687      -0.200       0.132
# roe            0.0751      0.039      1.901      0.057      -0.002       0.152
# ==============================================================================
# Omnibus:                       16.452   Durbin-Watson:                   1.668
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               40.041
# Skew:                          -0.245   Prob(JB):                     2.02e-09
# Kurtosis:                       4.967   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.906
# Model:                            OLS   Adj. R-squared:                  0.904
# Method:                 Least Squares   F-statistic:                     552.2
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):          2.56e-116
# Time:                        18:50:32   Log-Likelihood:                 663.73
# No. Observations:                 234   AIC:                            -1317.
# Df Residuals:                     229   BIC:                            -1300.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0027      0.001      2.849      0.005       0.001       0.005
# mktrf          0.9772      0.025     39.681      0.000       0.929       1.026
# smb            0.2410      0.031      7.838      0.000       0.180       0.302
# hml            0.0845      0.031      2.767      0.006       0.024       0.145
# umd            0.0640      0.020      3.194      0.002       0.025       0.103
# ==============================================================================
# Omnibus:                       22.046   Durbin-Watson:                   1.642
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               55.938
# Skew:                          -0.382   Prob(JB):                     7.13e-13
# Kurtosis:                       5.270   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.906
# Model:                            OLS   Adj. R-squared:                  0.904
# Method:                 Least Squares   F-statistic:                     686.6
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):          3.21e-126
# Time:                        18:50:32   Log-Likelihood:                 663.73
# No. Observations:                 234   AIC:                            -1317.
# Df Residuals:                     229   BIC:                            -1300.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0027      0.001      2.374      0.018       0.000       0.005
# mktrf          0.9772      0.031     31.641      0.000       0.917       1.038
# smb            0.2410      0.033      7.211      0.000       0.175       0.306
# hml            0.0845      0.060      1.417      0.156      -0.032       0.201
# umd            0.0640      0.027      2.399      0.016       0.012       0.116
# ==============================================================================
# Omnibus:                       22.046   Durbin-Watson:                   1.642
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               55.938
# Skew:                          -0.382   Prob(JB):                     7.13e-13
# Kurtosis:                       5.270   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.906
# Model:                            OLS   Adj. R-squared:                  0.904
# Method:                 Least Squares   F-statistic:                     983.1
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):          6.87e-143
# Time:                        18:50:32   Log-Likelihood:                 663.73
# No. Observations:                 234   AIC:                            -1317.
# Df Residuals:                     229   BIC:                            -1300.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0027      0.001      2.328      0.020       0.000       0.005
# mktrf          0.9772      0.029     33.431      0.000       0.920       1.035
# smb            0.2410      0.032      7.527      0.000       0.178       0.304
# hml            0.0845      0.065      1.302      0.193      -0.043       0.212
# umd            0.0640      0.025      2.608      0.009       0.016       0.112
# ==============================================================================
# Omnibus:                       22.046   Durbin-Watson:                   1.642
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               55.938
# Skew:                          -0.382   Prob(JB):                     7.13e-13
# Kurtosis:                       5.270   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.906
# Model:                            OLS   Adj. R-squared:                  0.904
# Method:                 Least Squares   F-statistic:                     552.2
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):          2.56e-116
# Time:                        18:50:32   Log-Likelihood:                 663.73
# No. Observations:                 234   AIC:                            -1317.
# Df Residuals:                     229   BIC:                            -1300.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0027      0.001      2.849      0.005       0.001       0.005
# mktrf          0.9772      0.025     39.681      0.000       0.929       1.026
# smb            0.2410      0.031      7.838      0.000       0.180       0.302
# hml            0.0845      0.031      2.767      0.006       0.024       0.145
# umd            0.0640      0.020      3.194      0.002       0.025       0.103
# ==============================================================================
# Omnibus:                       22.046   Durbin-Watson:                   1.642
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               55.938
# Skew:                          -0.382   Prob(JB):                     7.13e-13
# Kurtosis:                       5.270   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.906
# Model:                            OLS   Adj. R-squared:                  0.904
# Method:                 Least Squares   F-statistic:                     686.6
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):          3.21e-126
# Time:                        18:50:32   Log-Likelihood:                 663.73
# No. Observations:                 234   AIC:                            -1317.
# Df Residuals:                     229   BIC:                            -1300.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0027      0.001      2.374      0.018       0.000       0.005
# mktrf          0.9772      0.031     31.641      0.000       0.917       1.038
# smb            0.2410      0.033      7.211      0.000       0.175       0.306
# hml            0.0845      0.060      1.417      0.156      -0.032       0.201
# umd            0.0640      0.027      2.399      0.016       0.012       0.116
# ==============================================================================
# Omnibus:                       22.046   Durbin-Watson:                   1.642
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               55.938
# Skew:                          -0.382   Prob(JB):                     7.13e-13
# Kurtosis:                       5.270   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.906
# Model:                            OLS   Adj. R-squared:                  0.904
# Method:                 Least Squares   F-statistic:                     983.1
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):          6.87e-143
# Time:                        18:50:32   Log-Likelihood:                 663.73
# No. Observations:                 234   AIC:                            -1317.
# Df Residuals:                     229   BIC:                            -1300.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0027      0.001      2.328      0.020       0.000       0.005
# mktrf          0.9772      0.029     33.431      0.000       0.920       1.035
# smb            0.2410      0.032      7.527      0.000       0.178       0.304
# hml            0.0845      0.065      1.302      0.193      -0.043       0.212
# umd            0.0640      0.025      2.608      0.009       0.016       0.112
# ==============================================================================
# Omnibus:                       22.046   Durbin-Watson:                   1.642
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               55.938
# Skew:                          -0.382   Prob(JB):                     7.13e-13
# Kurtosis:                       5.270   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Pre-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.899
# Model:                            OLS   Adj. R-squared:                  0.895
# Method:                 Least Squares   F-statistic:                     255.8
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           3.00e-56
# Time:                        18:50:32   Log-Likelihood:                 323.90
# No. Observations:                 120   AIC:                            -637.8
# Df Residuals:                     115   BIC:                            -623.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0027      0.002      1.690      0.094      -0.000       0.006
# mktrf          0.9936      0.043     23.185      0.000       0.909       1.078
# me             0.3016      0.042      7.126      0.000       0.218       0.385
# ia            -0.0165      0.066     -0.249      0.804      -0.148       0.115
# roe            0.1478      0.059      2.520      0.013       0.032       0.264
# ==============================================================================
# Omnibus:                        6.414   Durbin-Watson:                   1.691
# Prob(Omnibus):                  0.040   Jarque-Bera (JB):                8.731
# Skew:                          -0.236   Prob(JB):                       0.0127
# Kurtosis:                       4.234   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.899
# Model:                            OLS   Adj. R-squared:                  0.895
# Method:                 Least Squares   F-statistic:                     324.5
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           1.22e-61
# Time:                        18:50:32   Log-Likelihood:                 323.90
# No. Observations:                 120   AIC:                            -637.8
# Df Residuals:                     115   BIC:                            -623.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0027      0.002      1.624      0.104      -0.001       0.006
# mktrf          0.9936      0.048     20.795      0.000       0.900       1.087
# me             0.3016      0.042      7.262      0.000       0.220       0.383
# ia            -0.0165      0.089     -0.186      0.853      -0.191       0.158
# roe            0.1478      0.059      2.491      0.013       0.032       0.264
# ==============================================================================
# Omnibus:                        6.414   Durbin-Watson:                   1.691
# Prob(Omnibus):                  0.040   Jarque-Bera (JB):                8.731
# Skew:                          -0.236   Prob(JB):                       0.0127
# Kurtosis:                       4.234   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.899
# Model:                            OLS   Adj. R-squared:                  0.895
# Method:                 Least Squares   F-statistic:                     503.5
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           7.30e-72
# Time:                        18:50:32   Log-Likelihood:                 323.90
# No. Observations:                 120   AIC:                            -637.8
# Df Residuals:                     115   BIC:                            -623.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0027      0.002      1.616      0.106      -0.001       0.006
# mktrf          0.9936      0.038     26.295      0.000       0.920       1.068
# me             0.3016      0.039      7.798      0.000       0.226       0.377
# ia            -0.0165      0.096     -0.172      0.864      -0.205       0.172
# roe            0.1478      0.047      3.125      0.002       0.055       0.241
# ==============================================================================
# Omnibus:                        6.414   Durbin-Watson:                   1.691
# Prob(Omnibus):                  0.040   Jarque-Bera (JB):                8.731
# Skew:                          -0.236   Prob(JB):                       0.0127
# Kurtosis:                       4.234   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.882
# Model:                            OLS   Adj. R-squared:                  0.878
# Method:                 Least Squares   F-statistic:                     215.0
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           2.18e-52
# Time:                        18:50:32   Log-Likelihood:                 314.60
# No. Observations:                 120   AIC:                            -619.2
# Df Residuals:                     115   BIC:                            -605.3
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0039      0.002      2.345      0.021       0.001       0.007
# mktrf          0.9940      0.041     24.367      0.000       0.913       1.075
# smb            0.2280      0.046      4.910      0.000       0.136       0.320
# hml            0.1148      0.047      2.468      0.015       0.023       0.207
# umd            0.0730      0.029      2.546      0.012       0.016       0.130
# ==============================================================================
# Omnibus:                        9.617   Durbin-Watson:                   1.734
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):               11.865
# Skew:                          -0.467   Prob(JB):                      0.00265
# Kurtosis:                       4.226   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.882
# Model:                            OLS   Adj. R-squared:                  0.878
# Method:                 Least Squares   F-statistic:                     321.9
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           1.88e-61
# Time:                        18:50:32   Log-Likelihood:                 314.60
# No. Observations:                 120   AIC:                            -619.2
# Df Residuals:                     115   BIC:                            -605.3
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0039      0.002      2.103      0.035       0.000       0.008
# mktrf          0.9940      0.051     19.559      0.000       0.894       1.094
# smb            0.2280      0.044      5.227      0.000       0.143       0.314
# hml            0.1148      0.078      1.479      0.139      -0.037       0.267
# umd            0.0730      0.033      2.198      0.028       0.008       0.138
# ==============================================================================
# Omnibus:                        9.617   Durbin-Watson:                   1.734
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):               11.865
# Skew:                          -0.467   Prob(JB):                      0.00265
# Kurtosis:                       4.226   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.882
# Model:                            OLS   Adj. R-squared:                  0.878
# Method:                 Least Squares   F-statistic:                     423.5
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           8.49e-68
# Time:                        18:50:33   Log-Likelihood:                 314.60
# No. Observations:                 120   AIC:                            -619.2
# Df Residuals:                     115   BIC:                            -605.3
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0039      0.002      2.187      0.029       0.000       0.007
# mktrf          0.9940      0.045     21.938      0.000       0.905       1.083
# smb            0.2280      0.040      5.658      0.000       0.149       0.307
# hml            0.1148      0.082      1.404      0.160      -0.046       0.275
# umd            0.0730      0.029      2.525      0.012       0.016       0.130
# ==============================================================================
# Omnibus:                        9.617   Durbin-Watson:                   1.734
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):               11.865
# Skew:                          -0.467   Prob(JB):                      0.00265
# Kurtosis:                       4.226   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.882
# Model:                            OLS   Adj. R-squared:                  0.878
# Method:                 Least Squares   F-statistic:                     215.0
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           2.18e-52
# Time:                        18:50:33   Log-Likelihood:                 314.60
# No. Observations:                 120   AIC:                            -619.2
# Df Residuals:                     115   BIC:                            -605.3
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0039      0.002      2.345      0.021       0.001       0.007
# mktrf          0.9940      0.041     24.367      0.000       0.913       1.075
# smb            0.2280      0.046      4.910      0.000       0.136       0.320
# hml            0.1148      0.047      2.468      0.015       0.023       0.207
# umd            0.0730      0.029      2.546      0.012       0.016       0.130
# ==============================================================================
# Omnibus:                        9.617   Durbin-Watson:                   1.734
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):               11.865
# Skew:                          -0.467   Prob(JB):                      0.00265
# Kurtosis:                       4.226   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.882
# Model:                            OLS   Adj. R-squared:                  0.878
# Method:                 Least Squares   F-statistic:                     321.9
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           1.88e-61
# Time:                        18:50:33   Log-Likelihood:                 314.60
# No. Observations:                 120   AIC:                            -619.2
# Df Residuals:                     115   BIC:                            -605.3
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0039      0.002      2.103      0.035       0.000       0.008
# mktrf          0.9940      0.051     19.559      0.000       0.894       1.094
# smb            0.2280      0.044      5.227      0.000       0.143       0.314
# hml            0.1148      0.078      1.479      0.139      -0.037       0.267
# umd            0.0730      0.033      2.198      0.028       0.008       0.138
# ==============================================================================
# Omnibus:                        9.617   Durbin-Watson:                   1.734
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):               11.865
# Skew:                          -0.467   Prob(JB):                      0.00265
# Kurtosis:                       4.226   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.882
# Model:                            OLS   Adj. R-squared:                  0.878
# Method:                 Least Squares   F-statistic:                     423.5
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           8.49e-68
# Time:                        18:50:33   Log-Likelihood:                 314.60
# No. Observations:                 120   AIC:                            -619.2
# Df Residuals:                     115   BIC:                            -605.3
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0039      0.002      2.187      0.029       0.000       0.007
# mktrf          0.9940      0.045     21.938      0.000       0.905       1.083
# smb            0.2280      0.040      5.658      0.000       0.149       0.307
# hml            0.1148      0.082      1.404      0.160      -0.046       0.275
# umd            0.0730      0.029      2.525      0.012       0.016       0.130
# ==============================================================================
# Omnibus:                        9.617   Durbin-Watson:                   1.734
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):               11.865
# Skew:                          -0.467   Prob(JB):                      0.00265
# Kurtosis:                       4.226   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Post-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.955
# Method:                 Least Squares   F-statistic:                     607.5
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           1.63e-73
# Time:                        18:50:33   Log-Likelihood:                 384.65
# No. Observations:                 114   AIC:                            -759.3
# Df Residuals:                     109   BIC:                            -745.6
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0031      0.001      3.622      0.000       0.001       0.005
# mktrf          0.9455      0.025     37.948      0.000       0.896       0.995
# me             0.2548      0.038      6.625      0.000       0.179       0.331
# ia            -0.1665      0.053     -3.121      0.002      -0.272      -0.061
# roe           -0.1559      0.047     -3.326      0.001      -0.249      -0.063
# ==============================================================================
# Omnibus:                        0.246   Durbin-Watson:                   1.601
# Prob(Omnibus):                  0.884   Jarque-Bera (JB):                0.108
# Skew:                          -0.075   Prob(JB):                        0.947
# Kurtosis:                       3.023   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.955
# Method:                 Least Squares   F-statistic:                     888.1
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           3.56e-82
# Time:                        18:50:33   Log-Likelihood:                 384.65
# No. Observations:                 114   AIC:                            -759.3
# Df Residuals:                     109   BIC:                            -745.6
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0031      0.001      2.669      0.008       0.001       0.005
# mktrf          0.9455      0.020     48.189      0.000       0.907       0.984
# me             0.2548      0.023     11.074      0.000       0.210       0.300
# ia            -0.1665      0.077     -2.153      0.031      -0.318      -0.015
# roe           -0.1559      0.041     -3.766      0.000      -0.237      -0.075
# ==============================================================================
# Omnibus:                        0.246   Durbin-Watson:                   1.601
# Prob(Omnibus):                  0.884   Jarque-Bera (JB):                0.108
# Skew:                          -0.075   Prob(JB):                        0.947
# Kurtosis:                       3.023   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.955
# Method:                 Least Squares   F-statistic:                     1175.
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           1.25e-88
# Time:                        18:50:33   Log-Likelihood:                 384.65
# No. Observations:                 114   AIC:                            -759.3
# Df Residuals:                     109   BIC:                            -745.6
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0031      0.001      2.295      0.022       0.000       0.006
# mktrf          0.9455      0.019     48.740      0.000       0.907       0.984
# me             0.2548      0.021     11.926      0.000       0.213       0.297
# ia            -0.1665      0.087     -1.904      0.057      -0.338       0.005
# roe           -0.1559      0.039     -4.009      0.000      -0.232      -0.080
# ==============================================================================
# Omnibus:                        0.246   Durbin-Watson:                   1.601
# Prob(Omnibus):                  0.884   Jarque-Bera (JB):                0.108
# Skew:                          -0.075   Prob(JB):                        0.947
# Kurtosis:                       3.023   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.954
# Model:                            OLS   Adj. R-squared:                  0.953
# Method:                 Least Squares   F-statistic:                     570.8
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           4.17e-72
# Time:                        18:50:33   Log-Likelihood:                 381.26
# No. Observations:                 114   AIC:                            -752.5
# Df Residuals:                     109   BIC:                            -738.8
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0014      0.001      1.596      0.113      -0.000       0.003
# mktrf          0.9767      0.024     40.152      0.000       0.928       1.025
# smb            0.2966      0.038      7.819      0.000       0.221       0.372
# hml           -0.0501      0.039     -1.282      0.203      -0.128       0.027
# umd            0.0160      0.029      0.541      0.589      -0.042       0.074
# ==============================================================================
# Omnibus:                        2.631   Durbin-Watson:                   1.412
# Prob(Omnibus):                  0.268   Jarque-Bera (JB):                2.391
# Skew:                          -0.355   Prob(JB):                        0.303
# Kurtosis:                       2.995   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.954
# Model:                            OLS   Adj. R-squared:                  0.953
# Method:                 Least Squares   F-statistic:                     571.9
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           3.77e-72
# Time:                        18:50:33   Log-Likelihood:                 381.26
# No. Observations:                 114   AIC:                            -752.5
# Df Residuals:                     109   BIC:                            -738.8
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0014      0.001      1.223      0.221      -0.001       0.004
# mktrf          0.9767      0.021     45.684      0.000       0.935       1.019
# smb            0.2966      0.030     10.001      0.000       0.238       0.355
# hml           -0.0501      0.042     -1.195      0.232      -0.132       0.032
# umd            0.0160      0.028      0.574      0.566      -0.039       0.070
# ==============================================================================
# Omnibus:                        2.631   Durbin-Watson:                   1.412
# Prob(Omnibus):                  0.268   Jarque-Bera (JB):                2.391
# Skew:                          -0.355   Prob(JB):                        0.303
# Kurtosis:                       2.995   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.954
# Model:                            OLS   Adj. R-squared:                  0.953
# Method:                 Least Squares   F-statistic:                     579.0
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           1.98e-72
# Time:                        18:50:33   Log-Likelihood:                 381.26
# No. Observations:                 114   AIC:                            -752.5
# Df Residuals:                     109   BIC:                            -738.8
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0014      0.001      1.066      0.286      -0.001       0.004
# mktrf          0.9767      0.023     42.122      0.000       0.931       1.022
# smb            0.2966      0.025     11.694      0.000       0.247       0.346
# hml           -0.0501      0.043     -1.178      0.239      -0.133       0.033
# umd            0.0160      0.031      0.509      0.610      -0.045       0.077
# ==============================================================================
# Omnibus:                        2.631   Durbin-Watson:                   1.412
# Prob(Omnibus):                  0.268   Jarque-Bera (JB):                2.391
# Skew:                          -0.355   Prob(JB):                        0.303
# Kurtosis:                       2.995   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.954
# Model:                            OLS   Adj. R-squared:                  0.953
# Method:                 Least Squares   F-statistic:                     570.8
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           4.17e-72
# Time:                        18:50:33   Log-Likelihood:                 381.26
# No. Observations:                 114   AIC:                            -752.5
# Df Residuals:                     109   BIC:                            -738.8
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0014      0.001      1.596      0.113      -0.000       0.003
# mktrf          0.9767      0.024     40.152      0.000       0.928       1.025
# smb            0.2966      0.038      7.819      0.000       0.221       0.372
# hml           -0.0501      0.039     -1.282      0.203      -0.128       0.027
# umd            0.0160      0.029      0.541      0.589      -0.042       0.074
# ==============================================================================
# Omnibus:                        2.631   Durbin-Watson:                   1.412
# Prob(Omnibus):                  0.268   Jarque-Bera (JB):                2.391
# Skew:                          -0.355   Prob(JB):                        0.303
# Kurtosis:                       2.995   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.954
# Model:                            OLS   Adj. R-squared:                  0.953
# Method:                 Least Squares   F-statistic:                     571.9
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           3.77e-72
# Time:                        18:50:33   Log-Likelihood:                 381.26
# No. Observations:                 114   AIC:                            -752.5
# Df Residuals:                     109   BIC:                            -738.8
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0014      0.001      1.223      0.221      -0.001       0.004
# mktrf          0.9767      0.021     45.684      0.000       0.935       1.019
# smb            0.2966      0.030     10.001      0.000       0.238       0.355
# hml           -0.0501      0.042     -1.195      0.232      -0.132       0.032
# umd            0.0160      0.028      0.574      0.566      -0.039       0.070
# ==============================================================================
# Omnibus:                        2.631   Durbin-Watson:                   1.412
# Prob(Omnibus):                  0.268   Jarque-Bera (JB):                2.391
# Skew:                          -0.355   Prob(JB):                        0.303
# Kurtosis:                       2.995   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.954
# Model:                            OLS   Adj. R-squared:                  0.953
# Method:                 Least Squares   F-statistic:                     579.0
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           1.98e-72
# Time:                        18:50:33   Log-Likelihood:                 381.26
# No. Observations:                 114   AIC:                            -752.5
# Df Residuals:                     109   BIC:                            -738.8
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0014      0.001      1.066      0.286      -0.001       0.004
# mktrf          0.9767      0.023     42.122      0.000       0.931       1.022
# smb            0.2966      0.025     11.694      0.000       0.247       0.346
# hml           -0.0501      0.043     -1.178      0.239      -0.133       0.033
# umd            0.0160      0.031      0.509      0.610      -0.045       0.077
# ==============================================================================
# Omnibus:                        2.631   Durbin-Watson:                   1.412
# Prob(Omnibus):                  0.268   Jarque-Bera (JB):                2.391
# Skew:                          -0.355   Prob(JB):                        0.303
# Kurtosis:                       2.995   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """
