# %% [markdown]
# # Method 1 - Best Minus Rest Top 5

# %%
# %matplotlib inline
import pandas as pd
import warnings
from statsmodels import api as sm

from eptooling import crsp, epd, fs, hfu, crsp, db, bi
from eptooling.bm import bmdb, iso
from epquant.engine import weights, portfolio
from epquant.gen import returns
from epquant.perf import relative_performance

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Fetch Holdings and Benchmark Data

# %%
# Get HFU Data

# %store -r inst_data
inst_data = inst_data[inst_data['datadate'] >= '1999-06-30']

# Count number of positions per manager

inst_data['num_pos'] = inst_data.groupby(['datadate', 'institution_id'])[
    'fsym_id'].transform(lambda s: s.nunique())

# Remove less than 20 holdings and less than $5mm per CSP

valid_data = inst_data[inst_data['num_pos'] >= 20]
valid_data = valid_data[valid_data['public_aum'] >= 5e6]

# Get Benchmark Weights

bm = crsp.get_crsp_market_portfolio()

# Merge Benchmark Weights onto Holdings

valid_data = valid_data.merge(bm, how='left', on=['datadate', 'fsym_id'])

# Calculate Market Tilt

valid_data['adj_target'] = valid_data['target'] - valid_data['weight'].fillna(0)

# %% [markdown]
# ## Calculate Best Ideas

# %%
# Extract Best Ideas

valid_data['pos_rank'] = valid_data\
    .groupby(['datadate', 'institution_id'])['adj_target'].rank(ascending=False)
                                                                                         
# Split Long and Short and Filter to Highest Tilts

long_ideas = valid_data[valid_data['pos_rank'] <= 5].copy()                                                                                         
short_ideas = valid_data[valid_data['pos_rank'] > 5].copy()

# Weight the best ideas

long_ideas['target'] = long_ideas['target'] / long_ideas.groupby([
    'datadate', 'institution_id'])['target'].transform('sum') * \
                        (1 / long_ideas.groupby('datadate')['institution_id']
                         .transform(lambda s: s.nunique()))

short_ideas['target'] = - short_ideas['target'] / short_ideas.groupby([
    'datadate', 'institution_id'])['target'].transform('sum') * \
                        (1 / short_ideas.groupby('datadate')['institution_id']
                         .transform(lambda s: s.nunique()))

best_ideas = pd.concat([long_ideas, short_ideas])

# %% [markdown]
# ## Backtest Portfolio

# %%
w = weights.Weights(best_ideas)

# %store -r r

p = portfolio.DailyPortfolio(w, r, end_date='2018-12-31')

monthly_return = p.port_return.loc['1999-07-01':].resample('M').apply(epd.prod_red)
monthly_return.name = 'port_return'

# %% [markdown]
# ## Plot Performance

# %%
epd.nav(monthly_return).plot()

# %%
monthly_return.resample('A').apply(epd.prod_red)
# Out:
# datadate
# 1999-12-31    0.049977
# 2000-12-31   -0.015899
# 2001-12-31   -0.072844
# 2002-12-31    0.023648
# 2003-12-31   -0.044404
# 2004-12-31    0.026064
# 2005-12-31    0.030494
# 2006-12-31    0.007749
# 2007-12-31    0.060181
# 2008-12-31    0.010862
# 2009-12-31   -0.076065
# 2010-12-31   -0.005876
# 2011-12-31    0.003988
# 2012-12-31   -0.005980
# 2013-12-31    0.021109
# 2014-12-31    0.015110
# 2015-12-31    0.008168
# 2016-12-31   -0.020272
# 2017-12-31   -0.006758
# 2018-12-31    0.017741
# Freq: A-DEC, Name: port_return, dtype: float64

# %% [markdown]
# ## Fetch Factor Models

# %%
# Get Factor Models
q_factor_model = bi.get_q_factor_model()
fama_french_five_factor_model = bi.get_fama_french_five_factor_model()
four_factor_model = bi.get_four_factor_model()

# Concat Portfolio Return
q_factor = pd.concat([monthly_return, q_factor_model], axis=1)
fama_french_five = pd.concat([monthly_return, fama_french_five_factor_model], axis=1)
four_factor = pd.concat([monthly_return, four_factor_model], axis=1)

# Add Constants
q_factor.insert(1, 'const', 1)
fama_french_five.insert(1, 'const', 1)
four_factor.insert(1, 'const', 1)

# Split Period into Pre and Post Crisis
q_factor_pre, q_factor_post = q_factor.loc[:'2009-06-30'], q_factor.loc['2009-07-31':]
fama_french_five_pre, fama_french_five_post = fama_french_five.loc[:'2009-06-30'], fama_french_five.loc['2009-07-31':] 
four_factor_pre, four_factor_post = four_factor.loc[:'2009-06-30'], four_factor.loc['2009-07-31':]

# %% [markdown]
# ## Full Time Period Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.397
# Model:                            OLS   Adj. R-squared:                  0.386
# Method:                 Least Squares   F-statistic:                     37.66
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           3.39e-24
# Time:                        12:37:35   Log-Likelihood:                 811.50
# No. Observations:                 234   AIC:                            -1613.
# Df Residuals:                     229   BIC:                            -1596.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.001     -0.646      0.519      -0.001       0.001
# mktrf         -0.0286      0.014     -2.009      0.046      -0.057      -0.001
# me             0.0271      0.017      1.639      0.103      -0.005       0.060
# ia            -0.1231      0.025     -4.896      0.000      -0.173      -0.074
# roe            0.1936      0.022      8.996      0.000       0.151       0.236
# ==============================================================================
# Omnibus:                       47.933   Durbin-Watson:                   2.151
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              328.392
# Skew:                          -0.545   Prob(JB):                     4.90e-72
# Kurtosis:                       8.700   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.397
# Model:                            OLS   Adj. R-squared:                  0.386
# Method:                 Least Squares   F-statistic:                     13.15
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           1.16e-09
# Time:                        12:37:35   Log-Likelihood:                 811.50
# No. Observations:                 234   AIC:                            -1613.
# Df Residuals:                     229   BIC:                            -1596.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.001     -0.594      0.552      -0.001       0.001
# mktrf         -0.0286      0.017     -1.660      0.097      -0.062       0.005
# me             0.0271      0.033      0.833      0.405      -0.037       0.091
# ia            -0.1231      0.065     -1.908      0.056      -0.250       0.003
# roe            0.1936      0.042      4.618      0.000       0.111       0.276
# ==============================================================================
# Omnibus:                       47.933   Durbin-Watson:                   2.151
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              328.392
# Skew:                          -0.545   Prob(JB):                     4.90e-72
# Kurtosis:                       8.700   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.397
# Model:                            OLS   Adj. R-squared:                  0.386
# Method:                 Least Squares   F-statistic:                     14.38
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           1.73e-10
# Time:                        12:37:35   Log-Likelihood:                 811.50
# No. Observations:                 234   AIC:                            -1613.
# Df Residuals:                     229   BIC:                            -1596.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.001     -0.521      0.602      -0.002       0.001
# mktrf         -0.0286      0.017     -1.705      0.088      -0.061       0.004
# me             0.0271      0.035      0.774      0.439      -0.042       0.096
# ia            -0.1231      0.059     -2.084      0.037      -0.239      -0.007
# roe            0.1936      0.043      4.462      0.000       0.109       0.279
# ==============================================================================
# Omnibus:                       47.933   Durbin-Watson:                   2.151
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              328.392
# Skew:                          -0.545   Prob(JB):                     4.90e-72
# Kurtosis:                       8.700   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.679
# Model:                            OLS   Adj. R-squared:                  0.674
# Method:                 Least Squares   F-statistic:                     121.3
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           2.11e-55
# Time:                        12:37:35   Log-Likelihood:                 885.47
# No. Observations:                 234   AIC:                            -1761.
# Df Residuals:                     229   BIC:                            -1744.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0002      0.000     -0.653      0.514      -0.001       0.000
# mktrf         -0.0112      0.010     -1.174      0.242      -0.030       0.008
# smb           -0.0835      0.012     -7.004      0.000      -0.107      -0.060
# hml           -0.0248      0.012     -2.094      0.037      -0.048      -0.001
# umd            0.1446      0.008     18.619      0.000       0.129       0.160
# ==============================================================================
# Omnibus:                       53.619   Durbin-Watson:                   2.026
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              308.149
# Skew:                          -0.725   Prob(JB):                     1.22e-67
# Kurtosis:                       8.432   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.679
# Model:                            OLS   Adj. R-squared:                  0.674
# Method:                 Least Squares   F-statistic:                     30.05
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           4.25e-20
# Time:                        12:37:35   Log-Likelihood:                 885.47
# No. Observations:                 234   AIC:                            -1761.
# Df Residuals:                     229   BIC:                            -1744.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0002      0.000     -0.570      0.569      -0.001       0.001
# mktrf         -0.0112      0.013     -0.874      0.382      -0.036       0.014
# smb           -0.0835      0.013     -6.311      0.000      -0.109      -0.058
# hml           -0.0248      0.012     -2.039      0.041      -0.049      -0.001
# umd            0.1446      0.017      8.624      0.000       0.112       0.177
# ==============================================================================
# Omnibus:                       53.619   Durbin-Watson:                   2.026
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              308.149
# Skew:                          -0.725   Prob(JB):                     1.22e-67
# Kurtosis:                       8.432   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.679
# Model:                            OLS   Adj. R-squared:                  0.674
# Method:                 Least Squares   F-statistic:                     24.90
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           3.93e-17
# Time:                        12:37:35   Log-Likelihood:                 885.47
# No. Observations:                 234   AIC:                            -1761.
# Df Residuals:                     229   BIC:                            -1744.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0002      0.000     -0.516      0.606      -0.001       0.001
# mktrf         -0.0112      0.014     -0.812      0.417      -0.038       0.016
# smb           -0.0835      0.013     -6.614      0.000      -0.108      -0.059
# hml           -0.0248      0.011     -2.304      0.021      -0.046      -0.004
# umd            0.1446      0.019      7.775      0.000       0.108       0.181
# ==============================================================================
# Omnibus:                       53.619   Durbin-Watson:                   2.026
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              308.149
# Skew:                          -0.725   Prob(JB):                     1.22e-67
# Kurtosis:                       8.432   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.679
# Model:                            OLS   Adj. R-squared:                  0.674
# Method:                 Least Squares   F-statistic:                     121.3
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           2.11e-55
# Time:                        12:37:35   Log-Likelihood:                 885.47
# No. Observations:                 234   AIC:                            -1761.
# Df Residuals:                     229   BIC:                            -1744.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0002      0.000     -0.653      0.514      -0.001       0.000
# mktrf         -0.0112      0.010     -1.174      0.242      -0.030       0.008
# smb           -0.0835      0.012     -7.004      0.000      -0.107      -0.060
# hml           -0.0248      0.012     -2.094      0.037      -0.048      -0.001
# umd            0.1446      0.008     18.619      0.000       0.129       0.160
# ==============================================================================
# Omnibus:                       53.619   Durbin-Watson:                   2.026
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              308.149
# Skew:                          -0.725   Prob(JB):                     1.22e-67
# Kurtosis:                       8.432   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.679
# Model:                            OLS   Adj. R-squared:                  0.674
# Method:                 Least Squares   F-statistic:                     30.05
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           4.25e-20
# Time:                        12:37:35   Log-Likelihood:                 885.47
# No. Observations:                 234   AIC:                            -1761.
# Df Residuals:                     229   BIC:                            -1744.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0002      0.000     -0.570      0.569      -0.001       0.001
# mktrf         -0.0112      0.013     -0.874      0.382      -0.036       0.014
# smb           -0.0835      0.013     -6.311      0.000      -0.109      -0.058
# hml           -0.0248      0.012     -2.039      0.041      -0.049      -0.001
# umd            0.1446      0.017      8.624      0.000       0.112       0.177
# ==============================================================================
# Omnibus:                       53.619   Durbin-Watson:                   2.026
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              308.149
# Skew:                          -0.725   Prob(JB):                     1.22e-67
# Kurtosis:                       8.432   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.679
# Model:                            OLS   Adj. R-squared:                  0.674
# Method:                 Least Squares   F-statistic:                     24.90
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           3.93e-17
# Time:                        12:37:35   Log-Likelihood:                 885.47
# No. Observations:                 234   AIC:                            -1761.
# Df Residuals:                     229   BIC:                            -1744.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0002      0.000     -0.516      0.606      -0.001       0.001
# mktrf         -0.0112      0.014     -0.812      0.417      -0.038       0.016
# smb           -0.0835      0.013     -6.614      0.000      -0.108      -0.059
# hml           -0.0248      0.011     -2.304      0.021      -0.046      -0.004
# umd            0.1446      0.019      7.775      0.000       0.108       0.181
# ==============================================================================
# Omnibus:                       53.619   Durbin-Watson:                   2.026
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              308.149
# Skew:                          -0.725   Prob(JB):                     1.22e-67
# Kurtosis:                       8.432   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Pre-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.471
# Model:                            OLS   Adj. R-squared:                  0.452
# Method:                 Least Squares   F-statistic:                     25.58
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           3.58e-15
# Time:                        12:37:35   Log-Likelihood:                 391.08
# No. Observations:                 120   AIC:                            -772.2
# Df Residuals:                     115   BIC:                            -758.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0011      0.001     -1.236      0.219      -0.003       0.001
# mktrf         -0.0002      0.024     -0.008      0.994      -0.049       0.048
# me             0.0615      0.024      2.544      0.012       0.014       0.109
# ia            -0.1618      0.038     -4.272      0.000      -0.237      -0.087
# roe            0.2673      0.034      7.975      0.000       0.201       0.334
# ==============================================================================
# Omnibus:                       13.309   Durbin-Watson:                   2.169
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               35.890
# Skew:                          -0.252   Prob(JB):                     1.61e-08
# Kurtosis:                       5.631   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.471
# Model:                            OLS   Adj. R-squared:                  0.452
# Method:                 Least Squares   F-statistic:                     21.94
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           1.78e-13
# Time:                        12:37:35   Log-Likelihood:                 391.08
# No. Observations:                 120   AIC:                            -772.2
# Df Residuals:                     115   BIC:                            -758.2
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0011      0.001     -1.229      0.219      -0.003       0.001
# mktrf         -0.0002      0.022     -0.009      0.993      -0.043       0.043
# me             0.0615      0.038      1.622      0.105      -0.013       0.136
# ia            -0.1618      0.080     -2.011      0.044      -0.319      -0.004
# roe            0.2673      0.042      6.345      0.000       0.185       0.350
# ==============================================================================
# Omnibus:                       13.309   Durbin-Watson:                   2.169
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               35.890
# Skew:                          -0.252   Prob(JB):                     1.61e-08
# Kurtosis:                       5.631   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.471
# Model:                            OLS   Adj. R-squared:                  0.452
# Method:                 Least Squares   F-statistic:                     29.56
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           6.63e-17
# Time:                        12:37:35   Log-Likelihood:                 391.08
# No. Observations:                 120   AIC:                            -772.2
# Df Residuals:                     115   BIC:                            -758.2
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0011      0.001     -1.067      0.286      -0.003       0.001
# mktrf         -0.0002      0.019     -0.011      0.991      -0.037       0.036
# me             0.0615      0.042      1.479      0.139      -0.020       0.143
# ia            -0.1618      0.075     -2.151      0.031      -0.309      -0.014
# roe            0.2673      0.038      7.028      0.000       0.193       0.342
# ==============================================================================
# Omnibus:                       13.309   Durbin-Watson:                   2.169
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               35.890
# Skew:                          -0.252   Prob(JB):                     1.61e-08
# Kurtosis:                       5.631   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.740
# Model:                            OLS   Adj. R-squared:                  0.731
# Method:                 Least Squares   F-statistic:                     81.94
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           9.43e-33
# Time:                        12:37:35   Log-Likelihood:                 433.78
# No. Observations:                 120   AIC:                            -857.6
# Df Residuals:                     115   BIC:                            -843.6
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.001     -0.448      0.655      -0.002       0.001
# mktrf          0.0085      0.015      0.561      0.576      -0.021       0.038
# smb           -0.1019      0.017     -5.926      0.000      -0.136      -0.068
# hml           -0.0321      0.017     -1.864      0.065      -0.066       0.002
# umd            0.1677      0.011     15.782      0.000       0.147       0.189
# ==============================================================================
# Omnibus:                       19.714   Durbin-Watson:                   2.005
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               53.318
# Skew:                          -0.541   Prob(JB):                     2.64e-12
# Kurtosis:                       6.081   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.740
# Model:                            OLS   Adj. R-squared:                  0.731
# Method:                 Least Squares   F-statistic:                     28.43
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           2.00e-16
# Time:                        12:37:35   Log-Likelihood:                 433.78
# No. Observations:                 120   AIC:                            -857.6
# Df Residuals:                     115   BIC:                            -843.6
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.001     -0.399      0.690      -0.002       0.001
# mktrf          0.0085      0.014      0.609      0.542      -0.019       0.036
# smb           -0.1019      0.015     -6.681      0.000      -0.132      -0.072
# hml           -0.0321      0.011     -2.825      0.005      -0.054      -0.010
# umd            0.1677      0.017      9.636      0.000       0.134       0.202
# ==============================================================================
# Omnibus:                       19.714   Durbin-Watson:                   2.005
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               53.318
# Skew:                          -0.541   Prob(JB):                     2.64e-12
# Kurtosis:                       6.081   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.740
# Model:                            OLS   Adj. R-squared:                  0.731
# Method:                 Least Squares   F-statistic:                     46.03
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           4.89e-23
# Time:                        12:37:35   Log-Likelihood:                 433.78
# No. Observations:                 120   AIC:                            -857.6
# Df Residuals:                     115   BIC:                            -843.6
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.001     -0.364      0.716      -0.002       0.001
# mktrf          0.0085      0.014      0.626      0.531      -0.018       0.035
# smb           -0.1019      0.013     -7.677      0.000      -0.128      -0.076
# hml           -0.0321      0.009     -3.394      0.001      -0.051      -0.014
# umd            0.1677      0.017      9.594      0.000       0.133       0.202
# ==============================================================================
# Omnibus:                       19.714   Durbin-Watson:                   2.005
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               53.318
# Skew:                          -0.541   Prob(JB):                     2.64e-12
# Kurtosis:                       6.081   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.740
# Model:                            OLS   Adj. R-squared:                  0.731
# Method:                 Least Squares   F-statistic:                     81.94
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           9.43e-33
# Time:                        12:37:35   Log-Likelihood:                 433.78
# No. Observations:                 120   AIC:                            -857.6
# Df Residuals:                     115   BIC:                            -843.6
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.001     -0.448      0.655      -0.002       0.001
# mktrf          0.0085      0.015      0.561      0.576      -0.021       0.038
# smb           -0.1019      0.017     -5.926      0.000      -0.136      -0.068
# hml           -0.0321      0.017     -1.864      0.065      -0.066       0.002
# umd            0.1677      0.011     15.782      0.000       0.147       0.189
# ==============================================================================
# Omnibus:                       19.714   Durbin-Watson:                   2.005
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               53.318
# Skew:                          -0.541   Prob(JB):                     2.64e-12
# Kurtosis:                       6.081   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.740
# Model:                            OLS   Adj. R-squared:                  0.731
# Method:                 Least Squares   F-statistic:                     28.43
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           2.00e-16
# Time:                        12:37:35   Log-Likelihood:                 433.78
# No. Observations:                 120   AIC:                            -857.6
# Df Residuals:                     115   BIC:                            -843.6
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.001     -0.399      0.690      -0.002       0.001
# mktrf          0.0085      0.014      0.609      0.542      -0.019       0.036
# smb           -0.1019      0.015     -6.681      0.000      -0.132      -0.072
# hml           -0.0321      0.011     -2.825      0.005      -0.054      -0.010
# umd            0.1677      0.017      9.636      0.000       0.134       0.202
# ==============================================================================
# Omnibus:                       19.714   Durbin-Watson:                   2.005
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               53.318
# Skew:                          -0.541   Prob(JB):                     2.64e-12
# Kurtosis:                       6.081   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.740
# Model:                            OLS   Adj. R-squared:                  0.731
# Method:                 Least Squares   F-statistic:                     46.03
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           4.89e-23
# Time:                        12:37:35   Log-Likelihood:                 433.78
# No. Observations:                 120   AIC:                            -857.6
# Df Residuals:                     115   BIC:                            -843.6
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.001     -0.364      0.716      -0.002       0.001
# mktrf          0.0085      0.014      0.626      0.531      -0.018       0.035
# smb           -0.1019      0.013     -7.677      0.000      -0.128      -0.076
# hml           -0.0321      0.009     -3.394      0.001      -0.051      -0.014
# umd            0.1677      0.017      9.594      0.000       0.133       0.202
# ==============================================================================
# Omnibus:                       19.714   Durbin-Watson:                   2.005
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               53.318
# Skew:                          -0.541   Prob(JB):                     2.64e-12
# Kurtosis:                       6.081   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Post-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.447
# Model:                            OLS   Adj. R-squared:                  0.427
# Method:                 Least Squares   F-statistic:                     22.01
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           2.45e-13
# Time:                        12:37:35   Log-Likelihood:                 484.04
# No. Observations:                 114   AIC:                            -958.1
# Df Residuals:                     109   BIC:                            -944.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0005      0.000      1.393      0.166      -0.000       0.001
# mktrf         -0.0415      0.010     -3.983      0.000      -0.062      -0.021
# me            -0.0579      0.016     -3.601      0.000      -0.090      -0.026
# ia            -0.0624      0.022     -2.798      0.006      -0.107      -0.018
# roe            0.0407      0.020      2.075      0.040       0.002       0.080
# ==============================================================================
# Omnibus:                       15.331   Durbin-Watson:                   1.898
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               26.615
# Skew:                          -0.579   Prob(JB):                     1.66e-06
# Kurtosis:                       5.064   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.447
# Model:                            OLS   Adj. R-squared:                  0.427
# Method:                 Least Squares   F-statistic:                     29.56
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           1.20e-16
# Time:                        12:37:35   Log-Likelihood:                 484.04
# No. Observations:                 114   AIC:                            -958.1
# Df Residuals:                     109   BIC:                            -944.4
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0005      0.000      1.401      0.161      -0.000       0.001
# mktrf         -0.0415      0.011     -3.818      0.000      -0.063      -0.020
# me            -0.0579      0.017     -3.408      0.001      -0.091      -0.025
# ia            -0.0624      0.024     -2.657      0.008      -0.109      -0.016
# roe            0.0407      0.022      1.846      0.065      -0.003       0.084
# ==============================================================================
# Omnibus:                       15.331   Durbin-Watson:                   1.898
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               26.615
# Skew:                          -0.579   Prob(JB):                     1.66e-06
# Kurtosis:                       5.064   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.447
# Model:                            OLS   Adj. R-squared:                  0.427
# Method:                 Least Squares   F-statistic:                     36.60
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           2.26e-19
# Time:                        12:37:35   Log-Likelihood:                 484.04
# No. Observations:                 114   AIC:                            -958.1
# Df Residuals:                     109   BIC:                            -944.4
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0005      0.000      1.289      0.197      -0.000       0.001
# mktrf         -0.0415      0.011     -3.740      0.000      -0.063      -0.020
# me            -0.0579      0.016     -3.630      0.000      -0.089      -0.027
# ia            -0.0624      0.026     -2.435      0.015      -0.113      -0.012
# roe            0.0407      0.022      1.862      0.063      -0.002       0.084
# ==============================================================================
# Omnibus:                       15.331   Durbin-Watson:                   1.898
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               26.615
# Skew:                          -0.579   Prob(JB):                     1.66e-06
# Kurtosis:                       5.064   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.592
# Model:                            OLS   Adj. R-squared:                  0.577
# Method:                 Least Squares   F-statistic:                     39.50
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           2.07e-20
# Time:                        12:37:35   Log-Likelihood:                 501.36
# No. Observations:                 114   AIC:                            -992.7
# Df Residuals:                     109   BIC:                            -979.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0003      0.000      1.094      0.276      -0.000       0.001
# mktrf         -0.0369      0.008     -4.345      0.000      -0.054      -0.020
# smb           -0.0620      0.013     -4.684      0.000      -0.088      -0.036
# hml           -0.0419      0.014     -3.078      0.003      -0.069      -0.015
# umd            0.0569      0.010      5.534      0.000       0.037       0.077
# ==============================================================================
# Omnibus:                       12.391   Durbin-Watson:                   1.886
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               18.868
# Skew:                          -0.511   Prob(JB):                     8.00e-05
# Kurtosis:                       4.711   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.592
# Model:                            OLS   Adj. R-squared:                  0.577
# Method:                 Least Squares   F-statistic:                     48.39
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           2.46e-23
# Time:                        12:37:35   Log-Likelihood:                 501.36
# No. Observations:                 114   AIC:                            -992.7
# Df Residuals:                     109   BIC:                            -979.0
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0003      0.000      1.181      0.238      -0.000       0.001
# mktrf         -0.0369      0.008     -4.562      0.000      -0.053      -0.021
# smb           -0.0620      0.012     -5.070      0.000      -0.086      -0.038
# hml           -0.0419      0.012     -3.527      0.000      -0.065      -0.019
# umd            0.0569      0.009      6.012      0.000       0.038       0.075
# ==============================================================================
# Omnibus:                       12.391   Durbin-Watson:                   1.886
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               18.868
# Skew:                          -0.511   Prob(JB):                     8.00e-05
# Kurtosis:                       4.711   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.592
# Model:                            OLS   Adj. R-squared:                  0.577
# Method:                 Least Squares   F-statistic:                     40.82
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           7.24e-21
# Time:                        12:37:35   Log-Likelihood:                 501.36
# No. Observations:                 114   AIC:                            -992.7
# Df Residuals:                     109   BIC:                            -979.0
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0003      0.000      1.238      0.216      -0.000       0.001
# mktrf         -0.0369      0.009     -4.205      0.000      -0.054      -0.020
# smb           -0.0620      0.012     -5.374      0.000      -0.085      -0.039
# hml           -0.0419      0.013     -3.164      0.002      -0.068      -0.016
# umd            0.0569      0.009      6.273      0.000       0.039       0.075
# ==============================================================================
# Omnibus:                       12.391   Durbin-Watson:                   1.886
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               18.868
# Skew:                          -0.511   Prob(JB):                     8.00e-05
# Kurtosis:                       4.711   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.592
# Model:                            OLS   Adj. R-squared:                  0.577
# Method:                 Least Squares   F-statistic:                     39.50
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           2.07e-20
# Time:                        12:37:35   Log-Likelihood:                 501.36
# No. Observations:                 114   AIC:                            -992.7
# Df Residuals:                     109   BIC:                            -979.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0003      0.000      1.094      0.276      -0.000       0.001
# mktrf         -0.0369      0.008     -4.345      0.000      -0.054      -0.020
# smb           -0.0620      0.013     -4.684      0.000      -0.088      -0.036
# hml           -0.0419      0.014     -3.078      0.003      -0.069      -0.015
# umd            0.0569      0.010      5.534      0.000       0.037       0.077
# ==============================================================================
# Omnibus:                       12.391   Durbin-Watson:                   1.886
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               18.868
# Skew:                          -0.511   Prob(JB):                     8.00e-05
# Kurtosis:                       4.711   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.592
# Model:                            OLS   Adj. R-squared:                  0.577
# Method:                 Least Squares   F-statistic:                     48.39
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           2.46e-23
# Time:                        12:37:35   Log-Likelihood:                 501.36
# No. Observations:                 114   AIC:                            -992.7
# Df Residuals:                     109   BIC:                            -979.0
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0003      0.000      1.181      0.238      -0.000       0.001
# mktrf         -0.0369      0.008     -4.562      0.000      -0.053      -0.021
# smb           -0.0620      0.012     -5.070      0.000      -0.086      -0.038
# hml           -0.0419      0.012     -3.527      0.000      -0.065      -0.019
# umd            0.0569      0.009      6.012      0.000       0.038       0.075
# ==============================================================================
# Omnibus:                       12.391   Durbin-Watson:                   1.886
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               18.868
# Skew:                          -0.511   Prob(JB):                     8.00e-05
# Kurtosis:                       4.711   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.592
# Model:                            OLS   Adj. R-squared:                  0.577
# Method:                 Least Squares   F-statistic:                     40.82
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           7.24e-21
# Time:                        12:37:35   Log-Likelihood:                 501.36
# No. Observations:                 114   AIC:                            -992.7
# Df Residuals:                     109   BIC:                            -979.0
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0003      0.000      1.238      0.216      -0.000       0.001
# mktrf         -0.0369      0.009     -4.205      0.000      -0.054      -0.020
# smb           -0.0620      0.012     -5.374      0.000      -0.085      -0.039
# hml           -0.0419      0.013     -3.164      0.002      -0.068      -0.016
# umd            0.0569      0.009      6.273      0.000       0.039       0.075
# ==============================================================================
# Omnibus:                       12.391   Durbin-Watson:                   1.886
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               18.868
# Skew:                          -0.511   Prob(JB):                     8.00e-05
# Kurtosis:                       4.711   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """
