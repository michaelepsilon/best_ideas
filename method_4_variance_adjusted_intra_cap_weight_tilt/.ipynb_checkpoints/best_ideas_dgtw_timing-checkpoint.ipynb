# %% [markdown]
# # Method 4 - Best Ideas DGTW Timing

# %%
# %matplotlib inline
import pandas as pd
import warnings
from statsmodels import api as sm

from eptooling import crsp, epd, fs, hfu, crsp, db, bi
from eptooling.bm import bmdb, iso
from epquant.engine import weights, portfolio
from epquant.gen import returns
from epquant.perf import relative_performance

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Fetch Holdings and Benchmark Data

# %%
# Get HFU Data

# %store -r inst_data
inst_data = inst_data[inst_data['datadate'] >= '1999-06-30']

# Count number of positions per manager

inst_data['num_pos'] = inst_data.groupby(['datadate', 'institution_id'])[
    'fsym_id'].transform(lambda s: s.nunique())

# Remove less than 20 holdings and less than $5mm per CSP

valid_data = inst_data[inst_data['num_pos'] >= 20]
valid_data = valid_data[valid_data['public_aum'] >= 5e6]

# Calculate Market Cap Adjusted Target

valid_data['weight'] = valid_data['market_cap_val_cur'] / valid_data.groupby(
    ['datadate', 'institution_id'])['market_cap_val_cur'].transform('sum')

# Grab Idiosyncratic Volatility

capm_var = crsp.get_capm_variance()

# Merge Idiosyncratic Volatility

valid_data = valid_data.merge(capm_var, how='left')

# Calculate Variance Adjusted Intra-Cap Weight Tilt

valid_data['adj_target'] = (valid_data['target'] - valid_data[
    'weight'].fillna(0)) * valid_data['capm_var']

# %% [markdown]
# ## Calculate Best Ideas

# %%
# Extract Best Ideas

valid_data['pos_rank'] = valid_data\
    .groupby(['datadate', 'institution_id'])['adj_target'].rank(ascending=False)

best_ideas = valid_data[valid_data['pos_rank'] == 1].copy()

# Weight the best ideas equally

best_ideas['target'] = 1 / best_ideas.groupby('datadate')[
    'institution_id'].transform('count')

# %% [markdown]
# ## Backtest Portfolio

# %%
w = weights.Weights(best_ideas)

# %store -r r

p = portfolio.DailyPortfolio(w, r, end_date='2018-12-31')

monthly_beg_pos = p.beg_port.iloc[1:].resample('M', level=0).apply(epd.take_first)
dgtw = crsp.get_dgtw_returns(list(set(best_ideas['fsym_id'].dropna())),
                    best_ideas['datadate'].min(), pd.datetime(2018, 12, 31))
dgtw_pivot = pd.pivot_table(dgtw, index='datadate', columns='fsym_id', values='total_return')
dgtw_cont = monthly_beg_pos.mul(dgtw_pivot, axis=1, level=0).sum(axis=1)
dgtw_cont = dgtw_cont[dgtw_cont != 0]

rf = bi.get_risk_free_rate()
monthly_return = dgtw_cont.loc['1999-07-01':]
monthly_return = (monthly_return - rf).dropna()
monthly_return.name = 'port_return'

# %% [markdown]
# ## Plot Performance

# %%
epd.nav(monthly_return).plot()

# %%
monthly_return.resample('A').apply(epd.prod_red)
# Out:
# datadate
# 1999-12-31    0.097242
# 2000-12-31   -0.111872
# 2001-12-31   -0.057417
# 2002-12-31   -0.220482
# 2003-12-31    0.497042
# 2004-12-31    0.121353
# 2005-12-31    0.031176
# 2006-12-31    0.069664
# 2007-12-31   -0.027475
# 2008-12-31   -0.444209
# 2009-12-31    0.499396
# 2010-12-31    0.243944
# 2011-12-31   -0.056882
# 2012-12-31    0.152316
# 2013-12-31    0.353766
# 2014-12-31    0.049843
# 2015-12-31   -0.054434
# 2016-12-31    0.156617
# 2017-12-31    0.150738
# 2018-12-31   -0.082171
# Freq: A-DEC, Name: port_return, dtype: float64

# %% [markdown]
# ## Fetch Factor Models

# %%
# Get Factor Models
q_factor_model = bi.get_q_factor_model()
fama_french_five_factor_model = bi.get_fama_french_five_factor_model()
four_factor_model = bi.get_four_factor_model()

# Concat Portfolio Return
q_factor = pd.concat([monthly_return, q_factor_model], axis=1)
fama_french_five = pd.concat([monthly_return, fama_french_five_factor_model], axis=1)
four_factor = pd.concat([monthly_return, four_factor_model], axis=1)

# Add Constants
q_factor.insert(1, 'const', 1)
fama_french_five.insert(1, 'const', 1)
four_factor.insert(1, 'const', 1)

# Split Period into Pre and Post Crisis
q_factor_pre, q_factor_post = q_factor.loc[:'2009-06-30'], q_factor.loc['2009-07-31':]
fama_french_five_pre, fama_french_five_post = fama_french_five.loc[:'2009-06-30'], fama_french_five.loc['2009-07-31':] 
four_factor_pre, four_factor_post = four_factor.loc[:'2009-06-30'], four_factor.loc['2009-07-31':]

# %% [markdown]
# ## Full Time Period Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.952
# Model:                            OLS   Adj. R-squared:                  0.951
# Method:                 Least Squares   F-statistic:                     1141.
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):          6.44e-150
# Time:                        14:42:18   Log-Likelihood:                 715.16
# No. Observations:                 234   AIC:                            -1420.
# Df Residuals:                     229   BIC:                            -1403.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0011      0.001      1.416      0.158      -0.000       0.003
# mktrf          0.9727      0.021     45.305      0.000       0.930       1.015
# me             0.2439      0.025      9.765      0.000       0.195       0.293
# ia             0.1114      0.038      2.936      0.004       0.037       0.186
# roe           -0.2987      0.032     -9.192      0.000      -0.363      -0.235
# ==============================================================================
# Omnibus:                       46.097   Durbin-Watson:                   1.894
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              294.823
# Skew:                           0.535   Prob(JB):                     9.55e-65
# Kurtosis:                       8.394   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.952
# Model:                            OLS   Adj. R-squared:                  0.951
# Method:                 Least Squares   F-statistic:                     803.1
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):          1.90e-133
# Time:                        14:42:18   Log-Likelihood:                 715.16
# No. Observations:                 234   AIC:                            -1420.
# Df Residuals:                     229   BIC:                            -1403.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0011      0.001      1.375      0.169      -0.000       0.003
# mktrf          0.9727      0.029     33.196      0.000       0.915       1.030
# me             0.2439      0.075      3.255      0.001       0.097       0.391
# ia             0.1114      0.079      1.416      0.157      -0.043       0.266
# roe           -0.2987      0.059     -5.085      0.000      -0.414      -0.184
# ==============================================================================
# Omnibus:                       46.097   Durbin-Watson:                   1.894
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              294.823
# Skew:                           0.535   Prob(JB):                     9.55e-65
# Kurtosis:                       8.394   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.952
# Model:                            OLS   Adj. R-squared:                  0.951
# Method:                 Least Squares   F-statistic:                     1087.
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):          1.33e-147
# Time:                        14:42:18   Log-Likelihood:                 715.16
# No. Observations:                 234   AIC:                            -1420.
# Df Residuals:                     229   BIC:                            -1403.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0011      0.001      1.486      0.137      -0.000       0.003
# mktrf          0.9727      0.027     36.437      0.000       0.920       1.025
# me             0.2439      0.081      3.012      0.003       0.085       0.403
# ia             0.1114      0.071      1.577      0.115      -0.027       0.250
# roe           -0.2987      0.057     -5.263      0.000      -0.410      -0.187
# ==============================================================================
# Omnibus:                       46.097   Durbin-Watson:                   1.894
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              294.823
# Skew:                           0.535   Prob(JB):                     9.55e-65
# Kurtosis:                       8.394   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.961
# Model:                            OLS   Adj. R-squared:                  0.961
# Method:                 Least Squares   F-statistic:                     1420.
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):          2.55e-160
# Time:                        14:42:18   Log-Likelihood:                 739.65
# No. Observations:                 234   AIC:                            -1469.
# Df Residuals:                     229   BIC:                            -1452.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0005      0.001      0.790      0.430      -0.001       0.002
# mktrf          0.9759      0.018     54.816      0.000       0.941       1.011
# smb            0.4086      0.022     18.384      0.000       0.365       0.452
# hml            0.1038      0.022      4.703      0.000       0.060       0.147
# umd           -0.1842      0.014    -12.716      0.000      -0.213      -0.156
# ==============================================================================
# Omnibus:                       16.707   Durbin-Watson:                   1.750
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               52.193
# Skew:                          -0.014   Prob(JB):                     4.64e-12
# Kurtosis:                       5.314   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.961
# Model:                            OLS   Adj. R-squared:                  0.961
# Method:                 Least Squares   F-statistic:                     1182.
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):          1.40e-151
# Time:                        14:42:18   Log-Likelihood:                 739.65
# No. Observations:                 234   AIC:                            -1469.
# Df Residuals:                     229   BIC:                            -1452.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0005      0.001      0.668      0.504      -0.001       0.002
# mktrf          0.9759      0.018     53.938      0.000       0.940       1.011
# smb            0.4086      0.048      8.570      0.000       0.315       0.502
# hml            0.1038      0.030      3.458      0.001       0.045       0.163
# umd           -0.1842      0.027     -6.847      0.000      -0.237      -0.131
# ==============================================================================
# Omnibus:                       16.707   Durbin-Watson:                   1.750
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               52.193
# Skew:                          -0.014   Prob(JB):                     4.64e-12
# Kurtosis:                       5.314   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.961
# Model:                            OLS   Adj. R-squared:                  0.961
# Method:                 Least Squares   F-statistic:                     1045.
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):          9.49e-146
# Time:                        14:42:18   Log-Likelihood:                 739.65
# No. Observations:                 234   AIC:                            -1469.
# Df Residuals:                     229   BIC:                            -1452.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0005      0.001      0.709      0.478      -0.001       0.002
# mktrf          0.9759      0.019     51.412      0.000       0.939       1.013
# smb            0.4086      0.050      8.185      0.000       0.311       0.506
# hml            0.1038      0.029      3.598      0.000       0.047       0.160
# umd           -0.1842      0.024     -7.702      0.000      -0.231      -0.137
# ==============================================================================
# Omnibus:                       16.707   Durbin-Watson:                   1.750
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               52.193
# Skew:                          -0.014   Prob(JB):                     4.64e-12
# Kurtosis:                       5.314   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.961
# Model:                            OLS   Adj. R-squared:                  0.961
# Method:                 Least Squares   F-statistic:                     1420.
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):          2.55e-160
# Time:                        14:42:18   Log-Likelihood:                 739.65
# No. Observations:                 234   AIC:                            -1469.
# Df Residuals:                     229   BIC:                            -1452.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0005      0.001      0.790      0.430      -0.001       0.002
# mktrf          0.9759      0.018     54.816      0.000       0.941       1.011
# smb            0.4086      0.022     18.384      0.000       0.365       0.452
# hml            0.1038      0.022      4.703      0.000       0.060       0.147
# umd           -0.1842      0.014    -12.716      0.000      -0.213      -0.156
# ==============================================================================
# Omnibus:                       16.707   Durbin-Watson:                   1.750
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               52.193
# Skew:                          -0.014   Prob(JB):                     4.64e-12
# Kurtosis:                       5.314   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.961
# Model:                            OLS   Adj. R-squared:                  0.961
# Method:                 Least Squares   F-statistic:                     1182.
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):          1.40e-151
# Time:                        14:42:18   Log-Likelihood:                 739.65
# No. Observations:                 234   AIC:                            -1469.
# Df Residuals:                     229   BIC:                            -1452.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0005      0.001      0.668      0.504      -0.001       0.002
# mktrf          0.9759      0.018     53.938      0.000       0.940       1.011
# smb            0.4086      0.048      8.570      0.000       0.315       0.502
# hml            0.1038      0.030      3.458      0.001       0.045       0.163
# umd           -0.1842      0.027     -6.847      0.000      -0.237      -0.131
# ==============================================================================
# Omnibus:                       16.707   Durbin-Watson:                   1.750
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               52.193
# Skew:                          -0.014   Prob(JB):                     4.64e-12
# Kurtosis:                       5.314   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.961
# Model:                            OLS   Adj. R-squared:                  0.961
# Method:                 Least Squares   F-statistic:                     1045.
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):          9.49e-146
# Time:                        14:42:18   Log-Likelihood:                 739.65
# No. Observations:                 234   AIC:                            -1469.
# Df Residuals:                     229   BIC:                            -1452.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0005      0.001      0.709      0.478      -0.001       0.002
# mktrf          0.9759      0.019     51.412      0.000       0.939       1.013
# smb            0.4086      0.050      8.185      0.000       0.311       0.506
# hml            0.1038      0.029      3.598      0.000       0.047       0.160
# umd           -0.1842      0.024     -7.702      0.000      -0.231      -0.137
# ==============================================================================
# Omnibus:                       16.707   Durbin-Watson:                   1.750
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               52.193
# Skew:                          -0.014   Prob(JB):                     4.64e-12
# Kurtosis:                       5.314   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Pre-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.947
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     514.5
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           2.26e-72
# Time:                        14:42:18   Log-Likelihood:                 344.15
# No. Observations:                 120   AIC:                            -678.3
# Df Residuals:                     115   BIC:                            -664.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0021      0.001      1.566      0.120      -0.001       0.005
# mktrf          1.0079      0.036     27.844      0.000       0.936       1.080
# me             0.1770      0.036      4.951      0.000       0.106       0.248
# ia             0.1339      0.056      2.391      0.018       0.023       0.245
# roe           -0.2901      0.050     -5.854      0.000      -0.388      -0.192
# ==============================================================================
# Omnibus:                       17.771   Durbin-Watson:                   1.978
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               47.287
# Skew:                           0.472   Prob(JB):                     5.39e-11
# Kurtosis:                       5.927   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.947
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     485.9
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           5.04e-71
# Time:                        14:42:18   Log-Likelihood:                 344.15
# No. Observations:                 120   AIC:                            -678.3
# Df Residuals:                     115   BIC:                            -664.4
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0021      0.001      1.411      0.158      -0.001       0.005
# mktrf          1.0079      0.033     30.650      0.000       0.943       1.072
# me             0.1770      0.072      2.445      0.014       0.035       0.319
# ia             0.1339      0.090      1.493      0.135      -0.042       0.310
# roe           -0.2901      0.061     -4.739      0.000      -0.410      -0.170
# ==============================================================================
# Omnibus:                       17.771   Durbin-Watson:                   1.978
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               47.287
# Skew:                           0.472   Prob(JB):                     5.39e-11
# Kurtosis:                       5.927   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.947
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     563.7
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           1.55e-74
# Time:                        14:42:18   Log-Likelihood:                 344.15
# No. Observations:                 120   AIC:                            -678.3
# Df Residuals:                     115   BIC:                            -664.4
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0021      0.001      1.425      0.154      -0.001       0.005
# mktrf          1.0079      0.028     35.636      0.000       0.953       1.063
# me             0.1770      0.079      2.248      0.025       0.023       0.331
# ia             0.1339      0.080      1.677      0.094      -0.023       0.290
# roe           -0.2901      0.052     -5.558      0.000      -0.392      -0.188
# ==============================================================================
# Omnibus:                       17.771   Durbin-Watson:                   1.978
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               47.287
# Skew:                           0.472   Prob(JB):                     5.39e-11
# Kurtosis:                       5.927   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.960
# Model:                            OLS   Adj. R-squared:                  0.958
# Method:                 Least Squares   F-statistic:                     681.2
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           4.75e-79
# Time:                        14:42:18   Log-Likelihood:                 360.20
# No. Observations:                 120   AIC:                            -710.4
# Df Residuals:                     115   BIC:                            -696.5
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0018      0.001      1.530      0.129      -0.001       0.004
# mktrf          1.0204      0.028     36.577      0.000       0.965       1.076
# smb            0.3693      0.032     11.628      0.000       0.306       0.432
# hml            0.1040      0.032      3.270      0.001       0.041       0.167
# umd           -0.1807      0.020     -9.211      0.000      -0.220      -0.142
# ==============================================================================
# Omnibus:                        7.029   Durbin-Watson:                   1.784
# Prob(Omnibus):                  0.030   Jarque-Bera (JB):                8.915
# Skew:                          -0.314   Prob(JB):                       0.0116
# Kurtosis:                       4.179   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.960
# Model:                            OLS   Adj. R-squared:                  0.958
# Method:                 Least Squares   F-statistic:                     1288.
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           1.85e-94
# Time:                        14:42:18   Log-Likelihood:                 360.20
# No. Observations:                 120   AIC:                            -710.4
# Df Residuals:                     115   BIC:                            -696.5
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0018      0.001      1.376      0.169      -0.001       0.004
# mktrf          1.0204      0.019     52.771      0.000       0.982       1.058
# smb            0.3693      0.051      7.193      0.000       0.269       0.470
# hml            0.1040      0.040      2.576      0.010       0.025       0.183
# umd           -0.1807      0.031     -5.918      0.000      -0.240      -0.121
# ==============================================================================
# Omnibus:                        7.029   Durbin-Watson:                   1.784
# Prob(Omnibus):                  0.030   Jarque-Bera (JB):                8.915
# Skew:                          -0.314   Prob(JB):                       0.0116
# Kurtosis:                       4.179   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.960
# Model:                            OLS   Adj. R-squared:                  0.958
# Method:                 Least Squares   F-statistic:                     1711.
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):          2.03e-101
# Time:                        14:42:18   Log-Likelihood:                 360.20
# No. Observations:                 120   AIC:                            -710.4
# Df Residuals:                     115   BIC:                            -696.5
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0018      0.001      1.477      0.140      -0.001       0.004
# mktrf          1.0204      0.018     55.275      0.000       0.984       1.057
# smb            0.3693      0.053      6.924      0.000       0.265       0.474
# hml            0.1040      0.042      2.456      0.014       0.021       0.187
# umd           -0.1807      0.027     -6.630      0.000      -0.234      -0.127
# ==============================================================================
# Omnibus:                        7.029   Durbin-Watson:                   1.784
# Prob(Omnibus):                  0.030   Jarque-Bera (JB):                8.915
# Skew:                          -0.314   Prob(JB):                       0.0116
# Kurtosis:                       4.179   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.960
# Model:                            OLS   Adj. R-squared:                  0.958
# Method:                 Least Squares   F-statistic:                     681.2
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           4.75e-79
# Time:                        14:42:18   Log-Likelihood:                 360.20
# No. Observations:                 120   AIC:                            -710.4
# Df Residuals:                     115   BIC:                            -696.5
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0018      0.001      1.530      0.129      -0.001       0.004
# mktrf          1.0204      0.028     36.577      0.000       0.965       1.076
# smb            0.3693      0.032     11.628      0.000       0.306       0.432
# hml            0.1040      0.032      3.270      0.001       0.041       0.167
# umd           -0.1807      0.020     -9.211      0.000      -0.220      -0.142
# ==============================================================================
# Omnibus:                        7.029   Durbin-Watson:                   1.784
# Prob(Omnibus):                  0.030   Jarque-Bera (JB):                8.915
# Skew:                          -0.314   Prob(JB):                       0.0116
# Kurtosis:                       4.179   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.960
# Model:                            OLS   Adj. R-squared:                  0.958
# Method:                 Least Squares   F-statistic:                     1288.
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           1.85e-94
# Time:                        14:42:18   Log-Likelihood:                 360.20
# No. Observations:                 120   AIC:                            -710.4
# Df Residuals:                     115   BIC:                            -696.5
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0018      0.001      1.376      0.169      -0.001       0.004
# mktrf          1.0204      0.019     52.771      0.000       0.982       1.058
# smb            0.3693      0.051      7.193      0.000       0.269       0.470
# hml            0.1040      0.040      2.576      0.010       0.025       0.183
# umd           -0.1807      0.031     -5.918      0.000      -0.240      -0.121
# ==============================================================================
# Omnibus:                        7.029   Durbin-Watson:                   1.784
# Prob(Omnibus):                  0.030   Jarque-Bera (JB):                8.915
# Skew:                          -0.314   Prob(JB):                       0.0116
# Kurtosis:                       4.179   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.960
# Model:                            OLS   Adj. R-squared:                  0.958
# Method:                 Least Squares   F-statistic:                     1711.
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):          2.03e-101
# Time:                        14:42:18   Log-Likelihood:                 360.20
# No. Observations:                 120   AIC:                            -710.4
# Df Residuals:                     115   BIC:                            -696.5
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0018      0.001      1.477      0.140      -0.001       0.004
# mktrf          1.0204      0.018     55.275      0.000       0.984       1.057
# smb            0.3693      0.053      6.924      0.000       0.265       0.474
# hml            0.1040      0.042      2.456      0.014       0.021       0.187
# umd           -0.1807      0.027     -6.630      0.000      -0.234      -0.127
# ==============================================================================
# Omnibus:                        7.029   Durbin-Watson:                   1.784
# Prob(Omnibus):                  0.030   Jarque-Bera (JB):                8.915
# Skew:                          -0.314   Prob(JB):                       0.0116
# Kurtosis:                       4.179   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Post-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.981
# Model:                            OLS   Adj. R-squared:                  0.980
# Method:                 Least Squares   F-statistic:                     1417.
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           5.86e-93
# Time:                        14:42:18   Log-Likelihood:                 425.85
# No. Observations:                 114   AIC:                            -841.7
# Df Residuals:                     109   BIC:                            -828.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0013      0.001      2.171      0.032       0.000       0.002
# mktrf          0.8837      0.017     50.906      0.000       0.849       0.918
# me             0.4716      0.027     17.598      0.000       0.419       0.525
# ia             0.0412      0.037      1.108      0.270      -0.032       0.115
# roe           -0.3007      0.033     -9.206      0.000      -0.365      -0.236
# ==============================================================================
# Omnibus:                       46.540   Durbin-Watson:                   2.042
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              226.780
# Skew:                           1.253   Prob(JB):                     5.69e-50
# Kurtosis:                       9.439   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.981
# Model:                            OLS   Adj. R-squared:                  0.980
# Method:                 Least Squares   F-statistic:                     1074.
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           1.48e-86
# Time:                        14:42:18   Log-Likelihood:                 425.85
# No. Observations:                 114   AIC:                            -841.7
# Df Residuals:                     109   BIC:                            -828.0
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0013      0.001      2.449      0.014       0.000       0.002
# mktrf          0.8837      0.021     42.737      0.000       0.843       0.924
# me             0.4716      0.033     14.282      0.000       0.407       0.536
# ia             0.0412      0.044      0.933      0.351      -0.045       0.128
# roe           -0.3007      0.043     -7.004      0.000      -0.385      -0.217
# ==============================================================================
# Omnibus:                       46.540   Durbin-Watson:                   2.042
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              226.780
# Skew:                           1.253   Prob(JB):                     5.69e-50
# Kurtosis:                       9.439   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.981
# Model:                            OLS   Adj. R-squared:                  0.980
# Method:                 Least Squares   F-statistic:                     1617.
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           4.95e-96
# Time:                        14:42:18   Log-Likelihood:                 425.85
# No. Observations:                 114   AIC:                            -841.7
# Df Residuals:                     109   BIC:                            -828.0
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0013      0.000      2.643      0.008       0.000       0.002
# mktrf          0.8837      0.021     42.314      0.000       0.843       0.925
# me             0.4716      0.037     12.800      0.000       0.399       0.544
# ia             0.0412      0.046      0.886      0.376      -0.050       0.132
# roe           -0.3007      0.045     -6.635      0.000      -0.390      -0.212
# ==============================================================================
# Omnibus:                       46.540   Durbin-Watson:                   2.042
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              226.780
# Skew:                           1.253   Prob(JB):                     5.69e-50
# Kurtosis:                       9.439   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.975
# Model:                            OLS   Adj. R-squared:                  0.974
# Method:                 Least Squares   F-statistic:                     1071.
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           1.74e-86
# Time:                        14:42:18   Log-Likelihood:                 410.26
# No. Observations:                 114   AIC:                            -810.5
# Df Residuals:                     109   BIC:                            -796.8
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0001      0.001      0.179      0.858      -0.001       0.001
# mktrf          0.9076      0.019     48.119      0.000       0.870       0.945
# smb            0.5249      0.029     17.846      0.000       0.467       0.583
# hml            0.1140      0.030      3.765      0.000       0.054       0.174
# umd           -0.1281      0.023     -5.606      0.000      -0.173      -0.083
# ==============================================================================
# Omnibus:                       18.201   Durbin-Watson:                   1.942
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               27.017
# Skew:                           0.769   Prob(JB):                     1.36e-06
# Kurtosis:                       4.823   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.975
# Model:                            OLS   Adj. R-squared:                  0.974
# Method:                 Least Squares   F-statistic:                     734.3
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           8.03e-78
# Time:                        14:42:18   Log-Likelihood:                 410.26
# No. Observations:                 114   AIC:                            -810.5
# Df Residuals:                     109   BIC:                            -796.8
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0001      0.001      0.182      0.855      -0.001       0.001
# mktrf          0.9076      0.020     44.802      0.000       0.868       0.947
# smb            0.5249      0.029     17.908      0.000       0.467       0.582
# hml            0.1140      0.052      2.202      0.028       0.013       0.216
# umd           -0.1281      0.026     -4.927      0.000      -0.179      -0.077
# ==============================================================================
# Omnibus:                       18.201   Durbin-Watson:                   1.942
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               27.017
# Skew:                           0.769   Prob(JB):                     1.36e-06
# Kurtosis:                       4.823   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.975
# Model:                            OLS   Adj. R-squared:                  0.974
# Method:                 Least Squares   F-statistic:                     1156.
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           2.95e-88
# Time:                        14:42:18   Log-Likelihood:                 410.26
# No. Observations:                 114   AIC:                            -810.5
# Df Residuals:                     109   BIC:                            -796.8
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0001      0.001      0.173      0.863      -0.001       0.001
# mktrf          0.9076      0.019     48.583      0.000       0.871       0.944
# smb            0.5249      0.029     18.414      0.000       0.469       0.581
# hml            0.1140      0.053      2.146      0.032       0.010       0.218
# umd           -0.1281      0.024     -5.321      0.000      -0.175      -0.081
# ==============================================================================
# Omnibus:                       18.201   Durbin-Watson:                   1.942
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               27.017
# Skew:                           0.769   Prob(JB):                     1.36e-06
# Kurtosis:                       4.823   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.975
# Model:                            OLS   Adj. R-squared:                  0.974
# Method:                 Least Squares   F-statistic:                     1071.
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           1.74e-86
# Time:                        14:42:18   Log-Likelihood:                 410.26
# No. Observations:                 114   AIC:                            -810.5
# Df Residuals:                     109   BIC:                            -796.8
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0001      0.001      0.179      0.858      -0.001       0.001
# mktrf          0.9076      0.019     48.119      0.000       0.870       0.945
# smb            0.5249      0.029     17.846      0.000       0.467       0.583
# hml            0.1140      0.030      3.765      0.000       0.054       0.174
# umd           -0.1281      0.023     -5.606      0.000      -0.173      -0.083
# ==============================================================================
# Omnibus:                       18.201   Durbin-Watson:                   1.942
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               27.017
# Skew:                           0.769   Prob(JB):                     1.36e-06
# Kurtosis:                       4.823   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.975
# Model:                            OLS   Adj. R-squared:                  0.974
# Method:                 Least Squares   F-statistic:                     734.3
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           8.03e-78
# Time:                        14:42:18   Log-Likelihood:                 410.26
# No. Observations:                 114   AIC:                            -810.5
# Df Residuals:                     109   BIC:                            -796.8
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0001      0.001      0.182      0.855      -0.001       0.001
# mktrf          0.9076      0.020     44.802      0.000       0.868       0.947
# smb            0.5249      0.029     17.908      0.000       0.467       0.582
# hml            0.1140      0.052      2.202      0.028       0.013       0.216
# umd           -0.1281      0.026     -4.927      0.000      -0.179      -0.077
# ==============================================================================
# Omnibus:                       18.201   Durbin-Watson:                   1.942
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               27.017
# Skew:                           0.769   Prob(JB):                     1.36e-06
# Kurtosis:                       4.823   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.975
# Model:                            OLS   Adj. R-squared:                  0.974
# Method:                 Least Squares   F-statistic:                     1156.
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           2.95e-88
# Time:                        14:42:18   Log-Likelihood:                 410.26
# No. Observations:                 114   AIC:                            -810.5
# Df Residuals:                     109   BIC:                            -796.8
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0001      0.001      0.173      0.863      -0.001       0.001
# mktrf          0.9076      0.019     48.583      0.000       0.871       0.944
# smb            0.5249      0.029     18.414      0.000       0.469       0.581
# hml            0.1140      0.053      2.146      0.032       0.010       0.218
# umd           -0.1281      0.024     -5.321      0.000      -0.175      -0.081
# ==============================================================================
# Omnibus:                       18.201   Durbin-Watson:                   1.942
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               27.017
# Skew:                           0.769   Prob(JB):                     1.36e-06
# Kurtosis:                       4.823   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """
