# %% [markdown]
# # Method 7 - Best Ideas High Minus Low Size

# %%
# %matplotlib inline
import pandas as pd
import warnings
from statsmodels import api as sm

from eptooling import crsp, epd, fs, hfu, crsp, db, bi
from eptooling.bm import bmdb, iso
from epquant.engine import weights, portfolio
from epquant.gen import returns
from epquant.perf import relative_performance

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Fetch Holdings and Benchmark Data

# %%
# Get HFU Data

# %store -r inst_data
inst_data = inst_data[inst_data['datadate'] >= '1999-06-30']

# Size

size = inst_data.groupby(['datadate', 'institution_id'])['pos_val'].sum().rename('size').reset_index()

# Count number of positions per manager

inst_data['num_pos'] = inst_data.groupby(['datadate', 'institution_id'])[
    'fsym_id'].transform(lambda s: s.nunique())

# Remove less than 20 holdings and less than $5mm per CSP

valid_data = inst_data[inst_data['num_pos'] >= 20]
valid_data = valid_data[valid_data['public_aum'] >= 5e6]

# Add Expected Returns from Intra-Cap Portfolio Weight per Shumway, Szefler, Yuan 2009

# %store -r cap_exp_ret

valid_data = valid_data.merge(cap_exp_ret, on=['datadate', 'institution_id', 'fsym_id'], how='left')

# Calculate CSP Weight per Market Tilt

valid_data['adj_target'] = valid_data['expected_return']

# %% [markdown]
# ## Calculate Best Ideas

# %%
# Extract Best Ideas

valid_data['pos_rank'] = valid_data\
    .groupby(['datadate', 'institution_id'])['adj_target'].rank(ascending=False)

best_ideas = valid_data[valid_data['pos_rank'] == 1].copy()

# Add Size

best_ideas = best_ideas.merge(size)
best_ideas['size_pct'] = best_ideas.groupby('datadate')['size'].rank(pct=True)
low_ideas = best_ideas[best_ideas['size_pct'] < (1 / 3)]
high_ideas = best_ideas[best_ideas['size_pct'] > (2 / 3)]

# Weight the best ideas equally

low_ideas['target'] = 1 / low_ideas.groupby('datadate')['institution_id'].transform('count')
high_ideas['target'] = 1 / high_ideas.groupby('datadate')['institution_id'].transform('count')

# %% [markdown]
# ## Backtest Portfolio

# %%
low_w = weights.Weights(low_ideas)
high_w = weights.Weights(high_ideas)

# %store -r r

low_p = portfolio.DailyPortfolio(low_w, r, end_date='2018-12-31')
high_p = portfolio.DailyPortfolio(high_w, r, end_date='2018-12-31')

monthly_return = (high_p.port_return - low_p.port_return).loc['1999-07-01':].resample('M').apply(epd.prod_red)
monthly_return.name = 'port_return'

# %% [markdown]
# ## Plot Performance

# %%
epd.nav(monthly_return).plot()

# %%
monthly_return.resample('A').apply(epd.prod_red)
# Out:
# datadate
# 1999-12-31    0.025888
# 2000-12-31   -0.173923
# 2001-12-31   -0.327006
# 2002-12-31   -0.133982
# 2003-12-31   -0.116989
# 2004-12-31   -0.074017
# 2005-12-31    0.030882
# 2006-12-31   -0.132680
# 2007-12-31    0.129775
# 2008-12-31   -0.001786
# 2009-12-31   -0.073357
# 2010-12-31   -0.073627
# 2011-12-31    0.011922
# 2012-12-31    0.154348
# 2013-12-31   -0.016559
# 2014-12-31    0.157801
# 2015-12-31   -0.045251
# 2016-12-31   -0.019337
# 2017-12-31    0.046505
# 2018-12-31    0.003927
# Freq: A-DEC, Name: port_return, dtype: float64

# %% [markdown]
# ## Fetch Factor Models

# %%
# Get Factor Models
q_factor_model = bi.get_q_factor_model()
fama_french_five_factor_model = bi.get_fama_french_five_factor_model()
four_factor_model = bi.get_four_factor_model()

# Concat Portfolio Return
q_factor = pd.concat([monthly_return, q_factor_model], axis=1)
fama_french_five = pd.concat([monthly_return, fama_french_five_factor_model], axis=1)
four_factor = pd.concat([monthly_return, four_factor_model], axis=1)

# Add Constants
q_factor.insert(1, 'const', 1)
fama_french_five.insert(1, 'const', 1)
four_factor.insert(1, 'const', 1)

# Split Period into Pre and Post Crisis
q_factor_pre, q_factor_post = q_factor.loc[:'2009-06-30'], q_factor.loc['2009-07-31':]
fama_french_five_pre, fama_french_five_post = fama_french_five.loc[:'2009-06-30'], fama_french_five.loc['2009-07-31':] 
four_factor_pre, four_factor_post = four_factor.loc[:'2009-06-30'], four_factor.loc['2009-07-31':]

# %% [markdown]
# ## Full Time Period Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.143
# Model:                            OLS   Adj. R-squared:                  0.129
# Method:                 Least Squares   F-statistic:                     9.591
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           3.46e-07
# Time:                        13:15:49   Log-Likelihood:                 549.52
# No. Observations:                 234   AIC:                            -1089.
# Df Residuals:                     229   BIC:                            -1072.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0028      0.002     -1.778      0.077      -0.006       0.000
# mktrf          0.1168      0.044      2.680      0.008       0.031       0.203
# me            -0.1086      0.051     -2.142      0.033      -0.208      -0.009
# ia            -0.3664      0.077     -4.756      0.000      -0.518      -0.215
# roe            0.1376      0.066      2.086      0.038       0.008       0.268
# ==============================================================================
# Omnibus:                       16.386   Durbin-Watson:                   2.152
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               32.551
# Skew:                           0.337   Prob(JB):                     8.54e-08
# Kurtosis:                       4.698   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.143
# Model:                            OLS   Adj. R-squared:                  0.129
# Method:                 Least Squares   F-statistic:                     10.76
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           5.19e-08
# Time:                        13:15:49   Log-Likelihood:                 549.52
# No. Observations:                 234   AIC:                            -1089.
# Df Residuals:                     229   BIC:                            -1072.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0028      0.002     -1.501      0.133      -0.007       0.001
# mktrf          0.1168      0.053      2.210      0.027       0.013       0.220
# me            -0.1086      0.082     -1.329      0.184      -0.269       0.052
# ia            -0.3664      0.080     -4.566      0.000      -0.524      -0.209
# roe            0.1376      0.081      1.688      0.091      -0.022       0.297
# ==============================================================================
# Omnibus:                       16.386   Durbin-Watson:                   2.152
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               32.551
# Skew:                           0.337   Prob(JB):                     8.54e-08
# Kurtosis:                       4.698   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.143
# Model:                            OLS   Adj. R-squared:                  0.129
# Method:                 Least Squares   F-statistic:                     12.71
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.32e-09
# Time:                        13:15:49   Log-Likelihood:                 549.52
# No. Observations:                 234   AIC:                            -1089.
# Df Residuals:                     229   BIC:                            -1072.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0028      0.002     -1.267      0.205      -0.007       0.002
# mktrf          0.1168      0.057      2.040      0.041       0.005       0.229
# me            -0.1086      0.080     -1.360      0.174      -0.265       0.048
# ia            -0.3664      0.088     -4.172      0.000      -0.539      -0.194
# roe            0.1376      0.092      1.500      0.134      -0.042       0.317
# ==============================================================================
# Omnibus:                       16.386   Durbin-Watson:                   2.152
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               32.551
# Skew:                           0.337   Prob(JB):                     8.54e-08
# Kurtosis:                       4.698   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.136
# Model:                            OLS   Adj. R-squared:                  0.121
# Method:                 Least Squares   F-statistic:                     9.027
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           8.70e-07
# Time:                        13:15:49   Log-Likelihood:                 548.53
# No. Observations:                 234   AIC:                            -1087.
# Df Residuals:                     229   BIC:                            -1070.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0028      0.002     -1.823      0.070      -0.006       0.000
# mktrf          0.1201      0.040      2.981      0.003       0.041       0.200
# smb           -0.1556      0.050     -3.094      0.002      -0.255      -0.057
# hml           -0.2394      0.050     -4.792      0.000      -0.338      -0.141
# umd            0.0480      0.033      1.464      0.145      -0.017       0.113
# ==============================================================================
# Omnibus:                        9.104   Durbin-Watson:                   2.122
# Prob(Omnibus):                  0.011   Jarque-Bera (JB):               12.741
# Skew:                           0.262   Prob(JB):                      0.00171
# Kurtosis:                       4.016   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.136
# Model:                            OLS   Adj. R-squared:                  0.121
# Method:                 Least Squares   F-statistic:                     6.726
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           3.90e-05
# Time:                        13:15:49   Log-Likelihood:                 548.53
# No. Observations:                 234   AIC:                            -1087.
# Df Residuals:                     229   BIC:                            -1070.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0028      0.002     -1.722      0.085      -0.006       0.000
# mktrf          0.1201      0.049      2.469      0.014       0.025       0.215
# smb           -0.1556      0.060     -2.613      0.009      -0.272      -0.039
# hml           -0.2394      0.069     -3.482      0.000      -0.374      -0.105
# umd            0.0480      0.048      1.007      0.314      -0.045       0.141
# ==============================================================================
# Omnibus:                        9.104   Durbin-Watson:                   2.122
# Prob(Omnibus):                  0.011   Jarque-Bera (JB):               12.741
# Skew:                           0.262   Prob(JB):                      0.00171
# Kurtosis:                       4.016   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.136
# Model:                            OLS   Adj. R-squared:                  0.121
# Method:                 Least Squares   F-statistic:                     6.628
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           4.60e-05
# Time:                        13:15:49   Log-Likelihood:                 548.53
# No. Observations:                 234   AIC:                            -1087.
# Df Residuals:                     229   BIC:                            -1070.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0028      0.002     -1.497      0.134      -0.007       0.001
# mktrf          0.1201      0.055      2.165      0.030       0.011       0.229
# smb           -0.1556      0.050     -3.122      0.002      -0.253      -0.058
# hml           -0.2394      0.076     -3.139      0.002      -0.389      -0.090
# umd            0.0480      0.044      1.100      0.271      -0.037       0.133
# ==============================================================================
# Omnibus:                        9.104   Durbin-Watson:                   2.122
# Prob(Omnibus):                  0.011   Jarque-Bera (JB):               12.741
# Skew:                           0.262   Prob(JB):                      0.00171
# Kurtosis:                       4.016   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.136
# Model:                            OLS   Adj. R-squared:                  0.121
# Method:                 Least Squares   F-statistic:                     9.027
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           8.70e-07
# Time:                        13:15:49   Log-Likelihood:                 548.53
# No. Observations:                 234   AIC:                            -1087.
# Df Residuals:                     229   BIC:                            -1070.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0028      0.002     -1.823      0.070      -0.006       0.000
# mktrf          0.1201      0.040      2.981      0.003       0.041       0.200
# smb           -0.1556      0.050     -3.094      0.002      -0.255      -0.057
# hml           -0.2394      0.050     -4.792      0.000      -0.338      -0.141
# umd            0.0480      0.033      1.464      0.145      -0.017       0.113
# ==============================================================================
# Omnibus:                        9.104   Durbin-Watson:                   2.122
# Prob(Omnibus):                  0.011   Jarque-Bera (JB):               12.741
# Skew:                           0.262   Prob(JB):                      0.00171
# Kurtosis:                       4.016   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.136
# Model:                            OLS   Adj. R-squared:                  0.121
# Method:                 Least Squares   F-statistic:                     6.726
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           3.90e-05
# Time:                        13:15:49   Log-Likelihood:                 548.53
# No. Observations:                 234   AIC:                            -1087.
# Df Residuals:                     229   BIC:                            -1070.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0028      0.002     -1.722      0.085      -0.006       0.000
# mktrf          0.1201      0.049      2.469      0.014       0.025       0.215
# smb           -0.1556      0.060     -2.613      0.009      -0.272      -0.039
# hml           -0.2394      0.069     -3.482      0.000      -0.374      -0.105
# umd            0.0480      0.048      1.007      0.314      -0.045       0.141
# ==============================================================================
# Omnibus:                        9.104   Durbin-Watson:                   2.122
# Prob(Omnibus):                  0.011   Jarque-Bera (JB):               12.741
# Skew:                           0.262   Prob(JB):                      0.00171
# Kurtosis:                       4.016   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.136
# Model:                            OLS   Adj. R-squared:                  0.121
# Method:                 Least Squares   F-statistic:                     6.628
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           4.60e-05
# Time:                        13:15:49   Log-Likelihood:                 548.53
# No. Observations:                 234   AIC:                            -1087.
# Df Residuals:                     229   BIC:                            -1070.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0028      0.002     -1.497      0.134      -0.007       0.001
# mktrf          0.1201      0.055      2.165      0.030       0.011       0.229
# smb           -0.1556      0.050     -3.122      0.002      -0.253      -0.058
# hml           -0.2394      0.076     -3.139      0.002      -0.389      -0.090
# umd            0.0480      0.044      1.100      0.271      -0.037       0.133
# ==============================================================================
# Omnibus:                        9.104   Durbin-Watson:                   2.122
# Prob(Omnibus):                  0.011   Jarque-Bera (JB):               12.741
# Skew:                           0.262   Prob(JB):                      0.00171
# Kurtosis:                       4.016   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Pre-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.244
# Model:                            OLS   Adj. R-squared:                  0.218
# Method:                 Least Squares   F-statistic:                     9.270
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.58e-06
# Time:                        13:15:49   Log-Likelihood:                 272.56
# No. Observations:                 120   AIC:                            -535.1
# Df Residuals:                     115   BIC:                            -521.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0066      0.002     -2.727      0.007      -0.011      -0.002
# mktrf          0.2001      0.066      3.044      0.003       0.070       0.330
# me            -0.0545      0.065     -0.840      0.403      -0.183       0.074
# ia            -0.4697      0.102     -4.620      0.000      -0.671      -0.268
# roe            0.2942      0.090      3.269      0.001       0.116       0.472
# ==============================================================================
# Omnibus:                       10.438   Durbin-Watson:                   2.219
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):               15.063
# Skew:                           0.433   Prob(JB):                     0.000536
# Kurtosis:                       4.505   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.244
# Model:                            OLS   Adj. R-squared:                  0.218
# Method:                 Least Squares   F-statistic:                     25.12
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           5.78e-15
# Time:                        13:15:49   Log-Likelihood:                 272.56
# No. Observations:                 120   AIC:                            -535.1
# Df Residuals:                     115   BIC:                            -521.2
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0066      0.003     -2.478      0.013      -0.012      -0.001
# mktrf          0.2001      0.067      3.004      0.003       0.070       0.331
# me            -0.0545      0.110     -0.497      0.619      -0.269       0.160
# ia            -0.4697      0.076     -6.204      0.000      -0.618      -0.321
# roe            0.2942      0.098      3.016      0.003       0.103       0.485
# ==============================================================================
# Omnibus:                       10.438   Durbin-Watson:                   2.219
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):               15.063
# Skew:                           0.433   Prob(JB):                     0.000536
# Kurtosis:                       4.505   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.244
# Model:                            OLS   Adj. R-squared:                  0.218
# Method:                 Least Squares   F-statistic:                     41.06
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.45e-21
# Time:                        13:15:49   Log-Likelihood:                 272.56
# No. Observations:                 120   AIC:                            -535.1
# Df Residuals:                     115   BIC:                            -521.2
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0066      0.003     -2.110      0.035      -0.013      -0.000
# mktrf          0.2001      0.068      2.922      0.003       0.066       0.334
# me            -0.0545      0.115     -0.475      0.635      -0.279       0.170
# ia            -0.4697      0.071     -6.596      0.000      -0.609      -0.330
# roe            0.2942      0.104      2.831      0.005       0.090       0.498
# ==============================================================================
# Omnibus:                       10.438   Durbin-Watson:                   2.219
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):               15.063
# Skew:                           0.433   Prob(JB):                     0.000536
# Kurtosis:                       4.505   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.218
# Model:                            OLS   Adj. R-squared:                  0.191
# Method:                 Least Squares   F-statistic:                     8.032
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           9.54e-06
# Time:                        13:15:49   Log-Likelihood:                 270.57
# No. Observations:                 120   AIC:                            -531.1
# Df Residuals:                     115   BIC:                            -517.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0054      0.002     -2.241      0.027      -0.010      -0.001
# mktrf          0.1832      0.059      3.111      0.002       0.067       0.300
# smb           -0.1988      0.067     -2.966      0.004      -0.332      -0.066
# hml           -0.2784      0.067     -4.146      0.000      -0.411      -0.145
# umd            0.0955      0.041      2.308      0.023       0.014       0.178
# ==============================================================================
# Omnibus:                        2.160   Durbin-Watson:                   2.128
# Prob(Omnibus):                  0.340   Jarque-Bera (JB):                1.622
# Skew:                           0.229   Prob(JB):                        0.444
# Kurtosis:                       3.340   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.218
# Model:                            OLS   Adj. R-squared:                  0.191
# Method:                 Least Squares   F-statistic:                     11.62
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           5.87e-08
# Time:                        13:15:49   Log-Likelihood:                 270.57
# No. Observations:                 120   AIC:                            -531.1
# Df Residuals:                     115   BIC:                            -517.2
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0054      0.002     -2.545      0.011      -0.010      -0.001
# mktrf          0.1832      0.051      3.577      0.000       0.083       0.284
# smb           -0.1988      0.067     -2.976      0.003      -0.330      -0.068
# hml           -0.2784      0.075     -3.698      0.000      -0.426      -0.131
# umd            0.0955      0.049      1.951      0.051      -0.000       0.192
# ==============================================================================
# Omnibus:                        2.160   Durbin-Watson:                   2.128
# Prob(Omnibus):                  0.340   Jarque-Bera (JB):                1.622
# Skew:                           0.229   Prob(JB):                        0.444
# Kurtosis:                       3.340   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.218
# Model:                            OLS   Adj. R-squared:                  0.191
# Method:                 Least Squares   F-statistic:                     20.33
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.09e-12
# Time:                        13:15:49   Log-Likelihood:                 270.57
# No. Observations:                 120   AIC:                            -531.1
# Df Residuals:                     115   BIC:                            -517.2
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0054      0.002     -2.213      0.027      -0.010      -0.001
# mktrf          0.1832      0.048      3.806      0.000       0.089       0.277
# smb           -0.1988      0.054     -3.698      0.000      -0.304      -0.093
# hml           -0.2784      0.076     -3.662      0.000      -0.427      -0.129
# umd            0.0955      0.041      2.304      0.021       0.014       0.177
# ==============================================================================
# Omnibus:                        2.160   Durbin-Watson:                   2.128
# Prob(Omnibus):                  0.340   Jarque-Bera (JB):                1.622
# Skew:                           0.229   Prob(JB):                        0.444
# Kurtosis:                       3.340   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.218
# Model:                            OLS   Adj. R-squared:                  0.191
# Method:                 Least Squares   F-statistic:                     8.032
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           9.54e-06
# Time:                        13:15:49   Log-Likelihood:                 270.57
# No. Observations:                 120   AIC:                            -531.1
# Df Residuals:                     115   BIC:                            -517.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0054      0.002     -2.241      0.027      -0.010      -0.001
# mktrf          0.1832      0.059      3.111      0.002       0.067       0.300
# smb           -0.1988      0.067     -2.966      0.004      -0.332      -0.066
# hml           -0.2784      0.067     -4.146      0.000      -0.411      -0.145
# umd            0.0955      0.041      2.308      0.023       0.014       0.178
# ==============================================================================
# Omnibus:                        2.160   Durbin-Watson:                   2.128
# Prob(Omnibus):                  0.340   Jarque-Bera (JB):                1.622
# Skew:                           0.229   Prob(JB):                        0.444
# Kurtosis:                       3.340   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.218
# Model:                            OLS   Adj. R-squared:                  0.191
# Method:                 Least Squares   F-statistic:                     11.62
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           5.87e-08
# Time:                        13:15:49   Log-Likelihood:                 270.57
# No. Observations:                 120   AIC:                            -531.1
# Df Residuals:                     115   BIC:                            -517.2
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0054      0.002     -2.545      0.011      -0.010      -0.001
# mktrf          0.1832      0.051      3.577      0.000       0.083       0.284
# smb           -0.1988      0.067     -2.976      0.003      -0.330      -0.068
# hml           -0.2784      0.075     -3.698      0.000      -0.426      -0.131
# umd            0.0955      0.049      1.951      0.051      -0.000       0.192
# ==============================================================================
# Omnibus:                        2.160   Durbin-Watson:                   2.128
# Prob(Omnibus):                  0.340   Jarque-Bera (JB):                1.622
# Skew:                           0.229   Prob(JB):                        0.444
# Kurtosis:                       3.340   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.218
# Model:                            OLS   Adj. R-squared:                  0.191
# Method:                 Least Squares   F-statistic:                     20.33
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.09e-12
# Time:                        13:15:49   Log-Likelihood:                 270.57
# No. Observations:                 120   AIC:                            -531.1
# Df Residuals:                     115   BIC:                            -517.2
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0054      0.002     -2.213      0.027      -0.010      -0.001
# mktrf          0.1832      0.048      3.806      0.000       0.089       0.277
# smb           -0.1988      0.054     -3.698      0.000      -0.304      -0.093
# hml           -0.2784      0.076     -3.662      0.000      -0.427      -0.129
# umd            0.0955      0.041      2.304      0.021       0.014       0.177
# ==============================================================================
# Omnibus:                        2.160   Durbin-Watson:                   2.128
# Prob(Omnibus):                  0.340   Jarque-Bera (JB):                1.622
# Skew:                           0.229   Prob(JB):                        0.444
# Kurtosis:                       3.340   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Post-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.033
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.9362
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):              0.446
# Time:                        13:15:49   Log-Likelihood:                 290.58
# No. Observations:                 114   AIC:                            -571.2
# Df Residuals:                     109   BIC:                            -557.5
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0019      0.002      1.007      0.316      -0.002       0.006
# mktrf          0.0004      0.057      0.007      0.995      -0.112       0.113
# me            -0.1396      0.088     -1.590      0.115      -0.314       0.034
# ia            -0.1022      0.122     -0.839      0.403      -0.344       0.139
# roe           -0.0692      0.107     -0.647      0.519      -0.281       0.143
# ==============================================================================
# Omnibus:                       16.297   Durbin-Watson:                   2.056
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               25.785
# Skew:                           0.661   Prob(JB):                     2.52e-06
# Kurtosis:                       4.919   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.033
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                     2.000
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):             0.0996
# Time:                        13:15:49   Log-Likelihood:                 290.58
# No. Observations:                 114   AIC:                            -571.2
# Df Residuals:                     109   BIC:                            -557.5
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0019      0.002      0.895      0.371      -0.002       0.006
# mktrf          0.0004      0.067      0.006      0.995      -0.132       0.132
# me            -0.1396      0.059     -2.354      0.019      -0.256      -0.023
# ia            -0.1022      0.079     -1.295      0.195      -0.257       0.052
# roe           -0.0692      0.085     -0.811      0.418      -0.237       0.098
# ==============================================================================
# Omnibus:                       16.297   Durbin-Watson:                   2.056
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               25.785
# Skew:                           0.661   Prob(JB):                     2.52e-06
# Kurtosis:                       4.919   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.033
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                     2.025
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):             0.0960
# Time:                        13:15:49   Log-Likelihood:                 290.58
# No. Observations:                 114   AIC:                            -571.2
# Df Residuals:                     109   BIC:                            -557.5
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0019      0.002      0.859      0.390      -0.002       0.006
# mktrf          0.0004      0.067      0.006      0.995      -0.130       0.131
# me            -0.1396      0.053     -2.617      0.009      -0.244      -0.035
# ia            -0.1022      0.079     -1.297      0.195      -0.257       0.052
# roe           -0.0692      0.087     -0.798      0.425      -0.239       0.101
# ==============================================================================
# Omnibus:                       16.297   Durbin-Watson:                   2.056
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               25.785
# Skew:                           0.661   Prob(JB):                     2.52e-06
# Kurtosis:                       4.919   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.034
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.9627
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):              0.431
# Time:                        13:15:49   Log-Likelihood:                 290.64
# No. Observations:                 114   AIC:                            -571.3
# Df Residuals:                     109   BIC:                            -557.6
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0020      0.002      1.033      0.304      -0.002       0.006
# mktrf         -0.0158      0.054     -0.294      0.770      -0.123       0.091
# smb           -0.0870      0.084     -1.036      0.303      -0.253       0.079
# hml           -0.1105      0.086     -1.278      0.204      -0.282       0.061
# umd           -0.0639      0.065     -0.980      0.329      -0.193       0.065
# ==============================================================================
# Omnibus:                        9.597   Durbin-Watson:                   2.059
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):               11.733
# Skew:                           0.481   Prob(JB):                      0.00283
# Kurtosis:                       4.242   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.034
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                     2.054
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):             0.0918
# Time:                        13:15:49   Log-Likelihood:                 290.64
# No. Observations:                 114   AIC:                            -571.3
# Df Residuals:                     109   BIC:                            -557.6
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0020      0.002      0.845      0.398      -0.003       0.007
# mktrf         -0.0158      0.075     -0.210      0.833      -0.163       0.131
# smb           -0.0870      0.060     -1.446      0.148      -0.205       0.031
# hml           -0.1105      0.086     -1.279      0.201      -0.280       0.059
# umd           -0.0639      0.095     -0.671      0.502      -0.251       0.123
# ==============================================================================
# Omnibus:                        9.597   Durbin-Watson:                   2.059
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):               11.733
# Skew:                           0.481   Prob(JB):                      0.00283
# Kurtosis:                       4.242   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.034
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                     2.965
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):             0.0228
# Time:                        13:15:49   Log-Likelihood:                 290.64
# No. Observations:                 114   AIC:                            -571.3
# Df Residuals:                     109   BIC:                            -557.6
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0020      0.002      0.804      0.422      -0.003       0.007
# mktrf         -0.0158      0.078     -0.202      0.840      -0.169       0.138
# smb           -0.0870      0.054     -1.626      0.104      -0.192       0.018
# hml           -0.1105      0.079     -1.391      0.164      -0.266       0.045
# umd           -0.0639      0.094     -0.677      0.499      -0.249       0.121
# ==============================================================================
# Omnibus:                        9.597   Durbin-Watson:                   2.059
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):               11.733
# Skew:                           0.481   Prob(JB):                      0.00283
# Kurtosis:                       4.242   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.034
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.9627
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):              0.431
# Time:                        13:15:49   Log-Likelihood:                 290.64
# No. Observations:                 114   AIC:                            -571.3
# Df Residuals:                     109   BIC:                            -557.6
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0020      0.002      1.033      0.304      -0.002       0.006
# mktrf         -0.0158      0.054     -0.294      0.770      -0.123       0.091
# smb           -0.0870      0.084     -1.036      0.303      -0.253       0.079
# hml           -0.1105      0.086     -1.278      0.204      -0.282       0.061
# umd           -0.0639      0.065     -0.980      0.329      -0.193       0.065
# ==============================================================================
# Omnibus:                        9.597   Durbin-Watson:                   2.059
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):               11.733
# Skew:                           0.481   Prob(JB):                      0.00283
# Kurtosis:                       4.242   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.034
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                     2.054
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):             0.0918
# Time:                        13:15:49   Log-Likelihood:                 290.64
# No. Observations:                 114   AIC:                            -571.3
# Df Residuals:                     109   BIC:                            -557.6
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0020      0.002      0.845      0.398      -0.003       0.007
# mktrf         -0.0158      0.075     -0.210      0.833      -0.163       0.131
# smb           -0.0870      0.060     -1.446      0.148      -0.205       0.031
# hml           -0.1105      0.086     -1.279      0.201      -0.280       0.059
# umd           -0.0639      0.095     -0.671      0.502      -0.251       0.123
# ==============================================================================
# Omnibus:                        9.597   Durbin-Watson:                   2.059
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):               11.733
# Skew:                           0.481   Prob(JB):                      0.00283
# Kurtosis:                       4.242   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.034
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                     2.965
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):             0.0228
# Time:                        13:15:49   Log-Likelihood:                 290.64
# No. Observations:                 114   AIC:                            -571.3
# Df Residuals:                     109   BIC:                            -557.6
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0020      0.002      0.804      0.422      -0.003       0.007
# mktrf         -0.0158      0.078     -0.202      0.840      -0.169       0.138
# smb           -0.0870      0.054     -1.626      0.104      -0.192       0.018
# hml           -0.1105      0.079     -1.391      0.164      -0.266       0.045
# umd           -0.0639      0.094     -0.677      0.499      -0.249       0.121
# ==============================================================================
# Omnibus:                        9.597   Durbin-Watson:                   2.059
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):               11.733
# Skew:                           0.481   Prob(JB):                      0.00283
# Kurtosis:                       4.242   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """
