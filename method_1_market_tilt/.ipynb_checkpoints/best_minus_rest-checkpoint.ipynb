# %% [markdown]
# # Method 1 - Best Minus Rest

# %%
# %matplotlib inline
import pandas as pd
import warnings
from statsmodels import api as sm

from eptooling import crsp, epd, fs, hfu, crsp, db, bi
from eptooling.bm import bmdb, iso
from epquant.engine import weights, portfolio
from epquant.gen import returns
from epquant.perf import relative_performance

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Fetch Holdings and Benchmark Data

# %%
# Get HFU Data

# %store -r inst_data
inst_data = inst_data[inst_data['datadate'] >= '1999-06-30']

# Count number of positions per manager

inst_data['num_pos'] = inst_data.groupby(['datadate', 'institution_id'])[
    'fsym_id'].transform(lambda s: s.nunique())

# Remove less than 20 holdings and less than $5mm per CSP

valid_data = inst_data[inst_data['num_pos'] >= 20]
valid_data = valid_data[valid_data['public_aum'] >= 5e6]

# Get Benchmark Weights

bm = crsp.get_crsp_market_portfolio()

# Merge Benchmark Weights onto Holdings

valid_data = valid_data.merge(bm, how='left', on=['datadate', 'fsym_id'])

# Calculate Market Tilt

valid_data['adj_target'] = valid_data['target'] - valid_data['weight'].fillna(0)

# %% [markdown]
# ## Calculate Best Ideas

# %%
# Extract Best Ideas

valid_data['pos_rank'] = valid_data\
    .groupby(['datadate', 'institution_id'])['adj_target'].rank(ascending=False)

                                                                                         
# Split Long and Short and Filter to Highest Tilts

long_ideas = valid_data[valid_data['pos_rank'] == 1].copy()                                                                           
short_ideas = valid_data[valid_data['pos_rank'] != 1].copy()

# Weight the best ideas equally

long_ideas['target'] = 1 / long_ideas.groupby('datadate')[
    'institution_id'].transform('count')

short_ideas['target'] = - short_ideas['target'] / short_ideas.groupby([
    'datadate', 'institution_id'])['target'].transform('sum') * \
                        (1 / short_ideas.groupby('datadate')['institution_id']
                         .transform(lambda s: s.nunique()))

best_ideas = pd.concat([long_ideas, short_ideas])

# %% [markdown]
# ## Backtest Portfolio

# %%
w = weights.Weights(best_ideas)

# %store -r r

p = portfolio.DailyPortfolio(w, r, end_date='2018-12-31')

monthly_return = p.port_return.loc['1999-07-01':].resample('M').apply(epd.prod_red)
monthly_return.name = 'port_return'

# %% [markdown]
# ## Plot Performance

# %%
epd.nav(monthly_return).plot()

# %%
monthly_return.resample('A').apply(epd.prod_red)
# Out:
# datadate
# 1999-12-31    0.126891
# 2000-12-31   -0.087612
# 2001-12-31   -0.081193
# 2002-12-31    0.013260
# 2003-12-31   -0.046614
# 2004-12-31    0.030404
# 2005-12-31    0.039466
# 2006-12-31    0.016965
# 2007-12-31    0.063924
# 2008-12-31   -0.000548
# 2009-12-31   -0.072370
# 2010-12-31   -0.006007
# 2011-12-31    0.009311
# 2012-12-31    0.006034
# 2013-12-31    0.045734
# 2014-12-31    0.003388
# 2015-12-31    0.003159
# 2016-12-31   -0.049274
# 2017-12-31   -0.007800
# 2018-12-31    0.030676
# Freq: A-DEC, Name: port_return, dtype: float64

# %% [markdown]
# ## Fetch Factor Models

# %%
# Get Factor Models
q_factor_model = bi.get_q_factor_model()
fama_french_five_factor_model = bi.get_fama_french_five_factor_model()
four_factor_model = bi.get_four_factor_model()

# Concat Portfolio Return
q_factor = pd.concat([monthly_return, q_factor_model], axis=1)
fama_french_five = pd.concat([monthly_return, fama_french_five_factor_model], axis=1)
four_factor = pd.concat([monthly_return, four_factor_model], axis=1)

# Add Constants
q_factor.insert(1, 'const', 1)
fama_french_five.insert(1, 'const', 1)
four_factor.insert(1, 'const', 1)

# Split Period into Pre and Post Crisis
q_factor_pre, q_factor_post = q_factor.loc[:'2009-06-30'], q_factor.loc['2009-07-31':]
fama_french_five_pre, fama_french_five_post = fama_french_five.loc[:'2009-06-30'], fama_french_five.loc['2009-07-31':] 
four_factor_pre, four_factor_post = four_factor.loc[:'2009-06-30'], four_factor.loc['2009-07-31':]

# %% [markdown]
# ## Full Time Period Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.304
# Model:                            OLS   Adj. R-squared:                  0.292
# Method:                 Least Squares   F-statistic:                     24.97
# Date:                Mon, 27 Apr 2020   Prob (F-statistic):           3.59e-17
# Time:                        08:51:46   Log-Likelihood:                 735.09
# No. Observations:                 234   AIC:                            -1460.
# Df Residuals:                     229   BIC:                            -1443.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.001     -0.438      0.662      -0.002       0.001
# mktrf         -0.0404      0.020     -2.049      0.042      -0.079      -0.002
# me             0.0459      0.023      2.003      0.046       0.001       0.091
# ia            -0.1676      0.035     -4.809      0.000      -0.236      -0.099
# roe            0.2111      0.030      7.074      0.000       0.152       0.270
# ==============================================================================
# Omnibus:                       62.959   Durbin-Watson:                   1.820
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              888.962
# Skew:                           0.554   Prob(JB):                    9.21e-194
# Kurtosis:                      12.484   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.304
# Model:                            OLS   Adj. R-squared:                  0.292
# Method:                 Least Squares   F-statistic:                     10.40
# Date:                Mon, 27 Apr 2020   Prob (F-statistic):           9.31e-08
# Time:                        08:51:46   Log-Likelihood:                 735.09
# No. Observations:                 234   AIC:                            -1460.
# Df Residuals:                     229   BIC:                            -1443.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.001     -0.388      0.698      -0.002       0.001
# mktrf         -0.0404      0.025     -1.611      0.107      -0.090       0.009
# me             0.0459      0.036      1.271      0.204      -0.025       0.117
# ia            -0.1676      0.079     -2.119      0.034      -0.323      -0.013
# roe            0.2111      0.052      4.035      0.000       0.109       0.314
# ==============================================================================
# Omnibus:                       62.959   Durbin-Watson:                   1.820
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              888.962
# Skew:                           0.554   Prob(JB):                    9.21e-194
# Kurtosis:                      12.484   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.304
# Model:                            OLS   Adj. R-squared:                  0.292
# Method:                 Least Squares   F-statistic:                     9.222
# Date:                Mon, 27 Apr 2020   Prob (F-statistic):           6.32e-07
# Time:                        08:51:46   Log-Likelihood:                 735.09
# No. Observations:                 234   AIC:                            -1460.
# Df Residuals:                     229   BIC:                            -1443.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.001     -0.344      0.731      -0.002       0.001
# mktrf         -0.0404      0.024     -1.670      0.095      -0.088       0.007
# me             0.0459      0.037      1.246      0.213      -0.026       0.118
# ia            -0.1676      0.072     -2.312      0.021      -0.310      -0.026
# roe            0.2111      0.054      3.888      0.000       0.105       0.317
# ==============================================================================
# Omnibus:                       62.959   Durbin-Watson:                   1.820
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              888.962
# Skew:                           0.554   Prob(JB):                    9.21e-194
# Kurtosis:                      12.484   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.556
# Model:                            OLS   Adj. R-squared:                  0.548
# Method:                 Least Squares   F-statistic:                     71.64
# Date:                Mon, 27 Apr 2020   Prob (F-statistic):           2.87e-39
# Time:                        08:51:46   Log-Likelihood:                 787.69
# No. Observations:                 234   AIC:                            -1565.
# Df Residuals:                     229   BIC:                            -1548.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.001     -0.559      0.576      -0.001       0.001
# mktrf         -0.0125      0.014     -0.863      0.389      -0.041       0.016
# smb           -0.0798      0.018     -4.411      0.000      -0.115      -0.044
# hml           -0.0394      0.018     -2.189      0.030      -0.075      -0.004
# umd            0.1696      0.012     14.380      0.000       0.146       0.193
# ==============================================================================
# Omnibus:                       38.078   Durbin-Watson:                   1.784
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              339.475
# Skew:                           0.055   Prob(JB):                     1.92e-74
# Kurtosis:                       8.900   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.556
# Model:                            OLS   Adj. R-squared:                  0.548
# Method:                 Least Squares   F-statistic:                     15.07
# Date:                Mon, 27 Apr 2020   Prob (F-statistic):           5.95e-11
# Time:                        08:51:46   Log-Likelihood:                 787.69
# No. Observations:                 234   AIC:                            -1565.
# Df Residuals:                     229   BIC:                            -1548.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.001     -0.521      0.603      -0.001       0.001
# mktrf         -0.0125      0.025     -0.491      0.623      -0.062       0.037
# smb           -0.0798      0.022     -3.685      0.000      -0.122      -0.037
# hml           -0.0394      0.024     -1.621      0.105      -0.087       0.008
# umd            0.1696      0.026      6.585      0.000       0.119       0.220
# ==============================================================================
# Omnibus:                       38.078   Durbin-Watson:                   1.784
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              339.475
# Skew:                           0.055   Prob(JB):                     1.92e-74
# Kurtosis:                       8.900   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.556
# Model:                            OLS   Adj. R-squared:                  0.548
# Method:                 Least Squares   F-statistic:                     12.60
# Date:                Mon, 27 Apr 2020   Prob (F-statistic):           2.77e-09
# Time:                        08:51:46   Log-Likelihood:                 787.69
# No. Observations:                 234   AIC:                            -1565.
# Df Residuals:                     229   BIC:                            -1548.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.001     -0.469      0.639      -0.002       0.001
# mktrf         -0.0125      0.026     -0.487      0.626      -0.063       0.038
# smb           -0.0798      0.019     -4.214      0.000      -0.117      -0.043
# hml           -0.0394      0.023     -1.694      0.090      -0.085       0.006
# umd            0.1696      0.027      6.349      0.000       0.117       0.222
# ==============================================================================
# Omnibus:                       38.078   Durbin-Watson:                   1.784
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              339.475
# Skew:                           0.055   Prob(JB):                     1.92e-74
# Kurtosis:                       8.900   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.556
# Model:                            OLS   Adj. R-squared:                  0.548
# Method:                 Least Squares   F-statistic:                     71.64
# Date:                Mon, 27 Apr 2020   Prob (F-statistic):           2.87e-39
# Time:                        08:51:46   Log-Likelihood:                 787.69
# No. Observations:                 234   AIC:                            -1565.
# Df Residuals:                     229   BIC:                            -1548.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.001     -0.559      0.576      -0.001       0.001
# mktrf         -0.0125      0.014     -0.863      0.389      -0.041       0.016
# smb           -0.0798      0.018     -4.411      0.000      -0.115      -0.044
# hml           -0.0394      0.018     -2.189      0.030      -0.075      -0.004
# umd            0.1696      0.012     14.380      0.000       0.146       0.193
# ==============================================================================
# Omnibus:                       38.078   Durbin-Watson:                   1.784
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              339.475
# Skew:                           0.055   Prob(JB):                     1.92e-74
# Kurtosis:                       8.900   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.556
# Model:                            OLS   Adj. R-squared:                  0.548
# Method:                 Least Squares   F-statistic:                     15.07
# Date:                Mon, 27 Apr 2020   Prob (F-statistic):           5.95e-11
# Time:                        08:51:46   Log-Likelihood:                 787.69
# No. Observations:                 234   AIC:                            -1565.
# Df Residuals:                     229   BIC:                            -1548.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.001     -0.521      0.603      -0.001       0.001
# mktrf         -0.0125      0.025     -0.491      0.623      -0.062       0.037
# smb           -0.0798      0.022     -3.685      0.000      -0.122      -0.037
# hml           -0.0394      0.024     -1.621      0.105      -0.087       0.008
# umd            0.1696      0.026      6.585      0.000       0.119       0.220
# ==============================================================================
# Omnibus:                       38.078   Durbin-Watson:                   1.784
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              339.475
# Skew:                           0.055   Prob(JB):                     1.92e-74
# Kurtosis:                       8.900   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.556
# Model:                            OLS   Adj. R-squared:                  0.548
# Method:                 Least Squares   F-statistic:                     12.60
# Date:                Mon, 27 Apr 2020   Prob (F-statistic):           2.77e-09
# Time:                        08:51:46   Log-Likelihood:                 787.69
# No. Observations:                 234   AIC:                            -1565.
# Df Residuals:                     229   BIC:                            -1548.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.001     -0.469      0.639      -0.002       0.001
# mktrf         -0.0125      0.026     -0.487      0.626      -0.063       0.038
# smb           -0.0798      0.019     -4.214      0.000      -0.117      -0.043
# hml           -0.0394      0.023     -1.694      0.090      -0.085       0.006
# umd            0.1696      0.027      6.349      0.000       0.117       0.222
# ==============================================================================
# Omnibus:                       38.078   Durbin-Watson:                   1.784
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              339.475
# Skew:                           0.055   Prob(JB):                     1.92e-74
# Kurtosis:                       8.900   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Pre-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.370
# Model:                            OLS   Adj. R-squared:                  0.348
# Method:                 Least Squares   F-statistic:                     16.86
# Date:                Mon, 27 Apr 2020   Prob (F-statistic):           6.62e-11
# Time:                        08:51:46   Log-Likelihood:                 351.00
# No. Observations:                 120   AIC:                            -692.0
# Df Residuals:                     115   BIC:                            -678.1
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0014      0.001     -1.114      0.267      -0.004       0.001
# mktrf          0.0008      0.034      0.024      0.981      -0.067       0.069
# me             0.0872      0.034      2.583      0.011       0.020       0.154
# ia            -0.2140      0.053     -4.047      0.000      -0.319      -0.109
# roe            0.3037      0.047      6.489      0.000       0.211       0.396
# ==============================================================================
# Omnibus:                       33.380   Durbin-Watson:                   1.730
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              206.487
# Skew:                           0.669   Prob(JB):                     1.45e-45
# Kurtosis:                       9.285   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.370
# Model:                            OLS   Adj. R-squared:                  0.348
# Method:                 Least Squares   F-statistic:                     17.01
# Date:                Mon, 27 Apr 2020   Prob (F-statistic):           5.54e-11
# Time:                        08:51:46   Log-Likelihood:                 351.00
# No. Observations:                 120   AIC:                            -692.0
# Df Residuals:                     115   BIC:                            -678.1
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0014      0.001     -1.020      0.308      -0.004       0.001
# mktrf          0.0008      0.036      0.023      0.981      -0.069       0.071
# me             0.0872      0.040      2.169      0.030       0.008       0.166
# ia            -0.2140      0.098     -2.178      0.029      -0.407      -0.021
# roe            0.3037      0.057      5.349      0.000       0.192       0.415
# ==============================================================================
# Omnibus:                       33.380   Durbin-Watson:                   1.730
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              206.487
# Skew:                           0.669   Prob(JB):                     1.45e-45
# Kurtosis:                       9.285   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.370
# Model:                            OLS   Adj. R-squared:                  0.348
# Method:                 Least Squares   F-statistic:                     16.97
# Date:                Mon, 27 Apr 2020   Prob (F-statistic):           5.82e-11
# Time:                        08:51:46   Log-Likelihood:                 351.00
# No. Observations:                 120   AIC:                            -692.0
# Df Residuals:                     115   BIC:                            -678.1
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0014      0.001     -0.950      0.342      -0.004       0.002
# mktrf          0.0008      0.029      0.029      0.977      -0.055       0.057
# me             0.0872      0.041      2.122      0.034       0.007       0.168
# ia            -0.2140      0.091     -2.349      0.019      -0.393      -0.035
# roe            0.3037      0.050      6.036      0.000       0.205       0.402
# ==============================================================================
# Omnibus:                       33.380   Durbin-Watson:                   1.730
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              206.487
# Skew:                           0.669   Prob(JB):                     1.45e-45
# Kurtosis:                       9.285   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.603
# Model:                            OLS   Adj. R-squared:                  0.589
# Method:                 Least Squares   F-statistic:                     43.61
# Date:                Mon, 27 Apr 2020   Prob (F-statistic):           3.18e-22
# Time:                        08:51:46   Log-Likelihood:                 378.69
# No. Observations:                 120   AIC:                            -747.4
# Df Residuals:                     115   BIC:                            -733.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0005      0.001     -0.496      0.621      -0.002       0.001
# mktrf          0.0187      0.024      0.780      0.437      -0.029       0.066
# smb           -0.1027      0.027     -3.774      0.000      -0.157      -0.049
# hml           -0.0448      0.027     -1.644      0.103      -0.099       0.009
# umd            0.1968      0.017     11.706      0.000       0.164       0.230
# ==============================================================================
# Omnibus:                       14.043   Durbin-Watson:                   1.773
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               46.262
# Skew:                          -0.131   Prob(JB):                     9.00e-11
# Kurtosis:                       6.031   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.603
# Model:                            OLS   Adj. R-squared:                  0.589
# Method:                 Least Squares   F-statistic:                     11.90
# Date:                Mon, 27 Apr 2020   Prob (F-statistic):           4.01e-08
# Time:                        08:51:46   Log-Likelihood:                 378.69
# No. Observations:                 120   AIC:                            -747.4
# Df Residuals:                     115   BIC:                            -733.4
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0005      0.001     -0.463      0.643      -0.003       0.002
# mktrf          0.0187      0.036      0.516      0.606      -0.052       0.090
# smb           -0.1027      0.029     -3.550      0.000      -0.159      -0.046
# hml           -0.0448      0.029     -1.546      0.122      -0.102       0.012
# umd            0.1968      0.031      6.369      0.000       0.136       0.257
# ==============================================================================
# Omnibus:                       14.043   Durbin-Watson:                   1.773
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               46.262
# Skew:                          -0.131   Prob(JB):                     9.00e-11
# Kurtosis:                       6.031   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.603
# Model:                            OLS   Adj. R-squared:                  0.589
# Method:                 Least Squares   F-statistic:                     14.25
# Date:                Mon, 27 Apr 2020   Prob (F-statistic):           1.77e-09
# Time:                        08:51:46   Log-Likelihood:                 378.69
# No. Observations:                 120   AIC:                            -747.4
# Df Residuals:                     115   BIC:                            -733.4
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0005      0.001     -0.444      0.657      -0.003       0.002
# mktrf          0.0187      0.033      0.558      0.577      -0.047       0.084
# smb           -0.1027      0.024     -4.342      0.000      -0.149      -0.056
# hml           -0.0448      0.028     -1.603      0.109      -0.100       0.010
# umd            0.1968      0.029      6.886      0.000       0.141       0.253
# ==============================================================================
# Omnibus:                       14.043   Durbin-Watson:                   1.773
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               46.262
# Skew:                          -0.131   Prob(JB):                     9.00e-11
# Kurtosis:                       6.031   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.603
# Model:                            OLS   Adj. R-squared:                  0.589
# Method:                 Least Squares   F-statistic:                     43.61
# Date:                Mon, 27 Apr 2020   Prob (F-statistic):           3.18e-22
# Time:                        08:51:46   Log-Likelihood:                 378.69
# No. Observations:                 120   AIC:                            -747.4
# Df Residuals:                     115   BIC:                            -733.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0005      0.001     -0.496      0.621      -0.002       0.001
# mktrf          0.0187      0.024      0.780      0.437      -0.029       0.066
# smb           -0.1027      0.027     -3.774      0.000      -0.157      -0.049
# hml           -0.0448      0.027     -1.644      0.103      -0.099       0.009
# umd            0.1968      0.017     11.706      0.000       0.164       0.230
# ==============================================================================
# Omnibus:                       14.043   Durbin-Watson:                   1.773
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               46.262
# Skew:                          -0.131   Prob(JB):                     9.00e-11
# Kurtosis:                       6.031   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.603
# Model:                            OLS   Adj. R-squared:                  0.589
# Method:                 Least Squares   F-statistic:                     11.90
# Date:                Mon, 27 Apr 2020   Prob (F-statistic):           4.01e-08
# Time:                        08:51:47   Log-Likelihood:                 378.69
# No. Observations:                 120   AIC:                            -747.4
# Df Residuals:                     115   BIC:                            -733.4
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0005      0.001     -0.463      0.643      -0.003       0.002
# mktrf          0.0187      0.036      0.516      0.606      -0.052       0.090
# smb           -0.1027      0.029     -3.550      0.000      -0.159      -0.046
# hml           -0.0448      0.029     -1.546      0.122      -0.102       0.012
# umd            0.1968      0.031      6.369      0.000       0.136       0.257
# ==============================================================================
# Omnibus:                       14.043   Durbin-Watson:                   1.773
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               46.262
# Skew:                          -0.131   Prob(JB):                     9.00e-11
# Kurtosis:                       6.031   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.603
# Model:                            OLS   Adj. R-squared:                  0.589
# Method:                 Least Squares   F-statistic:                     14.25
# Date:                Mon, 27 Apr 2020   Prob (F-statistic):           1.77e-09
# Time:                        08:51:47   Log-Likelihood:                 378.69
# No. Observations:                 120   AIC:                            -747.4
# Df Residuals:                     115   BIC:                            -733.4
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0005      0.001     -0.444      0.657      -0.003       0.002
# mktrf          0.0187      0.033      0.558      0.577      -0.047       0.084
# smb           -0.1027      0.024     -4.342      0.000      -0.149      -0.056
# hml           -0.0448      0.028     -1.603      0.109      -0.100       0.010
# umd            0.1968      0.029      6.886      0.000       0.141       0.253
# ==============================================================================
# Omnibus:                       14.043   Durbin-Watson:                   1.773
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               46.262
# Skew:                          -0.131   Prob(JB):                     9.00e-11
# Kurtosis:                       6.031   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Post-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.348
# Model:                            OLS   Adj. R-squared:                  0.324
# Method:                 Least Squares   F-statistic:                     14.57
# Date:                Mon, 27 Apr 2020   Prob (F-statistic):           1.46e-09
# Time:                        08:51:47   Log-Likelihood:                 438.73
# No. Observations:                 114   AIC:                            -867.5
# Df Residuals:                     109   BIC:                            -853.8
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0009      0.001      1.772      0.079      -0.000       0.002
# mktrf         -0.0684      0.016     -4.409      0.000      -0.099      -0.038
# me            -0.0453      0.024     -1.894      0.061      -0.093       0.002
# ia            -0.0850      0.033     -2.561      0.012      -0.151      -0.019
# roe            0.0342      0.029      1.172      0.244      -0.024       0.092
# ==============================================================================
# Omnibus:                        2.122   Durbin-Watson:                   1.967
# Prob(Omnibus):                  0.346   Jarque-Bera (JB):                1.925
# Skew:                          -0.215   Prob(JB):                        0.382
# Kurtosis:                       2.531   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.348
# Model:                            OLS   Adj. R-squared:                  0.324
# Method:                 Least Squares   F-statistic:                     20.61
# Date:                Mon, 27 Apr 2020   Prob (F-statistic):           1.15e-12
# Time:                        08:51:47   Log-Likelihood:                 438.73
# No. Observations:                 114   AIC:                            -867.5
# Df Residuals:                     109   BIC:                            -853.8
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0009      0.001      1.585      0.113      -0.000       0.002
# mktrf         -0.0684      0.017     -4.139      0.000      -0.101      -0.036
# me            -0.0453      0.029     -1.571      0.116      -0.102       0.011
# ia            -0.0850      0.038     -2.217      0.027      -0.160      -0.010
# roe            0.0342      0.032      1.083      0.279      -0.028       0.096
# ==============================================================================
# Omnibus:                        2.122   Durbin-Watson:                   1.967
# Prob(Omnibus):                  0.346   Jarque-Bera (JB):                1.925
# Skew:                          -0.215   Prob(JB):                        0.382
# Kurtosis:                       2.531   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.348
# Model:                            OLS   Adj. R-squared:                  0.324
# Method:                 Least Squares   F-statistic:                     19.84
# Date:                Mon, 27 Apr 2020   Prob (F-statistic):           2.72e-12
# Time:                        08:51:47   Log-Likelihood:                 438.73
# No. Observations:                 114   AIC:                            -867.5
# Df Residuals:                     109   BIC:                            -853.8
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0009      0.001      1.317      0.188      -0.000       0.002
# mktrf         -0.0684      0.016     -4.179      0.000      -0.100      -0.036
# me            -0.0453      0.029     -1.561      0.119      -0.102       0.012
# ia            -0.0850      0.042     -2.020      0.043      -0.168      -0.003
# roe            0.0342      0.032      1.075      0.282      -0.028       0.097
# ==============================================================================
# Omnibus:                        2.122   Durbin-Watson:                   1.967
# Prob(Omnibus):                  0.346   Jarque-Bera (JB):                1.925
# Skew:                          -0.215   Prob(JB):                        0.382
# Kurtosis:                       2.531   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.508
# Model:                            OLS   Adj. R-squared:                  0.490
# Method:                 Least Squares   F-statistic:                     28.11
# Date:                Mon, 27 Apr 2020   Prob (F-statistic):           4.79e-16
# Time:                        08:51:47   Log-Likelihood:                 454.72
# No. Observations:                 114   AIC:                            -899.4
# Df Residuals:                     109   BIC:                            -885.8
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0006      0.000      1.407      0.162      -0.000       0.002
# mktrf         -0.0577      0.013     -4.517      0.000      -0.083      -0.032
# smb           -0.0443      0.020     -2.223      0.028      -0.084      -0.005
# hml           -0.0540      0.021     -2.632      0.010      -0.095      -0.013
# umd            0.0781      0.015      5.048      0.000       0.047       0.109
# ==============================================================================
# Omnibus:                        2.376   Durbin-Watson:                   1.861
# Prob(Omnibus):                  0.305   Jarque-Bera (JB):                1.739
# Skew:                          -0.106   Prob(JB):                        0.419
# Kurtosis:                       2.433   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.508
# Model:                            OLS   Adj. R-squared:                  0.490
# Method:                 Least Squares   F-statistic:                     51.04
# Date:                Mon, 27 Apr 2020   Prob (F-statistic):           3.83e-24
# Time:                        08:51:47   Log-Likelihood:                 454.72
# No. Observations:                 114   AIC:                            -899.4
# Df Residuals:                     109   BIC:                            -885.8
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0006      0.000      1.351      0.177      -0.000       0.002
# mktrf         -0.0577      0.013     -4.395      0.000      -0.083      -0.032
# smb           -0.0443      0.021     -2.133      0.033      -0.085      -0.004
# hml           -0.0540      0.022     -2.494      0.013      -0.096      -0.012
# umd            0.0781      0.012      6.465      0.000       0.054       0.102
# ==============================================================================
# Omnibus:                        2.376   Durbin-Watson:                   1.861
# Prob(Omnibus):                  0.305   Jarque-Bera (JB):                1.739
# Skew:                          -0.106   Prob(JB):                        0.419
# Kurtosis:                       2.433   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.508
# Model:                            OLS   Adj. R-squared:                  0.490
# Method:                 Least Squares   F-statistic:                     59.49
# Date:                Mon, 27 Apr 2020   Prob (F-statistic):           1.51e-26
# Time:                        08:51:47   Log-Likelihood:                 454.72
# No. Observations:                 114   AIC:                            -899.4
# Df Residuals:                     109   BIC:                            -885.8
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0006      0.001      1.171      0.241      -0.000       0.002
# mktrf         -0.0577      0.013     -4.475      0.000      -0.083      -0.032
# smb           -0.0443      0.022     -2.045      0.041      -0.087      -0.002
# hml           -0.0540      0.021     -2.525      0.012      -0.096      -0.012
# umd            0.0781      0.013      5.832      0.000       0.052       0.104
# ==============================================================================
# Omnibus:                        2.376   Durbin-Watson:                   1.861
# Prob(Omnibus):                  0.305   Jarque-Bera (JB):                1.739
# Skew:                          -0.106   Prob(JB):                        0.419
# Kurtosis:                       2.433   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.508
# Model:                            OLS   Adj. R-squared:                  0.490
# Method:                 Least Squares   F-statistic:                     28.11
# Date:                Mon, 27 Apr 2020   Prob (F-statistic):           4.79e-16
# Time:                        08:51:47   Log-Likelihood:                 454.72
# No. Observations:                 114   AIC:                            -899.4
# Df Residuals:                     109   BIC:                            -885.8
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0006      0.000      1.407      0.162      -0.000       0.002
# mktrf         -0.0577      0.013     -4.517      0.000      -0.083      -0.032
# smb           -0.0443      0.020     -2.223      0.028      -0.084      -0.005
# hml           -0.0540      0.021     -2.632      0.010      -0.095      -0.013
# umd            0.0781      0.015      5.048      0.000       0.047       0.109
# ==============================================================================
# Omnibus:                        2.376   Durbin-Watson:                   1.861
# Prob(Omnibus):                  0.305   Jarque-Bera (JB):                1.739
# Skew:                          -0.106   Prob(JB):                        0.419
# Kurtosis:                       2.433   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.508
# Model:                            OLS   Adj. R-squared:                  0.490
# Method:                 Least Squares   F-statistic:                     51.04
# Date:                Mon, 27 Apr 2020   Prob (F-statistic):           3.83e-24
# Time:                        08:51:47   Log-Likelihood:                 454.72
# No. Observations:                 114   AIC:                            -899.4
# Df Residuals:                     109   BIC:                            -885.8
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0006      0.000      1.351      0.177      -0.000       0.002
# mktrf         -0.0577      0.013     -4.395      0.000      -0.083      -0.032
# smb           -0.0443      0.021     -2.133      0.033      -0.085      -0.004
# hml           -0.0540      0.022     -2.494      0.013      -0.096      -0.012
# umd            0.0781      0.012      6.465      0.000       0.054       0.102
# ==============================================================================
# Omnibus:                        2.376   Durbin-Watson:                   1.861
# Prob(Omnibus):                  0.305   Jarque-Bera (JB):                1.739
# Skew:                          -0.106   Prob(JB):                        0.419
# Kurtosis:                       2.433   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.508
# Model:                            OLS   Adj. R-squared:                  0.490
# Method:                 Least Squares   F-statistic:                     59.49
# Date:                Mon, 27 Apr 2020   Prob (F-statistic):           1.51e-26
# Time:                        08:51:47   Log-Likelihood:                 454.72
# No. Observations:                 114   AIC:                            -899.4
# Df Residuals:                     109   BIC:                            -885.8
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0006      0.001      1.171      0.241      -0.000       0.002
# mktrf         -0.0577      0.013     -4.475      0.000      -0.083      -0.032
# smb           -0.0443      0.022     -2.045      0.041      -0.087      -0.002
# hml           -0.0540      0.021     -2.525      0.012      -0.096      -0.012
# umd            0.0781      0.013      5.832      0.000       0.052       0.104
# ==============================================================================
# Omnibus:                        2.376   Durbin-Watson:                   1.861
# Prob(Omnibus):                  0.305   Jarque-Bera (JB):                1.739
# Skew:                          -0.106   Prob(JB):                        0.419
# Kurtosis:                       2.433   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """
