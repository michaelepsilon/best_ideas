# %% [markdown]
# # Method 6 - Best Ideas High Focus

# %%
# %matplotlib inline
import pandas as pd
import warnings
from statsmodels import api as sm

from eptooling import crsp, epd, fs, hfu, crsp, db, bi
from eptooling.bm import bmdb, iso
from epquant.engine import weights, portfolio
from epquant.gen import returns
from epquant.perf import relative_performance

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Fetch Holdings and Benchmark Data

# %%
# Get HFU Data

# %store -r inst_data
inst_data = inst_data[inst_data['datadate'] >= '1999-06-30']

# Focus

focus = inst_data.groupby(['datadate', 'institution_id'])['fsym_id'].count().rename('focus').reset_index()

# Count number of positions per manager

inst_data['num_pos'] = inst_data.groupby(['datadate', 'institution_id'])[
    'fsym_id'].transform(lambda s: s.nunique())

# Remove less than 20 holdings and less than $5mm per CSP

valid_data = inst_data[inst_data['num_pos'] >= 20]
valid_data = valid_data[valid_data['public_aum'] >= 5e6]

# Add Expected Returns from Market Relative Weight per Shumway, Szefler, Yuan 2009

# %store -r mkt_exp_ret

valid_data = valid_data.merge(mkt_exp_ret, on=['datadate', 'institution_id', 'fsym_id'], how='left')

# Calculate CSP Weight per Market Tilt

valid_data['adj_target'] = valid_data['expected_return']

# %% [markdown]
# ## Calculate Best Ideas

# %%
# Extract Best Ideas

valid_data['pos_rank'] = valid_data\
    .groupby(['datadate', 'institution_id'])['adj_target'].rank(ascending=False)

best_ideas = valid_data[valid_data['pos_rank'] == 1].copy()

# Add Focus

best_ideas = best_ideas.merge(focus)
best_ideas['focus_pct'] = best_ideas.groupby('datadate')['focus'].rank(pct=True)
best_ideas = best_ideas[best_ideas['focus_pct'] > (2 / 3)]

# Weight the best ideas equally

best_ideas['target'] = 1 / best_ideas.groupby('datadate')['institution_id'].transform('count')

# %% [markdown]
# ## Backtest Portfolio

# %%
w = weights.Weights(best_ideas)

# %store -r r

p = portfolio.DailyPortfolio(w, r, end_date='2018-12-31')

rf = bi.get_risk_free_rate()
monthly_return = p.port_return.loc['1999-07-01':].resample('M').apply(epd.prod_red)
monthly_return = (monthly_return - rf).dropna()
monthly_return.name = 'port_return'

# %% [markdown]
# ## Plot Performance

# %%
epd.nav(monthly_return).plot()

# %%
monthly_return.resample('A').apply(epd.prod_red)
# Out:
# datadate
# 1999-12-31    0.215282
# 2000-12-31   -0.314958
# 2001-12-31   -0.397923
# 2002-12-31   -0.358200
# 2003-12-31    0.838400
# 2004-12-31    0.063556
# 2005-12-31    0.026567
# 2006-12-31    0.032396
# 2007-12-31    0.018309
# 2008-12-31   -0.546759
# 2009-12-31    0.657100
# 2010-12-31    0.170729
# 2011-12-31   -0.139766
# 2012-12-31    0.274976
# 2013-12-31    0.485011
# 2014-12-31    0.093538
# 2015-12-31   -0.137405
# 2016-12-31    0.162624
# 2017-12-31    0.184301
# 2018-12-31   -0.144920
# Freq: A-DEC, Name: port_return, dtype: float64

# %% [markdown]
# ## Fetch Factor Models

# %%
# Get Factor Models
q_factor_model = bi.get_q_factor_model()
fama_french_five_factor_model = bi.get_fama_french_five_factor_model()
four_factor_model = bi.get_four_factor_model()

# Concat Portfolio Return
q_factor = pd.concat([monthly_return, q_factor_model], axis=1)
fama_french_five = pd.concat([monthly_return, fama_french_five_factor_model], axis=1)
four_factor = pd.concat([monthly_return, four_factor_model], axis=1)

# Add Constants
q_factor.insert(1, 'const', 1)
fama_french_five.insert(1, 'const', 1)
four_factor.insert(1, 'const', 1)

# Split Period into Pre and Post Crisis
q_factor_pre, q_factor_post = q_factor.loc[:'2009-06-30'], q_factor.loc['2009-07-31':]
fama_french_five_pre, fama_french_five_post = fama_french_five.loc[:'2009-06-30'], fama_french_five.loc['2009-07-31':] 
four_factor_pre, four_factor_post = four_factor.loc[:'2009-06-30'], four_factor.loc['2009-07-31':]

# %% [markdown]
# ## Full Time Period Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.877
# Model:                            OLS   Adj. R-squared:                  0.875
# Method:                 Least Squares   F-statistic:                     406.9
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):          8.69e-103
# Time:                        12:42:40   Log-Likelihood:                 511.18
# No. Observations:                 234   AIC:                            -1012.
# Df Residuals:                     229   BIC:                            -995.1
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0004      0.002     -0.231      0.818      -0.004       0.003
# mktrf          1.1787      0.051     22.960      0.000       1.078       1.280
# me             0.4704      0.060      7.878      0.000       0.353       0.588
# ia            -0.2271      0.091     -2.503      0.013      -0.406      -0.048
# roe           -0.6304      0.078     -8.115      0.000      -0.783      -0.477
# ==============================================================================
# Omnibus:                       23.002   Durbin-Watson:                   2.089
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               41.802
# Skew:                           0.533   Prob(JB):                     8.37e-10
# Kurtosis:                       4.776   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.877
# Model:                            OLS   Adj. R-squared:                  0.875
# Method:                 Least Squares   F-statistic:                     315.3
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           7.06e-92
# Time:                        12:42:40   Log-Likelihood:                 511.18
# No. Observations:                 234   AIC:                            -1012.
# Df Residuals:                     229   BIC:                            -995.1
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0004      0.002     -0.196      0.844      -0.005       0.004
# mktrf          1.1787      0.063     18.620      0.000       1.055       1.303
# me             0.4704      0.058      8.163      0.000       0.357       0.583
# ia            -0.2271      0.124     -1.834      0.067      -0.470       0.016
# roe           -0.6304      0.139     -4.529      0.000      -0.903      -0.358
# ==============================================================================
# Omnibus:                       23.002   Durbin-Watson:                   2.089
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               41.802
# Skew:                           0.533   Prob(JB):                     8.37e-10
# Kurtosis:                       4.776   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.877
# Model:                            OLS   Adj. R-squared:                  0.875
# Method:                 Least Squares   F-statistic:                     381.7
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):          5.19e-100
# Time:                        12:42:40   Log-Likelihood:                 511.18
# No. Observations:                 234   AIC:                            -1012.
# Df Residuals:                     229   BIC:                            -995.1
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0004      0.002     -0.200      0.842      -0.005       0.004
# mktrf          1.1787      0.061     19.200      0.000       1.058       1.299
# me             0.4704      0.055      8.532      0.000       0.362       0.578
# ia            -0.2271      0.116     -1.961      0.050      -0.454      -0.000
# roe           -0.6304      0.148     -4.273      0.000      -0.920      -0.341
# ==============================================================================
# Omnibus:                       23.002   Durbin-Watson:                   2.089
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               41.802
# Skew:                           0.533   Prob(JB):                     8.37e-10
# Kurtosis:                       4.776   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.859
# Model:                            OLS   Adj. R-squared:                  0.857
# Method:                 Least Squares   F-statistic:                     350.1
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.65e-96
# Time:                        12:42:40   Log-Likelihood:                 495.90
# No. Observations:                 234   AIC:                            -981.8
# Df Residuals:                     229   BIC:                            -964.5
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0030      0.002     -1.552      0.122      -0.007       0.001
# mktrf          1.3271      0.050     26.302      0.000       1.228       1.426
# smb            0.7222      0.063     11.467      0.000       0.598       0.846
# hml           -0.1711      0.063     -2.734      0.007      -0.294      -0.048
# umd           -0.1688      0.041     -4.113      0.000      -0.250      -0.088
# ==============================================================================
# Omnibus:                       31.360   Durbin-Watson:                   2.006
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               47.134
# Skew:                           0.796   Prob(JB):                     5.82e-11
# Kurtosis:                       4.517   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.859
# Model:                            OLS   Adj. R-squared:                  0.857
# Method:                 Least Squares   F-statistic:                     270.9
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.44e-85
# Time:                        12:42:40   Log-Likelihood:                 495.90
# No. Observations:                 234   AIC:                            -981.8
# Df Residuals:                     229   BIC:                            -964.5
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0030      0.002     -1.514      0.130      -0.007       0.001
# mktrf          1.3271      0.058     22.814      0.000       1.213       1.441
# smb            0.7222      0.074      9.723      0.000       0.577       0.868
# hml           -0.1711      0.075     -2.275      0.023      -0.318      -0.024
# umd           -0.1688      0.062     -2.719      0.007      -0.291      -0.047
# ==============================================================================
# Omnibus:                       31.360   Durbin-Watson:                   2.006
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               47.134
# Skew:                           0.796   Prob(JB):                     5.82e-11
# Kurtosis:                       4.517   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.859
# Model:                            OLS   Adj. R-squared:                  0.857
# Method:                 Least Squares   F-statistic:                     226.9
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.00e-78
# Time:                        12:42:40   Log-Likelihood:                 495.90
# No. Observations:                 234   AIC:                            -981.8
# Df Residuals:                     229   BIC:                            -964.5
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0030      0.002     -1.642      0.100      -0.007       0.001
# mktrf          1.3271      0.062     21.439      0.000       1.206       1.448
# smb            0.7222      0.070     10.285      0.000       0.585       0.860
# hml           -0.1711      0.069     -2.487      0.013      -0.306      -0.036
# umd           -0.1688      0.067     -2.530      0.011      -0.300      -0.038
# ==============================================================================
# Omnibus:                       31.360   Durbin-Watson:                   2.006
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               47.134
# Skew:                           0.796   Prob(JB):                     5.82e-11
# Kurtosis:                       4.517   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.859
# Model:                            OLS   Adj. R-squared:                  0.857
# Method:                 Least Squares   F-statistic:                     350.1
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.65e-96
# Time:                        12:42:40   Log-Likelihood:                 495.90
# No. Observations:                 234   AIC:                            -981.8
# Df Residuals:                     229   BIC:                            -964.5
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0030      0.002     -1.552      0.122      -0.007       0.001
# mktrf          1.3271      0.050     26.302      0.000       1.228       1.426
# smb            0.7222      0.063     11.467      0.000       0.598       0.846
# hml           -0.1711      0.063     -2.734      0.007      -0.294      -0.048
# umd           -0.1688      0.041     -4.113      0.000      -0.250      -0.088
# ==============================================================================
# Omnibus:                       31.360   Durbin-Watson:                   2.006
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               47.134
# Skew:                           0.796   Prob(JB):                     5.82e-11
# Kurtosis:                       4.517   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.859
# Model:                            OLS   Adj. R-squared:                  0.857
# Method:                 Least Squares   F-statistic:                     270.9
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.44e-85
# Time:                        12:42:40   Log-Likelihood:                 495.90
# No. Observations:                 234   AIC:                            -981.8
# Df Residuals:                     229   BIC:                            -964.5
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0030      0.002     -1.514      0.130      -0.007       0.001
# mktrf          1.3271      0.058     22.814      0.000       1.213       1.441
# smb            0.7222      0.074      9.723      0.000       0.577       0.868
# hml           -0.1711      0.075     -2.275      0.023      -0.318      -0.024
# umd           -0.1688      0.062     -2.719      0.007      -0.291      -0.047
# ==============================================================================
# Omnibus:                       31.360   Durbin-Watson:                   2.006
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               47.134
# Skew:                           0.796   Prob(JB):                     5.82e-11
# Kurtosis:                       4.517   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.859
# Model:                            OLS   Adj. R-squared:                  0.857
# Method:                 Least Squares   F-statistic:                     226.9
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.00e-78
# Time:                        12:42:40   Log-Likelihood:                 495.90
# No. Observations:                 234   AIC:                            -981.8
# Df Residuals:                     229   BIC:                            -964.5
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0030      0.002     -1.642      0.100      -0.007       0.001
# mktrf          1.3271      0.062     21.439      0.000       1.206       1.448
# smb            0.7222      0.070     10.285      0.000       0.585       0.860
# hml           -0.1711      0.069     -2.487      0.013      -0.306      -0.036
# umd           -0.1688      0.067     -2.530      0.011      -0.300      -0.038
# ==============================================================================
# Omnibus:                       31.360   Durbin-Watson:                   2.006
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               47.134
# Skew:                           0.796   Prob(JB):                     5.82e-11
# Kurtosis:                       4.517   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Pre-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.881
# Model:                            OLS   Adj. R-squared:                  0.877
# Method:                 Least Squares   F-statistic:                     213.0
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           3.48e-52
# Time:                        12:42:40   Log-Likelihood:                 245.04
# No. Observations:                 120   AIC:                            -480.1
# Df Residuals:                     115   BIC:                            -466.1
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0019      0.003     -0.614      0.541      -0.008       0.004
# mktrf          1.2560      0.083     15.192      0.000       1.092       1.420
# me             0.4874      0.082      5.969      0.000       0.326       0.649
# ia            -0.3211      0.128     -2.512      0.013      -0.574      -0.068
# roe           -0.4803      0.113     -4.244      0.000      -0.705      -0.256
# ==============================================================================
# Omnibus:                       21.877   Durbin-Watson:                   2.142
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               37.705
# Skew:                           0.815   Prob(JB):                     6.49e-09
# Kurtosis:                       5.210   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.881
# Model:                            OLS   Adj. R-squared:                  0.877
# Method:                 Least Squares   F-statistic:                     223.2
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           3.23e-53
# Time:                        12:42:40   Log-Likelihood:                 245.04
# No. Observations:                 120   AIC:                            -480.1
# Df Residuals:                     115   BIC:                            -466.1
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0019      0.004     -0.476      0.634      -0.010       0.006
# mktrf          1.2560      0.101     12.403      0.000       1.058       1.454
# me             0.4874      0.086      5.651      0.000       0.318       0.656
# ia            -0.3211      0.193     -1.663      0.096      -0.700       0.057
# roe           -0.4803      0.201     -2.392      0.017      -0.874      -0.087
# ==============================================================================
# Omnibus:                       21.877   Durbin-Watson:                   2.142
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               37.705
# Skew:                           0.815   Prob(JB):                     6.49e-09
# Kurtosis:                       5.210   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.881
# Model:                            OLS   Adj. R-squared:                  0.877
# Method:                 Least Squares   F-statistic:                     312.2
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           9.41e-61
# Time:                        12:42:40   Log-Likelihood:                 245.04
# No. Observations:                 120   AIC:                            -480.1
# Df Residuals:                     115   BIC:                            -466.1
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0019      0.004     -0.487      0.626      -0.009       0.006
# mktrf          1.2560      0.094     13.351      0.000       1.072       1.440
# me             0.4874      0.086      5.657      0.000       0.319       0.656
# ia            -0.3211      0.191     -1.678      0.093      -0.696       0.054
# roe           -0.4803      0.206     -2.328      0.020      -0.885      -0.076
# ==============================================================================
# Omnibus:                       21.877   Durbin-Watson:                   2.142
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               37.705
# Skew:                           0.815   Prob(JB):                     6.49e-09
# Kurtosis:                       5.210   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.883
# Model:                            OLS   Adj. R-squared:                  0.879
# Method:                 Least Squares   F-statistic:                     218.0
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.07e-52
# Time:                        12:42:40   Log-Likelihood:                 246.27
# No. Observations:                 120   AIC:                            -482.5
# Df Residuals:                     115   BIC:                            -468.6
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0025      0.003     -0.830      0.408      -0.008       0.003
# mktrf          1.4341      0.072     19.894      0.000       1.291       1.577
# smb            0.6715      0.082      8.181      0.000       0.509       0.834
# hml           -0.2382      0.082     -2.898      0.004      -0.401      -0.075
# umd           -0.1242      0.051     -2.451      0.016      -0.225      -0.024
# ==============================================================================
# Omnibus:                       18.270   Durbin-Watson:                   2.113
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.243
# Skew:                           0.840   Prob(JB):                     8.97e-06
# Kurtosis:                       4.352   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.883
# Model:                            OLS   Adj. R-squared:                  0.879
# Method:                 Least Squares   F-statistic:                     296.9
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.30e-59
# Time:                        12:42:40   Log-Likelihood:                 246.27
# No. Observations:                 120   AIC:                            -482.5
# Df Residuals:                     115   BIC:                            -468.6
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0025      0.003     -0.787      0.431      -0.009       0.004
# mktrf          1.4341      0.061     23.623      0.000       1.315       1.553
# smb            0.6715      0.095      7.094      0.000       0.486       0.857
# hml           -0.2382      0.076     -3.119      0.002      -0.388      -0.089
# umd           -0.1242      0.067     -1.842      0.065      -0.256       0.008
# ==============================================================================
# Omnibus:                       18.270   Durbin-Watson:                   2.113
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.243
# Skew:                           0.840   Prob(JB):                     8.97e-06
# Kurtosis:                       4.352   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.883
# Model:                            OLS   Adj. R-squared:                  0.879
# Method:                 Least Squares   F-statistic:                     518.3
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.51e-72
# Time:                        12:42:40   Log-Likelihood:                 246.27
# No. Observations:                 120   AIC:                            -482.5
# Df Residuals:                     115   BIC:                            -468.6
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0025      0.003     -0.890      0.374      -0.008       0.003
# mktrf          1.4341      0.047     30.259      0.000       1.341       1.527
# smb            0.6715      0.095      7.036      0.000       0.484       0.859
# hml           -0.2382      0.069     -3.461      0.001      -0.373      -0.103
# umd           -0.1242      0.069     -1.807      0.071      -0.259       0.010
# ==============================================================================
# Omnibus:                       18.270   Durbin-Watson:                   2.113
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.243
# Skew:                           0.840   Prob(JB):                     8.97e-06
# Kurtosis:                       4.352   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.883
# Model:                            OLS   Adj. R-squared:                  0.879
# Method:                 Least Squares   F-statistic:                     218.0
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.07e-52
# Time:                        12:42:40   Log-Likelihood:                 246.27
# No. Observations:                 120   AIC:                            -482.5
# Df Residuals:                     115   BIC:                            -468.6
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0025      0.003     -0.830      0.408      -0.008       0.003
# mktrf          1.4341      0.072     19.894      0.000       1.291       1.577
# smb            0.6715      0.082      8.181      0.000       0.509       0.834
# hml           -0.2382      0.082     -2.898      0.004      -0.401      -0.075
# umd           -0.1242      0.051     -2.451      0.016      -0.225      -0.024
# ==============================================================================
# Omnibus:                       18.270   Durbin-Watson:                   2.113
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.243
# Skew:                           0.840   Prob(JB):                     8.97e-06
# Kurtosis:                       4.352   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.883
# Model:                            OLS   Adj. R-squared:                  0.879
# Method:                 Least Squares   F-statistic:                     296.9
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.30e-59
# Time:                        12:42:40   Log-Likelihood:                 246.27
# No. Observations:                 120   AIC:                            -482.5
# Df Residuals:                     115   BIC:                            -468.6
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0025      0.003     -0.787      0.431      -0.009       0.004
# mktrf          1.4341      0.061     23.623      0.000       1.315       1.553
# smb            0.6715      0.095      7.094      0.000       0.486       0.857
# hml           -0.2382      0.076     -3.119      0.002      -0.388      -0.089
# umd           -0.1242      0.067     -1.842      0.065      -0.256       0.008
# ==============================================================================
# Omnibus:                       18.270   Durbin-Watson:                   2.113
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.243
# Skew:                           0.840   Prob(JB):                     8.97e-06
# Kurtosis:                       4.352   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.883
# Model:                            OLS   Adj. R-squared:                  0.879
# Method:                 Least Squares   F-statistic:                     518.3
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.51e-72
# Time:                        12:42:40   Log-Likelihood:                 246.27
# No. Observations:                 120   AIC:                            -482.5
# Df Residuals:                     115   BIC:                            -468.6
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0025      0.003     -0.890      0.374      -0.008       0.003
# mktrf          1.4341      0.047     30.259      0.000       1.341       1.527
# smb            0.6715      0.095      7.036      0.000       0.484       0.859
# hml           -0.2382      0.069     -3.461      0.001      -0.373      -0.103
# umd           -0.1242      0.069     -1.807      0.071      -0.259       0.010
# ==============================================================================
# Omnibus:                       18.270   Durbin-Watson:                   2.113
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.243
# Skew:                           0.840   Prob(JB):                     8.97e-06
# Kurtosis:                       4.352   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Post-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.877
# Model:                            OLS   Adj. R-squared:                  0.872
# Method:                 Least Squares   F-statistic:                     194.1
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.28e-48
# Time:                        12:42:40   Log-Likelihood:                 280.28
# No. Observations:                 114   AIC:                            -550.6
# Df Residuals:                     109   BIC:                            -536.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0021      0.002      0.986      0.326      -0.002       0.006
# mktrf          1.0760      0.062     17.287      0.000       0.953       1.199
# me             0.4951      0.096      5.152      0.000       0.305       0.686
# ia            -0.0516      0.133     -0.387      0.699      -0.316       0.213
# roe           -0.8908      0.117     -7.605      0.000      -1.123      -0.659
# ==============================================================================
# Omnibus:                       12.380   Durbin-Watson:                   1.944
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               16.796
# Skew:                           0.564   Prob(JB):                     0.000225
# Kurtosis:                       4.505   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.877
# Model:                            OLS   Adj. R-squared:                  0.872
# Method:                 Least Squares   F-statistic:                     263.1
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           5.06e-55
# Time:                        12:42:40   Log-Likelihood:                 280.28
# No. Observations:                 114   AIC:                            -550.6
# Df Residuals:                     109   BIC:                            -536.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0021      0.002      1.357      0.175      -0.001       0.005
# mktrf          1.0760      0.061     17.743      0.000       0.957       1.195
# me             0.4951      0.059      8.322      0.000       0.378       0.612
# ia            -0.0516      0.118     -0.439      0.661      -0.282       0.179
# roe           -0.8908      0.134     -6.673      0.000      -1.153      -0.629
# ==============================================================================
# Omnibus:                       12.380   Durbin-Watson:                   1.944
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               16.796
# Skew:                           0.564   Prob(JB):                     0.000225
# Kurtosis:                       4.505   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.877
# Model:                            OLS   Adj. R-squared:                  0.872
# Method:                 Least Squares   F-statistic:                     304.1
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           3.77e-58
# Time:                        12:42:40   Log-Likelihood:                 280.28
# No. Observations:                 114   AIC:                            -550.6
# Df Residuals:                     109   BIC:                            -536.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0021      0.001      1.485      0.138      -0.001       0.005
# mktrf          1.0760      0.053     20.396      0.000       0.973       1.179
# me             0.4951      0.055      8.932      0.000       0.386       0.604
# ia            -0.0516      0.112     -0.462      0.644      -0.271       0.167
# roe           -0.8908      0.120     -7.430      0.000      -1.126      -0.656
# ==============================================================================
# Omnibus:                       12.380   Durbin-Watson:                   1.944
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               16.796
# Skew:                           0.564   Prob(JB):                     0.000225
# Kurtosis:                       4.505   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.822
# Model:                            OLS   Adj. R-squared:                  0.816
# Method:                 Least Squares   F-statistic:                     126.2
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           5.65e-40
# Time:                        12:42:40   Log-Likelihood:                 259.39
# No. Observations:                 114   AIC:                            -508.8
# Df Residuals:                     109   BIC:                            -495.1
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0010      0.003     -0.377      0.707      -0.006       0.004
# mktrf          1.1513      0.071     16.250      0.000       1.011       1.292
# smb            0.7287      0.110      6.597      0.000       0.510       0.948
# hml            0.1035      0.114      0.909      0.365      -0.122       0.329
# umd           -0.1861      0.086     -2.168      0.032      -0.356      -0.016
# ==============================================================================
# Omnibus:                       12.395   Durbin-Watson:                   1.884
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               14.285
# Skew:                           0.654   Prob(JB):                     0.000791
# Kurtosis:                       4.139   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.822
# Model:                            OLS   Adj. R-squared:                  0.816
# Method:                 Least Squares   F-statistic:                     155.3
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           4.51e-44
# Time:                        12:42:40   Log-Likelihood:                 259.39
# No. Observations:                 114   AIC:                            -508.8
# Df Residuals:                     109   BIC:                            -495.1
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0010      0.002     -0.503      0.615      -0.005       0.003
# mktrf          1.1513      0.075     15.415      0.000       1.005       1.298
# smb            0.7287      0.088      8.240      0.000       0.555       0.902
# hml            0.1035      0.185      0.559      0.576      -0.260       0.467
# umd           -0.1861      0.095     -1.958      0.050      -0.372       0.000
# ==============================================================================
# Omnibus:                       12.395   Durbin-Watson:                   1.884
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               14.285
# Skew:                           0.654   Prob(JB):                     0.000791
# Kurtosis:                       4.139   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.822
# Model:                            OLS   Adj. R-squared:                  0.816
# Method:                 Least Squares   F-statistic:                     215.9
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           7.79e-51
# Time:                        12:42:40   Log-Likelihood:                 259.39
# No. Observations:                 114   AIC:                            -508.8
# Df Residuals:                     109   BIC:                            -495.1
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0010      0.002     -0.557      0.578      -0.004       0.002
# mktrf          1.1513      0.072     16.049      0.000       1.011       1.292
# smb            0.7287      0.066     11.011      0.000       0.599       0.858
# hml            0.1035      0.189      0.547      0.585      -0.268       0.474
# umd           -0.1861      0.082     -2.258      0.024      -0.348      -0.025
# ==============================================================================
# Omnibus:                       12.395   Durbin-Watson:                   1.884
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               14.285
# Skew:                           0.654   Prob(JB):                     0.000791
# Kurtosis:                       4.139   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.822
# Model:                            OLS   Adj. R-squared:                  0.816
# Method:                 Least Squares   F-statistic:                     126.2
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           5.65e-40
# Time:                        12:42:40   Log-Likelihood:                 259.39
# No. Observations:                 114   AIC:                            -508.8
# Df Residuals:                     109   BIC:                            -495.1
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0010      0.003     -0.377      0.707      -0.006       0.004
# mktrf          1.1513      0.071     16.250      0.000       1.011       1.292
# smb            0.7287      0.110      6.597      0.000       0.510       0.948
# hml            0.1035      0.114      0.909      0.365      -0.122       0.329
# umd           -0.1861      0.086     -2.168      0.032      -0.356      -0.016
# ==============================================================================
# Omnibus:                       12.395   Durbin-Watson:                   1.884
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               14.285
# Skew:                           0.654   Prob(JB):                     0.000791
# Kurtosis:                       4.139   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.822
# Model:                            OLS   Adj. R-squared:                  0.816
# Method:                 Least Squares   F-statistic:                     155.3
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           4.51e-44
# Time:                        12:42:40   Log-Likelihood:                 259.39
# No. Observations:                 114   AIC:                            -508.8
# Df Residuals:                     109   BIC:                            -495.1
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0010      0.002     -0.503      0.615      -0.005       0.003
# mktrf          1.1513      0.075     15.415      0.000       1.005       1.298
# smb            0.7287      0.088      8.240      0.000       0.555       0.902
# hml            0.1035      0.185      0.559      0.576      -0.260       0.467
# umd           -0.1861      0.095     -1.958      0.050      -0.372       0.000
# ==============================================================================
# Omnibus:                       12.395   Durbin-Watson:                   1.884
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               14.285
# Skew:                           0.654   Prob(JB):                     0.000791
# Kurtosis:                       4.139   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.822
# Model:                            OLS   Adj. R-squared:                  0.816
# Method:                 Least Squares   F-statistic:                     215.9
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           7.79e-51
# Time:                        12:42:40   Log-Likelihood:                 259.39
# No. Observations:                 114   AIC:                            -508.8
# Df Residuals:                     109   BIC:                            -495.1
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0010      0.002     -0.557      0.578      -0.004       0.002
# mktrf          1.1513      0.072     16.049      0.000       1.011       1.292
# smb            0.7287      0.066     11.011      0.000       0.599       0.858
# hml            0.1035      0.189      0.547      0.585      -0.268       0.474
# umd           -0.1861      0.082     -2.258      0.024      -0.348      -0.025
# ==============================================================================
# Omnibus:                       12.395   Durbin-Watson:                   1.884
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               14.285
# Skew:                           0.654   Prob(JB):                     0.000791
# Kurtosis:                       4.139   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """
