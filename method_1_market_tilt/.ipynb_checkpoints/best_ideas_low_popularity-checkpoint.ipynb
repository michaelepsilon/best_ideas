# %% [markdown]
# # Method 1 - Best Ideas Low Popularity

# %%
# %matplotlib inline
import pandas as pd
import warnings
from statsmodels import api as sm

from eptooling import crsp, epd, fs, hfu, crsp, db, bi
from eptooling.bm import bmdb, iso
from epquant.engine import weights, portfolio
from epquant.gen import returns
from epquant.perf import relative_performance

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Fetch Holdings and Benchmark Data

# %%
# Get HFU Data

# %store -r inst_data
inst_data = inst_data[inst_data['datadate'] >= '1999-06-30']

# Count number of positions per manager

inst_data['num_pos'] = inst_data.groupby(['datadate', 'institution_id'])[
    'fsym_id'].transform(lambda s: s.nunique())

# Remove less than 20 holdings and less than $5mm per CSP

valid_data = inst_data[inst_data['num_pos'] >= 20]
valid_data = valid_data[valid_data['public_aum'] >= 5e6]

# Get Benchmark Weights

bm = crsp.get_crsp_market_portfolio()

# Merge Benchmark Weights onto Holdings

valid_data = valid_data.merge(bm, how='left', on=['datadate', 'fsym_id'])

# Calculate Market Tilt

valid_data['adj_target'] = valid_data['target'] - valid_data['weight'].fillna(0)

# %% [markdown]
# ## Calculate Best Ideas

# %%
# Extract Best Ideas

valid_data['pos_rank'] = valid_data\
    .groupby(['datadate', 'institution_id'])['adj_target'].rank(ascending=False)

best_ideas = valid_data[valid_data['pos_rank'] == 1].copy()

# Filter Popularity

best_ideas['port_tilt_pct'] = best_ideas.groupby('datadate')['adj_target'].rank(pct=True)

popularity = best_ideas.groupby(['datadate', 'fsym_id'])['port_tilt_pct'].sum().reset_index()
popularity['median_port_tilt_pct'] = popularity.groupby('datadate')['port_tilt_pct'].transform('median')
popularity = popularity[popularity['port_tilt_pct'] < popularity['median_port_tilt_pct']]

best_ideas = best_ideas.merge(popularity[['datadate', 'fsym_id', 'median_port_tilt_pct']])

# Weight the best ideas equally

best_ideas['target'] = 1 / best_ideas.groupby('datadate')['institution_id'].transform('count')

# %% [markdown]
# ## Backtest Portfolio

# %%
w = weights.Weights(best_ideas)

# %store -r r

p = portfolio.DailyPortfolio(w, r, end_date='2018-12-31')

rf = bi.get_risk_free_rate()
monthly_return = p.port_return.loc['1999-07-01':].resample('M').apply(epd.prod_red)
monthly_return = (monthly_return - rf).dropna()
monthly_return.name = 'port_return'

# %% [markdown]
# ## Plot Performance

# %%
epd.nav(monthly_return).plot()

# %%
monthly_return.resample('A').apply(epd.prod_red)
# Out:
# datadate
# 1999-12-31    0.213849
# 2000-12-31   -0.088425
# 2001-12-31   -0.160795
# 2002-12-31   -0.171888
# 2003-12-31    0.453966
# 2004-12-31    0.151118
# 2005-12-31    0.080184
# 2006-12-31    0.124008
# 2007-12-31    0.063373
# 2008-12-31   -0.377930
# 2009-12-31    0.339011
# 2010-12-31    0.255944
# 2011-12-31   -0.038633
# 2012-12-31    0.188667
# 2013-12-31    0.446312
# 2014-12-31    0.048711
# 2015-12-31   -0.009089
# 2016-12-31    0.130444
# 2017-12-31    0.172636
# 2018-12-31   -0.088177
# Freq: A-DEC, Name: port_return, dtype: float64

# %% [markdown]
# ## Fetch Factor Models

# %%
# Get Factor Models
q_factor_model = bi.get_q_factor_model()
fama_french_five_factor_model = bi.get_fama_french_five_factor_model()
four_factor_model = bi.get_four_factor_model()

# Concat Portfolio Return
q_factor = pd.concat([monthly_return, q_factor_model], axis=1)
fama_french_five = pd.concat([monthly_return, fama_french_five_factor_model], axis=1)
four_factor = pd.concat([monthly_return, four_factor_model], axis=1)

# Add Constants
q_factor.insert(1, 'const', 1)
fama_french_five.insert(1, 'const', 1)
four_factor.insert(1, 'const', 1)

# Split Period into Pre and Post Crisis
q_factor_pre, q_factor_post = q_factor.loc[:'2009-06-30'], q_factor.loc['2009-07-31':]
fama_french_five_pre, fama_french_five_post = fama_french_five.loc[:'2009-06-30'], fama_french_five.loc['2009-07-31':] 
four_factor_pre, four_factor_post = four_factor.loc[:'2009-06-30'], four_factor.loc['2009-07-31':]

# %% [markdown]
# ## Full Time Period Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.936
# Model:                            OLS   Adj. R-squared:                  0.934
# Method:                 Least Squares   F-statistic:                     831.3
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):          4.73e-135
# Time:                        11:53:01   Log-Likelihood:                 696.94
# No. Observations:                 234   AIC:                            -1384.
# Df Residuals:                     229   BIC:                            -1367.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0004      0.001      0.473      0.637      -0.001       0.002
# mktrf          1.0093      0.023     43.487      0.000       0.964       1.055
# me             0.4326      0.027     16.024      0.000       0.379       0.486
# ia            -0.0221      0.041     -0.538      0.591      -0.103       0.059
# roe            0.1676      0.035      4.772      0.000       0.098       0.237
# ==============================================================================
# Omnibus:                       23.884   Durbin-Watson:                   1.946
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              106.094
# Skew:                           0.085   Prob(JB):                     9.16e-24
# Kurtosis:                       6.294   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.936
# Model:                            OLS   Adj. R-squared:                  0.934
# Method:                 Least Squares   F-statistic:                     619.5
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):          1.61e-121
# Time:                        11:53:01   Log-Likelihood:                 696.94
# No. Observations:                 234   AIC:                            -1384.
# Df Residuals:                     229   BIC:                            -1367.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0004      0.001      0.527      0.598      -0.001       0.002
# mktrf          1.0093      0.032     31.949      0.000       0.947       1.071
# me             0.4326      0.031     13.971      0.000       0.372       0.493
# ia            -0.0221      0.068     -0.327      0.744      -0.155       0.110
# roe            0.1676      0.047      3.572      0.000       0.076       0.260
# ==============================================================================
# Omnibus:                       23.884   Durbin-Watson:                   1.946
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              106.094
# Skew:                           0.085   Prob(JB):                     9.16e-24
# Kurtosis:                       6.294   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.936
# Model:                            OLS   Adj. R-squared:                  0.934
# Method:                 Least Squares   F-statistic:                     738.3
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):          1.48e-129
# Time:                        11:53:01   Log-Likelihood:                 696.94
# No. Observations:                 234   AIC:                            -1384.
# Df Residuals:                     229   BIC:                            -1367.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0004      0.001      0.554      0.580      -0.001       0.002
# mktrf          1.0093      0.027     38.059      0.000       0.957       1.061
# me             0.4326      0.029     14.875      0.000       0.376       0.490
# ia            -0.0221      0.061     -0.363      0.717      -0.141       0.097
# roe            0.1676      0.045      3.689      0.000       0.079       0.257
# ==============================================================================
# Omnibus:                       23.884   Durbin-Watson:                   1.946
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              106.094
# Skew:                           0.085   Prob(JB):                     9.16e-24
# Kurtosis:                       6.294   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.932
# Model:                            OLS   Adj. R-squared:                  0.930
# Method:                 Least Squares   F-statistic:                     779.7
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):          4.48e-132
# Time:                        11:53:01   Log-Likelihood:                 689.93
# No. Observations:                 234   AIC:                            -1370.
# Df Residuals:                     229   BIC:                            -1353.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0007      0.001      0.776      0.439      -0.001       0.002
# mktrf          1.0226      0.022     46.443      0.000       0.979       1.066
# smb            0.3420      0.027     12.444      0.000       0.288       0.396
# hml            0.1066      0.027      3.905      0.000       0.053       0.160
# umd            0.1273      0.018      7.107      0.000       0.092       0.163
# ==============================================================================
# Omnibus:                       30.205   Durbin-Watson:                   1.859
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              186.188
# Skew:                           0.045   Prob(JB):                     3.71e-41
# Kurtosis:                       7.369   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.932
# Model:                            OLS   Adj. R-squared:                  0.930
# Method:                 Least Squares   F-statistic:                     791.2
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):          9.29e-133
# Time:                        11:53:01   Log-Likelihood:                 689.93
# No. Observations:                 234   AIC:                            -1370.
# Df Residuals:                     229   BIC:                            -1353.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0007      0.001      0.799      0.424      -0.001       0.002
# mktrf          1.0226      0.033     31.267      0.000       0.958       1.087
# smb            0.3420      0.036      9.567      0.000       0.272       0.412
# hml            0.1066      0.051      2.088      0.037       0.007       0.207
# umd            0.1273      0.038      3.392      0.001       0.054       0.201
# ==============================================================================
# Omnibus:                       30.205   Durbin-Watson:                   1.859
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              186.188
# Skew:                           0.045   Prob(JB):                     3.71e-41
# Kurtosis:                       7.369   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.932
# Model:                            OLS   Adj. R-squared:                  0.930
# Method:                 Least Squares   F-statistic:                     1022.
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):          9.83e-145
# Time:                        11:53:01   Log-Likelihood:                 689.93
# No. Observations:                 234   AIC:                            -1370.
# Df Residuals:                     229   BIC:                            -1353.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0007      0.001      0.896      0.370      -0.001       0.002
# mktrf          1.0226      0.026     39.800      0.000       0.972       1.073
# smb            0.3420      0.035      9.832      0.000       0.274       0.410
# hml            0.1066      0.048      2.240      0.025       0.013       0.200
# umd            0.1273      0.032      3.926      0.000       0.064       0.191
# ==============================================================================
# Omnibus:                       30.205   Durbin-Watson:                   1.859
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              186.188
# Skew:                           0.045   Prob(JB):                     3.71e-41
# Kurtosis:                       7.369   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.932
# Model:                            OLS   Adj. R-squared:                  0.930
# Method:                 Least Squares   F-statistic:                     779.7
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):          4.48e-132
# Time:                        11:53:01   Log-Likelihood:                 689.93
# No. Observations:                 234   AIC:                            -1370.
# Df Residuals:                     229   BIC:                            -1353.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0007      0.001      0.776      0.439      -0.001       0.002
# mktrf          1.0226      0.022     46.443      0.000       0.979       1.066
# smb            0.3420      0.027     12.444      0.000       0.288       0.396
# hml            0.1066      0.027      3.905      0.000       0.053       0.160
# umd            0.1273      0.018      7.107      0.000       0.092       0.163
# ==============================================================================
# Omnibus:                       30.205   Durbin-Watson:                   1.859
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              186.188
# Skew:                           0.045   Prob(JB):                     3.71e-41
# Kurtosis:                       7.369   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.932
# Model:                            OLS   Adj. R-squared:                  0.930
# Method:                 Least Squares   F-statistic:                     791.2
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):          9.29e-133
# Time:                        11:53:01   Log-Likelihood:                 689.93
# No. Observations:                 234   AIC:                            -1370.
# Df Residuals:                     229   BIC:                            -1353.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0007      0.001      0.799      0.424      -0.001       0.002
# mktrf          1.0226      0.033     31.267      0.000       0.958       1.087
# smb            0.3420      0.036      9.567      0.000       0.272       0.412
# hml            0.1066      0.051      2.088      0.037       0.007       0.207
# umd            0.1273      0.038      3.392      0.001       0.054       0.201
# ==============================================================================
# Omnibus:                       30.205   Durbin-Watson:                   1.859
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              186.188
# Skew:                           0.045   Prob(JB):                     3.71e-41
# Kurtosis:                       7.369   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.932
# Model:                            OLS   Adj. R-squared:                  0.930
# Method:                 Least Squares   F-statistic:                     1022.
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):          9.83e-145
# Time:                        11:53:01   Log-Likelihood:                 689.93
# No. Observations:                 234   AIC:                            -1370.
# Df Residuals:                     229   BIC:                            -1353.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0007      0.001      0.896      0.370      -0.001       0.002
# mktrf          1.0226      0.026     39.800      0.000       0.972       1.073
# smb            0.3420      0.035      9.832      0.000       0.274       0.410
# hml            0.1066      0.048      2.240      0.025       0.013       0.200
# umd            0.1273      0.032      3.926      0.000       0.064       0.191
# ==============================================================================
# Omnibus:                       30.205   Durbin-Watson:                   1.859
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              186.188
# Skew:                           0.045   Prob(JB):                     3.71e-41
# Kurtosis:                       7.369   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Pre-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.924
# Model:                            OLS   Adj. R-squared:                  0.922
# Method:                 Least Squares   F-statistic:                     350.4
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           2.09e-63
# Time:                        11:53:01   Log-Likelihood:                 335.80
# No. Observations:                 120   AIC:                            -661.6
# Df Residuals:                     115   BIC:                            -647.7
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -7.408e-06      0.001     -0.005      0.996      -0.003       0.003
# mktrf          1.0423      0.039     26.859      0.000       0.965       1.119
# me             0.4582      0.038     11.954      0.000       0.382       0.534
# ia            -0.0594      0.060     -0.989      0.325      -0.178       0.060
# roe            0.2508      0.053      4.721      0.000       0.146       0.356
# ==============================================================================
# Omnibus:                       11.358   Durbin-Watson:                   2.037
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               30.234
# Skew:                           0.105   Prob(JB):                     2.72e-07
# Kurtosis:                       5.450   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.924
# Model:                            OLS   Adj. R-squared:                  0.922
# Method:                 Least Squares   F-statistic:                     349.3
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           2.48e-63
# Time:                        11:53:01   Log-Likelihood:                 335.80
# No. Observations:                 120   AIC:                            -661.6
# Df Residuals:                     115   BIC:                            -647.7
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -7.408e-06      0.001     -0.006      0.995      -0.002       0.002
# mktrf          1.0423      0.053     19.579      0.000       0.938       1.147
# me             0.4582      0.037     12.315      0.000       0.385       0.531
# ia            -0.0594      0.084     -0.711      0.477      -0.223       0.104
# roe            0.2508      0.058      4.294      0.000       0.136       0.365
# ==============================================================================
# Omnibus:                       11.358   Durbin-Watson:                   2.037
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               30.234
# Skew:                           0.105   Prob(JB):                     2.72e-07
# Kurtosis:                       5.450   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.924
# Model:                            OLS   Adj. R-squared:                  0.922
# Method:                 Least Squares   F-statistic:                     498.5
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           1.25e-71
# Time:                        11:53:01   Log-Likelihood:                 335.80
# No. Observations:                 120   AIC:                            -661.6
# Df Residuals:                     115   BIC:                            -647.7
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -7.408e-06      0.001     -0.006      0.995      -0.002       0.002
# mktrf          1.0423      0.041     25.519      0.000       0.962       1.122
# me             0.4582      0.035     13.178      0.000       0.390       0.526
# ia            -0.0594      0.075     -0.796      0.426      -0.205       0.087
# roe            0.2508      0.043      5.876      0.000       0.167       0.334
# ==============================================================================
# Omnibus:                       11.358   Durbin-Watson:                   2.037
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               30.234
# Skew:                           0.105   Prob(JB):                     2.72e-07
# Kurtosis:                       5.450   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.911
# Model:                            OLS   Adj. R-squared:                  0.908
# Method:                 Least Squares   F-statistic:                     295.8
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           1.60e-59
# Time:                        11:53:01   Log-Likelihood:                 326.46
# No. Observations:                 120   AIC:                            -642.9
# Df Residuals:                     115   BIC:                            -629.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0018      0.002      1.199      0.233      -0.001       0.005
# mktrf          1.0416      0.037     28.184      0.000       0.968       1.115
# smb            0.3254      0.042      7.734      0.000       0.242       0.409
# hml            0.1125      0.042      2.670      0.009       0.029       0.196
# umd            0.1418      0.026      5.459      0.000       0.090       0.193
# ==============================================================================
# Omnibus:                       12.299   Durbin-Watson:                   1.943
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               33.752
# Skew:                          -0.167   Prob(JB):                     4.69e-08
# Kurtosis:                       5.577   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.911
# Model:                            OLS   Adj. R-squared:                  0.908
# Method:                 Least Squares   F-statistic:                     368.7
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           1.41e-64
# Time:                        11:53:01   Log-Likelihood:                 326.46
# No. Observations:                 120   AIC:                            -642.9
# Df Residuals:                     115   BIC:                            -629.0
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0018      0.001      1.403      0.161      -0.001       0.004
# mktrf          1.0416      0.052     19.885      0.000       0.939       1.144
# smb            0.3254      0.048      6.851      0.000       0.232       0.419
# hml            0.1125      0.064      1.765      0.078      -0.012       0.237
# umd            0.1418      0.048      2.986      0.003       0.049       0.235
# ==============================================================================
# Omnibus:                       12.299   Durbin-Watson:                   1.943
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               33.752
# Skew:                          -0.167   Prob(JB):                     4.69e-08
# Kurtosis:                       5.577   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.911
# Model:                            OLS   Adj. R-squared:                  0.908
# Method:                 Least Squares   F-statistic:                     567.9
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           1.04e-74
# Time:                        11:53:01   Log-Likelihood:                 326.46
# No. Observations:                 120   AIC:                            -642.9
# Df Residuals:                     115   BIC:                            -629.0
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0018      0.001      1.458      0.145      -0.001       0.004
# mktrf          1.0416      0.037     28.170      0.000       0.969       1.114
# smb            0.3254      0.041      8.001      0.000       0.246       0.405
# hml            0.1125      0.059      1.921      0.055      -0.002       0.227
# umd            0.1418      0.037      3.798      0.000       0.069       0.215
# ==============================================================================
# Omnibus:                       12.299   Durbin-Watson:                   1.943
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               33.752
# Skew:                          -0.167   Prob(JB):                     4.69e-08
# Kurtosis:                       5.577   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.911
# Model:                            OLS   Adj. R-squared:                  0.908
# Method:                 Least Squares   F-statistic:                     295.8
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           1.60e-59
# Time:                        11:53:01   Log-Likelihood:                 326.46
# No. Observations:                 120   AIC:                            -642.9
# Df Residuals:                     115   BIC:                            -629.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0018      0.002      1.199      0.233      -0.001       0.005
# mktrf          1.0416      0.037     28.184      0.000       0.968       1.115
# smb            0.3254      0.042      7.734      0.000       0.242       0.409
# hml            0.1125      0.042      2.670      0.009       0.029       0.196
# umd            0.1418      0.026      5.459      0.000       0.090       0.193
# ==============================================================================
# Omnibus:                       12.299   Durbin-Watson:                   1.943
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               33.752
# Skew:                          -0.167   Prob(JB):                     4.69e-08
# Kurtosis:                       5.577   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.911
# Model:                            OLS   Adj. R-squared:                  0.908
# Method:                 Least Squares   F-statistic:                     368.7
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           1.41e-64
# Time:                        11:53:01   Log-Likelihood:                 326.46
# No. Observations:                 120   AIC:                            -642.9
# Df Residuals:                     115   BIC:                            -629.0
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0018      0.001      1.403      0.161      -0.001       0.004
# mktrf          1.0416      0.052     19.885      0.000       0.939       1.144
# smb            0.3254      0.048      6.851      0.000       0.232       0.419
# hml            0.1125      0.064      1.765      0.078      -0.012       0.237
# umd            0.1418      0.048      2.986      0.003       0.049       0.235
# ==============================================================================
# Omnibus:                       12.299   Durbin-Watson:                   1.943
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               33.752
# Skew:                          -0.167   Prob(JB):                     4.69e-08
# Kurtosis:                       5.577   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.911
# Model:                            OLS   Adj. R-squared:                  0.908
# Method:                 Least Squares   F-statistic:                     567.9
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           1.04e-74
# Time:                        11:53:01   Log-Likelihood:                 326.46
# No. Observations:                 120   AIC:                            -642.9
# Df Residuals:                     115   BIC:                            -629.0
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0018      0.001      1.458      0.145      -0.001       0.004
# mktrf          1.0416      0.037     28.170      0.000       0.969       1.114
# smb            0.3254      0.041      8.001      0.000       0.246       0.405
# hml            0.1125      0.059      1.921      0.055      -0.002       0.227
# umd            0.1418      0.037      3.798      0.000       0.069       0.215
# ==============================================================================
# Omnibus:                       12.299   Durbin-Watson:                   1.943
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               33.752
# Skew:                          -0.167   Prob(JB):                     4.69e-08
# Kurtosis:                       5.577   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Post-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.963
# Model:                            OLS   Adj. R-squared:                  0.961
# Method:                 Least Squares   F-statistic:                     704.0
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           7.34e-77
# Time:                        11:53:01   Log-Likelihood:                 386.88
# No. Observations:                 114   AIC:                            -763.8
# Df Residuals:                     109   BIC:                            -750.1
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0010      0.001      1.182      0.240      -0.001       0.003
# mktrf          0.9909      0.024     40.553      0.000       0.942       1.039
# me             0.3674      0.038      9.738      0.000       0.293       0.442
# ia             0.0119      0.052      0.227      0.821      -0.092       0.116
# roe           -0.0243      0.046     -0.528      0.599      -0.115       0.067
# ==============================================================================
# Omnibus:                        0.820   Durbin-Watson:                   1.649
# Prob(Omnibus):                  0.664   Jarque-Bera (JB):                0.920
# Skew:                          -0.124   Prob(JB):                        0.631
# Kurtosis:                       2.637   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.963
# Model:                            OLS   Adj. R-squared:                  0.961
# Method:                 Least Squares   F-statistic:                     961.6
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           5.32e-84
# Time:                        11:53:01   Log-Likelihood:                 386.88
# No. Observations:                 114   AIC:                            -763.8
# Df Residuals:                     109   BIC:                            -750.1
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0010      0.001      1.242      0.214      -0.001       0.003
# mktrf          0.9909      0.020     48.705      0.000       0.951       1.031
# me             0.3674      0.039      9.431      0.000       0.291       0.444
# ia             0.0119      0.054      0.218      0.827      -0.095       0.119
# roe           -0.0243      0.050     -0.488      0.625      -0.122       0.073
# ==============================================================================
# Omnibus:                        0.820   Durbin-Watson:                   1.649
# Prob(Omnibus):                  0.664   Jarque-Bera (JB):                0.920
# Skew:                          -0.124   Prob(JB):                        0.631
# Kurtosis:                       2.637   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.963
# Model:                            OLS   Adj. R-squared:                  0.961
# Method:                 Least Squares   F-statistic:                     950.1
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           1.01e-83
# Time:                        11:53:01   Log-Likelihood:                 386.88
# No. Observations:                 114   AIC:                            -763.8
# Df Residuals:                     109   BIC:                            -750.1
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0010      0.001      1.576      0.115      -0.000       0.002
# mktrf          0.9909      0.021     47.142      0.000       0.950       1.032
# me             0.3674      0.043      8.524      0.000       0.283       0.452
# ia             0.0119      0.059      0.200      0.842      -0.105       0.128
# roe           -0.0243      0.042     -0.583      0.560      -0.106       0.057
# ==============================================================================
# Omnibus:                        0.820   Durbin-Watson:                   1.649
# Prob(Omnibus):                  0.664   Jarque-Bera (JB):                0.920
# Skew:                          -0.124   Prob(JB):                        0.631
# Kurtosis:                       2.637   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.968
# Model:                            OLS   Adj. R-squared:                  0.967
# Method:                 Least Squares   F-statistic:                     835.9
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           8.75e-81
# Time:                        11:53:01   Log-Likelihood:                 396.33
# No. Observations:                 114   AIC:                            -782.7
# Df Residuals:                     109   BIC:                            -769.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.001     -0.452      0.652      -0.002       0.001
# mktrf          1.0139      0.021     47.571      0.000       0.972       1.056
# smb            0.3690      0.033     11.103      0.000       0.303       0.435
# hml            0.0468      0.034      1.366      0.175      -0.021       0.115
# umd            0.0702      0.026      2.718      0.008       0.019       0.121
# ==============================================================================
# Omnibus:                        1.364   Durbin-Watson:                   1.505
# Prob(Omnibus):                  0.506   Jarque-Bera (JB):                1.183
# Skew:                           0.057   Prob(JB):                        0.554
# Kurtosis:                       2.514   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.968
# Model:                            OLS   Adj. R-squared:                  0.967
# Method:                 Least Squares   F-statistic:                     709.9
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           4.71e-77
# Time:                        11:53:01   Log-Likelihood:                 396.33
# No. Observations:                 114   AIC:                            -782.7
# Df Residuals:                     109   BIC:                            -769.0
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.001     -0.387      0.699      -0.002       0.001
# mktrf          1.0139      0.023     43.286      0.000       0.968       1.060
# smb            0.3690      0.027     13.828      0.000       0.317       0.421
# hml            0.0468      0.038      1.247      0.212      -0.027       0.120
# umd            0.0702      0.022      3.159      0.002       0.027       0.114
# ==============================================================================
# Omnibus:                        1.364   Durbin-Watson:                   1.505
# Prob(Omnibus):                  0.506   Jarque-Bera (JB):                1.183
# Skew:                           0.057   Prob(JB):                        0.554
# Kurtosis:                       2.514   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.968
# Model:                            OLS   Adj. R-squared:                  0.967
# Method:                 Least Squares   F-statistic:                     569.4
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           4.75e-72
# Time:                        11:53:01   Log-Likelihood:                 396.33
# No. Observations:                 114   AIC:                            -782.7
# Df Residuals:                     109   BIC:                            -769.0
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.001     -0.479      0.632      -0.002       0.001
# mktrf          1.0139      0.027     37.871      0.000       0.961       1.066
# smb            0.3690      0.028     13.369      0.000       0.315       0.423
# hml            0.0468      0.035      1.326      0.185      -0.022       0.116
# umd            0.0702      0.021      3.281      0.001       0.028       0.112
# ==============================================================================
# Omnibus:                        1.364   Durbin-Watson:                   1.505
# Prob(Omnibus):                  0.506   Jarque-Bera (JB):                1.183
# Skew:                           0.057   Prob(JB):                        0.554
# Kurtosis:                       2.514   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.968
# Model:                            OLS   Adj. R-squared:                  0.967
# Method:                 Least Squares   F-statistic:                     835.9
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           8.75e-81
# Time:                        11:53:01   Log-Likelihood:                 396.33
# No. Observations:                 114   AIC:                            -782.7
# Df Residuals:                     109   BIC:                            -769.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.001     -0.452      0.652      -0.002       0.001
# mktrf          1.0139      0.021     47.571      0.000       0.972       1.056
# smb            0.3690      0.033     11.103      0.000       0.303       0.435
# hml            0.0468      0.034      1.366      0.175      -0.021       0.115
# umd            0.0702      0.026      2.718      0.008       0.019       0.121
# ==============================================================================
# Omnibus:                        1.364   Durbin-Watson:                   1.505
# Prob(Omnibus):                  0.506   Jarque-Bera (JB):                1.183
# Skew:                           0.057   Prob(JB):                        0.554
# Kurtosis:                       2.514   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.968
# Model:                            OLS   Adj. R-squared:                  0.967
# Method:                 Least Squares   F-statistic:                     709.9
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           4.71e-77
# Time:                        11:53:01   Log-Likelihood:                 396.33
# No. Observations:                 114   AIC:                            -782.7
# Df Residuals:                     109   BIC:                            -769.0
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.001     -0.387      0.699      -0.002       0.001
# mktrf          1.0139      0.023     43.286      0.000       0.968       1.060
# smb            0.3690      0.027     13.828      0.000       0.317       0.421
# hml            0.0468      0.038      1.247      0.212      -0.027       0.120
# umd            0.0702      0.022      3.159      0.002       0.027       0.114
# ==============================================================================
# Omnibus:                        1.364   Durbin-Watson:                   1.505
# Prob(Omnibus):                  0.506   Jarque-Bera (JB):                1.183
# Skew:                           0.057   Prob(JB):                        0.554
# Kurtosis:                       2.514   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.968
# Model:                            OLS   Adj. R-squared:                  0.967
# Method:                 Least Squares   F-statistic:                     569.4
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           4.75e-72
# Time:                        11:53:01   Log-Likelihood:                 396.33
# No. Observations:                 114   AIC:                            -782.7
# Df Residuals:                     109   BIC:                            -769.0
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.001     -0.479      0.632      -0.002       0.001
# mktrf          1.0139      0.027     37.871      0.000       0.961       1.066
# smb            0.3690      0.028     13.369      0.000       0.315       0.423
# hml            0.0468      0.035      1.326      0.185      -0.022       0.116
# umd            0.0702      0.021      3.281      0.001       0.028       0.112
# ==============================================================================
# Omnibus:                        1.364   Durbin-Watson:                   1.505
# Prob(Omnibus):                  0.506   Jarque-Bera (JB):                1.183
# Skew:                           0.057   Prob(JB):                        0.554
# Kurtosis:                       2.514   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """
