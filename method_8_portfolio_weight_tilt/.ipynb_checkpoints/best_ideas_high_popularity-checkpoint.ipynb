# %% [markdown]
# # Method 8 - Best Ideas High Popularity

# %%
# %matplotlib inline
import pandas as pd
import warnings
from statsmodels import api as sm

from eptooling import crsp, epd, fs, hfu, crsp, db, bi
from eptooling.bm import bmdb, iso
from epquant.engine import weights, portfolio
from epquant.gen import returns
from epquant.perf import relative_performance

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Fetch Holdings and Benchmark Data

# %%
# Get HFU Data

# %store -r inst_data
inst_data = inst_data[inst_data['datadate'] >= '1999-06-30']

# Count number of positions per manager

inst_data['num_pos'] = inst_data.groupby(['datadate', 'institution_id'])[
    'fsym_id'].transform(lambda s: s.nunique())

# Remove less than 20 holdings and less than $5mm per CSP

valid_data = inst_data[inst_data['num_pos'] >= 20]
valid_data = valid_data[valid_data['public_aum'] >= 5e6]

# Use Raw Weight

valid_data['adj_target'] = valid_data['target']

# %% [markdown]
# ## Calculate Best Ideas

# %%
# Extract Best Ideas

valid_data['pos_rank'] = valid_data\
    .groupby(['datadate', 'institution_id'])['adj_target'].rank(ascending=False)

best_ideas = valid_data[valid_data['pos_rank'] == 1].copy()

# Filter Popularity

best_ideas['port_tilt_pct'] = best_ideas.groupby('datadate')['adj_target'].rank(pct=True)

popularity = best_ideas.groupby(['datadate', 'fsym_id'])['port_tilt_pct'].sum().reset_index()
popularity['median_port_tilt_pct'] = popularity.groupby('datadate')['port_tilt_pct'].transform('median')
popularity = popularity[popularity['port_tilt_pct'] > popularity['median_port_tilt_pct']]

best_ideas = best_ideas.merge(popularity[['datadate', 'fsym_id', 'median_port_tilt_pct']])

# Weight the best ideas equally

best_ideas['target'] = 1 / best_ideas.groupby('datadate')['institution_id'].transform('count')

# %% [markdown]
# ## Backtest Portfolio

# %%
w = weights.Weights(best_ideas)

# %store -r r

p = portfolio.DailyPortfolio(w, r, end_date='2018-12-31')

rf = bi.get_risk_free_rate()
monthly_return = p.port_return.loc['1999-07-01':].resample('M').apply(epd.prod_red)
monthly_return = (monthly_return - rf).dropna()
monthly_return.name = 'port_return'

# %% [markdown]
# ## Plot Performance

# %%
epd.nav(monthly_return).plot()

# %%
monthly_return.resample('A').apply(epd.prod_red)
# Out:
# datadate
# 1999-12-31    0.439783
# 2000-12-31   -0.309195
# 2001-12-31   -0.191250
# 2002-12-31   -0.357579
# 2003-12-31    0.935519
# 2004-12-31    0.181701
# 2005-12-31    0.013122
# 2006-12-31    0.090623
# 2007-12-31    0.006814
# 2008-12-31   -0.528840
# 2009-12-31    0.801199
# 2010-12-31    0.236823
# 2011-12-31   -0.133634
# 2012-12-31    0.290019
# 2013-12-31    0.563675
# 2014-12-31    0.085083
# 2015-12-31   -0.119673
# 2016-12-31    0.172174
# 2017-12-31    0.198446
# 2018-12-31   -0.125633
# Freq: A-DEC, Name: port_return, dtype: float64

# %% [markdown]
# ## Fetch Factor Models

# %%
# Get Factor Models
q_factor_model = bi.get_q_factor_model()
fama_french_five_factor_model = bi.get_fama_french_five_factor_model()
four_factor_model = bi.get_four_factor_model()

# Concat Portfolio Return
q_factor = pd.concat([monthly_return, q_factor_model], axis=1)
fama_french_five = pd.concat([monthly_return, fama_french_five_factor_model], axis=1)
four_factor = pd.concat([monthly_return, four_factor_model], axis=1)

# Add Constants
q_factor.insert(1, 'const', 1)
fama_french_five.insert(1, 'const', 1)
four_factor.insert(1, 'const', 1)

# Split Period into Pre and Post Crisis
q_factor_pre, q_factor_post = q_factor.loc[:'2009-06-30'], q_factor.loc['2009-07-31':]
fama_french_five_pre, fama_french_five_post = fama_french_five.loc[:'2009-06-30'], fama_french_five.loc['2009-07-31':] 
four_factor_pre, four_factor_post = four_factor.loc[:'2009-06-30'], four_factor.loc['2009-07-31':]

# %% [markdown]
# ## Full Time Period Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.878
# Model:                            OLS   Adj. R-squared:                  0.876
# Method:                 Least Squares   F-statistic:                     413.1
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):          1.90e-103
# Time:                        12:49:23   Log-Likelihood:                 499.19
# No. Observations:                 234   AIC:                            -988.4
# Df Residuals:                     229   BIC:                            -971.1
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0047      0.002      2.396      0.017       0.001       0.009
# mktrf          1.0520      0.054     19.469      0.000       0.946       1.158
# me             0.6391      0.063     10.167      0.000       0.515       0.763
# ia            -0.1367      0.096     -1.431      0.154      -0.325       0.052
# roe           -0.9233      0.082    -11.291      0.000      -1.084      -0.762
# ==============================================================================
# Omnibus:                       61.096   Durbin-Watson:                   1.978
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              239.537
# Skew:                           1.001   Prob(JB):                     9.67e-53
# Kurtosis:                       7.535   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.878
# Model:                            OLS   Adj. R-squared:                  0.876
# Method:                 Least Squares   F-statistic:                     253.0
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           8.63e-83
# Time:                        12:49:23   Log-Likelihood:                 499.19
# No. Observations:                 234   AIC:                            -988.4
# Df Residuals:                     229   BIC:                            -971.1
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0047      0.002      2.038      0.042       0.000       0.009
# mktrf          1.0520      0.052     20.239      0.000       0.950       1.154
# me             0.6391      0.083      7.724      0.000       0.477       0.801
# ia            -0.1367      0.173     -0.789      0.430      -0.476       0.203
# roe           -0.9233      0.171     -5.406      0.000      -1.258      -0.589
# ==============================================================================
# Omnibus:                       61.096   Durbin-Watson:                   1.978
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              239.537
# Skew:                           1.001   Prob(JB):                     9.67e-53
# Kurtosis:                       7.535   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.878
# Model:                            OLS   Adj. R-squared:                  0.876
# Method:                 Least Squares   F-statistic:                     336.5
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.27e-94
# Time:                        12:49:23   Log-Likelihood:                 499.19
# No. Observations:                 234   AIC:                            -988.4
# Df Residuals:                     229   BIC:                            -971.1
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0047      0.002      2.119      0.034       0.000       0.009
# mktrf          1.0520      0.041     25.379      0.000       0.971       1.133
# me             0.6391      0.086      7.438      0.000       0.471       0.807
# ia            -0.1367      0.140     -0.975      0.330      -0.412       0.138
# roe           -0.9233      0.177     -5.214      0.000      -1.270      -0.576
# ==============================================================================
# Omnibus:                       61.096   Durbin-Watson:                   1.978
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              239.537
# Skew:                           1.001   Prob(JB):                     9.67e-53
# Kurtosis:                       7.535   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.837
# Model:                            OLS   Adj. R-squared:                  0.834
# Method:                 Least Squares   F-statistic:                     294.6
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           4.89e-89
# Time:                        12:49:23   Log-Likelihood:                 465.24
# No. Observations:                 234   AIC:                            -920.5
# Df Residuals:                     229   BIC:                            -903.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0010      0.002      0.452      0.652      -0.003       0.005
# mktrf          1.2797      0.058     22.249      0.000       1.166       1.393
# smb            0.9675      0.072     13.475      0.000       0.826       1.109
# hml           -0.1528      0.071     -2.142      0.033      -0.293      -0.012
# umd           -0.1964      0.047     -4.197      0.000      -0.289      -0.104
# ==============================================================================
# Omnibus:                       64.428   Durbin-Watson:                   1.921
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              268.364
# Skew:                           1.040   Prob(JB):                     5.31e-59
# Kurtosis:                       7.817   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.837
# Model:                            OLS   Adj. R-squared:                  0.834
# Method:                 Least Squares   F-statistic:                     176.8
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           8.49e-69
# Time:                        12:49:23   Log-Likelihood:                 465.24
# No. Observations:                 234   AIC:                            -920.5
# Df Residuals:                     229   BIC:                            -903.2
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0010      0.002      0.456      0.648      -0.003       0.005
# mktrf          1.2797      0.058     22.099      0.000       1.166       1.393
# smb            0.9675      0.104      9.320      0.000       0.764       1.171
# hml           -0.1528      0.119     -1.283      0.199      -0.386       0.081
# umd           -0.1964      0.100     -1.956      0.051      -0.393       0.000
# ==============================================================================
# Omnibus:                       64.428   Durbin-Watson:                   1.921
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              268.364
# Skew:                           1.040   Prob(JB):                     5.31e-59
# Kurtosis:                       7.817   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.837
# Model:                            OLS   Adj. R-squared:                  0.834
# Method:                 Least Squares   F-statistic:                     168.6
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           4.89e-67
# Time:                        12:49:23   Log-Likelihood:                 465.24
# No. Observations:                 234   AIC:                            -920.5
# Df Residuals:                     229   BIC:                            -903.2
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0010      0.002      0.502      0.616      -0.003       0.005
# mktrf          1.2797      0.056     22.698      0.000       1.169       1.390
# smb            0.9675      0.088     11.056      0.000       0.796       1.139
# hml           -0.1528      0.103     -1.485      0.137      -0.354       0.049
# umd           -0.1964      0.107     -1.837      0.066      -0.406       0.013
# ==============================================================================
# Omnibus:                       64.428   Durbin-Watson:                   1.921
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              268.364
# Skew:                           1.040   Prob(JB):                     5.31e-59
# Kurtosis:                       7.817   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.837
# Model:                            OLS   Adj. R-squared:                  0.834
# Method:                 Least Squares   F-statistic:                     294.6
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           4.89e-89
# Time:                        12:49:23   Log-Likelihood:                 465.24
# No. Observations:                 234   AIC:                            -920.5
# Df Residuals:                     229   BIC:                            -903.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0010      0.002      0.452      0.652      -0.003       0.005
# mktrf          1.2797      0.058     22.249      0.000       1.166       1.393
# smb            0.9675      0.072     13.475      0.000       0.826       1.109
# hml           -0.1528      0.071     -2.142      0.033      -0.293      -0.012
# umd           -0.1964      0.047     -4.197      0.000      -0.289      -0.104
# ==============================================================================
# Omnibus:                       64.428   Durbin-Watson:                   1.921
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              268.364
# Skew:                           1.040   Prob(JB):                     5.31e-59
# Kurtosis:                       7.817   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.837
# Model:                            OLS   Adj. R-squared:                  0.834
# Method:                 Least Squares   F-statistic:                     176.8
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           8.49e-69
# Time:                        12:49:23   Log-Likelihood:                 465.24
# No. Observations:                 234   AIC:                            -920.5
# Df Residuals:                     229   BIC:                            -903.2
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0010      0.002      0.456      0.648      -0.003       0.005
# mktrf          1.2797      0.058     22.099      0.000       1.166       1.393
# smb            0.9675      0.104      9.320      0.000       0.764       1.171
# hml           -0.1528      0.119     -1.283      0.199      -0.386       0.081
# umd           -0.1964      0.100     -1.956      0.051      -0.393       0.000
# ==============================================================================
# Omnibus:                       64.428   Durbin-Watson:                   1.921
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              268.364
# Skew:                           1.040   Prob(JB):                     5.31e-59
# Kurtosis:                       7.817   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.837
# Model:                            OLS   Adj. R-squared:                  0.834
# Method:                 Least Squares   F-statistic:                     168.6
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           4.89e-67
# Time:                        12:49:23   Log-Likelihood:                 465.24
# No. Observations:                 234   AIC:                            -920.5
# Df Residuals:                     229   BIC:                            -903.2
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0010      0.002      0.502      0.616      -0.003       0.005
# mktrf          1.2797      0.056     22.698      0.000       1.169       1.390
# smb            0.9675      0.088     11.056      0.000       0.796       1.139
# hml           -0.1528      0.103     -1.485      0.137      -0.354       0.049
# umd           -0.1964      0.107     -1.837      0.066      -0.406       0.013
# ==============================================================================
# Omnibus:                       64.428   Durbin-Watson:                   1.921
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              268.364
# Skew:                           1.040   Prob(JB):                     5.31e-59
# Kurtosis:                       7.817   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Pre-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.875
# Model:                            OLS   Adj. R-squared:                  0.871
# Method:                 Least Squares   F-statistic:                     201.1
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           6.25e-51
# Time:                        12:49:23   Log-Likelihood:                 233.99
# No. Observations:                 120   AIC:                            -458.0
# Df Residuals:                     115   BIC:                            -444.1
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0050      0.003      1.486      0.140      -0.002       0.012
# mktrf          1.0633      0.091     11.730      0.000       0.884       1.243
# me             0.6541      0.090      7.306      0.000       0.477       0.831
# ia            -0.1319      0.140     -0.941      0.349      -0.410       0.146
# roe           -0.8847      0.124     -7.130      0.000      -1.131      -0.639
# ==============================================================================
# Omnibus:                       33.523   Durbin-Watson:                   2.011
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               89.939
# Skew:                           1.025   Prob(JB):                     2.95e-20
# Kurtosis:                       6.713   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.875
# Model:                            OLS   Adj. R-squared:                  0.871
# Method:                 Least Squares   F-statistic:                     119.8
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           4.63e-40
# Time:                        12:49:23   Log-Likelihood:                 233.99
# No. Observations:                 120   AIC:                            -458.0
# Df Residuals:                     115   BIC:                            -444.1
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0050      0.004      1.190      0.234      -0.003       0.013
# mktrf          1.0633      0.088     12.032      0.000       0.890       1.237
# me             0.6541      0.116      5.625      0.000       0.426       0.882
# ia            -0.1319      0.250     -0.528      0.598      -0.621       0.358
# roe           -0.8847      0.243     -3.641      0.000      -1.361      -0.408
# ==============================================================================
# Omnibus:                       33.523   Durbin-Watson:                   2.011
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               89.939
# Skew:                           1.025   Prob(JB):                     2.95e-20
# Kurtosis:                       6.713   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.875
# Model:                            OLS   Adj. R-squared:                  0.871
# Method:                 Least Squares   F-statistic:                     153.0
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           4.43e-45
# Time:                        12:49:23   Log-Likelihood:                 233.99
# No. Observations:                 120   AIC:                            -458.0
# Df Residuals:                     115   BIC:                            -444.1
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0050      0.004      1.240      0.215      -0.003       0.013
# mktrf          1.0633      0.074     14.316      0.000       0.918       1.209
# me             0.6541      0.123      5.320      0.000       0.413       0.895
# ia            -0.1319      0.214     -0.616      0.538      -0.551       0.287
# roe           -0.8847      0.254     -3.490      0.000      -1.382      -0.388
# ==============================================================================
# Omnibus:                       33.523   Durbin-Watson:                   2.011
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               89.939
# Skew:                           1.025   Prob(JB):                     2.95e-20
# Kurtosis:                       6.713   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.853
# Model:                            OLS   Adj. R-squared:                  0.848
# Method:                 Least Squares   F-statistic:                     166.6
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           7.15e-47
# Time:                        12:49:23   Log-Likelihood:                 224.22
# No. Observations:                 120   AIC:                            -438.4
# Df Residuals:                     115   BIC:                            -424.5
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0029      0.004      0.823      0.412      -0.004       0.010
# mktrf          1.3682      0.087     15.793      0.000       1.197       1.540
# smb            0.9610      0.099      9.742      0.000       0.766       1.156
# hml           -0.1991      0.099     -2.016      0.046      -0.395      -0.003
# umd           -0.1636      0.061     -2.686      0.008      -0.284      -0.043
# ==============================================================================
# Omnibus:                       39.952   Durbin-Watson:                   2.077
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              133.360
# Skew:                           1.145   Prob(JB):                     1.10e-29
# Kurtosis:                       7.629   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.853
# Model:                            OLS   Adj. R-squared:                  0.848
# Method:                 Least Squares   F-statistic:                     165.3
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.05e-46
# Time:                        12:49:24   Log-Likelihood:                 224.22
# No. Observations:                 120   AIC:                            -438.4
# Df Residuals:                     115   BIC:                            -424.5
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0029      0.004      0.833      0.405      -0.004       0.010
# mktrf          1.3682      0.072     18.956      0.000       1.227       1.510
# smb            0.9610      0.125      7.670      0.000       0.715       1.207
# hml           -0.1991      0.146     -1.367      0.172      -0.485       0.086
# umd           -0.1636      0.112     -1.459      0.144      -0.383       0.056
# ==============================================================================
# Omnibus:                       39.952   Durbin-Watson:                   2.077
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              133.360
# Skew:                           1.145   Prob(JB):                     1.10e-29
# Kurtosis:                       7.629   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.853
# Model:                            OLS   Adj. R-squared:                  0.848
# Method:                 Least Squares   F-statistic:                     214.1
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.66e-52
# Time:                        12:49:24   Log-Likelihood:                 224.22
# No. Observations:                 120   AIC:                            -438.4
# Df Residuals:                     115   BIC:                            -424.5
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0029      0.003      0.933      0.351      -0.003       0.009
# mktrf          1.3682      0.058     23.512      0.000       1.254       1.482
# smb            0.9610      0.110      8.737      0.000       0.745       1.177
# hml           -0.1991      0.130     -1.526      0.127      -0.455       0.057
# umd           -0.1636      0.114     -1.431      0.152      -0.388       0.060
# ==============================================================================
# Omnibus:                       39.952   Durbin-Watson:                   2.077
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              133.360
# Skew:                           1.145   Prob(JB):                     1.10e-29
# Kurtosis:                       7.629   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.853
# Model:                            OLS   Adj. R-squared:                  0.848
# Method:                 Least Squares   F-statistic:                     166.6
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           7.15e-47
# Time:                        12:49:24   Log-Likelihood:                 224.22
# No. Observations:                 120   AIC:                            -438.4
# Df Residuals:                     115   BIC:                            -424.5
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0029      0.004      0.823      0.412      -0.004       0.010
# mktrf          1.3682      0.087     15.793      0.000       1.197       1.540
# smb            0.9610      0.099      9.742      0.000       0.766       1.156
# hml           -0.1991      0.099     -2.016      0.046      -0.395      -0.003
# umd           -0.1636      0.061     -2.686      0.008      -0.284      -0.043
# ==============================================================================
# Omnibus:                       39.952   Durbin-Watson:                   2.077
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              133.360
# Skew:                           1.145   Prob(JB):                     1.10e-29
# Kurtosis:                       7.629   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.853
# Model:                            OLS   Adj. R-squared:                  0.848
# Method:                 Least Squares   F-statistic:                     165.3
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.05e-46
# Time:                        12:49:24   Log-Likelihood:                 224.22
# No. Observations:                 120   AIC:                            -438.4
# Df Residuals:                     115   BIC:                            -424.5
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0029      0.004      0.833      0.405      -0.004       0.010
# mktrf          1.3682      0.072     18.956      0.000       1.227       1.510
# smb            0.9610      0.125      7.670      0.000       0.715       1.207
# hml           -0.1991      0.146     -1.367      0.172      -0.485       0.086
# umd           -0.1636      0.112     -1.459      0.144      -0.383       0.056
# ==============================================================================
# Omnibus:                       39.952   Durbin-Watson:                   2.077
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              133.360
# Skew:                           1.145   Prob(JB):                     1.10e-29
# Kurtosis:                       7.629   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.853
# Model:                            OLS   Adj. R-squared:                  0.848
# Method:                 Least Squares   F-statistic:                     214.1
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.66e-52
# Time:                        12:49:24   Log-Likelihood:                 224.22
# No. Observations:                 120   AIC:                            -438.4
# Df Residuals:                     115   BIC:                            -424.5
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0029      0.003      0.933      0.351      -0.003       0.009
# mktrf          1.3682      0.058     23.512      0.000       1.254       1.482
# smb            0.9610      0.110      8.737      0.000       0.745       1.177
# hml           -0.1991      0.130     -1.526      0.127      -0.455       0.057
# umd           -0.1636      0.114     -1.431      0.152      -0.388       0.060
# ==============================================================================
# Omnibus:                       39.952   Durbin-Watson:                   2.077
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              133.360
# Skew:                           1.145   Prob(JB):                     1.10e-29
# Kurtosis:                       7.629   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Post-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.888
# Model:                            OLS   Adj. R-squared:                  0.883
# Method:                 Least Squares   F-statistic:                     215.0
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           9.43e-51
# Time:                        12:49:24   Log-Likelihood:                 280.18
# No. Observations:                 114   AIC:                            -550.4
# Df Residuals:                     109   BIC:                            -536.7
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0043      0.002      2.062      0.042       0.000       0.009
# mktrf          1.0645      0.062     17.088      0.000       0.941       1.188
# me             0.5761      0.096      5.989      0.000       0.385       0.767
# ia            -0.2041      0.133     -1.529      0.129      -0.468       0.060
# roe           -1.0582      0.117     -9.026      0.000      -1.291      -0.826
# ==============================================================================
# Omnibus:                       12.267   Durbin-Watson:                   1.892
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               17.512
# Skew:                           0.535   Prob(JB):                     0.000158
# Kurtosis:                       4.594   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.888
# Model:                            OLS   Adj. R-squared:                  0.883
# Method:                 Least Squares   F-statistic:                     433.9
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           5.84e-66
# Time:                        12:49:24   Log-Likelihood:                 280.18
# No. Observations:                 114   AIC:                            -550.4
# Df Residuals:                     109   BIC:                            -536.7
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0043      0.002      2.651      0.008       0.001       0.008
# mktrf          1.0645      0.048     22.184      0.000       0.970       1.159
# me             0.5761      0.050     11.425      0.000       0.477       0.675
# ia            -0.2041      0.121     -1.681      0.093      -0.442       0.034
# roe           -1.0582      0.135     -7.813      0.000      -1.324      -0.793
# ==============================================================================
# Omnibus:                       12.267   Durbin-Watson:                   1.892
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               17.512
# Skew:                           0.535   Prob(JB):                     0.000158
# Kurtosis:                       4.594   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.888
# Model:                            OLS   Adj. R-squared:                  0.883
# Method:                 Least Squares   F-statistic:                     725.0
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.57e-77
# Time:                        12:49:24   Log-Likelihood:                 280.18
# No. Observations:                 114   AIC:                            -550.4
# Df Residuals:                     109   BIC:                            -536.7
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0043      0.002      2.747      0.006       0.001       0.007
# mktrf          1.0645      0.038     28.277      0.000       0.991       1.138
# me             0.5761      0.042     13.860      0.000       0.495       0.658
# ia            -0.2041      0.116     -1.760      0.078      -0.431       0.023
# roe           -1.0582      0.116     -9.100      0.000      -1.286      -0.830
# ==============================================================================
# Omnibus:                       12.267   Durbin-Watson:                   1.892
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               17.512
# Skew:                           0.535   Prob(JB):                     0.000158
# Kurtosis:                       4.594   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.816
# Model:                            OLS   Adj. R-squared:                  0.809
# Method:                 Least Squares   F-statistic:                     120.7
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           4.19e-39
# Time:                        12:49:24   Log-Likelihood:                 252.05
# No. Observations:                 114   AIC:                            -494.1
# Df Residuals:                     109   BIC:                            -480.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0007      0.003      0.252      0.802      -0.005       0.006
# mktrf          1.1677      0.076     15.454      0.000       1.018       1.317
# smb            0.8390      0.118      7.121      0.000       0.605       1.072
# hml            0.0800      0.121      0.659      0.511      -0.160       0.321
# umd           -0.2093      0.092     -2.287      0.024      -0.391      -0.028
# ==============================================================================
# Omnibus:                       12.887   Durbin-Watson:                   1.771
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               19.304
# Skew:                           0.541   Prob(JB):                     6.43e-05
# Kurtosis:                       4.701   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.816
# Model:                            OLS   Adj. R-squared:                  0.809
# Method:                 Least Squares   F-statistic:                     103.2
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           3.77e-36
# Time:                        12:49:24   Log-Likelihood:                 252.05
# No. Observations:                 114   AIC:                            -494.1
# Df Residuals:                     109   BIC:                            -480.4
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0007      0.002      0.310      0.757      -0.004       0.005
# mktrf          1.1677      0.073     16.069      0.000       1.025       1.310
# smb            0.8390      0.102      8.192      0.000       0.638       1.040
# hml            0.0800      0.194      0.413      0.680      -0.300       0.460
# umd           -0.2093      0.092     -2.270      0.023      -0.390      -0.029
# ==============================================================================
# Omnibus:                       12.887   Durbin-Watson:                   1.771
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               19.304
# Skew:                           0.541   Prob(JB):                     6.43e-05
# Kurtosis:                       4.701   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.816
# Model:                            OLS   Adj. R-squared:                  0.809
# Method:                 Least Squares   F-statistic:                     104.2
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.47e-36
# Time:                        12:49:24   Log-Likelihood:                 252.05
# No. Observations:                 114   AIC:                            -494.1
# Df Residuals:                     109   BIC:                            -480.4
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0007      0.002      0.315      0.753      -0.004       0.005
# mktrf          1.1677      0.071     16.375      0.000       1.028       1.307
# smb            0.8390      0.075     11.157      0.000       0.692       0.986
# hml            0.0800      0.201      0.398      0.690      -0.314       0.474
# umd           -0.2093      0.085     -2.470      0.014      -0.375      -0.043
# ==============================================================================
# Omnibus:                       12.887   Durbin-Watson:                   1.771
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               19.304
# Skew:                           0.541   Prob(JB):                     6.43e-05
# Kurtosis:                       4.701   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.816
# Model:                            OLS   Adj. R-squared:                  0.809
# Method:                 Least Squares   F-statistic:                     120.7
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           4.19e-39
# Time:                        12:49:24   Log-Likelihood:                 252.05
# No. Observations:                 114   AIC:                            -494.1
# Df Residuals:                     109   BIC:                            -480.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0007      0.003      0.252      0.802      -0.005       0.006
# mktrf          1.1677      0.076     15.454      0.000       1.018       1.317
# smb            0.8390      0.118      7.121      0.000       0.605       1.072
# hml            0.0800      0.121      0.659      0.511      -0.160       0.321
# umd           -0.2093      0.092     -2.287      0.024      -0.391      -0.028
# ==============================================================================
# Omnibus:                       12.887   Durbin-Watson:                   1.771
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               19.304
# Skew:                           0.541   Prob(JB):                     6.43e-05
# Kurtosis:                       4.701   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.816
# Model:                            OLS   Adj. R-squared:                  0.809
# Method:                 Least Squares   F-statistic:                     103.2
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           3.77e-36
# Time:                        12:49:24   Log-Likelihood:                 252.05
# No. Observations:                 114   AIC:                            -494.1
# Df Residuals:                     109   BIC:                            -480.4
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0007      0.002      0.310      0.757      -0.004       0.005
# mktrf          1.1677      0.073     16.069      0.000       1.025       1.310
# smb            0.8390      0.102      8.192      0.000       0.638       1.040
# hml            0.0800      0.194      0.413      0.680      -0.300       0.460
# umd           -0.2093      0.092     -2.270      0.023      -0.390      -0.029
# ==============================================================================
# Omnibus:                       12.887   Durbin-Watson:                   1.771
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               19.304
# Skew:                           0.541   Prob(JB):                     6.43e-05
# Kurtosis:                       4.701   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.816
# Model:                            OLS   Adj. R-squared:                  0.809
# Method:                 Least Squares   F-statistic:                     104.2
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.47e-36
# Time:                        12:49:24   Log-Likelihood:                 252.05
# No. Observations:                 114   AIC:                            -494.1
# Df Residuals:                     109   BIC:                            -480.4
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0007      0.002      0.315      0.753      -0.004       0.005
# mktrf          1.1677      0.071     16.375      0.000       1.028       1.307
# smb            0.8390      0.075     11.157      0.000       0.692       0.986
# hml            0.0800      0.201      0.398      0.690      -0.314       0.474
# umd           -0.2093      0.085     -2.470      0.014      -0.375      -0.043
# ==============================================================================
# Omnibus:                       12.887   Durbin-Watson:                   1.771
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               19.304
# Skew:                           0.541   Prob(JB):                     6.43e-05
# Kurtosis:                       4.701   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """
