# %% [markdown]
# # Method 8 - Best Ideas Low Concentration

# %%
# %matplotlib inline
import pandas as pd
import warnings
from statsmodels import api as sm

from eptooling import crsp, epd, fs, hfu, crsp, db, bi
from eptooling.bm import bmdb, iso
from epquant.engine import weights, portfolio
from epquant.gen import returns
from epquant.perf import relative_performance

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Fetch Holdings and Benchmark Data

# %%
# Get HFU Data

# %store -r inst_data
inst_data = inst_data[inst_data['datadate'] >= '1999-06-30']

# Herfindahl

inst_data['target_sq'] = inst_data['target'] ** 2
herf = inst_data.groupby(['datadate', 'institution_id'])['target_sq'].sum().rename('herf').reset_index()

# Count number of positions per manager

inst_data['num_pos'] = inst_data.groupby(['datadate', 'institution_id'])[
    'fsym_id'].transform(lambda s: s.nunique())

# Remove less than 20 holdings and less than $5mm per CSP

valid_data = inst_data[inst_data['num_pos'] >= 20]
valid_data = valid_data[valid_data['public_aum'] >= 5e6]

# Use Raw Weight

valid_data['adj_target'] = valid_data['target']

# %% [markdown]
# ## Calculate Best Ideas

# %%
# Extract Best Ideas

valid_data['pos_rank'] = valid_data\
    .groupby(['datadate', 'institution_id'])['adj_target'].rank(ascending=False)

best_ideas = valid_data[valid_data['pos_rank'] == 1].copy()

# Add Herf

best_ideas = best_ideas.merge(herf)
best_ideas['herf_pct'] = best_ideas.groupby('datadate')['herf'].rank(pct=True)
best_ideas = best_ideas[best_ideas['herf_pct'] < (1 / 3)]

# Weight the best ideas equally

best_ideas['target'] = 1 / best_ideas.groupby('datadate')['institution_id'].transform('count')

# %% [markdown]
# ## Backtest Portfolio

# %%
w = weights.Weights(best_ideas)

# %store -r r

p = portfolio.DailyPortfolio(w, r, end_date='2018-12-31')

rf = bi.get_risk_free_rate()
monthly_return = p.port_return.loc['1999-07-01':].resample('M').apply(epd.prod_red)
monthly_return = (monthly_return - rf).dropna()
monthly_return.name = 'port_return'

# %% [markdown]
# ## Plot Performance

# %%
epd.nav(monthly_return).plot()

# %%
monthly_return.resample('A').apply(epd.prod_red)
# Out:
# datadate
# 1999-12-31    0.208548
# 2000-12-31   -0.381093
# 2001-12-31   -0.360663
# 2002-12-31   -0.339070
# 2003-12-31    0.832425
# 2004-12-31    0.126512
# 2005-12-31    0.041050
# 2006-12-31    0.050482
# 2007-12-31   -0.028957
# 2008-12-31   -0.547894
# 2009-12-31    0.874941
# 2010-12-31    0.194479
# 2011-12-31   -0.162195
# 2012-12-31    0.271962
# 2013-12-31    0.478358
# 2014-12-31    0.083628
# 2015-12-31   -0.174044
# 2016-12-31    0.140538
# 2017-12-31    0.191682
# 2018-12-31   -0.141795
# Freq: A-DEC, Name: port_return, dtype: float64

# %% [markdown]
# ## Fetch Factor Models

# %%
# Get Factor Models
q_factor_model = bi.get_q_factor_model()
fama_french_five_factor_model = bi.get_fama_french_five_factor_model()
four_factor_model = bi.get_four_factor_model()

# Concat Portfolio Return
q_factor = pd.concat([monthly_return, q_factor_model], axis=1)
fama_french_five = pd.concat([monthly_return, fama_french_five_factor_model], axis=1)
four_factor = pd.concat([monthly_return, four_factor_model], axis=1)

# Add Constants
q_factor.insert(1, 'const', 1)
fama_french_five.insert(1, 'const', 1)
four_factor.insert(1, 'const', 1)

# Split Period into Pre and Post Crisis
q_factor_pre, q_factor_post = q_factor.loc[:'2009-06-30'], q_factor.loc['2009-07-31':]
fama_french_five_pre, fama_french_five_post = fama_french_five.loc[:'2009-06-30'], fama_french_five.loc['2009-07-31':] 
four_factor_pre, four_factor_post = four_factor.loc[:'2009-06-30'], four_factor.loc['2009-07-31':]

# %% [markdown]
# ## Full Time Period Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.863
# Model:                            OLS   Adj. R-squared:                  0.860
# Method:                 Least Squares   F-statistic:                     360.3
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.57e-97
# Time:                        12:41:10   Log-Likelihood:                 491.17
# No. Observations:                 234   AIC:                            -972.3
# Df Residuals:                     229   BIC:                            -955.1
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       6.645e-05      0.002      0.033      0.974      -0.004       0.004
# mktrf          1.1851      0.056     21.194      0.000       1.075       1.295
# me             0.4933      0.065      7.584      0.000       0.365       0.621
# ia            -0.1813      0.099     -1.834      0.068      -0.376       0.013
# roe           -0.6930      0.085     -8.189      0.000      -0.860      -0.526
# ==============================================================================
# Omnibus:                       30.203   Durbin-Watson:                   2.202
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               84.533
# Skew:                           0.529   Prob(JB):                     4.40e-19
# Kurtosis:                       5.748   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.863
# Model:                            OLS   Adj. R-squared:                  0.860
# Method:                 Least Squares   F-statistic:                     525.6
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):          4.27e-114
# Time:                        12:41:10   Log-Likelihood:                 491.17
# No. Observations:                 234   AIC:                            -972.3
# Df Residuals:                     229   BIC:                            -955.1
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       6.645e-05      0.002      0.028      0.978      -0.005       0.005
# mktrf          1.1851      0.055     21.526      0.000       1.077       1.293
# me             0.4933      0.055      8.926      0.000       0.385       0.602
# ia            -0.1813      0.130     -1.399      0.162      -0.435       0.073
# roe           -0.6930      0.156     -4.451      0.000      -0.998      -0.388
# ==============================================================================
# Omnibus:                       30.203   Durbin-Watson:                   2.202
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               84.533
# Skew:                           0.529   Prob(JB):                     4.40e-19
# Kurtosis:                       5.748   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.863
# Model:                            OLS   Adj. R-squared:                  0.860
# Method:                 Least Squares   F-statistic:                     848.7
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):          5.16e-136
# Time:                        12:41:10   Log-Likelihood:                 491.17
# No. Observations:                 234   AIC:                            -972.3
# Df Residuals:                     229   BIC:                            -955.1
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       6.645e-05      0.002      0.029      0.977      -0.004       0.005
# mktrf          1.1851      0.055     21.737      0.000       1.078       1.292
# me             0.4933      0.054      9.095      0.000       0.387       0.600
# ia            -0.1813      0.119     -1.525      0.127      -0.414       0.052
# roe           -0.6930      0.159     -4.356      0.000      -1.005      -0.381
# ==============================================================================
# Omnibus:                       30.203   Durbin-Watson:                   2.202
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               84.533
# Skew:                           0.529   Prob(JB):                     4.40e-19
# Kurtosis:                       5.748   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.840
# Model:                            OLS   Adj. R-squared:                  0.837
# Method:                 Least Squares   F-statistic:                     299.9
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           8.94e-90
# Time:                        12:41:10   Log-Likelihood:                 472.89
# No. Observations:                 234   AIC:                            -935.8
# Df Residuals:                     229   BIC:                            -918.5
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0026      0.002     -1.203      0.230      -0.007       0.002
# mktrf          1.3328      0.056     23.942      0.000       1.223       1.442
# smb            0.7676      0.069     11.047      0.000       0.631       0.905
# hml           -0.1567      0.069     -2.270      0.024      -0.293      -0.021
# umd           -0.1984      0.045     -4.381      0.000      -0.288      -0.109
# ==============================================================================
# Omnibus:                       40.873   Durbin-Watson:                   2.099
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               75.529
# Skew:                           0.904   Prob(JB):                     3.97e-17
# Kurtosis:                       5.116   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.840
# Model:                            OLS   Adj. R-squared:                  0.837
# Method:                 Least Squares   F-statistic:                     338.1
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           8.08e-95
# Time:                        12:41:10   Log-Likelihood:                 472.89
# No. Observations:                 234   AIC:                            -935.8
# Df Residuals:                     229   BIC:                            -918.5
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0026      0.002     -1.182      0.237      -0.007       0.002
# mktrf          1.3328      0.053     25.163      0.000       1.229       1.437
# smb            0.7676      0.074     10.369      0.000       0.623       0.913
# hml           -0.1567      0.080     -1.967      0.049      -0.313      -0.001
# umd           -0.1984      0.077     -2.570      0.010      -0.350      -0.047
# ==============================================================================
# Omnibus:                       40.873   Durbin-Watson:                   2.099
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               75.529
# Skew:                           0.904   Prob(JB):                     3.97e-17
# Kurtosis:                       5.116   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.840
# Model:                            OLS   Adj. R-squared:                  0.837
# Method:                 Least Squares   F-statistic:                     299.3
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.08e-89
# Time:                        12:41:10   Log-Likelihood:                 472.89
# No. Observations:                 234   AIC:                            -935.8
# Df Residuals:                     229   BIC:                            -918.5
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0026      0.002     -1.271      0.204      -0.007       0.001
# mktrf          1.3328      0.057     23.182      0.000       1.220       1.445
# smb            0.7676      0.072     10.595      0.000       0.626       0.910
# hml           -0.1567      0.073     -2.160      0.031      -0.299      -0.014
# umd           -0.1984      0.079     -2.523      0.012      -0.353      -0.044
# ==============================================================================
# Omnibus:                       40.873   Durbin-Watson:                   2.099
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               75.529
# Skew:                           0.904   Prob(JB):                     3.97e-17
# Kurtosis:                       5.116   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.840
# Model:                            OLS   Adj. R-squared:                  0.837
# Method:                 Least Squares   F-statistic:                     299.9
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           8.94e-90
# Time:                        12:41:10   Log-Likelihood:                 472.89
# No. Observations:                 234   AIC:                            -935.8
# Df Residuals:                     229   BIC:                            -918.5
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0026      0.002     -1.203      0.230      -0.007       0.002
# mktrf          1.3328      0.056     23.942      0.000       1.223       1.442
# smb            0.7676      0.069     11.047      0.000       0.631       0.905
# hml           -0.1567      0.069     -2.270      0.024      -0.293      -0.021
# umd           -0.1984      0.045     -4.381      0.000      -0.288      -0.109
# ==============================================================================
# Omnibus:                       40.873   Durbin-Watson:                   2.099
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               75.529
# Skew:                           0.904   Prob(JB):                     3.97e-17
# Kurtosis:                       5.116   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.840
# Model:                            OLS   Adj. R-squared:                  0.837
# Method:                 Least Squares   F-statistic:                     338.1
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           8.08e-95
# Time:                        12:41:10   Log-Likelihood:                 472.89
# No. Observations:                 234   AIC:                            -935.8
# Df Residuals:                     229   BIC:                            -918.5
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0026      0.002     -1.182      0.237      -0.007       0.002
# mktrf          1.3328      0.053     25.163      0.000       1.229       1.437
# smb            0.7676      0.074     10.369      0.000       0.623       0.913
# hml           -0.1567      0.080     -1.967      0.049      -0.313      -0.001
# umd           -0.1984      0.077     -2.570      0.010      -0.350      -0.047
# ==============================================================================
# Omnibus:                       40.873   Durbin-Watson:                   2.099
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               75.529
# Skew:                           0.904   Prob(JB):                     3.97e-17
# Kurtosis:                       5.116   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.840
# Model:                            OLS   Adj. R-squared:                  0.837
# Method:                 Least Squares   F-statistic:                     299.3
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.08e-89
# Time:                        12:41:10   Log-Likelihood:                 472.89
# No. Observations:                 234   AIC:                            -935.8
# Df Residuals:                     229   BIC:                            -918.5
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0026      0.002     -1.271      0.204      -0.007       0.001
# mktrf          1.3328      0.057     23.182      0.000       1.220       1.445
# smb            0.7676      0.072     10.595      0.000       0.626       0.910
# hml           -0.1567      0.073     -2.160      0.031      -0.299      -0.014
# umd           -0.1984      0.079     -2.523      0.012      -0.353      -0.044
# ==============================================================================
# Omnibus:                       40.873   Durbin-Watson:                   2.099
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               75.529
# Skew:                           0.904   Prob(JB):                     3.97e-17
# Kurtosis:                       5.116   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Pre-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.861
# Model:                            OLS   Adj. R-squared:                  0.857
# Method:                 Least Squares   F-statistic:                     178.6
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.33e-48
# Time:                        12:41:10   Log-Likelihood:                 232.15
# No. Observations:                 120   AIC:                            -454.3
# Df Residuals:                     115   BIC:                            -440.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0007      0.003     -0.191      0.849      -0.007       0.006
# mktrf          1.2460      0.092     13.536      0.000       1.064       1.428
# me             0.5010      0.091      5.511      0.000       0.321       0.681
# ia            -0.2729      0.142     -1.917      0.058      -0.555       0.009
# roe           -0.5578      0.126     -4.427      0.000      -0.807      -0.308
# ==============================================================================
# Omnibus:                       21.239   Durbin-Watson:                   2.300
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               45.038
# Skew:                           0.700   Prob(JB):                     1.66e-10
# Kurtosis:                       5.654   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.861
# Model:                            OLS   Adj. R-squared:                  0.857
# Method:                 Least Squares   F-statistic:                     366.9
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.82e-64
# Time:                        12:41:10   Log-Likelihood:                 232.15
# No. Observations:                 120   AIC:                            -454.3
# Df Residuals:                     115   BIC:                            -440.4
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0007      0.004     -0.154      0.878      -0.009       0.008
# mktrf          1.2460      0.081     15.422      0.000       1.088       1.404
# me             0.5010      0.086      5.832      0.000       0.333       0.669
# ia            -0.2729      0.204     -1.338      0.181      -0.673       0.127
# roe           -0.5578      0.224     -2.494      0.013      -0.996      -0.119
# ==============================================================================
# Omnibus:                       21.239   Durbin-Watson:                   2.300
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               45.038
# Skew:                           0.700   Prob(JB):                     1.66e-10
# Kurtosis:                       5.654   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.861
# Model:                            OLS   Adj. R-squared:                  0.857
# Method:                 Least Squares   F-statistic:                     605.7
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           3.03e-76
# Time:                        12:41:10   Log-Likelihood:                 232.15
# No. Observations:                 120   AIC:                            -454.3
# Df Residuals:                     115   BIC:                            -440.4
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0007      0.004     -0.159      0.874      -0.009       0.007
# mktrf          1.2460      0.074     16.791      0.000       1.101       1.391
# me             0.5010      0.085      5.896      0.000       0.334       0.668
# ia            -0.2729      0.197     -1.388      0.165      -0.658       0.112
# roe           -0.5578      0.223     -2.501      0.012      -0.995      -0.121
# ==============================================================================
# Omnibus:                       21.239   Durbin-Watson:                   2.300
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               45.038
# Skew:                           0.700   Prob(JB):                     1.66e-10
# Kurtosis:                       5.654   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.855
# Model:                            OLS   Adj. R-squared:                  0.850
# Method:                 Least Squares   F-statistic:                     170.1
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.52e-47
# Time:                        12:41:10   Log-Likelihood:                 229.66
# No. Observations:                 120   AIC:                            -449.3
# Df Residuals:                     115   BIC:                            -435.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0015      0.003     -0.427      0.670      -0.008       0.005
# mktrf          1.4342      0.083     17.322      0.000       1.270       1.598
# smb            0.7105      0.094      7.537      0.000       0.524       0.897
# hml           -0.2285      0.094     -2.420      0.017      -0.416      -0.041
# umd           -0.1462      0.058     -2.511      0.013      -0.261      -0.031
# ==============================================================================
# Omnibus:                       23.090   Durbin-Watson:                   2.254
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               35.744
# Skew:                           0.915   Prob(JB):                     1.73e-08
# Kurtosis:                       4.949   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.855
# Model:                            OLS   Adj. R-squared:                  0.850
# Method:                 Least Squares   F-statistic:                     379.9
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.85e-65
# Time:                        12:41:10   Log-Likelihood:                 229.66
# No. Observations:                 120   AIC:                            -449.3
# Df Residuals:                     115   BIC:                            -435.4
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0015      0.003     -0.430      0.667      -0.008       0.005
# mktrf          1.4342      0.050     28.644      0.000       1.336       1.532
# smb            0.7105      0.096      7.388      0.000       0.522       0.899
# hml           -0.2285      0.090     -2.526      0.012      -0.406      -0.051
# umd           -0.1462      0.084     -1.745      0.081      -0.310       0.018
# ==============================================================================
# Omnibus:                       23.090   Durbin-Watson:                   2.254
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               35.744
# Skew:                           0.915   Prob(JB):                     1.73e-08
# Kurtosis:                       4.949   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.855
# Model:                            OLS   Adj. R-squared:                  0.850
# Method:                 Least Squares   F-statistic:                     524.6
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           7.82e-73
# Time:                        12:41:10   Log-Likelihood:                 229.66
# No. Observations:                 120   AIC:                            -449.3
# Df Residuals:                     115   BIC:                            -435.4
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0015      0.003     -0.468      0.640      -0.008       0.005
# mktrf          1.4342      0.039     37.056      0.000       1.358       1.510
# smb            0.7105      0.099      7.144      0.000       0.516       0.905
# hml           -0.2285      0.088     -2.595      0.009      -0.401      -0.056
# umd           -0.1462      0.083     -1.762      0.078      -0.309       0.016
# ==============================================================================
# Omnibus:                       23.090   Durbin-Watson:                   2.254
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               35.744
# Skew:                           0.915   Prob(JB):                     1.73e-08
# Kurtosis:                       4.949   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.855
# Model:                            OLS   Adj. R-squared:                  0.850
# Method:                 Least Squares   F-statistic:                     170.1
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.52e-47
# Time:                        12:41:10   Log-Likelihood:                 229.66
# No. Observations:                 120   AIC:                            -449.3
# Df Residuals:                     115   BIC:                            -435.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0015      0.003     -0.427      0.670      -0.008       0.005
# mktrf          1.4342      0.083     17.322      0.000       1.270       1.598
# smb            0.7105      0.094      7.537      0.000       0.524       0.897
# hml           -0.2285      0.094     -2.420      0.017      -0.416      -0.041
# umd           -0.1462      0.058     -2.511      0.013      -0.261      -0.031
# ==============================================================================
# Omnibus:                       23.090   Durbin-Watson:                   2.254
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               35.744
# Skew:                           0.915   Prob(JB):                     1.73e-08
# Kurtosis:                       4.949   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.855
# Model:                            OLS   Adj. R-squared:                  0.850
# Method:                 Least Squares   F-statistic:                     379.9
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.85e-65
# Time:                        12:41:10   Log-Likelihood:                 229.66
# No. Observations:                 120   AIC:                            -449.3
# Df Residuals:                     115   BIC:                            -435.4
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0015      0.003     -0.430      0.667      -0.008       0.005
# mktrf          1.4342      0.050     28.644      0.000       1.336       1.532
# smb            0.7105      0.096      7.388      0.000       0.522       0.899
# hml           -0.2285      0.090     -2.526      0.012      -0.406      -0.051
# umd           -0.1462      0.084     -1.745      0.081      -0.310       0.018
# ==============================================================================
# Omnibus:                       23.090   Durbin-Watson:                   2.254
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               35.744
# Skew:                           0.915   Prob(JB):                     1.73e-08
# Kurtosis:                       4.949   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.855
# Model:                            OLS   Adj. R-squared:                  0.850
# Method:                 Least Squares   F-statistic:                     524.6
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           7.82e-73
# Time:                        12:41:10   Log-Likelihood:                 229.66
# No. Observations:                 120   AIC:                            -449.3
# Df Residuals:                     115   BIC:                            -435.4
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0015      0.003     -0.468      0.640      -0.008       0.005
# mktrf          1.4342      0.039     37.056      0.000       1.358       1.510
# smb            0.7105      0.099      7.144      0.000       0.516       0.905
# hml           -0.2285      0.088     -2.595      0.009      -0.401      -0.056
# umd           -0.1462      0.083     -1.762      0.078      -0.309       0.016
# ==============================================================================
# Omnibus:                       23.090   Durbin-Watson:                   2.254
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               35.744
# Skew:                           0.915   Prob(JB):                     1.73e-08
# Kurtosis:                       4.949   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Post-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.875
# Model:                            OLS   Adj. R-squared:                  0.870
# Method:                 Least Squares   F-statistic:                     190.8
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.93e-48
# Time:                        12:41:10   Log-Likelihood:                 274.69
# No. Observations:                 114   AIC:                            -539.4
# Df Residuals:                     109   BIC:                            -525.7
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0017      0.002      0.764      0.446      -0.003       0.006
# mktrf          1.1078      0.065     16.946      0.000       0.978       1.237
# me             0.5162      0.101      5.114      0.000       0.316       0.716
# ia            -0.0367      0.140     -0.262      0.794      -0.314       0.241
# roe           -0.9599      0.123     -7.803      0.000      -1.204      -0.716
# ==============================================================================
# Omnibus:                       18.388   Durbin-Watson:                   1.976
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               27.796
# Skew:                           0.768   Prob(JB):                     9.21e-07
# Kurtosis:                       4.870   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.875
# Model:                            OLS   Adj. R-squared:                  0.870
# Method:                 Least Squares   F-statistic:                     266.8
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.50e-55
# Time:                        12:41:10   Log-Likelihood:                 274.69
# No. Observations:                 114   AIC:                            -539.4
# Df Residuals:                     109   BIC:                            -525.7
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0017      0.002      1.073      0.283      -0.001       0.005
# mktrf          1.1078      0.059     18.924      0.000       0.993       1.223
# me             0.5162      0.062      8.324      0.000       0.395       0.638
# ia            -0.0367      0.125     -0.294      0.769      -0.281       0.208
# roe           -0.9599      0.143     -6.714      0.000      -1.240      -0.680
# ==============================================================================
# Omnibus:                       18.388   Durbin-Watson:                   1.976
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               27.796
# Skew:                           0.768   Prob(JB):                     9.21e-07
# Kurtosis:                       4.870   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.875
# Model:                            OLS   Adj. R-squared:                  0.870
# Method:                 Least Squares   F-statistic:                     449.7
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           9.32e-67
# Time:                        12:41:10   Log-Likelihood:                 274.69
# No. Observations:                 114   AIC:                            -539.4
# Df Residuals:                     109   BIC:                            -525.7
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0017      0.001      1.268      0.205      -0.001       0.004
# mktrf          1.1078      0.050     22.208      0.000       1.010       1.206
# me             0.5162      0.058      8.872      0.000       0.402       0.630
# ia            -0.0367      0.120     -0.307      0.759      -0.271       0.198
# roe           -0.9599      0.139     -6.901      0.000      -1.232      -0.687
# ==============================================================================
# Omnibus:                       18.388   Durbin-Watson:                   1.976
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               27.796
# Skew:                           0.768   Prob(JB):                     9.21e-07
# Kurtosis:                       4.870   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.821
# Model:                            OLS   Adj. R-squared:                  0.814
# Method:                 Least Squares   F-statistic:                     124.9
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           9.05e-40
# Time:                        12:41:10   Log-Likelihood:                 254.18
# No. Observations:                 114   AIC:                            -498.4
# Df Residuals:                     109   BIC:                            -484.7
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0012      0.003     -0.461      0.646      -0.006       0.004
# mktrf          1.1771      0.074     15.872      0.000       1.030       1.324
# smb            0.7707      0.116      6.665      0.000       0.542       1.000
# hml            0.0854      0.119      0.717      0.475      -0.151       0.321
# umd           -0.2666      0.090     -2.967      0.004      -0.445      -0.089
# ==============================================================================
# Omnibus:                       11.288   Durbin-Watson:                   1.884
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               12.620
# Skew:                           0.618   Prob(JB):                      0.00182
# Kurtosis:                       4.063   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.821
# Model:                            OLS   Adj. R-squared:                  0.814
# Method:                 Least Squares   F-statistic:                     148.9
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           3.18e-43
# Time:                        12:41:10   Log-Likelihood:                 254.18
# No. Observations:                 114   AIC:                            -498.4
# Df Residuals:                     109   BIC:                            -484.7
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0012      0.002     -0.571      0.568      -0.005       0.003
# mktrf          1.1771      0.074     15.899      0.000       1.032       1.322
# smb            0.7707      0.091      8.456      0.000       0.592       0.949
# hml            0.0854      0.186      0.460      0.646      -0.279       0.449
# umd           -0.2666      0.111     -2.403      0.016      -0.484      -0.049
# ==============================================================================
# Omnibus:                       11.288   Durbin-Watson:                   1.884
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               12.620
# Skew:                           0.618   Prob(JB):                      0.00182
# Kurtosis:                       4.063   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.821
# Model:                            OLS   Adj. R-squared:                  0.814
# Method:                 Least Squares   F-statistic:                     222.8
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.69e-51
# Time:                        12:41:10   Log-Likelihood:                 254.18
# No. Observations:                 114   AIC:                            -498.4
# Df Residuals:                     109   BIC:                            -484.7
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0012      0.002     -0.624      0.533      -0.005       0.003
# mktrf          1.1771      0.069     17.031      0.000       1.042       1.313
# smb            0.7707      0.069     11.151      0.000       0.635       0.906
# hml            0.0854      0.197      0.433      0.665      -0.301       0.472
# umd           -0.2666      0.098     -2.714      0.007      -0.459      -0.074
# ==============================================================================
# Omnibus:                       11.288   Durbin-Watson:                   1.884
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               12.620
# Skew:                           0.618   Prob(JB):                      0.00182
# Kurtosis:                       4.063   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.821
# Model:                            OLS   Adj. R-squared:                  0.814
# Method:                 Least Squares   F-statistic:                     124.9
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           9.05e-40
# Time:                        12:41:10   Log-Likelihood:                 254.18
# No. Observations:                 114   AIC:                            -498.4
# Df Residuals:                     109   BIC:                            -484.7
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0012      0.003     -0.461      0.646      -0.006       0.004
# mktrf          1.1771      0.074     15.872      0.000       1.030       1.324
# smb            0.7707      0.116      6.665      0.000       0.542       1.000
# hml            0.0854      0.119      0.717      0.475      -0.151       0.321
# umd           -0.2666      0.090     -2.967      0.004      -0.445      -0.089
# ==============================================================================
# Omnibus:                       11.288   Durbin-Watson:                   1.884
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               12.620
# Skew:                           0.618   Prob(JB):                      0.00182
# Kurtosis:                       4.063   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.821
# Model:                            OLS   Adj. R-squared:                  0.814
# Method:                 Least Squares   F-statistic:                     148.9
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           3.18e-43
# Time:                        12:41:10   Log-Likelihood:                 254.18
# No. Observations:                 114   AIC:                            -498.4
# Df Residuals:                     109   BIC:                            -484.7
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0012      0.002     -0.571      0.568      -0.005       0.003
# mktrf          1.1771      0.074     15.899      0.000       1.032       1.322
# smb            0.7707      0.091      8.456      0.000       0.592       0.949
# hml            0.0854      0.186      0.460      0.646      -0.279       0.449
# umd           -0.2666      0.111     -2.403      0.016      -0.484      -0.049
# ==============================================================================
# Omnibus:                       11.288   Durbin-Watson:                   1.884
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               12.620
# Skew:                           0.618   Prob(JB):                      0.00182
# Kurtosis:                       4.063   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.821
# Model:                            OLS   Adj. R-squared:                  0.814
# Method:                 Least Squares   F-statistic:                     222.8
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.69e-51
# Time:                        12:41:11   Log-Likelihood:                 254.18
# No. Observations:                 114   AIC:                            -498.4
# Df Residuals:                     109   BIC:                            -484.7
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0012      0.002     -0.624      0.533      -0.005       0.003
# mktrf          1.1771      0.069     17.031      0.000       1.042       1.313
# smb            0.7707      0.069     11.151      0.000       0.635       0.906
# hml            0.0854      0.197      0.433      0.665      -0.301       0.472
# umd           -0.2666      0.098     -2.714      0.007      -0.459      -0.074
# ==============================================================================
# Omnibus:                       11.288   Durbin-Watson:                   1.884
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               12.620
# Skew:                           0.618   Prob(JB):                      0.00182
# Kurtosis:                       4.063   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """
