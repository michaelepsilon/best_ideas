# %% [markdown]
# # Method 6 - Best Minus Rest Fresh Ideas

# %%
# %matplotlib inline
import pandas as pd
import warnings
from statsmodels import api as sm

from eptooling import crsp, epd, fs, hfu, crsp, db, bi
from eptooling.bm import bmdb, iso
from epquant.engine import weights, portfolio
from epquant.gen import returns
from epquant.perf import relative_performance

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Fetch Holdings and Benchmark Data

# %%
# Get HFU Data

# %store -r inst_data

# Count number of positions per manager

inst_data['num_pos'] = inst_data.groupby(['datadate', 'institution_id'])[
    'fsym_id'].transform(lambda s: s.nunique())

# Remove less than 20 holdings and less than $5mm per CSP

valid_data = inst_data[inst_data['num_pos'] >= 20]
valid_data = valid_data[valid_data['public_aum'] >= 5e6]

# Get Returns for Fresh Ideas

# %store -r r

# Get Adjusted Quantities

qty_pivot = pd.pivot_table(inst_data, index='datadate', columns=['institution_id', 'fsym_id'], values='quantity',
                           aggfunc='sum')
qty_pivot = qty_pivot.mul(r.splits.reindex(qty_pivot.index), level=1).fillna(0)
qty_pivot = qty_pivot - qty_pivot.shift(1)
flat_qty = pd.melt(qty_pivot.reset_index(), id_vars='datadate', value_name='qty_change')
flat_qty = flat_qty[flat_qty['qty_change'] > 0]

# Get Pos Size Change

pos_size_pivot = pd.pivot_table(inst_data, index='datadate', columns=['institution_id', 'fsym_id'], values='target',
                                aggfunc='sum')
pos_size_pivot = pos_size_pivot - pos_size_pivot.shift(1)
flat_pos_size = pd.melt(pos_size_pivot.reset_index(), id_vars='datadate', value_name='size_change')
flat_pos_size = flat_pos_size[flat_pos_size['size_change'] > 0]

# Add Expected Returns from Market Relative Weight per Shumway, Szefler, Yuan 2009

# %store -r mkt_exp_ret

valid_data = valid_data.merge(mkt_exp_ret, on=['datadate', 'institution_id', 'fsym_id'], how='left')

# Calculate CSP Weight per Market Tilt

valid_data['adj_target'] = valid_data['expected_return']

# %% [markdown]
# ## Calculate Best Ideas

# %%
# Extract Best Ideas

valid_data['pos_rank'] = valid_data\
    .groupby(['datadate', 'institution_id'])['adj_target'].rank(ascending=False)

# Get Managers with Best Fresh Ideas

fresh_idea_mgrs = valid_data.merge(flat_qty).merge(flat_pos_size)
fresh_idea_mgrs = fresh_idea_mgrs[fresh_idea_mgrs['pos_rank'] == 1][['datadate', 'institution_id']].drop_duplicates()
fresh_idea_mgrs['fresh'] = 1

# Split Long and Short and Filter to Highest Tilts

long_ideas = valid_data[valid_data['pos_rank'] == 1].copy()
long_ideas = long_ideas.merge(fresh_idea_mgrs, on=['datadate', 'institution_id'], how='inner')
                                                                                         
short_ideas = valid_data[valid_data['pos_rank'] != 1].copy()
short_ideas = short_ideas.merge(fresh_idea_mgrs, on=['datadate', 'institution_id'], how='inner')

# Weight the best ideas equally

long_ideas['target'] = 1 / long_ideas.groupby('datadate')[
    'institution_id'].transform('count')

short_ideas['target'] = - short_ideas['target'] / short_ideas.groupby([
    'datadate', 'institution_id'])['target'].transform('sum') * \
                        (1 / short_ideas.groupby('datadate')['institution_id']
                         .transform(lambda s: s.nunique()))

best_ideas = pd.concat([long_ideas, short_ideas])

# %% [markdown]
# ## Backtest Portfolio

# %%
w = weights.Weights(best_ideas)

# %store -r r

p = portfolio.DailyPortfolio(w, r, end_date='2018-12-31')

monthly_return = p.port_return.loc['1999-07-01':].resample('M').apply(epd.prod_red)
monthly_return.name = 'port_return'

# %% [markdown]
# ## Plot Performance

# %%
epd.nav(monthly_return).plot()

# %%
monthly_return.resample('A').apply(epd.prod_red)
# Out:
# datadate
# 1999-12-31    0.062326
# 2000-12-31   -0.148841
# 2001-12-31   -0.230074
# 2002-12-31   -0.127577
# 2003-12-31    0.426438
# 2004-12-31   -0.001967
# 2005-12-31    0.019205
# 2006-12-31    0.024464
# 2007-12-31   -0.000159
# 2008-12-31   -0.144695
# 2009-12-31    0.233817
# 2010-12-31    0.047875
# 2011-12-31   -0.091462
# 2012-12-31    0.091058
# 2013-12-31    0.118164
# 2014-12-31   -0.063554
# 2015-12-31   -0.071828
# 2016-12-31   -0.000766
# 2017-12-31   -0.029547
# 2018-12-31    0.003160
# Freq: A-DEC, Name: port_return, dtype: float64

# %% [markdown]
# ## Fetch Factor Models

# %%
# Get Factor Models
q_factor_model = bi.get_q_factor_model()
fama_french_five_factor_model = bi.get_fama_french_five_factor_model()
four_factor_model = bi.get_four_factor_model()

# Concat Portfolio Return
q_factor = pd.concat([monthly_return, q_factor_model], axis=1)
fama_french_five = pd.concat([monthly_return, fama_french_five_factor_model], axis=1)
four_factor = pd.concat([monthly_return, four_factor_model], axis=1)

# Add Constants
q_factor.insert(1, 'const', 1)
fama_french_five.insert(1, 'const', 1)
four_factor.insert(1, 'const', 1)

# Split Period into Pre and Post Crisis
q_factor_pre, q_factor_post = q_factor.loc[:'2009-06-30'], q_factor.loc['2009-07-31':]
fama_french_five_pre, fama_french_five_post = fama_french_five.loc[:'2009-06-30'], fama_french_five.loc['2009-07-31':] 
four_factor_pre, four_factor_post = four_factor.loc[:'2009-06-30'], four_factor.loc['2009-07-31':]

# %% [markdown]
# ## Full Time Period Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.579
# Model:                            OLS   Adj. R-squared:                  0.572
# Method:                 Least Squares   F-statistic:                     78.89
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           5.66e-42
# Time:                        13:03:37   Log-Likelihood:                 561.63
# No. Observations:                 234   AIC:                            -1113.
# Df Residuals:                     229   BIC:                            -1096.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0009      0.002      0.578      0.564      -0.002       0.004
# mktrf          0.1246      0.041      3.011      0.003       0.043       0.206
# me             0.2633      0.048      5.469      0.000       0.168       0.358
# ia            -0.0094      0.073     -0.129      0.897      -0.154       0.135
# roe           -0.5791      0.063     -9.248      0.000      -0.702      -0.456
# ==============================================================================
# Omnibus:                       24.413   Durbin-Watson:                   1.926
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               61.957
# Skew:                           0.439   Prob(JB):                     3.52e-14
# Kurtosis:                       5.363   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.579
# Model:                            OLS   Adj. R-squared:                  0.572
# Method:                 Least Squares   F-statistic:                     70.14
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.08e-38
# Time:                        13:03:37   Log-Likelihood:                 561.63
# No. Observations:                 234   AIC:                            -1113.
# Df Residuals:                     229   BIC:                            -1096.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0009      0.002      0.427      0.669      -0.003       0.005
# mktrf          0.1246      0.043      2.910      0.004       0.041       0.208
# me             0.2633      0.036      7.246      0.000       0.192       0.334
# ia            -0.0094      0.107     -0.089      0.929      -0.218       0.199
# roe           -0.5791      0.116     -5.000      0.000      -0.806      -0.352
# ==============================================================================
# Omnibus:                       24.413   Durbin-Watson:                   1.926
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               61.957
# Skew:                           0.439   Prob(JB):                     3.52e-14
# Kurtosis:                       5.363   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.579
# Model:                            OLS   Adj. R-squared:                  0.572
# Method:                 Least Squares   F-statistic:                     101.4
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.48e-49
# Time:                        13:03:37   Log-Likelihood:                 561.63
# No. Observations:                 234   AIC:                            -1113.
# Df Residuals:                     229   BIC:                            -1096.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0009      0.002      0.435      0.663      -0.003       0.005
# mktrf          0.1246      0.044      2.838      0.005       0.039       0.211
# me             0.2633      0.035      7.473      0.000       0.194       0.332
# ia            -0.0094      0.096     -0.099      0.921      -0.197       0.178
# roe           -0.5791      0.117     -4.966      0.000      -0.808      -0.351
# ==============================================================================
# Omnibus:                       24.413   Durbin-Watson:                   1.926
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               61.957
# Skew:                           0.439   Prob(JB):                     3.52e-14
# Kurtosis:                       5.363   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.507
# Model:                            OLS   Adj. R-squared:                  0.498
# Method:                 Least Squares   F-statistic:                     58.83
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           4.20e-34
# Time:                        13:03:37   Log-Likelihood:                 542.97
# No. Observations:                 234   AIC:                            -1076.
# Df Residuals:                     229   BIC:                            -1059.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0011      0.002     -0.675      0.501      -0.004       0.002
# mktrf          0.2282      0.041      5.531      0.000       0.147       0.309
# smb            0.4905      0.052      9.524      0.000       0.389       0.592
# hml           -0.0441      0.051     -0.862      0.389      -0.145       0.057
# umd           -0.1837      0.034     -5.472      0.000      -0.250      -0.118
# ==============================================================================
# Omnibus:                       35.425   Durbin-Watson:                   1.934
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               85.910
# Skew:                           0.688   Prob(JB):                     2.21e-19
# Kurtosis:                       5.630   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.507
# Model:                            OLS   Adj. R-squared:                  0.498
# Method:                 Least Squares   F-statistic:                     36.28
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.78e-23
# Time:                        13:03:37   Log-Likelihood:                 542.97
# No. Observations:                 234   AIC:                            -1076.
# Df Residuals:                     229   BIC:                            -1059.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0011      0.002     -0.547      0.584      -0.005       0.003
# mktrf          0.2282      0.043      5.348      0.000       0.145       0.312
# smb            0.4905      0.055      8.887      0.000       0.382       0.599
# hml           -0.0441      0.068     -0.652      0.514      -0.177       0.088
# umd           -0.1837      0.062     -2.959      0.003      -0.305      -0.062
# ==============================================================================
# Omnibus:                       35.425   Durbin-Watson:                   1.934
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               85.910
# Skew:                           0.688   Prob(JB):                     2.21e-19
# Kurtosis:                       5.630   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.507
# Model:                            OLS   Adj. R-squared:                  0.498
# Method:                 Least Squares   F-statistic:                     41.33
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           4.65e-26
# Time:                        13:03:37   Log-Likelihood:                 542.97
# No. Observations:                 234   AIC:                            -1076.
# Df Residuals:                     229   BIC:                            -1059.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0011      0.002     -0.547      0.585      -0.005       0.003
# mktrf          0.2282      0.046      5.008      0.000       0.139       0.318
# smb            0.4905      0.051      9.621      0.000       0.391       0.590
# hml           -0.0441      0.069     -0.640      0.522      -0.179       0.091
# umd           -0.1837      0.065     -2.828      0.005      -0.311      -0.056
# ==============================================================================
# Omnibus:                       35.425   Durbin-Watson:                   1.934
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               85.910
# Skew:                           0.688   Prob(JB):                     2.21e-19
# Kurtosis:                       5.630   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.507
# Model:                            OLS   Adj. R-squared:                  0.498
# Method:                 Least Squares   F-statistic:                     58.83
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           4.20e-34
# Time:                        13:03:37   Log-Likelihood:                 542.97
# No. Observations:                 234   AIC:                            -1076.
# Df Residuals:                     229   BIC:                            -1059.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0011      0.002     -0.675      0.501      -0.004       0.002
# mktrf          0.2282      0.041      5.531      0.000       0.147       0.309
# smb            0.4905      0.052      9.524      0.000       0.389       0.592
# hml           -0.0441      0.051     -0.862      0.389      -0.145       0.057
# umd           -0.1837      0.034     -5.472      0.000      -0.250      -0.118
# ==============================================================================
# Omnibus:                       35.425   Durbin-Watson:                   1.934
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               85.910
# Skew:                           0.688   Prob(JB):                     2.21e-19
# Kurtosis:                       5.630   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.507
# Model:                            OLS   Adj. R-squared:                  0.498
# Method:                 Least Squares   F-statistic:                     36.28
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.78e-23
# Time:                        13:03:37   Log-Likelihood:                 542.97
# No. Observations:                 234   AIC:                            -1076.
# Df Residuals:                     229   BIC:                            -1059.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0011      0.002     -0.547      0.584      -0.005       0.003
# mktrf          0.2282      0.043      5.348      0.000       0.145       0.312
# smb            0.4905      0.055      8.887      0.000       0.382       0.599
# hml           -0.0441      0.068     -0.652      0.514      -0.177       0.088
# umd           -0.1837      0.062     -2.959      0.003      -0.305      -0.062
# ==============================================================================
# Omnibus:                       35.425   Durbin-Watson:                   1.934
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               85.910
# Skew:                           0.688   Prob(JB):                     2.21e-19
# Kurtosis:                       5.630   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.507
# Model:                            OLS   Adj. R-squared:                  0.498
# Method:                 Least Squares   F-statistic:                     41.33
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           4.65e-26
# Time:                        13:03:37   Log-Likelihood:                 542.97
# No. Observations:                 234   AIC:                            -1076.
# Df Residuals:                     229   BIC:                            -1059.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0011      0.002     -0.547      0.585      -0.005       0.003
# mktrf          0.2282      0.046      5.008      0.000       0.139       0.318
# smb            0.4905      0.051      9.621      0.000       0.391       0.590
# hml           -0.0441      0.069     -0.640      0.522      -0.179       0.091
# umd           -0.1837      0.065     -2.828      0.005      -0.311      -0.056
# ==============================================================================
# Omnibus:                       35.425   Durbin-Watson:                   1.934
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               85.910
# Skew:                           0.688   Prob(JB):                     2.21e-19
# Kurtosis:                       5.630   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Pre-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.583
# Model:                            OLS   Adj. R-squared:                  0.568
# Method:                 Least Squares   F-statistic:                     40.19
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           4.97e-21
# Time:                        13:03:37   Log-Likelihood:                 267.26
# No. Observations:                 120   AIC:                            -524.5
# Df Residuals:                     115   BIC:                            -510.6
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0007      0.003      0.279      0.781      -0.004       0.006
# mktrf          0.1807      0.069      2.631      0.010       0.045       0.317
# me             0.2590      0.068      3.818      0.000       0.125       0.393
# ia            -0.0261      0.106     -0.246      0.806      -0.237       0.184
# roe           -0.4934      0.094     -5.247      0.000      -0.680      -0.307
# ==============================================================================
# Omnibus:                       17.296   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               30.872
# Skew:                           0.627   Prob(JB):                     1.98e-07
# Kurtosis:                       5.145   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.583
# Model:                            OLS   Adj. R-squared:                  0.568
# Method:                 Least Squares   F-statistic:                     61.98
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           8.05e-28
# Time:                        13:03:37   Log-Likelihood:                 267.26
# No. Observations:                 120   AIC:                            -524.5
# Df Residuals:                     115   BIC:                            -510.6
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0007      0.004      0.190      0.850      -0.007       0.008
# mktrf          0.1807      0.061      2.948      0.003       0.061       0.301
# me             0.2590      0.055      4.671      0.000       0.150       0.368
# ia            -0.0261      0.154     -0.169      0.866      -0.329       0.277
# roe           -0.4934      0.159     -3.100      0.002      -0.805      -0.181
# ==============================================================================
# Omnibus:                       17.296   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               30.872
# Skew:                           0.627   Prob(JB):                     1.98e-07
# Kurtosis:                       5.145   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.583
# Model:                            OLS   Adj. R-squared:                  0.568
# Method:                 Least Squares   F-statistic:                     108.3
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           4.63e-38
# Time:                        13:03:37   Log-Likelihood:                 267.26
# No. Observations:                 120   AIC:                            -524.5
# Df Residuals:                     115   BIC:                            -510.6
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0007      0.004      0.193      0.847      -0.007       0.008
# mktrf          0.1807      0.058      3.123      0.002       0.067       0.294
# me             0.2590      0.054      4.837      0.000       0.154       0.364
# ia            -0.0261      0.138     -0.189      0.850      -0.297       0.245
# roe           -0.4934      0.156     -3.158      0.002      -0.800      -0.187
# ==============================================================================
# Omnibus:                       17.296   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               30.872
# Skew:                           0.627   Prob(JB):                     1.98e-07
# Kurtosis:                       5.145   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.565
# Model:                            OLS   Adj. R-squared:                  0.550
# Method:                 Least Squares   F-statistic:                     37.34
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           5.50e-20
# Time:                        13:03:37   Log-Likelihood:                 264.72
# No. Observations:                 120   AIC:                            -519.4
# Df Residuals:                     115   BIC:                            -505.5
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0006      0.003     -0.229      0.820      -0.006       0.004
# mktrf          0.2908      0.062      4.704      0.000       0.168       0.413
# smb            0.4602      0.070      6.538      0.000       0.321       0.600
# hml           -0.1013      0.070     -1.436      0.154      -0.241       0.038
# umd           -0.1632      0.043     -3.754      0.000      -0.249      -0.077
# ==============================================================================
# Omnibus:                       24.033   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               42.008
# Skew:                           0.888   Prob(JB):                     7.55e-10
# Kurtosis:                       5.291   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.565
# Model:                            OLS   Adj. R-squared:                  0.550
# Method:                 Least Squares   F-statistic:                     41.34
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.95e-21
# Time:                        13:03:37   Log-Likelihood:                 264.72
# No. Observations:                 120   AIC:                            -519.4
# Df Residuals:                     115   BIC:                            -505.5
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0006      0.003     -0.174      0.862      -0.007       0.006
# mktrf          0.2908      0.049      5.974      0.000       0.195       0.386
# smb            0.4602      0.065      7.071      0.000       0.333       0.588
# hml           -0.1013      0.074     -1.371      0.170      -0.246       0.043
# umd           -0.1632      0.069     -2.362      0.018      -0.299      -0.028
# ==============================================================================
# Omnibus:                       24.033   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               42.008
# Skew:                           0.888   Prob(JB):                     7.55e-10
# Kurtosis:                       5.291   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.565
# Model:                            OLS   Adj. R-squared:                  0.550
# Method:                 Least Squares   F-statistic:                     54.28
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.27e-25
# Time:                        13:03:37   Log-Likelihood:                 264.72
# No. Observations:                 120   AIC:                            -519.4
# Df Residuals:                     115   BIC:                            -505.5
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0006      0.003     -0.177      0.860      -0.007       0.006
# mktrf          0.2908      0.044      6.575      0.000       0.204       0.377
# smb            0.4602      0.061      7.575      0.000       0.341       0.579
# hml           -0.1013      0.063     -1.604      0.109      -0.225       0.022
# umd           -0.1632      0.072     -2.272      0.023      -0.304      -0.022
# ==============================================================================
# Omnibus:                       24.033   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               42.008
# Skew:                           0.888   Prob(JB):                     7.55e-10
# Kurtosis:                       5.291   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.565
# Model:                            OLS   Adj. R-squared:                  0.550
# Method:                 Least Squares   F-statistic:                     37.34
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           5.50e-20
# Time:                        13:03:37   Log-Likelihood:                 264.72
# No. Observations:                 120   AIC:                            -519.4
# Df Residuals:                     115   BIC:                            -505.5
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0006      0.003     -0.229      0.820      -0.006       0.004
# mktrf          0.2908      0.062      4.704      0.000       0.168       0.413
# smb            0.4602      0.070      6.538      0.000       0.321       0.600
# hml           -0.1013      0.070     -1.436      0.154      -0.241       0.038
# umd           -0.1632      0.043     -3.754      0.000      -0.249      -0.077
# ==============================================================================
# Omnibus:                       24.033   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               42.008
# Skew:                           0.888   Prob(JB):                     7.55e-10
# Kurtosis:                       5.291   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.565
# Model:                            OLS   Adj. R-squared:                  0.550
# Method:                 Least Squares   F-statistic:                     41.34
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.95e-21
# Time:                        13:03:37   Log-Likelihood:                 264.72
# No. Observations:                 120   AIC:                            -519.4
# Df Residuals:                     115   BIC:                            -505.5
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0006      0.003     -0.174      0.862      -0.007       0.006
# mktrf          0.2908      0.049      5.974      0.000       0.195       0.386
# smb            0.4602      0.065      7.071      0.000       0.333       0.588
# hml           -0.1013      0.074     -1.371      0.170      -0.246       0.043
# umd           -0.1632      0.069     -2.362      0.018      -0.299      -0.028
# ==============================================================================
# Omnibus:                       24.033   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               42.008
# Skew:                           0.888   Prob(JB):                     7.55e-10
# Kurtosis:                       5.291   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.565
# Model:                            OLS   Adj. R-squared:                  0.550
# Method:                 Least Squares   F-statistic:                     54.28
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.27e-25
# Time:                        13:03:37   Log-Likelihood:                 264.72
# No. Observations:                 120   AIC:                            -519.4
# Df Residuals:                     115   BIC:                            -505.5
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0006      0.003     -0.177      0.860      -0.007       0.006
# mktrf          0.2908      0.044      6.575      0.000       0.204       0.377
# smb            0.4602      0.061      7.575      0.000       0.341       0.579
# hml           -0.1013      0.063     -1.604      0.109      -0.225       0.022
# umd           -0.1632      0.072     -2.272      0.023      -0.304      -0.022
# ==============================================================================
# Omnibus:                       24.033   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               42.008
# Skew:                           0.888   Prob(JB):                     7.55e-10
# Kurtosis:                       5.291   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Post-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.600
# Model:                            OLS   Adj. R-squared:                  0.585
# Method:                 Least Squares   F-statistic:                     40.82
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           7.24e-21
# Time:                        13:03:37   Log-Likelihood:                 310.36
# No. Observations:                 114   AIC:                            -610.7
# Df Residuals:                     109   BIC:                            -597.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0018      0.002      1.114      0.268      -0.001       0.005
# mktrf          0.0535      0.048      1.119      0.265      -0.041       0.148
# me             0.3119      0.074      4.226      0.000       0.166       0.458
# ia            -0.0167      0.102     -0.163      0.871      -0.220       0.186
# roe           -0.7527      0.090     -8.366      0.000      -0.931      -0.574
# ==============================================================================
# Omnibus:                        3.136   Durbin-Watson:                   1.803
# Prob(Omnibus):                  0.208   Jarque-Bera (JB):                2.979
# Skew:                           0.395   Prob(JB):                        0.225
# Kurtosis:                       2.935   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.600
# Model:                            OLS   Adj. R-squared:                  0.585
# Method:                 Least Squares   F-statistic:                     38.39
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           5.11e-20
# Time:                        13:03:37   Log-Likelihood:                 310.36
# No. Observations:                 114   AIC:                            -610.7
# Df Residuals:                     109   BIC:                            -597.0
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0018      0.001      1.488      0.137      -0.001       0.004
# mktrf          0.0535      0.041      1.302      0.193      -0.027       0.134
# me             0.3119      0.040      7.812      0.000       0.234       0.390
# ia            -0.0167      0.103     -0.162      0.871      -0.218       0.184
# roe           -0.7527      0.091     -8.259      0.000      -0.931      -0.574
# ==============================================================================
# Omnibus:                        3.136   Durbin-Watson:                   1.803
# Prob(Omnibus):                  0.208   Jarque-Bera (JB):                2.979
# Skew:                           0.395   Prob(JB):                        0.225
# Kurtosis:                       2.935   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.600
# Model:                            OLS   Adj. R-squared:                  0.585
# Method:                 Least Squares   F-statistic:                     39.09
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.88e-20
# Time:                        13:03:37   Log-Likelihood:                 310.36
# No. Observations:                 114   AIC:                            -610.7
# Df Residuals:                     109   BIC:                            -597.0
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0018      0.001      1.769      0.077      -0.000       0.004
# mktrf          0.0535      0.038      1.394      0.163      -0.022       0.129
# me             0.3119      0.035      8.828      0.000       0.243       0.381
# ia            -0.0167      0.112     -0.149      0.882      -0.236       0.203
# roe           -0.7527      0.089     -8.447      0.000      -0.927      -0.578
# ==============================================================================
# Omnibus:                        3.136   Durbin-Watson:                   1.803
# Prob(Omnibus):                  0.208   Jarque-Bera (JB):                2.979
# Skew:                           0.395   Prob(JB):                        0.225
# Kurtosis:                       2.935   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.427
# Model:                            OLS   Adj. R-squared:                  0.406
# Method:                 Least Squares   F-statistic:                     20.34
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.55e-12
# Time:                        13:03:37   Log-Likelihood:                 289.95
# No. Observations:                 114   AIC:                            -569.9
# Df Residuals:                     109   BIC:                            -556.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       9.046e-05      0.002      0.047      0.963      -0.004       0.004
# mktrf          0.1190      0.054      2.196      0.030       0.012       0.226
# smb            0.4774      0.084      5.651      0.000       0.310       0.645
# hml            0.1923      0.087      2.209      0.029       0.020       0.365
# umd           -0.1506      0.066     -2.294      0.024      -0.281      -0.020
# ==============================================================================
# Omnibus:                        4.387   Durbin-Watson:                   1.949
# Prob(Omnibus):                  0.112   Jarque-Bera (JB):                5.633
# Skew:                           0.062   Prob(JB):                       0.0598
# Kurtosis:                       4.082   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.427
# Model:                            OLS   Adj. R-squared:                  0.406
# Method:                 Least Squares   F-statistic:                     15.09
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           7.58e-10
# Time:                        13:03:37   Log-Likelihood:                 289.95
# No. Observations:                 114   AIC:                            -569.9
# Df Residuals:                     109   BIC:                            -556.2
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       9.046e-05      0.001      0.062      0.950      -0.003       0.003
# mktrf          0.1190      0.049      2.426      0.015       0.023       0.215
# smb            0.4774      0.075      6.405      0.000       0.331       0.624
# hml            0.1923      0.127      1.512      0.130      -0.057       0.441
# umd           -0.1506      0.064     -2.344      0.019      -0.276      -0.025
# ==============================================================================
# Omnibus:                        4.387   Durbin-Watson:                   1.949
# Prob(Omnibus):                  0.112   Jarque-Bera (JB):                5.633
# Skew:                           0.062   Prob(JB):                       0.0598
# Kurtosis:                       4.082   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.427
# Model:                            OLS   Adj. R-squared:                  0.406
# Method:                 Least Squares   F-statistic:                     19.22
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           5.47e-12
# Time:                        13:03:37   Log-Likelihood:                 289.95
# No. Observations:                 114   AIC:                            -569.9
# Df Residuals:                     109   BIC:                            -556.2
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       9.046e-05      0.001      0.065      0.948      -0.003       0.003
# mktrf          0.1190      0.046      2.589      0.010       0.029       0.209
# smb            0.4774      0.067      7.102      0.000       0.346       0.609
# hml            0.1923      0.132      1.454      0.146      -0.067       0.451
# umd           -0.1506      0.056     -2.704      0.007      -0.260      -0.041
# ==============================================================================
# Omnibus:                        4.387   Durbin-Watson:                   1.949
# Prob(Omnibus):                  0.112   Jarque-Bera (JB):                5.633
# Skew:                           0.062   Prob(JB):                       0.0598
# Kurtosis:                       4.082   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.427
# Model:                            OLS   Adj. R-squared:                  0.406
# Method:                 Least Squares   F-statistic:                     20.34
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.55e-12
# Time:                        13:03:37   Log-Likelihood:                 289.95
# No. Observations:                 114   AIC:                            -569.9
# Df Residuals:                     109   BIC:                            -556.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       9.046e-05      0.002      0.047      0.963      -0.004       0.004
# mktrf          0.1190      0.054      2.196      0.030       0.012       0.226
# smb            0.4774      0.084      5.651      0.000       0.310       0.645
# hml            0.1923      0.087      2.209      0.029       0.020       0.365
# umd           -0.1506      0.066     -2.294      0.024      -0.281      -0.020
# ==============================================================================
# Omnibus:                        4.387   Durbin-Watson:                   1.949
# Prob(Omnibus):                  0.112   Jarque-Bera (JB):                5.633
# Skew:                           0.062   Prob(JB):                       0.0598
# Kurtosis:                       4.082   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.427
# Model:                            OLS   Adj. R-squared:                  0.406
# Method:                 Least Squares   F-statistic:                     15.09
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           7.58e-10
# Time:                        13:03:37   Log-Likelihood:                 289.95
# No. Observations:                 114   AIC:                            -569.9
# Df Residuals:                     109   BIC:                            -556.2
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       9.046e-05      0.001      0.062      0.950      -0.003       0.003
# mktrf          0.1190      0.049      2.426      0.015       0.023       0.215
# smb            0.4774      0.075      6.405      0.000       0.331       0.624
# hml            0.1923      0.127      1.512      0.130      -0.057       0.441
# umd           -0.1506      0.064     -2.344      0.019      -0.276      -0.025
# ==============================================================================
# Omnibus:                        4.387   Durbin-Watson:                   1.949
# Prob(Omnibus):                  0.112   Jarque-Bera (JB):                5.633
# Skew:                           0.062   Prob(JB):                       0.0598
# Kurtosis:                       4.082   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.427
# Model:                            OLS   Adj. R-squared:                  0.406
# Method:                 Least Squares   F-statistic:                     19.22
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           5.47e-12
# Time:                        13:03:37   Log-Likelihood:                 289.95
# No. Observations:                 114   AIC:                            -569.9
# Df Residuals:                     109   BIC:                            -556.2
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       9.046e-05      0.001      0.065      0.948      -0.003       0.003
# mktrf          0.1190      0.046      2.589      0.010       0.029       0.209
# smb            0.4774      0.067      7.102      0.000       0.346       0.609
# hml            0.1923      0.132      1.454      0.146      -0.067       0.451
# umd           -0.1506      0.056     -2.704      0.007      -0.260      -0.041
# ==============================================================================
# Omnibus:                        4.387   Durbin-Watson:                   1.949
# Prob(Omnibus):                  0.112   Jarque-Bera (JB):                5.633
# Skew:                           0.062   Prob(JB):                       0.0598
# Kurtosis:                       4.082   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """
