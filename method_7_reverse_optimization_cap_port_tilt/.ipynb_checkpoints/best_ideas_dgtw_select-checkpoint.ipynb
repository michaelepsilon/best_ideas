# %% [markdown]
# # Method 7 - Best Ideas DGTW Select

# %%
# %matplotlib inline
import pandas as pd
import warnings
from statsmodels import api as sm

from eptooling import crsp, epd, fs, hfu, crsp, db, bi
from eptooling.bm import bmdb, iso
from epquant.engine import weights, portfolio
from epquant.gen import returns
from epquant.perf import relative_performance

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Fetch Holdings and Benchmark Data

# %%
# Get HFU Data

# %store -r inst_data
inst_data = inst_data[inst_data['datadate'] >= '1999-06-30']

# Count number of positions per manager

inst_data['num_pos'] = inst_data.groupby(['datadate', 'institution_id'])[
    'fsym_id'].transform(lambda s: s.nunique())

# Remove less than 20 holdings and less than $5mm per CSP

valid_data = inst_data[inst_data['num_pos'] >= 20]
valid_data = valid_data[valid_data['public_aum'] >= 5e6]

# Add Expected Returns from Intra-Cap Portfolio Weight per Shumway, Szefler, Yuan 2009

# %store -r cap_exp_ret

valid_data = valid_data.merge(cap_exp_ret, on=['datadate', 'institution_id', 'fsym_id'], how='left')

# Calculate CSP Weight per Market Tilt

valid_data['adj_target'] = valid_data['expected_return']

# %% [markdown]
# ## Calculate Best Ideas

# %%
# Extract Best Ideas

valid_data['pos_rank'] = valid_data\
    .groupby(['datadate', 'institution_id'])['adj_target'].rank(ascending=False)

best_ideas = valid_data[valid_data['pos_rank'] == 1].copy()

# Weight the best ideas equally

best_ideas['target'] = 1 / best_ideas.groupby('datadate')[
    'institution_id'].transform('count')

# %% [markdown]
# ## Backtest Portfolio

# %%
w = weights.Weights(best_ideas)

# %store -r r

p = portfolio.DailyPortfolio(w, r, end_date='2018-12-31')

monthly_beg_pos = p.beg_port.iloc[1:].resample('M', level=0).apply(epd.take_first)
dgtw = crsp.get_dgtw_returns(list(set(best_ideas['fsym_id'].dropna())),
                    best_ideas['datadate'].min(), pd.datetime(2018, 12, 31))
dgtw_pivot = pd.pivot_table(dgtw, index='datadate', columns='fsym_id', values='total_return')
dgtw_cont = monthly_beg_pos.mul(dgtw_pivot, axis=1, level=0).sum(axis=1)

monthly_return = p.port_return.loc['1999-07-01':].resample('M').apply(epd.prod_red)
monthly_return = (monthly_return - dgtw_cont).dropna()
monthly_return.name = 'port_return'

# %% [markdown]
# ## Plot Performance

# %%
epd.nav(monthly_return).plot()

# %%
monthly_return.resample('A').apply(epd.prod_red)
# Out:
# datadate
# 1999-12-31    0.185824
# 2000-12-31   -0.115567
# 2001-12-31   -0.140143
# 2002-12-31   -0.147747
# 2003-12-31    0.248753
# 2004-12-31    0.045277
# 2005-12-31    0.012450
# 2006-12-31    0.041037
# 2007-12-31    0.021921
# 2008-12-31   -0.134633
# 2009-12-31    0.195401
# 2010-12-31   -0.004585
# 2011-12-31   -0.063149
# 2012-12-31    0.077450
# 2013-12-31    0.106650
# 2014-12-31    0.027210
# 2015-12-31   -0.047495
# 2016-12-31    0.024060
# 2017-12-31    0.044381
# 2018-12-31   -0.060450
# Freq: A-DEC, Name: port_return, dtype: float64

# %% [markdown]
# ## Fetch Factor Models

# %%
# Get Factor Models
q_factor_model = bi.get_q_factor_model()
fama_french_five_factor_model = bi.get_fama_french_five_factor_model()
four_factor_model = bi.get_four_factor_model()

# Concat Portfolio Return
q_factor = pd.concat([monthly_return, q_factor_model], axis=1)
fama_french_five = pd.concat([monthly_return, fama_french_five_factor_model], axis=1)
four_factor = pd.concat([monthly_return, four_factor_model], axis=1)

# Add Constants
q_factor.insert(1, 'const', 1)
fama_french_five.insert(1, 'const', 1)
four_factor.insert(1, 'const', 1)

# Split Period into Pre and Post Crisis
q_factor_pre, q_factor_post = q_factor.loc[:'2009-06-30'], q_factor.loc['2009-07-31':]
fama_french_five_pre, fama_french_five_post = fama_french_five.loc[:'2009-06-30'], fama_french_five.loc['2009-07-31':] 
four_factor_pre, four_factor_post = four_factor.loc[:'2009-06-30'], four_factor.loc['2009-07-31':]

# %% [markdown]
# ## Full Time Period Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.557
# Model:                            OLS   Adj. R-squared:                  0.549
# Method:                 Least Squares   F-statistic:                     71.85
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.38e-39
# Time:                        13:14:12   Log-Likelihood:                 589.03
# No. Observations:                 234   AIC:                            -1168.
# Df Residuals:                     229   BIC:                            -1151.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0014      0.001      1.074      0.284      -0.001       0.004
# mktrf          0.1444      0.037      3.923      0.000       0.072       0.217
# me             0.2560      0.043      5.979      0.000       0.172       0.340
# ia            -0.1909      0.065     -2.934      0.004      -0.319      -0.063
# roe           -0.3731      0.056     -6.698      0.000      -0.483      -0.263
# ==============================================================================
# Omnibus:                       23.058   Durbin-Watson:                   2.204
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               98.584
# Skew:                           0.079   Prob(JB):                     3.91e-22
# Kurtosis:                       6.176   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.557
# Model:                            OLS   Adj. R-squared:                  0.549
# Method:                 Least Squares   F-statistic:                     20.64
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.55e-14
# Time:                        13:14:12   Log-Likelihood:                 589.03
# No. Observations:                 234   AIC:                            -1168.
# Df Residuals:                     229   BIC:                            -1151.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0014      0.001      0.972      0.331      -0.001       0.004
# mktrf          0.1444      0.050      2.862      0.004       0.046       0.243
# me             0.2560      0.095      2.682      0.007       0.069       0.443
# ia            -0.1909      0.136     -1.406      0.160      -0.457       0.075
# roe           -0.3731      0.118     -3.159      0.002      -0.605      -0.142
# ==============================================================================
# Omnibus:                       23.058   Durbin-Watson:                   2.204
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               98.584
# Skew:                           0.079   Prob(JB):                     3.91e-22
# Kurtosis:                       6.176   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.557
# Model:                            OLS   Adj. R-squared:                  0.549
# Method:                 Least Squares   F-statistic:                     28.09
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           5.48e-19
# Time:                        13:14:12   Log-Likelihood:                 589.03
# No. Observations:                 234   AIC:                            -1168.
# Df Residuals:                     229   BIC:                            -1151.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0014      0.001      0.973      0.331      -0.001       0.004
# mktrf          0.1444      0.039      3.745      0.000       0.069       0.220
# me             0.2560      0.102      2.509      0.012       0.056       0.456
# ia            -0.1909      0.111     -1.719      0.086      -0.409       0.027
# roe           -0.3731      0.118     -3.158      0.002      -0.605      -0.142
# ==============================================================================
# Omnibus:                       23.058   Durbin-Watson:                   2.204
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               98.584
# Skew:                           0.079   Prob(JB):                     3.91e-22
# Kurtosis:                       6.176   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.521
# Model:                            OLS   Adj. R-squared:                  0.512
# Method:                 Least Squares   F-statistic:                     62.15
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.70e-35
# Time:                        13:14:12   Log-Likelihood:                 579.89
# No. Observations:                 234   AIC:                            -1150.
# Df Residuals:                     229   BIC:                            -1133.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0006      0.001     -0.416      0.678      -0.003       0.002
# mktrf          0.2874      0.035      8.157      0.000       0.218       0.357
# smb            0.3492      0.044      7.938      0.000       0.263       0.436
# hml           -0.1731      0.044     -3.961      0.000      -0.259      -0.087
# umd            0.0059      0.029      0.207      0.836      -0.051       0.062
# ==============================================================================
# Omnibus:                       39.130   Durbin-Watson:                   2.091
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              147.182
# Skew:                           0.602   Prob(JB):                     1.10e-32
# Kurtosis:                       6.694   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.521
# Model:                            OLS   Adj. R-squared:                  0.512
# Method:                 Least Squares   F-statistic:                     26.21
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           6.68e-18
# Time:                        13:14:12   Log-Likelihood:                 579.89
# No. Observations:                 234   AIC:                            -1150.
# Df Residuals:                     229   BIC:                            -1133.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0006      0.001     -0.425      0.671      -0.003       0.002
# mktrf          0.2874      0.040      7.267      0.000       0.210       0.365
# smb            0.3492      0.085      4.131      0.000       0.183       0.515
# hml           -0.1731      0.066     -2.630      0.009      -0.302      -0.044
# umd            0.0059      0.061      0.097      0.923      -0.114       0.126
# ==============================================================================
# Omnibus:                       39.130   Durbin-Watson:                   2.091
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              147.182
# Skew:                           0.602   Prob(JB):                     1.10e-32
# Kurtosis:                       6.694   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.521
# Model:                            OLS   Adj. R-squared:                  0.512
# Method:                 Least Squares   F-statistic:                     25.78
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.19e-17
# Time:                        13:14:12   Log-Likelihood:                 579.89
# No. Observations:                 234   AIC:                            -1150.
# Df Residuals:                     229   BIC:                            -1133.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0006      0.001     -0.441      0.659      -0.003       0.002
# mktrf          0.2874      0.037      7.726      0.000       0.215       0.360
# smb            0.3492      0.074      4.739      0.000       0.205       0.494
# hml           -0.1731      0.054     -3.188      0.001      -0.280      -0.067
# umd            0.0059      0.069      0.086      0.931      -0.129       0.140
# ==============================================================================
# Omnibus:                       39.130   Durbin-Watson:                   2.091
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              147.182
# Skew:                           0.602   Prob(JB):                     1.10e-32
# Kurtosis:                       6.694   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.521
# Model:                            OLS   Adj. R-squared:                  0.512
# Method:                 Least Squares   F-statistic:                     62.15
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.70e-35
# Time:                        13:14:12   Log-Likelihood:                 579.89
# No. Observations:                 234   AIC:                            -1150.
# Df Residuals:                     229   BIC:                            -1133.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0006      0.001     -0.416      0.678      -0.003       0.002
# mktrf          0.2874      0.035      8.157      0.000       0.218       0.357
# smb            0.3492      0.044      7.938      0.000       0.263       0.436
# hml           -0.1731      0.044     -3.961      0.000      -0.259      -0.087
# umd            0.0059      0.029      0.207      0.836      -0.051       0.062
# ==============================================================================
# Omnibus:                       39.130   Durbin-Watson:                   2.091
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              147.182
# Skew:                           0.602   Prob(JB):                     1.10e-32
# Kurtosis:                       6.694   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.521
# Model:                            OLS   Adj. R-squared:                  0.512
# Method:                 Least Squares   F-statistic:                     26.21
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           6.68e-18
# Time:                        13:14:12   Log-Likelihood:                 579.89
# No. Observations:                 234   AIC:                            -1150.
# Df Residuals:                     229   BIC:                            -1133.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0006      0.001     -0.425      0.671      -0.003       0.002
# mktrf          0.2874      0.040      7.267      0.000       0.210       0.365
# smb            0.3492      0.085      4.131      0.000       0.183       0.515
# hml           -0.1731      0.066     -2.630      0.009      -0.302      -0.044
# umd            0.0059      0.061      0.097      0.923      -0.114       0.126
# ==============================================================================
# Omnibus:                       39.130   Durbin-Watson:                   2.091
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              147.182
# Skew:                           0.602   Prob(JB):                     1.10e-32
# Kurtosis:                       6.694   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.521
# Model:                            OLS   Adj. R-squared:                  0.512
# Method:                 Least Squares   F-statistic:                     25.78
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.19e-17
# Time:                        13:14:12   Log-Likelihood:                 579.89
# No. Observations:                 234   AIC:                            -1150.
# Df Residuals:                     229   BIC:                            -1133.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0006      0.001     -0.441      0.659      -0.003       0.002
# mktrf          0.2874      0.037      7.726      0.000       0.215       0.360
# smb            0.3492      0.074      4.739      0.000       0.205       0.494
# hml           -0.1731      0.054     -3.188      0.001      -0.280      -0.067
# umd            0.0059      0.069      0.086      0.931      -0.129       0.140
# ==============================================================================
# Omnibus:                       39.130   Durbin-Watson:                   2.091
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              147.182
# Skew:                           0.602   Prob(JB):                     1.10e-32
# Kurtosis:                       6.694   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Pre-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.579
# Model:                            OLS   Adj. R-squared:                  0.564
# Method:                 Least Squares   F-statistic:                     39.56
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           8.42e-21
# Time:                        13:14:12   Log-Likelihood:                 280.62
# No. Observations:                 120   AIC:                            -551.2
# Df Residuals:                     115   BIC:                            -537.3
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0010      0.002      0.429      0.669      -0.004       0.005
# mktrf          0.1515      0.061      2.464      0.015       0.030       0.273
# me             0.3216      0.061      5.298      0.000       0.201       0.442
# ia            -0.2174      0.095     -2.287      0.024      -0.406      -0.029
# roe           -0.3137      0.084     -3.729      0.000      -0.480      -0.147
# ==============================================================================
# Omnibus:                       12.566   Durbin-Watson:                   2.280
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               34.518
# Skew:                           0.188   Prob(JB):                     3.20e-08
# Kurtosis:                       5.600   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.579
# Model:                            OLS   Adj. R-squared:                  0.564
# Method:                 Least Squares   F-statistic:                     12.27
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.41e-08
# Time:                        13:14:12   Log-Likelihood:                 280.62
# No. Observations:                 120   AIC:                            -551.2
# Df Residuals:                     115   BIC:                            -537.3
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0010      0.003      0.361      0.718      -0.004       0.006
# mktrf          0.1515      0.082      1.858      0.063      -0.008       0.311
# me             0.3216      0.113      2.843      0.004       0.100       0.543
# ia            -0.2174      0.192     -1.132      0.258      -0.594       0.159
# roe           -0.3137      0.170     -1.843      0.065      -0.647       0.020
# ==============================================================================
# Omnibus:                       12.566   Durbin-Watson:                   2.280
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               34.518
# Skew:                           0.188   Prob(JB):                     3.20e-08
# Kurtosis:                       5.600   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.579
# Model:                            OLS   Adj. R-squared:                  0.564
# Method:                 Least Squares   F-statistic:                     16.21
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.49e-10
# Time:                        13:14:12   Log-Likelihood:                 280.62
# No. Observations:                 120   AIC:                            -551.2
# Df Residuals:                     115   BIC:                            -537.3
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0010      0.003      0.353      0.724      -0.004       0.006
# mktrf          0.1515      0.067      2.253      0.024       0.020       0.283
# me             0.3216      0.123      2.624      0.009       0.081       0.562
# ia            -0.2174      0.172     -1.265      0.206      -0.554       0.119
# roe           -0.3137      0.170     -1.841      0.066      -0.648       0.020
# ==============================================================================
# Omnibus:                       12.566   Durbin-Watson:                   2.280
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               34.518
# Skew:                           0.188   Prob(JB):                     3.20e-08
# Kurtosis:                       5.600   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.610
# Model:                            OLS   Adj. R-squared:                  0.596
# Method:                 Least Squares   F-statistic:                     44.97
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.10e-22
# Time:                        13:14:12   Log-Likelihood:                 285.20
# No. Observations:                 120   AIC:                            -560.4
# Df Residuals:                     115   BIC:                            -546.5
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0002      0.002      0.097      0.923      -0.004       0.004
# mktrf          0.3309      0.052      6.348      0.000       0.228       0.434
# smb            0.3626      0.059      6.111      0.000       0.245       0.480
# hml           -0.2119      0.059     -3.565      0.001      -0.330      -0.094
# umd            0.0379      0.037      1.035      0.303      -0.035       0.111
# ==============================================================================
# Omnibus:                       28.467   Durbin-Watson:                   2.318
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               89.108
# Skew:                           0.790   Prob(JB):                     4.47e-20
# Kurtosis:                       6.915   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.610
# Model:                            OLS   Adj. R-squared:                  0.596
# Method:                 Least Squares   F-statistic:                     34.33
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           7.74e-19
# Time:                        13:14:12   Log-Likelihood:                 285.20
# No. Observations:                 120   AIC:                            -560.4
# Df Residuals:                     115   BIC:                            -546.5
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0002      0.002      0.101      0.920      -0.004       0.004
# mktrf          0.3309      0.048      6.837      0.000       0.236       0.426
# smb            0.3626      0.092      3.950      0.000       0.183       0.543
# hml           -0.2119      0.077     -2.750      0.006      -0.363      -0.061
# umd            0.0379      0.067      0.564      0.573      -0.094       0.170
# ==============================================================================
# Omnibus:                       28.467   Durbin-Watson:                   2.318
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               89.108
# Skew:                           0.790   Prob(JB):                     4.47e-20
# Kurtosis:                       6.915   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.610
# Model:                            OLS   Adj. R-squared:                  0.596
# Method:                 Least Squares   F-statistic:                     44.36
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.77e-22
# Time:                        13:14:12   Log-Likelihood:                 285.20
# No. Observations:                 120   AIC:                            -560.4
# Df Residuals:                     115   BIC:                            -546.5
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0002      0.002      0.106      0.916      -0.004       0.004
# mktrf          0.3309      0.041      7.979      0.000       0.250       0.412
# smb            0.3626      0.079      4.613      0.000       0.209       0.517
# hml           -0.2119      0.069     -3.056      0.002      -0.348      -0.076
# umd            0.0379      0.072      0.529      0.597      -0.103       0.179
# ==============================================================================
# Omnibus:                       28.467   Durbin-Watson:                   2.318
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               89.108
# Skew:                           0.790   Prob(JB):                     4.47e-20
# Kurtosis:                       6.915   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.610
# Model:                            OLS   Adj. R-squared:                  0.596
# Method:                 Least Squares   F-statistic:                     44.97
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.10e-22
# Time:                        13:14:12   Log-Likelihood:                 285.20
# No. Observations:                 120   AIC:                            -560.4
# Df Residuals:                     115   BIC:                            -546.5
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0002      0.002      0.097      0.923      -0.004       0.004
# mktrf          0.3309      0.052      6.348      0.000       0.228       0.434
# smb            0.3626      0.059      6.111      0.000       0.245       0.480
# hml           -0.2119      0.059     -3.565      0.001      -0.330      -0.094
# umd            0.0379      0.037      1.035      0.303      -0.035       0.111
# ==============================================================================
# Omnibus:                       28.467   Durbin-Watson:                   2.318
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               89.108
# Skew:                           0.790   Prob(JB):                     4.47e-20
# Kurtosis:                       6.915   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.610
# Model:                            OLS   Adj. R-squared:                  0.596
# Method:                 Least Squares   F-statistic:                     34.33
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           7.74e-19
# Time:                        13:14:12   Log-Likelihood:                 285.20
# No. Observations:                 120   AIC:                            -560.4
# Df Residuals:                     115   BIC:                            -546.5
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0002      0.002      0.101      0.920      -0.004       0.004
# mktrf          0.3309      0.048      6.837      0.000       0.236       0.426
# smb            0.3626      0.092      3.950      0.000       0.183       0.543
# hml           -0.2119      0.077     -2.750      0.006      -0.363      -0.061
# umd            0.0379      0.067      0.564      0.573      -0.094       0.170
# ==============================================================================
# Omnibus:                       28.467   Durbin-Watson:                   2.318
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               89.108
# Skew:                           0.790   Prob(JB):                     4.47e-20
# Kurtosis:                       6.915   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.610
# Model:                            OLS   Adj. R-squared:                  0.596
# Method:                 Least Squares   F-statistic:                     44.36
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.77e-22
# Time:                        13:14:12   Log-Likelihood:                 285.20
# No. Observations:                 120   AIC:                            -560.4
# Df Residuals:                     115   BIC:                            -546.5
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0002      0.002      0.106      0.916      -0.004       0.004
# mktrf          0.3309      0.041      7.979      0.000       0.250       0.412
# smb            0.3626      0.079      4.613      0.000       0.209       0.517
# hml           -0.2119      0.069     -3.056      0.002      -0.348      -0.076
# umd            0.0379      0.072      0.529      0.597      -0.103       0.179
# ==============================================================================
# Omnibus:                       28.467   Durbin-Watson:                   2.318
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               89.108
# Skew:                           0.790   Prob(JB):                     4.47e-20
# Kurtosis:                       6.915   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Post-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.554
# Model:                            OLS   Adj. R-squared:                  0.537
# Method:                 Least Squares   F-statistic:                     33.79
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.54e-18
# Time:                        13:14:12   Log-Likelihood:                 330.13
# No. Observations:                 114   AIC:                            -650.3
# Df Residuals:                     109   BIC:                            -636.6
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0012      0.001      0.879      0.381      -0.002       0.004
# mktrf          0.1940      0.040      4.827      0.000       0.114       0.274
# me             0.0386      0.062      0.622      0.535      -0.084       0.162
# ia            -0.1677      0.086     -1.948      0.054      -0.338       0.003
# roe           -0.5346      0.076     -7.067      0.000      -0.684      -0.385
# ==============================================================================
# Omnibus:                        2.804   Durbin-Watson:                   1.883
# Prob(Omnibus):                  0.246   Jarque-Bera (JB):                2.292
# Skew:                           0.331   Prob(JB):                        0.318
# Kurtosis:                       3.213   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.554
# Model:                            OLS   Adj. R-squared:                  0.537
# Method:                 Least Squares   F-statistic:                     39.68
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.79e-20
# Time:                        13:14:12   Log-Likelihood:                 330.13
# No. Observations:                 114   AIC:                            -650.3
# Df Residuals:                     109   BIC:                            -636.6
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0012      0.001      1.186      0.235      -0.001       0.003
# mktrf          0.1940      0.041      4.704      0.000       0.113       0.275
# me             0.0386      0.040      0.973      0.330      -0.039       0.116
# ia            -0.1677      0.078     -2.158      0.031      -0.320      -0.015
# roe           -0.5346      0.077     -6.965      0.000      -0.685      -0.384
# ==============================================================================
# Omnibus:                        2.804   Durbin-Watson:                   1.883
# Prob(Omnibus):                  0.246   Jarque-Bera (JB):                2.292
# Skew:                           0.331   Prob(JB):                        0.318
# Kurtosis:                       3.213   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.554
# Model:                            OLS   Adj. R-squared:                  0.537
# Method:                 Least Squares   F-statistic:                     72.94
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           6.19e-30
# Time:                        13:14:12   Log-Likelihood:                 330.13
# No. Observations:                 114   AIC:                            -650.3
# Df Residuals:                     109   BIC:                            -636.6
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0012      0.001      1.262      0.207      -0.001       0.003
# mktrf          0.1940      0.038      5.132      0.000       0.120       0.268
# me             0.0386      0.034      1.136      0.256      -0.028       0.105
# ia            -0.1677      0.070     -2.406      0.016      -0.304      -0.031
# roe           -0.5346      0.058     -9.182      0.000      -0.649      -0.420
# ==============================================================================
# Omnibus:                        2.804   Durbin-Watson:                   1.883
# Prob(Omnibus):                  0.246   Jarque-Bera (JB):                2.292
# Skew:                           0.331   Prob(JB):                        0.318
# Kurtosis:                       3.213   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.355
# Model:                            OLS   Adj. R-squared:                  0.331
# Method:                 Least Squares   F-statistic:                     15.01
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           8.40e-10
# Time:                        13:14:12   Log-Likelihood:                 309.16
# No. Observations:                 114   AIC:                            -608.3
# Df Residuals:                     109   BIC:                            -594.6
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0005      0.002     -0.306      0.760      -0.004       0.003
# mktrf          0.2431      0.046      5.309      0.000       0.152       0.334
# smb            0.1808      0.071      2.533      0.013       0.039       0.322
# hml           -0.0156      0.074     -0.212      0.833      -0.161       0.130
# umd           -0.0815      0.055     -1.469      0.145      -0.191       0.028
# ==============================================================================
# Omnibus:                        5.910   Durbin-Watson:                   1.801
# Prob(Omnibus):                  0.052   Jarque-Bera (JB):                6.480
# Skew:                           0.323   Prob(JB):                       0.0392
# Kurtosis:                       3.973   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.355
# Model:                            OLS   Adj. R-squared:                  0.331
# Method:                 Least Squares   F-statistic:                     10.54
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.95e-07
# Time:                        13:14:12   Log-Likelihood:                 309.16
# No. Observations:                 114   AIC:                            -608.3
# Df Residuals:                     109   BIC:                            -594.6
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0005      0.001     -0.409      0.683      -0.003       0.002
# mktrf          0.2431      0.053      4.596      0.000       0.139       0.347
# smb            0.1808      0.063      2.868      0.004       0.057       0.304
# hml           -0.0156      0.112     -0.139      0.889      -0.235       0.204
# umd           -0.0815      0.056     -1.466      0.143      -0.190       0.027
# ==============================================================================
# Omnibus:                        5.910   Durbin-Watson:                   1.801
# Prob(Omnibus):                  0.052   Jarque-Bera (JB):                6.480
# Skew:                           0.323   Prob(JB):                       0.0392
# Kurtosis:                       3.973   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.355
# Model:                            OLS   Adj. R-squared:                  0.331
# Method:                 Least Squares   F-statistic:                     11.12
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.33e-07
# Time:                        13:14:12   Log-Likelihood:                 309.16
# No. Observations:                 114   AIC:                            -608.3
# Df Residuals:                     109   BIC:                            -594.6
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0005      0.001     -0.464      0.643      -0.003       0.002
# mktrf          0.2431      0.052      4.637      0.000       0.140       0.346
# smb            0.1808      0.054      3.355      0.001       0.075       0.286
# hml           -0.0156      0.118     -0.132      0.895      -0.247       0.216
# umd           -0.0815      0.050     -1.622      0.105      -0.180       0.017
# ==============================================================================
# Omnibus:                        5.910   Durbin-Watson:                   1.801
# Prob(Omnibus):                  0.052   Jarque-Bera (JB):                6.480
# Skew:                           0.323   Prob(JB):                       0.0392
# Kurtosis:                       3.973   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.355
# Model:                            OLS   Adj. R-squared:                  0.331
# Method:                 Least Squares   F-statistic:                     15.01
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           8.40e-10
# Time:                        13:14:12   Log-Likelihood:                 309.16
# No. Observations:                 114   AIC:                            -608.3
# Df Residuals:                     109   BIC:                            -594.6
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0005      0.002     -0.306      0.760      -0.004       0.003
# mktrf          0.2431      0.046      5.309      0.000       0.152       0.334
# smb            0.1808      0.071      2.533      0.013       0.039       0.322
# hml           -0.0156      0.074     -0.212      0.833      -0.161       0.130
# umd           -0.0815      0.055     -1.469      0.145      -0.191       0.028
# ==============================================================================
# Omnibus:                        5.910   Durbin-Watson:                   1.801
# Prob(Omnibus):                  0.052   Jarque-Bera (JB):                6.480
# Skew:                           0.323   Prob(JB):                       0.0392
# Kurtosis:                       3.973   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.355
# Model:                            OLS   Adj. R-squared:                  0.331
# Method:                 Least Squares   F-statistic:                     10.54
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.95e-07
# Time:                        13:14:12   Log-Likelihood:                 309.16
# No. Observations:                 114   AIC:                            -608.3
# Df Residuals:                     109   BIC:                            -594.6
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0005      0.001     -0.409      0.683      -0.003       0.002
# mktrf          0.2431      0.053      4.596      0.000       0.139       0.347
# smb            0.1808      0.063      2.868      0.004       0.057       0.304
# hml           -0.0156      0.112     -0.139      0.889      -0.235       0.204
# umd           -0.0815      0.056     -1.466      0.143      -0.190       0.027
# ==============================================================================
# Omnibus:                        5.910   Durbin-Watson:                   1.801
# Prob(Omnibus):                  0.052   Jarque-Bera (JB):                6.480
# Skew:                           0.323   Prob(JB):                       0.0392
# Kurtosis:                       3.973   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.355
# Model:                            OLS   Adj. R-squared:                  0.331
# Method:                 Least Squares   F-statistic:                     11.12
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.33e-07
# Time:                        13:14:12   Log-Likelihood:                 309.16
# No. Observations:                 114   AIC:                            -608.3
# Df Residuals:                     109   BIC:                            -594.6
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0005      0.001     -0.464      0.643      -0.003       0.002
# mktrf          0.2431      0.052      4.637      0.000       0.140       0.346
# smb            0.1808      0.054      3.355      0.001       0.075       0.286
# hml           -0.0156      0.118     -0.132      0.895      -0.247       0.216
# umd           -0.0815      0.050     -1.622      0.105      -0.180       0.017
# ==============================================================================
# Omnibus:                        5.910   Durbin-Watson:                   1.801
# Prob(Omnibus):                  0.052   Jarque-Bera (JB):                6.480
# Skew:                           0.323   Prob(JB):                       0.0392
# Kurtosis:                       3.973   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """
