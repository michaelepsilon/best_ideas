# %% [markdown]
# # Method 5 - Best Fresh Ideas

# %%
# %matplotlib inline
import pandas as pd
import warnings
from statsmodels import api as sm

from eptooling import crsp, epd, fs, hfu, crsp, db, bi
from eptooling.bm import bmdb, iso
from epquant.engine import weights, portfolio
from epquant.gen import returns
from epquant.perf import relative_performance

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Fetch Holdings and Benchmark Data

# %%
# Get HFU Data

# %store -r inst_data

# Count number of positions per manager

inst_data['num_pos'] = inst_data.groupby(['datadate', 'institution_id'])[
    'fsym_id'].transform(lambda s: s.nunique())

# Remove less than 20 holdings and less than $5mm per CSP

valid_data = inst_data[inst_data['num_pos'] >= 20]
valid_data = valid_data[valid_data['public_aum'] >= 5e6]

# Get Returns for Fresh Ideas

# %store -r r

# Get Adjusted Quantities

qty_pivot = pd.pivot_table(inst_data, index='datadate', columns=['institution_id', 'fsym_id'], values='quantity',
                           aggfunc='sum')
qty_pivot = qty_pivot.mul(r.splits.reindex(qty_pivot.index), level=1).fillna(0)
qty_pivot = qty_pivot - qty_pivot.shift(1)
flat_qty = pd.melt(qty_pivot.reset_index(), id_vars='datadate', value_name='qty_change')
flat_qty = flat_qty[flat_qty['qty_change'] > 0]

# Get Pos Size Change

pos_size_pivot = pd.pivot_table(inst_data, index='datadate', columns=['institution_id', 'fsym_id'], values='target',
                                aggfunc='sum')
pos_size_pivot = pos_size_pivot - pos_size_pivot.shift(1)
flat_pos_size = pd.melt(pos_size_pivot.reset_index(), id_vars='datadate', value_name='size_change')
flat_pos_size = flat_pos_size[flat_pos_size['size_change'] > 0]

# Add Expected Returns per Shumway, Szefler, Yuan 2009

# %store -r exp_ret

valid_data = valid_data.merge(exp_ret, on=['datadate', 'institution_id', 'fsym_id'], how='left')

# Calculate CSP Weight per Market Tilt

valid_data['adj_target'] = valid_data['expected_return']

# %% [markdown]
# ## Calculate Best Fresh Ideas

# %%
# Extract Best Ideas

valid_data['pos_rank'] = valid_data\
    .groupby(['datadate', 'institution_id'])['adj_target'].rank(ascending=False)

# Get Best

best_ideas = valid_data[valid_data['pos_rank'] == 1].copy()

# Filter to Fresh

best_ideas = best_ideas.merge(flat_qty).merge(flat_pos_size)

# Weight the best ideas equally

best_ideas['target'] = 1 / best_ideas.groupby('datadate')[
    'institution_id'].transform('count')

# %% [markdown]
# ## Backtest Portfolio

# %%
# Backtest the Portfolio

w = weights.Weights(best_ideas)

p = portfolio.DailyPortfolio(w, r, end_date='2018-12-31')

rf = bi.get_risk_free_rate()
monthly_return = p.port_return.loc['1999-07-01':].resample('M').apply(epd.prod_red)
monthly_return = (monthly_return - rf).dropna()
monthly_return.name = 'port_return'

# %% [markdown]
# ## Plot Performance

# %%
epd.nav(monthly_return).plot()

# %%
monthly_return.resample('A').apply(epd.prod_red)
# Out:
# datadate
# 1999-12-31    0.237099
# 2000-12-31   -0.222395
# 2001-12-31   -0.332644
# 2002-12-31   -0.334911
# 2003-12-31    0.998932
# 2004-12-31    0.163807
# 2005-12-31    0.101914
# 2006-12-31    0.127170
# 2007-12-31    0.020691
# 2008-12-31   -0.524192
# 2009-12-31    0.678759
# 2010-12-31    0.276598
# 2011-12-31   -0.108022
# 2012-12-31    0.287803
# 2013-12-31    0.575543
# 2014-12-31    0.040928
# 2015-12-31   -0.097438
# 2016-12-31    0.143964
# 2017-12-31    0.184498
# 2018-12-31   -0.093493
# Freq: A-DEC, Name: port_return, dtype: float64

# %% [markdown]
# ## Fetch Factor Models

# %%
# Get Factor Models
q_factor_model = bi.get_q_factor_model()
fama_french_five_factor_model = bi.get_fama_french_five_factor_model()
four_factor_model = bi.get_four_factor_model()

# Concat Portfolio Return
q_factor = pd.concat([monthly_return, q_factor_model], axis=1)
fama_french_five = pd.concat([monthly_return, fama_french_five_factor_model], axis=1)
four_factor = pd.concat([monthly_return, four_factor_model], axis=1)

# Add Constants
q_factor.insert(1, 'const', 1)
fama_french_five.insert(1, 'const', 1)
four_factor.insert(1, 'const', 1)

# Split Period into Pre and Post Crisis
q_factor_pre, q_factor_post = q_factor.loc[:'2009-06-30'], q_factor.loc['2009-07-31':]
fama_french_five_pre, fama_french_five_post = fama_french_five.loc[:'2009-06-30'], fama_french_five.loc['2009-07-31':] 
four_factor_pre, four_factor_post = four_factor.loc[:'2009-06-30'], four_factor.loc['2009-07-31':]

# %% [markdown]
# ## Full Time Period Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.899
# Model:                            OLS   Adj. R-squared:                  0.898
# Method:                 Least Squares   F-statistic:                     511.8
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):          6.56e-113
# Time:                        13:26:36   Log-Likelihood:                 540.37
# No. Observations:                 234   AIC:                            -1071.
# Df Residuals:                     229   BIC:                            -1053.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0025      0.002      1.514      0.131      -0.001       0.006
# mktrf          1.1801      0.045     26.043      0.000       1.091       1.269
# me             0.5376      0.053     10.199      0.000       0.434       0.641
# ia             0.0087      0.080      0.109      0.913      -0.149       0.167
# roe           -0.6123      0.069     -8.929      0.000      -0.747      -0.477
# ==============================================================================
# Omnibus:                       18.170   Durbin-Watson:                   2.059
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               52.661
# Skew:                           0.202   Prob(JB):                     3.67e-12
# Kurtosis:                       5.289   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.899
# Model:                            OLS   Adj. R-squared:                  0.898
# Method:                 Least Squares   F-statistic:                     491.4
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):          4.28e-111
# Time:                        13:26:36   Log-Likelihood:                 540.37
# No. Observations:                 234   AIC:                            -1071.
# Df Residuals:                     229   BIC:                            -1053.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0025      0.002      1.175      0.240      -0.002       0.007
# mktrf          1.1801      0.049     24.042      0.000       1.084       1.276
# me             0.5376      0.052     10.330      0.000       0.436       0.640
# ia             0.0087      0.125      0.070      0.944      -0.236       0.253
# roe           -0.6123      0.128     -4.791      0.000      -0.863      -0.362
# ==============================================================================
# Omnibus:                       18.170   Durbin-Watson:                   2.059
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               52.661
# Skew:                           0.202   Prob(JB):                     3.67e-12
# Kurtosis:                       5.289   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.899
# Model:                            OLS   Adj. R-squared:                  0.898
# Method:                 Least Squares   F-statistic:                     838.5
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):          1.88e-135
# Time:                        13:26:36   Log-Likelihood:                 540.37
# No. Observations:                 234   AIC:                            -1071.
# Df Residuals:                     229   BIC:                            -1053.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0025      0.002      1.229      0.219      -0.001       0.007
# mktrf          1.1801      0.053     22.277      0.000       1.076       1.284
# me             0.5376      0.053     10.155      0.000       0.434       0.641
# ia             0.0087      0.108      0.081      0.936      -0.203       0.220
# roe           -0.6123      0.135     -4.547      0.000      -0.876      -0.348
# ==============================================================================
# Omnibus:                       18.170   Durbin-Watson:                   2.059
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               52.661
# Skew:                           0.202   Prob(JB):                     3.67e-12
# Kurtosis:                       5.289   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.877
# Model:                            OLS   Adj. R-squared:                  0.874
# Method:                 Least Squares   F-statistic:                     406.6
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):          9.42e-103
# Time:                        13:26:37   Log-Likelihood:                 516.45
# No. Observations:                 234   AIC:                            -1023.
# Df Residuals:                     229   BIC:                            -1006.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0003      0.002      0.177      0.860      -0.003       0.004
# mktrf          1.3016      0.046     28.166      0.000       1.211       1.393
# smb            0.7780      0.058     13.488      0.000       0.664       0.892
# hml            0.0272      0.057      0.476      0.635      -0.086       0.140
# umd           -0.1789      0.038     -4.759      0.000      -0.253      -0.105
# ==============================================================================
# Omnibus:                       23.251   Durbin-Watson:                   2.016
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               46.929
# Skew:                           0.499   Prob(JB):                     6.45e-11
# Kurtosis:                       4.954   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.877
# Model:                            OLS   Adj. R-squared:                  0.874
# Method:                 Least Squares   F-statistic:                     369.0
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.48e-98
# Time:                        13:26:37   Log-Likelihood:                 516.45
# No. Observations:                 234   AIC:                            -1023.
# Df Residuals:                     229   BIC:                            -1006.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0003      0.002      0.149      0.881      -0.004       0.004
# mktrf          1.3016      0.044     29.641      0.000       1.216       1.388
# smb            0.7780      0.064     12.139      0.000       0.652       0.904
# hml            0.0272      0.079      0.344      0.731      -0.128       0.182
# umd           -0.1789      0.073     -2.437      0.015      -0.323      -0.035
# ==============================================================================
# Omnibus:                       23.251   Durbin-Watson:                   2.016
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               46.929
# Skew:                           0.499   Prob(JB):                     6.45e-11
# Kurtosis:                       4.954   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.877
# Model:                            OLS   Adj. R-squared:                  0.874
# Method:                 Least Squares   F-statistic:                     384.3
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):          2.60e-100
# Time:                        13:26:37   Log-Likelihood:                 516.45
# No. Observations:                 234   AIC:                            -1023.
# Df Residuals:                     229   BIC:                            -1006.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0003      0.002      0.155      0.877      -0.004       0.004
# mktrf          1.3016      0.047     27.694      0.000       1.210       1.394
# smb            0.7780      0.064     12.087      0.000       0.652       0.904
# hml            0.0272      0.073      0.373      0.709      -0.116       0.171
# umd           -0.1789      0.073     -2.434      0.015      -0.323      -0.035
# ==============================================================================
# Omnibus:                       23.251   Durbin-Watson:                   2.016
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               46.929
# Skew:                           0.499   Prob(JB):                     6.45e-11
# Kurtosis:                       4.954   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.877
# Model:                            OLS   Adj. R-squared:                  0.874
# Method:                 Least Squares   F-statistic:                     406.6
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):          9.42e-103
# Time:                        13:26:37   Log-Likelihood:                 516.45
# No. Observations:                 234   AIC:                            -1023.
# Df Residuals:                     229   BIC:                            -1006.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0003      0.002      0.177      0.860      -0.003       0.004
# mktrf          1.3016      0.046     28.166      0.000       1.211       1.393
# smb            0.7780      0.058     13.488      0.000       0.664       0.892
# hml            0.0272      0.057      0.476      0.635      -0.086       0.140
# umd           -0.1789      0.038     -4.759      0.000      -0.253      -0.105
# ==============================================================================
# Omnibus:                       23.251   Durbin-Watson:                   2.016
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               46.929
# Skew:                           0.499   Prob(JB):                     6.45e-11
# Kurtosis:                       4.954   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.877
# Model:                            OLS   Adj. R-squared:                  0.874
# Method:                 Least Squares   F-statistic:                     369.0
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.48e-98
# Time:                        13:26:37   Log-Likelihood:                 516.45
# No. Observations:                 234   AIC:                            -1023.
# Df Residuals:                     229   BIC:                            -1006.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0003      0.002      0.149      0.881      -0.004       0.004
# mktrf          1.3016      0.044     29.641      0.000       1.216       1.388
# smb            0.7780      0.064     12.139      0.000       0.652       0.904
# hml            0.0272      0.079      0.344      0.731      -0.128       0.182
# umd           -0.1789      0.073     -2.437      0.015      -0.323      -0.035
# ==============================================================================
# Omnibus:                       23.251   Durbin-Watson:                   2.016
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               46.929
# Skew:                           0.499   Prob(JB):                     6.45e-11
# Kurtosis:                       4.954   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.877
# Model:                            OLS   Adj. R-squared:                  0.874
# Method:                 Least Squares   F-statistic:                     384.3
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):          2.60e-100
# Time:                        13:26:37   Log-Likelihood:                 516.45
# No. Observations:                 234   AIC:                            -1023.
# Df Residuals:                     229   BIC:                            -1006.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0003      0.002      0.155      0.877      -0.004       0.004
# mktrf          1.3016      0.047     27.694      0.000       1.210       1.394
# smb            0.7780      0.064     12.087      0.000       0.652       0.904
# hml            0.0272      0.073      0.373      0.709      -0.116       0.171
# umd           -0.1789      0.073     -2.434      0.015      -0.323      -0.035
# ==============================================================================
# Omnibus:                       23.251   Durbin-Watson:                   2.016
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               46.929
# Skew:                           0.499   Prob(JB):                     6.45e-11
# Kurtosis:                       4.954   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Pre-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.894
# Model:                            OLS   Adj. R-squared:                  0.890
# Method:                 Least Squares   F-statistic:                     242.4
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           4.82e-55
# Time:                        13:26:37   Log-Likelihood:                 255.89
# No. Observations:                 120   AIC:                            -501.8
# Df Residuals:                     115   BIC:                            -487.8
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0026      0.003      0.927      0.356      -0.003       0.008
# mktrf          1.2561      0.076     16.631      0.000       1.106       1.406
# me             0.5170      0.075      6.931      0.000       0.369       0.665
# ia             0.0276      0.117      0.236      0.814      -0.204       0.259
# roe           -0.5121      0.103     -4.953      0.000      -0.717      -0.307
# ==============================================================================
# Omnibus:                       11.095   Durbin-Watson:                   2.162
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               20.807
# Skew:                           0.341   Prob(JB):                     3.03e-05
# Kurtosis:                       4.923   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.894
# Model:                            OLS   Adj. R-squared:                  0.890
# Method:                 Least Squares   F-statistic:                     265.3
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           4.61e-57
# Time:                        13:26:37   Log-Likelihood:                 255.89
# No. Observations:                 120   AIC:                            -501.8
# Df Residuals:                     115   BIC:                            -487.8
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0026      0.004      0.666      0.506      -0.005       0.010
# mktrf          1.2561      0.069     18.148      0.000       1.120       1.392
# me             0.5170      0.065      8.010      0.000       0.391       0.644
# ia             0.0276      0.172      0.160      0.873      -0.310       0.365
# roe           -0.5121      0.171     -2.988      0.003      -0.848      -0.176
# ==============================================================================
# Omnibus:                       11.095   Durbin-Watson:                   2.162
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               20.807
# Skew:                           0.341   Prob(JB):                     3.03e-05
# Kurtosis:                       4.923   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.894
# Model:                            OLS   Adj. R-squared:                  0.890
# Method:                 Least Squares   F-statistic:                     493.7
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.12e-71
# Time:                        13:26:37   Log-Likelihood:                 255.89
# No. Observations:                 120   AIC:                            -501.8
# Df Residuals:                     115   BIC:                            -487.8
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0026      0.004      0.702      0.483      -0.005       0.010
# mktrf          1.2561      0.070     17.821      0.000       1.118       1.394
# me             0.5170      0.064      8.057      0.000       0.391       0.643
# ia             0.0276      0.146      0.189      0.850      -0.258       0.313
# roe           -0.5121      0.174     -2.940      0.003      -0.854      -0.171
# ==============================================================================
# Omnibus:                       11.095   Durbin-Watson:                   2.162
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               20.807
# Skew:                           0.341   Prob(JB):                     3.03e-05
# Kurtosis:                       4.923   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.882
# Model:                            OLS   Adj. R-squared:                  0.878
# Method:                 Least Squares   F-statistic:                     215.8
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.80e-52
# Time:                        13:26:37   Log-Likelihood:                 249.70
# No. Observations:                 120   AIC:                            -489.4
# Df Residuals:                     115   BIC:                            -475.5
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0020      0.003      0.686      0.494      -0.004       0.008
# mktrf          1.3946      0.070     19.906      0.000       1.256       1.533
# smb            0.7330      0.080      9.189      0.000       0.575       0.891
# hml           -0.0043      0.080     -0.053      0.958      -0.163       0.154
# umd           -0.1488      0.049     -3.021      0.003      -0.246      -0.051
# ==============================================================================
# Omnibus:                       12.737   Durbin-Watson:                   2.132
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               17.909
# Skew:                           0.548   Prob(JB):                     0.000129
# Kurtosis:                       4.543   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.882
# Model:                            OLS   Adj. R-squared:                  0.878
# Method:                 Least Squares   F-statistic:                     359.8
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           5.15e-64
# Time:                        13:26:37   Log-Likelihood:                 249.70
# No. Observations:                 120   AIC:                            -489.4
# Df Residuals:                     115   BIC:                            -475.5
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0020      0.004      0.554      0.580      -0.005       0.009
# mktrf          1.3946      0.046     30.494      0.000       1.305       1.484
# smb            0.7330      0.081      9.023      0.000       0.574       0.892
# hml           -0.0043      0.103     -0.041      0.967      -0.206       0.197
# umd           -0.1488      0.083     -1.793      0.073      -0.312       0.014
# ==============================================================================
# Omnibus:                       12.737   Durbin-Watson:                   2.132
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               17.909
# Skew:                           0.548   Prob(JB):                     0.000129
# Kurtosis:                       4.543   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.882
# Model:                            OLS   Adj. R-squared:                  0.878
# Method:                 Least Squares   F-statistic:                     513.1
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.62e-72
# Time:                        13:26:37   Log-Likelihood:                 249.70
# No. Observations:                 120   AIC:                            -489.4
# Df Residuals:                     115   BIC:                            -475.5
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0020      0.003      0.587      0.557      -0.005       0.009
# mktrf          1.3946      0.041     34.296      0.000       1.315       1.474
# smb            0.7330      0.079      9.237      0.000       0.577       0.889
# hml           -0.0043      0.099     -0.043      0.966      -0.198       0.189
# umd           -0.1488      0.081     -1.836      0.066      -0.308       0.010
# ==============================================================================
# Omnibus:                       12.737   Durbin-Watson:                   2.132
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               17.909
# Skew:                           0.548   Prob(JB):                     0.000129
# Kurtosis:                       4.543   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.882
# Model:                            OLS   Adj. R-squared:                  0.878
# Method:                 Least Squares   F-statistic:                     215.8
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.80e-52
# Time:                        13:26:37   Log-Likelihood:                 249.70
# No. Observations:                 120   AIC:                            -489.4
# Df Residuals:                     115   BIC:                            -475.5
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0020      0.003      0.686      0.494      -0.004       0.008
# mktrf          1.3946      0.070     19.906      0.000       1.256       1.533
# smb            0.7330      0.080      9.189      0.000       0.575       0.891
# hml           -0.0043      0.080     -0.053      0.958      -0.163       0.154
# umd           -0.1488      0.049     -3.021      0.003      -0.246      -0.051
# ==============================================================================
# Omnibus:                       12.737   Durbin-Watson:                   2.132
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               17.909
# Skew:                           0.548   Prob(JB):                     0.000129
# Kurtosis:                       4.543   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.882
# Model:                            OLS   Adj. R-squared:                  0.878
# Method:                 Least Squares   F-statistic:                     359.8
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           5.15e-64
# Time:                        13:26:37   Log-Likelihood:                 249.70
# No. Observations:                 120   AIC:                            -489.4
# Df Residuals:                     115   BIC:                            -475.5
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0020      0.004      0.554      0.580      -0.005       0.009
# mktrf          1.3946      0.046     30.494      0.000       1.305       1.484
# smb            0.7330      0.081      9.023      0.000       0.574       0.892
# hml           -0.0043      0.103     -0.041      0.967      -0.206       0.197
# umd           -0.1488      0.083     -1.793      0.073      -0.312       0.014
# ==============================================================================
# Omnibus:                       12.737   Durbin-Watson:                   2.132
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               17.909
# Skew:                           0.548   Prob(JB):                     0.000129
# Kurtosis:                       4.543   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.882
# Model:                            OLS   Adj. R-squared:                  0.878
# Method:                 Least Squares   F-statistic:                     513.1
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.62e-72
# Time:                        13:26:37   Log-Likelihood:                 249.70
# No. Observations:                 120   AIC:                            -489.4
# Df Residuals:                     115   BIC:                            -475.5
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0020      0.003      0.587      0.557      -0.005       0.009
# mktrf          1.3946      0.041     34.296      0.000       1.315       1.474
# smb            0.7330      0.079      9.237      0.000       0.577       0.889
# hml           -0.0043      0.099     -0.043      0.966      -0.198       0.189
# umd           -0.1488      0.081     -1.836      0.066      -0.308       0.010
# ==============================================================================
# Omnibus:                       12.737   Durbin-Watson:                   2.132
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               17.909
# Skew:                           0.548   Prob(JB):                     0.000129
# Kurtosis:                       4.543   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Post-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.921
# Model:                            OLS   Adj. R-squared:                  0.918
# Method:                 Least Squares   F-statistic:                     319.4
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           3.28e-59
# Time:                        13:26:37   Log-Likelihood:                 304.78
# No. Observations:                 114   AIC:                            -599.6
# Df Residuals:                     109   BIC:                            -585.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0035      0.002      2.080      0.040       0.000       0.007
# mktrf          1.0810      0.050     21.531      0.000       0.981       1.181
# me             0.6410      0.078      8.270      0.000       0.487       0.795
# ia            -0.1119      0.108     -1.041      0.300      -0.325       0.101
# roe           -0.8441      0.094     -8.934      0.000      -1.031      -0.657
# ==============================================================================
# Omnibus:                        2.592   Durbin-Watson:                   1.925
# Prob(Omnibus):                  0.274   Jarque-Bera (JB):                2.617
# Skew:                           0.338   Prob(JB):                        0.270
# Kurtosis:                       2.694   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.921
# Model:                            OLS   Adj. R-squared:                  0.918
# Method:                 Least Squares   F-statistic:                     406.3
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.69e-64
# Time:                        13:26:37   Log-Likelihood:                 304.78
# No. Observations:                 114   AIC:                            -599.6
# Df Residuals:                     109   BIC:                            -585.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0035      0.001      2.894      0.004       0.001       0.006
# mktrf          1.0810      0.039     28.077      0.000       1.006       1.156
# me             0.6410      0.051     12.607      0.000       0.541       0.741
# ia            -0.1119      0.099     -1.126      0.260      -0.307       0.083
# roe           -0.8441      0.091     -9.278      0.000      -1.022      -0.666
# ==============================================================================
# Omnibus:                        2.592   Durbin-Watson:                   1.925
# Prob(Omnibus):                  0.274   Jarque-Bera (JB):                2.617
# Skew:                           0.338   Prob(JB):                        0.270
# Kurtosis:                       2.694   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.921
# Model:                            OLS   Adj. R-squared:                  0.918
# Method:                 Least Squares   F-statistic:                     535.1
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.19e-70
# Time:                        13:26:37   Log-Likelihood:                 304.78
# No. Observations:                 114   AIC:                            -599.6
# Df Residuals:                     109   BIC:                            -585.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0035      0.001      3.157      0.002       0.001       0.006
# mktrf          1.0810      0.036     30.387      0.000       1.011       1.151
# me             0.6410      0.047     13.588      0.000       0.549       0.734
# ia            -0.1119      0.103     -1.086      0.278      -0.314       0.090
# roe           -0.8441      0.087     -9.663      0.000      -1.015      -0.673
# ==============================================================================
# Omnibus:                        2.592   Durbin-Watson:                   1.925
# Prob(Omnibus):                  0.274   Jarque-Bera (JB):                2.617
# Skew:                           0.338   Prob(JB):                        0.270
# Kurtosis:                       2.694   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.874
# Model:                            OLS   Adj. R-squared:                  0.870
# Method:                 Least Squares   F-statistic:                     189.8
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           3.72e-48
# Time:                        13:26:37   Log-Likelihood:                 278.11
# No. Observations:                 114   AIC:                            -546.2
# Df Residuals:                     109   BIC:                            -532.5
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0005      0.002      0.236      0.814      -0.004       0.005
# mktrf          1.1667      0.060     19.406      0.000       1.048       1.286
# smb            0.8199      0.094      8.746      0.000       0.634       1.006
# hml            0.1715      0.097      1.776      0.079      -0.020       0.363
# umd           -0.1702      0.073     -2.337      0.021      -0.315      -0.026
# ==============================================================================
# Omnibus:                        3.790   Durbin-Watson:                   1.950
# Prob(Omnibus):                  0.150   Jarque-Bera (JB):                4.163
# Skew:                           0.132   Prob(JB):                        0.125
# Kurtosis:                       3.898   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.874
# Model:                            OLS   Adj. R-squared:                  0.870
# Method:                 Least Squares   F-statistic:                     195.0
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.04e-48
# Time:                        13:26:37   Log-Likelihood:                 278.11
# No. Observations:                 114   AIC:                            -546.2
# Df Residuals:                     109   BIC:                            -532.5
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0005      0.002      0.312      0.755      -0.003       0.004
# mktrf          1.1667      0.048     24.425      0.000       1.073       1.260
# smb            0.8199      0.086      9.558      0.000       0.652       0.988
# hml            0.1715      0.133      1.287      0.198      -0.090       0.432
# umd           -0.1702      0.074     -2.286      0.022      -0.316      -0.024
# ==============================================================================
# Omnibus:                        3.790   Durbin-Watson:                   1.950
# Prob(Omnibus):                  0.150   Jarque-Bera (JB):                4.163
# Skew:                           0.132   Prob(JB):                        0.125
# Kurtosis:                       3.898   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.874
# Model:                            OLS   Adj. R-squared:                  0.870
# Method:                 Least Squares   F-statistic:                     219.9
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           3.22e-51
# Time:                        13:26:37   Log-Likelihood:                 278.11
# No. Observations:                 114   AIC:                            -546.2
# Df Residuals:                     109   BIC:                            -532.5
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0005      0.002      0.311      0.756      -0.003       0.004
# mktrf          1.1667      0.043     27.363      0.000       1.083       1.250
# smb            0.8199      0.075     11.000      0.000       0.674       0.966
# hml            0.1715      0.135      1.268      0.205      -0.094       0.436
# umd           -0.1702      0.067     -2.553      0.011      -0.301      -0.040
# ==============================================================================
# Omnibus:                        3.790   Durbin-Watson:                   1.950
# Prob(Omnibus):                  0.150   Jarque-Bera (JB):                4.163
# Skew:                           0.132   Prob(JB):                        0.125
# Kurtosis:                       3.898   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.874
# Model:                            OLS   Adj. R-squared:                  0.870
# Method:                 Least Squares   F-statistic:                     189.8
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           3.72e-48
# Time:                        13:26:37   Log-Likelihood:                 278.11
# No. Observations:                 114   AIC:                            -546.2
# Df Residuals:                     109   BIC:                            -532.5
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0005      0.002      0.236      0.814      -0.004       0.005
# mktrf          1.1667      0.060     19.406      0.000       1.048       1.286
# smb            0.8199      0.094      8.746      0.000       0.634       1.006
# hml            0.1715      0.097      1.776      0.079      -0.020       0.363
# umd           -0.1702      0.073     -2.337      0.021      -0.315      -0.026
# ==============================================================================
# Omnibus:                        3.790   Durbin-Watson:                   1.950
# Prob(Omnibus):                  0.150   Jarque-Bera (JB):                4.163
# Skew:                           0.132   Prob(JB):                        0.125
# Kurtosis:                       3.898   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.874
# Model:                            OLS   Adj. R-squared:                  0.870
# Method:                 Least Squares   F-statistic:                     195.0
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.04e-48
# Time:                        13:26:37   Log-Likelihood:                 278.11
# No. Observations:                 114   AIC:                            -546.2
# Df Residuals:                     109   BIC:                            -532.5
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0005      0.002      0.312      0.755      -0.003       0.004
# mktrf          1.1667      0.048     24.425      0.000       1.073       1.260
# smb            0.8199      0.086      9.558      0.000       0.652       0.988
# hml            0.1715      0.133      1.287      0.198      -0.090       0.432
# umd           -0.1702      0.074     -2.286      0.022      -0.316      -0.024
# ==============================================================================
# Omnibus:                        3.790   Durbin-Watson:                   1.950
# Prob(Omnibus):                  0.150   Jarque-Bera (JB):                4.163
# Skew:                           0.132   Prob(JB):                        0.125
# Kurtosis:                       3.898   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.874
# Model:                            OLS   Adj. R-squared:                  0.870
# Method:                 Least Squares   F-statistic:                     219.9
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           3.22e-51
# Time:                        13:26:37   Log-Likelihood:                 278.11
# No. Observations:                 114   AIC:                            -546.2
# Df Residuals:                     109   BIC:                            -532.5
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0005      0.002      0.311      0.756      -0.003       0.004
# mktrf          1.1667      0.043     27.363      0.000       1.083       1.250
# smb            0.8199      0.075     11.000      0.000       0.674       0.966
# hml            0.1715      0.135      1.268      0.205      -0.094       0.436
# umd           -0.1702      0.067     -2.553      0.011      -0.301      -0.040
# ==============================================================================
# Omnibus:                        3.790   Durbin-Watson:                   1.950
# Prob(Omnibus):                  0.150   Jarque-Bera (JB):                4.163
# Skew:                           0.132   Prob(JB):                        0.125
# Kurtosis:                       3.898   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """
