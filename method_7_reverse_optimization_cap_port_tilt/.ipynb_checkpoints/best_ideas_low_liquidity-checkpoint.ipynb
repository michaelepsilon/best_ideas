# %% [markdown]
# # Method 7 - Best Ideas Low Liquidity

# %%
# %matplotlib inline
import pandas as pd
import warnings
from statsmodels import api as sm

from eptooling import crsp, epd, fs, hfu, crsp, db, bi
from eptooling.bm import bmdb, iso
from epquant.engine import weights, portfolio
from epquant.gen import returns
from epquant.perf import relative_performance

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Fetch Holdings and Benchmark Data

# %%
# Get HFU Data

# %store -r inst_data
inst_data = inst_data[inst_data['datadate'] >= '1999-06-30']

# Count number of positions per manager

inst_data['num_pos'] = inst_data.groupby(['datadate', 'institution_id'])[
    'fsym_id'].transform(lambda s: s.nunique())

# Remove less than 20 holdings and less than $5mm per CSP

valid_data = inst_data[inst_data['num_pos'] >= 20]
valid_data = valid_data[valid_data['public_aum'] >= 5e6]

# Add Expected Returns from Intra-Cap Portfolio Weight per Shumway, Szefler, Yuan 2009

# %store -r cap_exp_ret

valid_data = valid_data.merge(cap_exp_ret, on=['datadate', 'institution_id', 'fsym_id'], how='left')

# Calculate CSP Weight per Market Tilt

valid_data['adj_target'] = valid_data['expected_return']

# %% [markdown]
# ## Calculate Best Ideas

# %%
# Extract Best Ideas

valid_data['pos_rank'] = valid_data\
    .groupby(['datadate', 'institution_id'])['adj_target'].rank(ascending=False)

best_ideas = valid_data[valid_data['pos_rank'] == 1].copy()

# Get Liquidity

distinct_ideas = best_ideas[['datadate', 'fsym_id']].drop_duplicates()
distinct_ideas['in'] = 1

bid_asks = crsp.get_crsp_fsym_bid_ask(list(set(distinct_ideas['fsym_id'].dropna())),
                                      distinct_ideas['datadate'].min(), pd.datetime(2018, 12, 31))
bid_asks['rel_bid_ask'] = (bid_asks['ask'] - bid_asks['bid']) / ((bid_asks['bid'] + bid_asks['ask']) / 2)
bid_asks['datadate'] = bid_asks['datadate'] + pd.offsets.QuarterEnd(0)
qe_bid_asks = bid_asks.groupby(['datadate', 'fsym_id'])['rel_bid_ask'].mean().reset_index()
qe_bid_asks = qe_bid_asks.merge(distinct_ideas)

qe_bid_asks['median_bid_ask'] = qe_bid_asks.groupby('datadate')['rel_bid_ask'].transform('median')
qe_bid_asks = qe_bid_asks[qe_bid_asks['rel_bid_ask'] > qe_bid_asks['median_bid_ask']]

best_ideas = best_ideas.merge(qe_bid_asks)

# Weight the best ideas equally

best_ideas['target'] = 1 / best_ideas.groupby('datadate')['institution_id'].transform('count')

# %% [markdown]
# ## Backtest Portfolio

# %%
w = weights.Weights(best_ideas)

# %store -r r

p = portfolio.DailyPortfolio(w, r, end_date='2018-12-31')

rf = bi.get_risk_free_rate()
monthly_return = p.port_return.loc['1999-07-01':].resample('M').apply(epd.prod_red)
monthly_return = (monthly_return - rf).dropna()
monthly_return.name = 'port_return'

# %% [markdown]
# ## Plot Performance

# %%
epd.nav(monthly_return).plot()

# %%
monthly_return.resample('A').apply(epd.prod_red)
# Out:
# datadate
# 1999-12-31    0.063677
# 2000-12-31   -0.116927
# 2001-12-31   -0.028675
# 2002-12-31   -0.251354
# 2003-12-31    0.949269
# 2004-12-31    0.162714
# 2005-12-31   -0.020467
# 2006-12-31    0.179486
# 2007-12-31   -0.162346
# 2008-12-31   -0.529791
# 2009-12-31    1.073495
# 2010-12-31    0.153481
# 2011-12-31   -0.182530
# 2012-12-31    0.233452
# 2013-12-31    0.579114
# 2014-12-31    0.052878
# 2015-12-31   -0.157361
# 2016-12-31    0.206292
# 2017-12-31    0.132501
# 2018-12-31   -0.236400
# Freq: A-DEC, Name: port_return, dtype: float64

# %% [markdown]
# ## Fetch Factor Models

# %%
# Get Factor Models
q_factor_model = bi.get_q_factor_model()
fama_french_five_factor_model = bi.get_fama_french_five_factor_model()
four_factor_model = bi.get_four_factor_model()

# Concat Portfolio Return
q_factor = pd.concat([monthly_return, q_factor_model], axis=1)
fama_french_five = pd.concat([monthly_return, fama_french_five_factor_model], axis=1)
four_factor = pd.concat([monthly_return, four_factor_model], axis=1)

# Add Constants
q_factor.insert(1, 'const', 1)
fama_french_five.insert(1, 'const', 1)
four_factor.insert(1, 'const', 1)

# Split Period into Pre and Post Crisis
q_factor_pre, q_factor_post = q_factor.loc[:'2009-06-30'], q_factor.loc['2009-07-31':]
fama_french_five_pre, fama_french_five_post = fama_french_five.loc[:'2009-06-30'], fama_french_five.loc['2009-07-31':] 
four_factor_pre, four_factor_post = four_factor.loc[:'2009-06-30'], four_factor.loc['2009-07-31':]

# %% [markdown]
# ## Full Time Period Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.852
# Model:                            OLS   Adj. R-squared:                  0.850
# Method:                 Least Squares   F-statistic:                     330.1
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           8.41e-94
# Time:                        13:24:11   Log-Likelihood:                 475.84
# No. Observations:                 234   AIC:                            -941.7
# Df Residuals:                     229   BIC:                            -924.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0021      0.002      0.984      0.326      -0.002       0.006
# mktrf          1.1373      0.060     19.050      0.000       1.020       1.255
# me             0.6587      0.069      9.485      0.000       0.522       0.796
# ia             0.5469      0.106      5.181      0.000       0.339       0.755
# roe           -0.8628      0.090     -9.549      0.000      -1.041      -0.685
# ==============================================================================
# Omnibus:                       60.165   Durbin-Watson:                   2.028
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              175.366
# Skew:                           1.095   Prob(JB):                     8.31e-39
# Kurtosis:                       6.631   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.852
# Model:                            OLS   Adj. R-squared:                  0.850
# Method:                 Least Squares   F-statistic:                     194.3
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.23e-72
# Time:                        13:24:11   Log-Likelihood:                 475.84
# No. Observations:                 234   AIC:                            -941.7
# Df Residuals:                     229   BIC:                            -924.4
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0021      0.002      0.889      0.374      -0.003       0.007
# mktrf          1.1373      0.060     19.007      0.000       1.020       1.255
# me             0.6587      0.081      8.181      0.000       0.501       0.817
# ia             0.5469      0.144      3.785      0.000       0.264       0.830
# roe           -0.8628      0.166     -5.186      0.000      -1.189      -0.537
# ==============================================================================
# Omnibus:                       60.165   Durbin-Watson:                   2.028
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              175.366
# Skew:                           1.095   Prob(JB):                     8.31e-39
# Kurtosis:                       6.631   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.852
# Model:                            OLS   Adj. R-squared:                  0.850
# Method:                 Least Squares   F-statistic:                     246.5
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           9.64e-82
# Time:                        13:24:11   Log-Likelihood:                 475.84
# No. Observations:                 234   AIC:                            -941.7
# Df Residuals:                     229   BIC:                            -924.4
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0021      0.002      0.933      0.351      -0.002       0.007
# mktrf          1.1373      0.055     20.808      0.000       1.030       1.244
# me             0.6587      0.081      8.158      0.000       0.500       0.817
# ia             0.5469      0.131      4.160      0.000       0.289       0.805
# roe           -0.8628      0.179     -4.819      0.000      -1.214      -0.512
# ==============================================================================
# Omnibus:                       60.165   Durbin-Watson:                   2.028
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              175.366
# Skew:                           1.095   Prob(JB):                     8.31e-39
# Kurtosis:                       6.631   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.826
# Model:                            OLS   Adj. R-squared:                  0.823
# Method:                 Least Squares   F-statistic:                     271.4
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.20e-85
# Time:                        13:24:11   Log-Likelihood:                 456.62
# No. Observations:                 234   AIC:                            -903.2
# Df Residuals:                     229   BIC:                            -886.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       9.132e-06      0.002      0.004      0.997      -0.005       0.005
# mktrf          1.2379      0.060     20.745      0.000       1.120       1.356
# smb            1.0103      0.074     13.563      0.000       0.864       1.157
# hml            0.3619      0.074      4.891      0.000       0.216       0.508
# umd           -0.3097      0.049     -6.379      0.000      -0.405      -0.214
# ==============================================================================
# Omnibus:                       82.597   Durbin-Watson:                   2.141
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              375.889
# Skew:                           1.344   Prob(JB):                     2.38e-82
# Kurtosis:                       8.597   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.826
# Model:                            OLS   Adj. R-squared:                  0.823
# Method:                 Least Squares   F-statistic:                     219.2
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           4.54e-77
# Time:                        13:24:11   Log-Likelihood:                 456.62
# No. Observations:                 234   AIC:                            -903.2
# Df Residuals:                     229   BIC:                            -886.0
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       9.132e-06      0.002      0.004      0.997      -0.005       0.005
# mktrf          1.2379      0.049     25.072      0.000       1.141       1.335
# smb            1.0103      0.066     15.356      0.000       0.881       1.139
# hml            0.3619      0.131      2.758      0.006       0.105       0.619
# umd           -0.3097      0.105     -2.953      0.003      -0.515      -0.104
# ==============================================================================
# Omnibus:                       82.597   Durbin-Watson:                   2.141
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              375.889
# Skew:                           1.344   Prob(JB):                     2.38e-82
# Kurtosis:                       8.597   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.826
# Model:                            OLS   Adj. R-squared:                  0.823
# Method:                 Least Squares   F-statistic:                     251.5
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.51e-82
# Time:                        13:24:11   Log-Likelihood:                 456.62
# No. Observations:                 234   AIC:                            -903.2
# Df Residuals:                     229   BIC:                            -886.0
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       9.132e-06      0.002      0.004      0.997      -0.004       0.004
# mktrf          1.2379      0.043     29.034      0.000       1.154       1.322
# smb            1.0103      0.064     15.760      0.000       0.885       1.136
# hml            0.3619      0.127      2.855      0.004       0.113       0.610
# umd           -0.3097      0.101     -3.070      0.002      -0.507      -0.112
# ==============================================================================
# Omnibus:                       82.597   Durbin-Watson:                   2.141
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              375.889
# Skew:                           1.344   Prob(JB):                     2.38e-82
# Kurtosis:                       8.597   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.826
# Model:                            OLS   Adj. R-squared:                  0.823
# Method:                 Least Squares   F-statistic:                     271.4
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.20e-85
# Time:                        13:24:11   Log-Likelihood:                 456.62
# No. Observations:                 234   AIC:                            -903.2
# Df Residuals:                     229   BIC:                            -886.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       9.132e-06      0.002      0.004      0.997      -0.005       0.005
# mktrf          1.2379      0.060     20.745      0.000       1.120       1.356
# smb            1.0103      0.074     13.563      0.000       0.864       1.157
# hml            0.3619      0.074      4.891      0.000       0.216       0.508
# umd           -0.3097      0.049     -6.379      0.000      -0.405      -0.214
# ==============================================================================
# Omnibus:                       82.597   Durbin-Watson:                   2.141
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              375.889
# Skew:                           1.344   Prob(JB):                     2.38e-82
# Kurtosis:                       8.597   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.826
# Model:                            OLS   Adj. R-squared:                  0.823
# Method:                 Least Squares   F-statistic:                     219.2
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           4.54e-77
# Time:                        13:24:11   Log-Likelihood:                 456.62
# No. Observations:                 234   AIC:                            -903.2
# Df Residuals:                     229   BIC:                            -886.0
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       9.132e-06      0.002      0.004      0.997      -0.005       0.005
# mktrf          1.2379      0.049     25.072      0.000       1.141       1.335
# smb            1.0103      0.066     15.356      0.000       0.881       1.139
# hml            0.3619      0.131      2.758      0.006       0.105       0.619
# umd           -0.3097      0.105     -2.953      0.003      -0.515      -0.104
# ==============================================================================
# Omnibus:                       82.597   Durbin-Watson:                   2.141
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              375.889
# Skew:                           1.344   Prob(JB):                     2.38e-82
# Kurtosis:                       8.597   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.826
# Model:                            OLS   Adj. R-squared:                  0.823
# Method:                 Least Squares   F-statistic:                     251.5
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.51e-82
# Time:                        13:24:11   Log-Likelihood:                 456.62
# No. Observations:                 234   AIC:                            -903.2
# Df Residuals:                     229   BIC:                            -886.0
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       9.132e-06      0.002      0.004      0.997      -0.004       0.004
# mktrf          1.2379      0.043     29.034      0.000       1.154       1.322
# smb            1.0103      0.064     15.760      0.000       0.885       1.136
# hml            0.3619      0.127      2.855      0.004       0.113       0.610
# umd           -0.3097      0.101     -3.070      0.002      -0.507      -0.112
# ==============================================================================
# Omnibus:                       82.597   Durbin-Watson:                   2.141
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              375.889
# Skew:                           1.344   Prob(JB):                     2.38e-82
# Kurtosis:                       8.597   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Pre-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.849
# Model:                            OLS   Adj. R-squared:                  0.844
# Method:                 Least Squares   F-statistic:                     161.8
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.96e-46
# Time:                        13:24:11   Log-Likelihood:                 229.19
# No. Observations:                 120   AIC:                            -448.4
# Df Residuals:                     115   BIC:                            -434.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0039      0.003      1.110      0.269      -0.003       0.011
# mktrf          1.1659      0.094     12.358      0.000       0.979       1.353
# me             0.5992      0.093      6.430      0.000       0.415       0.784
# ia             0.6247      0.146      4.281      0.000       0.336       0.914
# roe           -0.7883      0.129     -6.103      0.000      -1.044      -0.532
# ==============================================================================
# Omnibus:                       32.906   Durbin-Watson:                   2.205
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               79.692
# Skew:                           1.049   Prob(JB):                     4.96e-18
# Kurtosis:                       6.396   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.849
# Model:                            OLS   Adj. R-squared:                  0.844
# Method:                 Least Squares   F-statistic:                     102.3
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           6.16e-37
# Time:                        13:24:11   Log-Likelihood:                 229.19
# No. Observations:                 120   AIC:                            -448.4
# Df Residuals:                     115   BIC:                            -434.4
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0039      0.004      1.034      0.301      -0.003       0.011
# mktrf          1.1659      0.082     14.246      0.000       1.006       1.326
# me             0.5992      0.081      7.432      0.000       0.441       0.757
# ia             0.6247      0.172      3.635      0.000       0.288       0.961
# roe           -0.7883      0.203     -3.889      0.000      -1.186      -0.391
# ==============================================================================
# Omnibus:                       32.906   Durbin-Watson:                   2.205
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               79.692
# Skew:                           1.049   Prob(JB):                     4.96e-18
# Kurtosis:                       6.396   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.849
# Model:                            OLS   Adj. R-squared:                  0.844
# Method:                 Least Squares   F-statistic:                     120.4
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           3.71e-40
# Time:                        13:24:11   Log-Likelihood:                 229.19
# No. Observations:                 120   AIC:                            -448.4
# Df Residuals:                     115   BIC:                            -434.4
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0039      0.004      1.091      0.275      -0.003       0.011
# mktrf          1.1659      0.079     14.848      0.000       1.012       1.320
# me             0.5992      0.085      7.066      0.000       0.433       0.765
# ia             0.6247      0.134      4.669      0.000       0.362       0.887
# roe           -0.7883      0.215     -3.668      0.000      -1.209      -0.367
# ==============================================================================
# Omnibus:                       32.906   Durbin-Watson:                   2.205
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               79.692
# Skew:                           1.049   Prob(JB):                     4.96e-18
# Kurtosis:                       6.396   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.829
# Model:                            OLS   Adj. R-squared:                  0.823
# Method:                 Least Squares   F-statistic:                     139.2
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           4.15e-43
# Time:                        13:24:11   Log-Likelihood:                 221.60
# No. Observations:                 120   AIC:                            -433.2
# Df Residuals:                     115   BIC:                            -419.3
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0024      0.004      0.670      0.504      -0.005       0.010
# mktrf          1.2600      0.089     14.231      0.000       1.085       1.435
# smb            0.9879      0.101      9.799      0.000       0.788       1.188
# hml            0.3665      0.101      3.630      0.000       0.166       0.566
# umd           -0.3098      0.062     -4.977      0.000      -0.433      -0.187
# ==============================================================================
# Omnibus:                       51.184   Durbin-Watson:                   2.311
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              201.866
# Skew:                           1.447   Prob(JB):                     1.46e-44
# Kurtosis:                       8.657   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.829
# Model:                            OLS   Adj. R-squared:                  0.823
# Method:                 Least Squares   F-statistic:                     128.1
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.03e-41
# Time:                        13:24:11   Log-Likelihood:                 221.60
# No. Observations:                 120   AIC:                            -433.2
# Df Residuals:                     115   BIC:                            -419.3
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0024      0.004      0.649      0.516      -0.005       0.010
# mktrf          1.2600      0.065     19.443      0.000       1.133       1.387
# smb            0.9879      0.091     10.903      0.000       0.810       1.165
# hml            0.3665      0.165      2.221      0.026       0.043       0.690
# umd           -0.3098      0.117     -2.652      0.008      -0.539      -0.081
# ==============================================================================
# Omnibus:                       51.184   Durbin-Watson:                   2.311
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              201.866
# Skew:                           1.447   Prob(JB):                     1.46e-44
# Kurtosis:                       8.657   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.829
# Model:                            OLS   Adj. R-squared:                  0.823
# Method:                 Least Squares   F-statistic:                     136.7
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           9.80e-43
# Time:                        13:24:11   Log-Likelihood:                 221.60
# No. Observations:                 120   AIC:                            -433.2
# Df Residuals:                     115   BIC:                            -419.3
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0024      0.004      0.678      0.498      -0.005       0.010
# mktrf          1.2600      0.059     21.326      0.000       1.144       1.376
# smb            0.9879      0.093     10.606      0.000       0.805       1.170
# hml            0.3665      0.169      2.174      0.030       0.036       0.697
# umd           -0.3098      0.113     -2.732      0.006      -0.532      -0.088
# ==============================================================================
# Omnibus:                       51.184   Durbin-Watson:                   2.311
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              201.866
# Skew:                           1.447   Prob(JB):                     1.46e-44
# Kurtosis:                       8.657   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.829
# Model:                            OLS   Adj. R-squared:                  0.823
# Method:                 Least Squares   F-statistic:                     139.2
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           4.15e-43
# Time:                        13:24:11   Log-Likelihood:                 221.60
# No. Observations:                 120   AIC:                            -433.2
# Df Residuals:                     115   BIC:                            -419.3
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0024      0.004      0.670      0.504      -0.005       0.010
# mktrf          1.2600      0.089     14.231      0.000       1.085       1.435
# smb            0.9879      0.101      9.799      0.000       0.788       1.188
# hml            0.3665      0.101      3.630      0.000       0.166       0.566
# umd           -0.3098      0.062     -4.977      0.000      -0.433      -0.187
# ==============================================================================
# Omnibus:                       51.184   Durbin-Watson:                   2.311
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              201.866
# Skew:                           1.447   Prob(JB):                     1.46e-44
# Kurtosis:                       8.657   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.829
# Model:                            OLS   Adj. R-squared:                  0.823
# Method:                 Least Squares   F-statistic:                     128.1
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.03e-41
# Time:                        13:24:11   Log-Likelihood:                 221.60
# No. Observations:                 120   AIC:                            -433.2
# Df Residuals:                     115   BIC:                            -419.3
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0024      0.004      0.649      0.516      -0.005       0.010
# mktrf          1.2600      0.065     19.443      0.000       1.133       1.387
# smb            0.9879      0.091     10.903      0.000       0.810       1.165
# hml            0.3665      0.165      2.221      0.026       0.043       0.690
# umd           -0.3098      0.117     -2.652      0.008      -0.539      -0.081
# ==============================================================================
# Omnibus:                       51.184   Durbin-Watson:                   2.311
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              201.866
# Skew:                           1.447   Prob(JB):                     1.46e-44
# Kurtosis:                       8.657   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.829
# Model:                            OLS   Adj. R-squared:                  0.823
# Method:                 Least Squares   F-statistic:                     136.7
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           9.80e-43
# Time:                        13:24:11   Log-Likelihood:                 221.60
# No. Observations:                 120   AIC:                            -433.2
# Df Residuals:                     115   BIC:                            -419.3
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0024      0.004      0.678      0.498      -0.005       0.010
# mktrf          1.2600      0.059     21.326      0.000       1.144       1.376
# smb            0.9879      0.093     10.606      0.000       0.805       1.170
# hml            0.3665      0.169      2.174      0.030       0.036       0.697
# umd           -0.3098      0.113     -2.732      0.006      -0.532      -0.088
# ==============================================================================
# Omnibus:                       51.184   Durbin-Watson:                   2.311
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              201.866
# Skew:                           1.447   Prob(JB):                     1.46e-44
# Kurtosis:                       8.657   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Post-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.884
# Model:                            OLS   Adj. R-squared:                  0.880
# Method:                 Least Squares   F-statistic:                     208.2
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           4.53e-50
# Time:                        13:24:11   Log-Likelihood:                 263.77
# No. Observations:                 114   AIC:                            -517.5
# Df Residuals:                     109   BIC:                            -503.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0013      0.002      0.518      0.605      -0.004       0.006
# mktrf          1.1133      0.072     15.475      0.000       0.971       1.256
# me             0.7843      0.111      7.060      0.000       0.564       1.004
# ia             0.1310      0.154      0.850      0.397      -0.174       0.436
# roe           -1.2584      0.135     -9.295      0.000      -1.527      -0.990
# ==============================================================================
# Omnibus:                       27.884   Durbin-Watson:                   1.939
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               53.892
# Skew:                           1.013   Prob(JB):                     1.98e-12
# Kurtosis:                       5.691   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.884
# Model:                            OLS   Adj. R-squared:                  0.880
# Method:                 Least Squares   F-statistic:                     449.8
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           9.26e-67
# Time:                        13:24:11   Log-Likelihood:                 263.77
# No. Observations:                 114   AIC:                            -517.5
# Df Residuals:                     109   BIC:                            -503.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0013      0.002      0.552      0.581      -0.003       0.006
# mktrf          1.1133      0.057     19.414      0.000       1.001       1.226
# me             0.7843      0.069     11.347      0.000       0.649       0.920
# ia             0.1310      0.147      0.888      0.374      -0.158       0.420
# roe           -1.2584      0.167     -7.527      0.000      -1.586      -0.931
# ==============================================================================
# Omnibus:                       27.884   Durbin-Watson:                   1.939
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               53.892
# Skew:                           1.013   Prob(JB):                     1.98e-12
# Kurtosis:                       5.691   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.884
# Model:                            OLS   Adj. R-squared:                  0.880
# Method:                 Least Squares   F-statistic:                     876.8
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           7.04e-82
# Time:                        13:24:11   Log-Likelihood:                 263.77
# No. Observations:                 114   AIC:                            -517.5
# Df Residuals:                     109   BIC:                            -503.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0013      0.002      0.611      0.541      -0.003       0.005
# mktrf          1.1133      0.047     23.851      0.000       1.022       1.205
# me             0.7843      0.068     11.566      0.000       0.651       0.917
# ia             0.1310      0.145      0.902      0.367      -0.154       0.416
# roe           -1.2584      0.152     -8.259      0.000      -1.557      -0.960
# ==============================================================================
# Omnibus:                       27.884   Durbin-Watson:                   1.939
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               53.892
# Skew:                           1.013   Prob(JB):                     1.98e-12
# Kurtosis:                       5.691   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.823
# Model:                            OLS   Adj. R-squared:                  0.816
# Method:                 Least Squares   F-statistic:                     126.6
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           4.95e-40
# Time:                        13:24:11   Log-Likelihood:                 239.52
# No. Observations:                 114   AIC:                            -469.0
# Df Residuals:                     109   BIC:                            -455.3
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0024      0.003     -0.807      0.422      -0.008       0.004
# mktrf          1.2298      0.084     14.581      0.000       1.063       1.397
# smb            1.0584      0.132      8.048      0.000       0.798       1.319
# hml            0.3241      0.135      2.393      0.018       0.056       0.593
# umd           -0.2836      0.102     -2.776      0.006      -0.486      -0.081
# ==============================================================================
# Omnibus:                       26.797   Durbin-Watson:                   1.872
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               55.716
# Skew:                           0.938   Prob(JB):                     7.97e-13
# Kurtosis:                       5.866   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.823
# Model:                            OLS   Adj. R-squared:                  0.816
# Method:                 Least Squares   F-statistic:                     122.8
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.94e-39
# Time:                        13:24:11   Log-Likelihood:                 239.52
# No. Observations:                 114   AIC:                            -469.0
# Df Residuals:                     109   BIC:                            -455.3
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0024      0.002     -0.990      0.322      -0.007       0.002
# mktrf          1.2298      0.082     14.962      0.000       1.069       1.391
# smb            1.0584      0.114      9.256      0.000       0.834       1.283
# hml            0.3241      0.228      1.419      0.156      -0.124       0.772
# umd           -0.2836      0.088     -3.212      0.001      -0.457      -0.111
# ==============================================================================
# Omnibus:                       26.797   Durbin-Watson:                   1.872
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               55.716
# Skew:                           0.938   Prob(JB):                     7.97e-13
# Kurtosis:                       5.866   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.823
# Model:                            OLS   Adj. R-squared:                  0.816
# Method:                 Least Squares   F-statistic:                     130.0
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.51e-40
# Time:                        13:24:12   Log-Likelihood:                 239.52
# No. Observations:                 114   AIC:                            -469.0
# Df Residuals:                     109   BIC:                            -455.3
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0024      0.002     -1.093      0.274      -0.007       0.002
# mktrf          1.2298      0.077     15.906      0.000       1.078       1.381
# smb            1.0584      0.092     11.562      0.000       0.879       1.238
# hml            0.3241      0.249      1.304      0.192      -0.163       0.811
# umd           -0.2836      0.073     -3.868      0.000      -0.427      -0.140
# ==============================================================================
# Omnibus:                       26.797   Durbin-Watson:                   1.872
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               55.716
# Skew:                           0.938   Prob(JB):                     7.97e-13
# Kurtosis:                       5.866   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.823
# Model:                            OLS   Adj. R-squared:                  0.816
# Method:                 Least Squares   F-statistic:                     126.6
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           4.95e-40
# Time:                        13:24:12   Log-Likelihood:                 239.52
# No. Observations:                 114   AIC:                            -469.0
# Df Residuals:                     109   BIC:                            -455.3
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0024      0.003     -0.807      0.422      -0.008       0.004
# mktrf          1.2298      0.084     14.581      0.000       1.063       1.397
# smb            1.0584      0.132      8.048      0.000       0.798       1.319
# hml            0.3241      0.135      2.393      0.018       0.056       0.593
# umd           -0.2836      0.102     -2.776      0.006      -0.486      -0.081
# ==============================================================================
# Omnibus:                       26.797   Durbin-Watson:                   1.872
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               55.716
# Skew:                           0.938   Prob(JB):                     7.97e-13
# Kurtosis:                       5.866   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.823
# Model:                            OLS   Adj. R-squared:                  0.816
# Method:                 Least Squares   F-statistic:                     122.8
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.94e-39
# Time:                        13:24:12   Log-Likelihood:                 239.52
# No. Observations:                 114   AIC:                            -469.0
# Df Residuals:                     109   BIC:                            -455.3
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0024      0.002     -0.990      0.322      -0.007       0.002
# mktrf          1.2298      0.082     14.962      0.000       1.069       1.391
# smb            1.0584      0.114      9.256      0.000       0.834       1.283
# hml            0.3241      0.228      1.419      0.156      -0.124       0.772
# umd           -0.2836      0.088     -3.212      0.001      -0.457      -0.111
# ==============================================================================
# Omnibus:                       26.797   Durbin-Watson:                   1.872
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               55.716
# Skew:                           0.938   Prob(JB):                     7.97e-13
# Kurtosis:                       5.866   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.823
# Model:                            OLS   Adj. R-squared:                  0.816
# Method:                 Least Squares   F-statistic:                     130.0
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.51e-40
# Time:                        13:24:12   Log-Likelihood:                 239.52
# No. Observations:                 114   AIC:                            -469.0
# Df Residuals:                     109   BIC:                            -455.3
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0024      0.002     -1.093      0.274      -0.007       0.002
# mktrf          1.2298      0.077     15.906      0.000       1.078       1.381
# smb            1.0584      0.092     11.562      0.000       0.879       1.238
# hml            0.3241      0.249      1.304      0.192      -0.163       0.811
# umd           -0.2836      0.073     -3.868      0.000      -0.427      -0.140
# ==============================================================================
# Omnibus:                       26.797   Durbin-Watson:                   1.872
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               55.716
# Skew:                           0.938   Prob(JB):                     7.97e-13
# Kurtosis:                       5.866   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """
