# %% [markdown]
# # Method 7 - Best Ideas High Minus Low Focus

# %%
# %matplotlib inline
import pandas as pd
import warnings
from statsmodels import api as sm

from eptooling import crsp, epd, fs, hfu, crsp, db, bi
from eptooling.bm import bmdb, iso
from epquant.engine import weights, portfolio
from epquant.gen import returns
from epquant.perf import relative_performance

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Fetch Holdings and Benchmark Data

# %%
# Get HFU Data

# %store -r inst_data
inst_data = inst_data[inst_data['datadate'] >= '1999-06-30']

# Focus

focus = inst_data.groupby(['datadate', 'institution_id'])['fsym_id'].count().rename('focus').reset_index()

# Count number of positions per manager

inst_data['num_pos'] = inst_data.groupby(['datadate', 'institution_id'])[
    'fsym_id'].transform(lambda s: s.nunique())

# Remove less than 20 holdings and less than $5mm per CSP

valid_data = inst_data[inst_data['num_pos'] >= 20]
valid_data = valid_data[valid_data['public_aum'] >= 5e6]

# Add Expected Returns from Intra-Cap Portfolio Weight per Shumway, Szefler, Yuan 2009

# %store -r cap_exp_ret

valid_data = valid_data.merge(cap_exp_ret, on=['datadate', 'institution_id', 'fsym_id'], how='left')

# Calculate CSP Weight per Market Tilt

valid_data['adj_target'] = valid_data['expected_return']

# %% [markdown]
# ## Calculate Best Ideas

# %%
# Extract Best Ideas

valid_data['pos_rank'] = valid_data\
    .groupby(['datadate', 'institution_id'])['adj_target'].rank(ascending=False)

best_ideas = valid_data[valid_data['pos_rank'] == 1].copy()

# Add Focus

best_ideas = best_ideas.merge(focus)
best_ideas['focus_pct'] = best_ideas.groupby('datadate')['focus'].rank(pct=True)
low_ideas = best_ideas[best_ideas['focus_pct'] < (1 / 3)]
high_ideas = best_ideas[best_ideas['focus_pct'] > (2 / 3)]

# Weight the best ideas equally

low_ideas['target'] = 1 / low_ideas.groupby('datadate')['institution_id'].transform('count')
high_ideas['target'] = 1 / high_ideas.groupby('datadate')['institution_id'].transform('count')

# %% [markdown]
# ## Backtest Portfolio

# %%
low_w = weights.Weights(low_ideas)
high_w = weights.Weights(high_ideas)

# %store -r r

low_p = portfolio.DailyPortfolio(low_w, r, end_date='2018-12-31')
high_p = portfolio.DailyPortfolio(high_w, r, end_date='2018-12-31')

monthly_return = (high_p.port_return - low_p.port_return).loc['1999-07-01':].resample('M').apply(epd.prod_red)
monthly_return.name = 'port_return'

# %% [markdown]
# ## Plot Performance

# %%
epd.nav(monthly_return).plot()

# %%
monthly_return.resample('A').apply(epd.prod_red)
# Out:
# datadate
# 1999-12-31   -0.071967
# 2000-12-31   -0.248487
# 2001-12-31   -0.384486
# 2002-12-31   -0.056592
# 2003-12-31    0.026049
# 2004-12-31   -0.169852
# 2005-12-31    0.015595
# 2006-12-31   -0.111211
# 2007-12-31    0.092441
# 2008-12-31   -0.086701
# 2009-12-31   -0.088880
# 2010-12-31   -0.065198
# 2011-12-31   -0.065858
# 2012-12-31    0.081243
# 2013-12-31   -0.038082
# 2014-12-31    0.075284
# 2015-12-31   -0.018084
# 2016-12-31   -0.000601
# 2017-12-31   -0.004522
# 2018-12-31   -0.073272
# Freq: A-DEC, Name: port_return, dtype: float64

# %% [markdown]
# ## Fetch Factor Models

# %%
# Get Factor Models
q_factor_model = bi.get_q_factor_model()
fama_french_five_factor_model = bi.get_fama_french_five_factor_model()
four_factor_model = bi.get_four_factor_model()

# Concat Portfolio Return
q_factor = pd.concat([monthly_return, q_factor_model], axis=1)
fama_french_five = pd.concat([monthly_return, fama_french_five_factor_model], axis=1)
four_factor = pd.concat([monthly_return, four_factor_model], axis=1)

# Add Constants
q_factor.insert(1, 'const', 1)
fama_french_five.insert(1, 'const', 1)
four_factor.insert(1, 'const', 1)

# Split Period into Pre and Post Crisis
q_factor_pre, q_factor_post = q_factor.loc[:'2009-06-30'], q_factor.loc['2009-07-31':]
fama_french_five_pre, fama_french_five_post = fama_french_five.loc[:'2009-06-30'], fama_french_five.loc['2009-07-31':] 
four_factor_pre, four_factor_post = four_factor.loc[:'2009-06-30'], four_factor.loc['2009-07-31':]

# %% [markdown]
# ## Full Time Period Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.128
# Model:                            OLS   Adj. R-squared:                  0.113
# Method:                 Least Squares   F-statistic:                     8.413
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.38e-06
# Time:                        13:29:44   Log-Likelihood:                 540.88
# No. Observations:                 234   AIC:                            -1072.
# Df Residuals:                     229   BIC:                            -1054.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0051      0.002     -3.112      0.002      -0.008      -0.002
# mktrf          0.1036      0.045      2.292      0.023       0.015       0.193
# me            -0.0991      0.053     -1.884      0.061      -0.203       0.005
# ia            -0.3640      0.080     -4.554      0.000      -0.522      -0.207
# roe            0.0765      0.068      1.119      0.264      -0.058       0.211
# ==============================================================================
# Omnibus:                        9.346   Durbin-Watson:                   1.873
# Prob(Omnibus):                  0.009   Jarque-Bera (JB):               13.068
# Skew:                          -0.270   Prob(JB):                      0.00145
# Kurtosis:                       4.024   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.128
# Model:                            OLS   Adj. R-squared:                  0.113
# Method:                 Least Squares   F-statistic:                     3.113
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):             0.0161
# Time:                        13:29:44   Log-Likelihood:                 540.88
# No. Observations:                 234   AIC:                            -1072.
# Df Residuals:                     229   BIC:                            -1054.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0051      0.002     -2.633      0.008      -0.009      -0.001
# mktrf          0.1036      0.063      1.648      0.099      -0.020       0.227
# me            -0.0991      0.074     -1.346      0.178      -0.243       0.045
# ia            -0.3640      0.115     -3.156      0.002      -0.590      -0.138
# roe            0.0765      0.082      0.939      0.348      -0.083       0.236
# ==============================================================================
# Omnibus:                        9.346   Durbin-Watson:                   1.873
# Prob(Omnibus):                  0.009   Jarque-Bera (JB):               13.068
# Skew:                          -0.270   Prob(JB):                      0.00145
# Kurtosis:                       4.024   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.128
# Model:                            OLS   Adj. R-squared:                  0.113
# Method:                 Least Squares   F-statistic:                     3.104
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):             0.0163
# Time:                        13:29:44   Log-Likelihood:                 540.88
# No. Observations:                 234   AIC:                            -1072.
# Df Residuals:                     229   BIC:                            -1054.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0051      0.002     -2.368      0.018      -0.009      -0.001
# mktrf          0.1036      0.065      1.586      0.113      -0.024       0.232
# me            -0.0991      0.067     -1.490      0.136      -0.229       0.031
# ia            -0.3640      0.134     -2.715      0.007      -0.627      -0.101
# roe            0.0765      0.088      0.868      0.385      -0.096       0.249
# ==============================================================================
# Omnibus:                        9.346   Durbin-Watson:                   1.873
# Prob(Omnibus):                  0.009   Jarque-Bera (JB):               13.068
# Skew:                          -0.270   Prob(JB):                      0.00145
# Kurtosis:                       4.024   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.146
# Model:                            OLS   Adj. R-squared:                  0.131
# Method:                 Least Squares   F-statistic:                     9.775
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.57e-07
# Time:                        13:29:44   Log-Likelihood:                 543.28
# No. Observations:                 234   AIC:                            -1077.
# Df Residuals:                     229   BIC:                            -1059.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0053      0.002     -3.338      0.001      -0.008      -0.002
# mktrf          0.1198      0.041      2.907      0.004       0.039       0.201
# smb           -0.1228      0.051     -2.387      0.018      -0.224      -0.021
# hml           -0.2691      0.051     -5.267      0.000      -0.370      -0.168
# umd            0.0299      0.034      0.891      0.374      -0.036       0.096
# ==============================================================================
# Omnibus:                       10.886   Durbin-Watson:                   1.841
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               16.844
# Skew:                          -0.279   Prob(JB):                     0.000220
# Kurtosis:                       4.190   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.146
# Model:                            OLS   Adj. R-squared:                  0.131
# Method:                 Least Squares   F-statistic:                     5.059
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           0.000634
# Time:                        13:29:44   Log-Likelihood:                 543.28
# No. Observations:                 234   AIC:                            -1077.
# Df Residuals:                     229   BIC:                            -1059.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0053      0.002     -3.072      0.002      -0.009      -0.002
# mktrf          0.1198      0.057      2.103      0.035       0.008       0.231
# smb           -0.1228      0.052     -2.369      0.018      -0.224      -0.021
# hml           -0.2691      0.098     -2.737      0.006      -0.462      -0.076
# umd            0.0299      0.047      0.640      0.522      -0.062       0.121
# ==============================================================================
# Omnibus:                       10.886   Durbin-Watson:                   1.841
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               16.844
# Skew:                          -0.279   Prob(JB):                     0.000220
# Kurtosis:                       4.190   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.146
# Model:                            OLS   Adj. R-squared:                  0.131
# Method:                 Least Squares   F-statistic:                     6.374
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           7.02e-05
# Time:                        13:29:44   Log-Likelihood:                 543.28
# No. Observations:                 234   AIC:                            -1077.
# Df Residuals:                     229   BIC:                            -1059.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0053      0.002     -2.876      0.004      -0.009      -0.002
# mktrf          0.1198      0.061      1.954      0.051      -0.000       0.240
# smb           -0.1228      0.050     -2.474      0.013      -0.220      -0.026
# hml           -0.2691      0.106     -2.537      0.011      -0.477      -0.061
# umd            0.0299      0.047      0.632      0.528      -0.063       0.123
# ==============================================================================
# Omnibus:                       10.886   Durbin-Watson:                   1.841
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               16.844
# Skew:                          -0.279   Prob(JB):                     0.000220
# Kurtosis:                       4.190   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.146
# Model:                            OLS   Adj. R-squared:                  0.131
# Method:                 Least Squares   F-statistic:                     9.775
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.57e-07
# Time:                        13:29:44   Log-Likelihood:                 543.28
# No. Observations:                 234   AIC:                            -1077.
# Df Residuals:                     229   BIC:                            -1059.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0053      0.002     -3.338      0.001      -0.008      -0.002
# mktrf          0.1198      0.041      2.907      0.004       0.039       0.201
# smb           -0.1228      0.051     -2.387      0.018      -0.224      -0.021
# hml           -0.2691      0.051     -5.267      0.000      -0.370      -0.168
# umd            0.0299      0.034      0.891      0.374      -0.036       0.096
# ==============================================================================
# Omnibus:                       10.886   Durbin-Watson:                   1.841
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               16.844
# Skew:                          -0.279   Prob(JB):                     0.000220
# Kurtosis:                       4.190   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.146
# Model:                            OLS   Adj. R-squared:                  0.131
# Method:                 Least Squares   F-statistic:                     5.059
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           0.000634
# Time:                        13:29:44   Log-Likelihood:                 543.28
# No. Observations:                 234   AIC:                            -1077.
# Df Residuals:                     229   BIC:                            -1059.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0053      0.002     -3.072      0.002      -0.009      -0.002
# mktrf          0.1198      0.057      2.103      0.035       0.008       0.231
# smb           -0.1228      0.052     -2.369      0.018      -0.224      -0.021
# hml           -0.2691      0.098     -2.737      0.006      -0.462      -0.076
# umd            0.0299      0.047      0.640      0.522      -0.062       0.121
# ==============================================================================
# Omnibus:                       10.886   Durbin-Watson:                   1.841
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               16.844
# Skew:                          -0.279   Prob(JB):                     0.000220
# Kurtosis:                       4.190   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.146
# Model:                            OLS   Adj. R-squared:                  0.131
# Method:                 Least Squares   F-statistic:                     6.374
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           7.02e-05
# Time:                        13:29:44   Log-Likelihood:                 543.28
# No. Observations:                 234   AIC:                            -1077.
# Df Residuals:                     229   BIC:                            -1059.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0053      0.002     -2.876      0.004      -0.009      -0.002
# mktrf          0.1198      0.061      1.954      0.051      -0.000       0.240
# smb           -0.1228      0.050     -2.474      0.013      -0.220      -0.026
# hml           -0.2691      0.106     -2.537      0.011      -0.477      -0.061
# umd            0.0299      0.047      0.632      0.528      -0.063       0.123
# ==============================================================================
# Omnibus:                       10.886   Durbin-Watson:                   1.841
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               16.844
# Skew:                          -0.279   Prob(JB):                     0.000220
# Kurtosis:                       4.190   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Pre-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.232
# Model:                            OLS   Adj. R-squared:                  0.205
# Method:                 Least Squares   F-statistic:                     8.695
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           3.62e-06
# Time:                        13:29:44   Log-Likelihood:                 262.87
# No. Observations:                 120   AIC:                            -515.7
# Df Residuals:                     115   BIC:                            -501.8
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0090      0.003     -3.386      0.001      -0.014      -0.004
# mktrf          0.1765      0.071      2.476      0.015       0.035       0.318
# me            -0.0457      0.070     -0.649      0.518      -0.185       0.094
# ia            -0.5296      0.110     -4.805      0.000      -0.748      -0.311
# roe            0.2368      0.098      2.427      0.017       0.044       0.430
# ==============================================================================
# Omnibus:                        3.840   Durbin-Watson:                   1.780
# Prob(Omnibus):                  0.147   Jarque-Bera (JB):                3.275
# Skew:                          -0.323   Prob(JB):                        0.194
# Kurtosis:                       3.486   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.232
# Model:                            OLS   Adj. R-squared:                  0.205
# Method:                 Least Squares   F-statistic:                     5.204
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           0.000688
# Time:                        13:29:44   Log-Likelihood:                 262.87
# No. Observations:                 120   AIC:                            -515.7
# Df Residuals:                     115   BIC:                            -501.8
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0090      0.003     -2.931      0.003      -0.015      -0.003
# mktrf          0.1765      0.077      2.305      0.021       0.026       0.327
# me            -0.0457      0.084     -0.545      0.586      -0.210       0.119
# ia            -0.5296      0.126     -4.211      0.000      -0.776      -0.283
# roe            0.2368      0.094      2.523      0.012       0.053       0.421
# ==============================================================================
# Omnibus:                        3.840   Durbin-Watson:                   1.780
# Prob(Omnibus):                  0.147   Jarque-Bera (JB):                3.275
# Skew:                          -0.323   Prob(JB):                        0.194
# Kurtosis:                       3.486   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.232
# Model:                            OLS   Adj. R-squared:                  0.205
# Method:                 Least Squares   F-statistic:                     5.361
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           0.000540
# Time:                        13:29:44   Log-Likelihood:                 262.87
# No. Observations:                 120   AIC:                            -515.7
# Df Residuals:                     115   BIC:                            -501.8
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0090      0.003     -2.727      0.006      -0.015      -0.003
# mktrf          0.1765      0.071      2.477      0.013       0.037       0.316
# me            -0.0457      0.083     -0.554      0.580      -0.207       0.116
# ia            -0.5296      0.143     -3.700      0.000      -0.810      -0.249
# roe            0.2368      0.094      2.527      0.012       0.053       0.421
# ==============================================================================
# Omnibus:                        3.840   Durbin-Watson:                   1.780
# Prob(Omnibus):                  0.147   Jarque-Bera (JB):                3.275
# Skew:                          -0.323   Prob(JB):                        0.194
# Kurtosis:                       3.486   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.216
# Model:                            OLS   Adj. R-squared:                  0.189
# Method:                 Least Squares   F-statistic:                     7.932
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.11e-05
# Time:                        13:29:44   Log-Likelihood:                 261.63
# No. Observations:                 120   AIC:                            -513.3
# Df Residuals:                     115   BIC:                            -499.3
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0079      0.003     -3.000      0.003      -0.013      -0.003
# mktrf          0.1620      0.063      2.554      0.012       0.036       0.288
# smb           -0.1605      0.072     -2.222      0.028      -0.304      -0.017
# hml           -0.3330      0.072     -4.604      0.000      -0.476      -0.190
# umd            0.0497      0.045      1.115      0.267      -0.039       0.138
# ==============================================================================
# Omnibus:                        4.176   Durbin-Watson:                   1.727
# Prob(Omnibus):                  0.124   Jarque-Bera (JB):                3.960
# Skew:                          -0.270   Prob(JB):                        0.138
# Kurtosis:                       3.707   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.216
# Model:                            OLS   Adj. R-squared:                  0.189
# Method:                 Least Squares   F-statistic:                     5.217
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           0.000674
# Time:                        13:29:44   Log-Likelihood:                 261.63
# No. Observations:                 120   AIC:                            -513.3
# Df Residuals:                     115   BIC:                            -499.3
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0079      0.003     -3.058      0.002      -0.013      -0.003
# mktrf          0.1620      0.064      2.512      0.012       0.036       0.288
# smb           -0.1605      0.069     -2.342      0.019      -0.295      -0.026
# hml           -0.3330      0.106     -3.142      0.002      -0.541      -0.125
# umd            0.0497      0.048      1.040      0.298      -0.044       0.143
# ==============================================================================
# Omnibus:                        4.176   Durbin-Watson:                   1.727
# Prob(Omnibus):                  0.124   Jarque-Bera (JB):                3.960
# Skew:                          -0.270   Prob(JB):                        0.138
# Kurtosis:                       3.707   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.216
# Model:                            OLS   Adj. R-squared:                  0.189
# Method:                 Least Squares   F-statistic:                     7.688
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.59e-05
# Time:                        13:29:44   Log-Likelihood:                 261.63
# No. Observations:                 120   AIC:                            -513.3
# Df Residuals:                     115   BIC:                            -499.3
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0079      0.003     -3.061      0.002      -0.013      -0.003
# mktrf          0.1620      0.054      3.015      0.003       0.057       0.267
# smb           -0.1605      0.064     -2.509      0.012      -0.286      -0.035
# hml           -0.3330      0.103     -3.236      0.001      -0.535      -0.131
# umd            0.0497      0.045      1.115      0.265      -0.038       0.137
# ==============================================================================
# Omnibus:                        4.176   Durbin-Watson:                   1.727
# Prob(Omnibus):                  0.124   Jarque-Bera (JB):                3.960
# Skew:                          -0.270   Prob(JB):                        0.138
# Kurtosis:                       3.707   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.216
# Model:                            OLS   Adj. R-squared:                  0.189
# Method:                 Least Squares   F-statistic:                     7.932
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.11e-05
# Time:                        13:29:44   Log-Likelihood:                 261.63
# No. Observations:                 120   AIC:                            -513.3
# Df Residuals:                     115   BIC:                            -499.3
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0079      0.003     -3.000      0.003      -0.013      -0.003
# mktrf          0.1620      0.063      2.554      0.012       0.036       0.288
# smb           -0.1605      0.072     -2.222      0.028      -0.304      -0.017
# hml           -0.3330      0.072     -4.604      0.000      -0.476      -0.190
# umd            0.0497      0.045      1.115      0.267      -0.039       0.138
# ==============================================================================
# Omnibus:                        4.176   Durbin-Watson:                   1.727
# Prob(Omnibus):                  0.124   Jarque-Bera (JB):                3.960
# Skew:                          -0.270   Prob(JB):                        0.138
# Kurtosis:                       3.707   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.216
# Model:                            OLS   Adj. R-squared:                  0.189
# Method:                 Least Squares   F-statistic:                     5.217
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           0.000674
# Time:                        13:29:44   Log-Likelihood:                 261.63
# No. Observations:                 120   AIC:                            -513.3
# Df Residuals:                     115   BIC:                            -499.3
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0079      0.003     -3.058      0.002      -0.013      -0.003
# mktrf          0.1620      0.064      2.512      0.012       0.036       0.288
# smb           -0.1605      0.069     -2.342      0.019      -0.295      -0.026
# hml           -0.3330      0.106     -3.142      0.002      -0.541      -0.125
# umd            0.0497      0.048      1.040      0.298      -0.044       0.143
# ==============================================================================
# Omnibus:                        4.176   Durbin-Watson:                   1.727
# Prob(Omnibus):                  0.124   Jarque-Bera (JB):                3.960
# Skew:                          -0.270   Prob(JB):                        0.138
# Kurtosis:                       3.707   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.216
# Model:                            OLS   Adj. R-squared:                  0.189
# Method:                 Least Squares   F-statistic:                     7.688
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.59e-05
# Time:                        13:29:44   Log-Likelihood:                 261.63
# No. Observations:                 120   AIC:                            -513.3
# Df Residuals:                     115   BIC:                            -499.3
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0079      0.003     -3.061      0.002      -0.013      -0.003
# mktrf          0.1620      0.054      3.015      0.003       0.057       0.267
# smb           -0.1605      0.064     -2.509      0.012      -0.286      -0.035
# hml           -0.3330      0.103     -3.236      0.001      -0.535      -0.131
# umd            0.0497      0.045      1.115      0.265      -0.038       0.137
# ==============================================================================
# Omnibus:                        4.176   Durbin-Watson:                   1.727
# Prob(Omnibus):                  0.124   Jarque-Bera (JB):                3.960
# Skew:                          -0.270   Prob(JB):                        0.138
# Kurtosis:                       3.707   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Post-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.032
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                    0.9007
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):              0.466
# Time:                        13:29:44   Log-Likelihood:                 301.70
# No. Observations:                 114   AIC:                            -593.4
# Df Residuals:                     109   BIC:                            -579.7
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0004      0.002     -0.208      0.836      -0.004       0.003
# mktrf         -0.0098      0.052     -0.190      0.850      -0.112       0.092
# me            -0.1269      0.080     -1.593      0.114      -0.285       0.031
# ia             0.0630      0.110      0.570      0.570      -0.156       0.282
# roe           -0.1002      0.097     -1.032      0.304      -0.293       0.092
# ==============================================================================
# Omnibus:                        1.632   Durbin-Watson:                   2.138
# Prob(Omnibus):                  0.442   Jarque-Bera (JB):                1.565
# Skew:                           0.189   Prob(JB):                        0.457
# Kurtosis:                       2.567   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.032
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                     1.370
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):              0.249
# Time:                        13:29:44   Log-Likelihood:                 301.70
# No. Observations:                 114   AIC:                            -593.4
# Df Residuals:                     109   BIC:                            -579.7
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0004      0.002     -0.191      0.849      -0.004       0.003
# mktrf         -0.0098      0.081     -0.120      0.904      -0.169       0.150
# me            -0.1269      0.066     -1.913      0.056      -0.257       0.003
# ia             0.0630      0.086      0.733      0.464      -0.106       0.232
# roe           -0.1002      0.094     -1.070      0.284      -0.284       0.083
# ==============================================================================
# Omnibus:                        1.632   Durbin-Watson:                   2.138
# Prob(Omnibus):                  0.442   Jarque-Bera (JB):                1.565
# Skew:                           0.189   Prob(JB):                        0.457
# Kurtosis:                       2.567   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.032
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                     1.567
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):              0.188
# Time:                        13:29:44   Log-Likelihood:                 301.70
# No. Observations:                 114   AIC:                            -593.4
# Df Residuals:                     109   BIC:                            -579.7
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0004      0.002     -0.184      0.854      -0.004       0.003
# mktrf         -0.0098      0.087     -0.112      0.911      -0.181       0.161
# me            -0.1269      0.057     -2.208      0.027      -0.239      -0.014
# ia             0.0630      0.080      0.783      0.433      -0.095       0.221
# roe           -0.1002      0.090     -1.118      0.264      -0.276       0.075
# ==============================================================================
# Omnibus:                        1.632   Durbin-Watson:                   2.138
# Prob(Omnibus):                  0.442   Jarque-Bera (JB):                1.565
# Skew:                           0.189   Prob(JB):                        0.457
# Kurtosis:                       2.567   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                 -0.014
# Method:                 Least Squares   F-statistic:                    0.6116
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):              0.655
# Time:                        13:29:44   Log-Likelihood:                 301.12
# No. Observations:                 114   AIC:                            -592.2
# Df Residuals:                     109   BIC:                            -578.6
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0008      0.002     -0.460      0.646      -0.004       0.003
# mktrf         -0.0042      0.049     -0.085      0.932      -0.102       0.093
# smb           -0.0674      0.077     -0.880      0.381      -0.219       0.084
# hml           -0.0151      0.079     -0.192      0.848      -0.171       0.141
# umd            0.0553      0.060      0.930      0.355      -0.063       0.173
# ==============================================================================
# Omnibus:                        2.170   Durbin-Watson:                   2.169
# Prob(Omnibus):                  0.338   Jarque-Bera (JB):                2.208
# Skew:                           0.304   Prob(JB):                        0.332
# Kurtosis:                       2.693   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                 -0.014
# Method:                 Least Squares   F-statistic:                     1.320
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):              0.267
# Time:                        13:29:44   Log-Likelihood:                 301.12
# No. Observations:                 114   AIC:                            -592.2
# Df Residuals:                     109   BIC:                            -578.6
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0008      0.002     -0.415      0.678      -0.005       0.003
# mktrf         -0.0042      0.079     -0.053      0.958      -0.160       0.152
# smb           -0.0674      0.067     -1.000      0.317      -0.199       0.065
# hml           -0.0151      0.091     -0.166      0.868      -0.194       0.164
# umd            0.0553      0.068      0.813      0.416      -0.078       0.189
# ==============================================================================
# Omnibus:                        2.170   Durbin-Watson:                   2.169
# Prob(Omnibus):                  0.338   Jarque-Bera (JB):                2.208
# Skew:                           0.304   Prob(JB):                        0.332
# Kurtosis:                       2.693   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                 -0.014
# Method:                 Least Squares   F-statistic:                     1.962
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):              0.105
# Time:                        13:29:44   Log-Likelihood:                 301.12
# No. Observations:                 114   AIC:                            -592.2
# Df Residuals:                     109   BIC:                            -578.6
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0008      0.002     -0.404      0.686      -0.005       0.003
# mktrf         -0.0042      0.087     -0.048      0.961      -0.174       0.165
# smb           -0.0674      0.061     -1.106      0.269      -0.187       0.052
# hml           -0.0151      0.080     -0.190      0.849      -0.171       0.141
# umd            0.0553      0.063      0.879      0.379      -0.068       0.179
# ==============================================================================
# Omnibus:                        2.170   Durbin-Watson:                   2.169
# Prob(Omnibus):                  0.338   Jarque-Bera (JB):                2.208
# Skew:                           0.304   Prob(JB):                        0.332
# Kurtosis:                       2.693   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                 -0.014
# Method:                 Least Squares   F-statistic:                    0.6116
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):              0.655
# Time:                        13:29:44   Log-Likelihood:                 301.12
# No. Observations:                 114   AIC:                            -592.2
# Df Residuals:                     109   BIC:                            -578.6
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0008      0.002     -0.460      0.646      -0.004       0.003
# mktrf         -0.0042      0.049     -0.085      0.932      -0.102       0.093
# smb           -0.0674      0.077     -0.880      0.381      -0.219       0.084
# hml           -0.0151      0.079     -0.192      0.848      -0.171       0.141
# umd            0.0553      0.060      0.930      0.355      -0.063       0.173
# ==============================================================================
# Omnibus:                        2.170   Durbin-Watson:                   2.169
# Prob(Omnibus):                  0.338   Jarque-Bera (JB):                2.208
# Skew:                           0.304   Prob(JB):                        0.332
# Kurtosis:                       2.693   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                 -0.014
# Method:                 Least Squares   F-statistic:                     1.320
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):              0.267
# Time:                        13:29:44   Log-Likelihood:                 301.12
# No. Observations:                 114   AIC:                            -592.2
# Df Residuals:                     109   BIC:                            -578.6
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0008      0.002     -0.415      0.678      -0.005       0.003
# mktrf         -0.0042      0.079     -0.053      0.958      -0.160       0.152
# smb           -0.0674      0.067     -1.000      0.317      -0.199       0.065
# hml           -0.0151      0.091     -0.166      0.868      -0.194       0.164
# umd            0.0553      0.068      0.813      0.416      -0.078       0.189
# ==============================================================================
# Omnibus:                        2.170   Durbin-Watson:                   2.169
# Prob(Omnibus):                  0.338   Jarque-Bera (JB):                2.208
# Skew:                           0.304   Prob(JB):                        0.332
# Kurtosis:                       2.693   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                 -0.014
# Method:                 Least Squares   F-statistic:                     1.962
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):              0.105
# Time:                        13:29:44   Log-Likelihood:                 301.12
# No. Observations:                 114   AIC:                            -592.2
# Df Residuals:                     109   BIC:                            -578.6
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0008      0.002     -0.404      0.686      -0.005       0.003
# mktrf         -0.0042      0.087     -0.048      0.961      -0.174       0.165
# smb           -0.0674      0.061     -1.106      0.269      -0.187       0.052
# hml           -0.0151      0.080     -0.190      0.849      -0.171       0.141
# umd            0.0553      0.063      0.879      0.379      -0.068       0.179
# ==============================================================================
# Omnibus:                        2.170   Durbin-Watson:                   2.169
# Prob(Omnibus):                  0.338   Jarque-Bera (JB):                2.208
# Skew:                           0.304   Prob(JB):                        0.332
# Kurtosis:                       2.693   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """
