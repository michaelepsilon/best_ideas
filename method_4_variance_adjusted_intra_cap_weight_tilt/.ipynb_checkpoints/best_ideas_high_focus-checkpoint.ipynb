# %% [markdown]
# # Method 4 - Best Ideas High Focus

# %%
# %matplotlib inline
import pandas as pd
import warnings
from statsmodels import api as sm

from eptooling import crsp, epd, fs, hfu, crsp, db, bi
from eptooling.bm import bmdb, iso
from epquant.engine import weights, portfolio
from epquant.gen import returns
from epquant.perf import relative_performance

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Fetch Holdings and Benchmark Data

# %%
# Get HFU Data

# %store -r inst_data
inst_data = inst_data[inst_data['datadate'] >= '1999-06-30']

# Focus

focus = inst_data.groupby(['datadate', 'institution_id'])['fsym_id'].count().rename('focus').reset_index()

# Count number of positions per manager

inst_data['num_pos'] = inst_data.groupby(['datadate', 'institution_id'])[
    'fsym_id'].transform(lambda s: s.nunique())

# Remove less than 20 holdings and less than $5mm per CSP

valid_data = inst_data[inst_data['num_pos'] >= 20]
valid_data = valid_data[valid_data['public_aum'] >= 5e6]

# Calculate Market Cap Adjusted Target

valid_data['weight'] = valid_data['market_cap_val_cur'] / valid_data.groupby(
    ['datadate', 'institution_id'])['market_cap_val_cur'].transform('sum')

# Grab Idiosyncratic Volatility

capm_var = crsp.get_capm_variance()

# Merge Idiosyncratic Volatility

valid_data = valid_data.merge(capm_var, how='left')

# Calculate Variance Adjusted Intra-Cap Weight Tilt

valid_data['adj_target'] = (valid_data['target'] - valid_data[
    'weight'].fillna(0)) * valid_data['capm_var']

# %% [markdown]
# ## Calculate Best Ideas

# %%
# Extract Best Ideas

valid_data['pos_rank'] = valid_data\
    .groupby(['datadate', 'institution_id'])['adj_target'].rank(ascending=False)

best_ideas = valid_data[valid_data['pos_rank'] == 1].copy()

# Add Focus

best_ideas = best_ideas.merge(focus)
best_ideas['focus_pct'] = best_ideas.groupby('datadate')['focus'].rank(pct=True)
best_ideas = best_ideas[best_ideas['focus_pct'] > (2 / 3)]

# Weight the best ideas equally

best_ideas['target'] = 1 / best_ideas.groupby('datadate')['institution_id'].transform('count')

# %% [markdown]
# ## Backtest Portfolio

# %%
w = weights.Weights(best_ideas)

# %store -r r

p = portfolio.DailyPortfolio(w, r, end_date='2018-12-31')

rf = bi.get_risk_free_rate()
monthly_return = p.port_return.loc['1999-07-01':].resample('M').apply(epd.prod_red)
monthly_return = (monthly_return - rf).dropna()
monthly_return.name = 'port_return'

# %% [markdown]
# ## Plot Performance

# %%
epd.nav(monthly_return).plot()

# %%
monthly_return.resample('A').apply(epd.prod_red)
# Out:
# datadate
# 1999-12-31    0.285533
# 2000-12-31   -0.378410
# 2001-12-31   -0.423897
# 2002-12-31   -0.342617
# 2003-12-31    0.895562
# 2004-12-31    0.063632
# 2005-12-31    0.027974
# 2006-12-31    0.048058
# 2007-12-31    0.064521
# 2008-12-31   -0.544936
# 2009-12-31    0.587289
# 2010-12-31    0.158645
# 2011-12-31   -0.131906
# 2012-12-31    0.314330
# 2013-12-31    0.492773
# 2014-12-31    0.100675
# 2015-12-31   -0.102121
# 2016-12-31    0.160665
# 2017-12-31    0.216724
# 2018-12-31   -0.137745
# Freq: A-DEC, Name: port_return, dtype: float64

# %% [markdown]
# ## Fetch Factor Models

# %%
# Get Factor Models
q_factor_model = bi.get_q_factor_model()
fama_french_five_factor_model = bi.get_fama_french_five_factor_model()
four_factor_model = bi.get_four_factor_model()

# Concat Portfolio Return
q_factor = pd.concat([monthly_return, q_factor_model], axis=1)
fama_french_five = pd.concat([monthly_return, fama_french_five_factor_model], axis=1)
four_factor = pd.concat([monthly_return, four_factor_model], axis=1)

# Add Constants
q_factor.insert(1, 'const', 1)
fama_french_five.insert(1, 'const', 1)
four_factor.insert(1, 'const', 1)

# Split Period into Pre and Post Crisis
q_factor_pre, q_factor_post = q_factor.loc[:'2009-06-30'], q_factor.loc['2009-07-31':]
fama_french_five_pre, fama_french_five_post = fama_french_five.loc[:'2009-06-30'], fama_french_five.loc['2009-07-31':] 
four_factor_pre, four_factor_post = four_factor.loc[:'2009-06-30'], four_factor.loc['2009-07-31':]

# %% [markdown]
# ## Full Time Period Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.863
# Model:                            OLS   Adj. R-squared:                  0.861
# Method:                 Least Squares   F-statistic:                     362.0
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           9.92e-98
# Time:                        13:35:37   Log-Likelihood:                 496.14
# No. Observations:                 234   AIC:                            -982.3
# Df Residuals:                     229   BIC:                            -965.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0001      0.002      0.055      0.957      -0.004       0.004
# mktrf          1.1903      0.055     21.744      0.000       1.082       1.298
# me             0.4694      0.064      7.371      0.000       0.344       0.595
# ia            -0.2784      0.097     -2.876      0.004      -0.469      -0.088
# roe           -0.6131      0.083     -7.400      0.000      -0.776      -0.450
# ==============================================================================
# Omnibus:                       21.287   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               43.135
# Skew:                           0.452   Prob(JB):                     4.30e-10
# Kurtosis:                       4.899   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.863
# Model:                            OLS   Adj. R-squared:                  0.861
# Method:                 Least Squares   F-statistic:                     265.7
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           8.81e-85
# Time:                        13:35:37   Log-Likelihood:                 496.14
# No. Observations:                 234   AIC:                            -982.3
# Df Residuals:                     229   BIC:                            -965.0
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0001      0.002      0.045      0.964      -0.005       0.005
# mktrf          1.1903      0.069     17.302      0.000       1.055       1.325
# me             0.4694      0.067      6.989      0.000       0.338       0.601
# ia            -0.2784      0.126     -2.204      0.028      -0.526      -0.031
# roe           -0.6131      0.141     -4.349      0.000      -0.889      -0.337
# ==============================================================================
# Omnibus:                       21.287   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               43.135
# Skew:                           0.452   Prob(JB):                     4.30e-10
# Kurtosis:                       4.899   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.863
# Model:                            OLS   Adj. R-squared:                  0.861
# Method:                 Least Squares   F-statistic:                     332.2
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           4.51e-94
# Time:                        13:35:37   Log-Likelihood:                 496.14
# No. Observations:                 234   AIC:                            -982.3
# Df Residuals:                     229   BIC:                            -965.0
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0001      0.002      0.044      0.965      -0.005       0.005
# mktrf          1.1903      0.064     18.472      0.000       1.064       1.317
# me             0.4694      0.060      7.865      0.000       0.352       0.586
# ia            -0.2784      0.119     -2.349      0.019      -0.511      -0.046
# roe           -0.6131      0.151     -4.072      0.000      -0.908      -0.318
# ==============================================================================
# Omnibus:                       21.287   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               43.135
# Skew:                           0.452   Prob(JB):                     4.30e-10
# Kurtosis:                       4.899   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.850
# Model:                            OLS   Adj. R-squared:                  0.847
# Method:                 Least Squares   F-statistic:                     324.2
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           4.87e-93
# Time:                        13:35:37   Log-Likelihood:                 485.09
# No. Observations:                 234   AIC:                            -960.2
# Df Residuals:                     229   BIC:                            -942.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0025      0.002     -1.237      0.217      -0.007       0.002
# mktrf          1.3428      0.053     25.413      0.000       1.239       1.447
# smb            0.7166      0.066     10.864      0.000       0.587       0.847
# hml           -0.2034      0.066     -3.104      0.002      -0.332      -0.074
# umd           -0.1568      0.043     -3.646      0.000      -0.241      -0.072
# ==============================================================================
# Omnibus:                       29.184   Durbin-Watson:                   1.884
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               45.302
# Skew:                           0.732   Prob(JB):                     1.46e-10
# Kurtosis:                       4.582   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.850
# Model:                            OLS   Adj. R-squared:                  0.847
# Method:                 Least Squares   F-statistic:                     231.9
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           2.68e-79
# Time:                        13:35:37   Log-Likelihood:                 485.09
# No. Observations:                 234   AIC:                            -960.2
# Df Residuals:                     229   BIC:                            -942.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0025      0.002     -1.183      0.237      -0.007       0.002
# mktrf          1.3428      0.065     20.641      0.000       1.215       1.470
# smb            0.7166      0.077      9.263      0.000       0.565       0.868
# hml           -0.2034      0.094     -2.157      0.031      -0.388      -0.019
# umd           -0.1568      0.063     -2.503      0.012      -0.280      -0.034
# ==============================================================================
# Omnibus:                       29.184   Durbin-Watson:                   1.884
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               45.302
# Skew:                           0.732   Prob(JB):                     1.46e-10
# Kurtosis:                       4.582   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.850
# Model:                            OLS   Adj. R-squared:                  0.847
# Method:                 Least Squares   F-statistic:                     198.0
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           4.09e-73
# Time:                        13:35:37   Log-Likelihood:                 485.09
# No. Observations:                 234   AIC:                            -960.2
# Df Residuals:                     229   BIC:                            -942.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0025      0.002     -1.222      0.222      -0.007       0.002
# mktrf          1.3428      0.068     19.889      0.000       1.210       1.475
# smb            0.7166      0.070     10.300      0.000       0.580       0.853
# hml           -0.2034      0.089     -2.282      0.022      -0.378      -0.029
# umd           -0.1568      0.068     -2.300      0.021      -0.290      -0.023
# ==============================================================================
# Omnibus:                       29.184   Durbin-Watson:                   1.884
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               45.302
# Skew:                           0.732   Prob(JB):                     1.46e-10
# Kurtosis:                       4.582   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.850
# Model:                            OLS   Adj. R-squared:                  0.847
# Method:                 Least Squares   F-statistic:                     324.2
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           4.87e-93
# Time:                        13:35:37   Log-Likelihood:                 485.09
# No. Observations:                 234   AIC:                            -960.2
# Df Residuals:                     229   BIC:                            -942.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0025      0.002     -1.237      0.217      -0.007       0.002
# mktrf          1.3428      0.053     25.413      0.000       1.239       1.447
# smb            0.7166      0.066     10.864      0.000       0.587       0.847
# hml           -0.2034      0.066     -3.104      0.002      -0.332      -0.074
# umd           -0.1568      0.043     -3.646      0.000      -0.241      -0.072
# ==============================================================================
# Omnibus:                       29.184   Durbin-Watson:                   1.884
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               45.302
# Skew:                           0.732   Prob(JB):                     1.46e-10
# Kurtosis:                       4.582   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.850
# Model:                            OLS   Adj. R-squared:                  0.847
# Method:                 Least Squares   F-statistic:                     231.9
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           2.68e-79
# Time:                        13:35:37   Log-Likelihood:                 485.09
# No. Observations:                 234   AIC:                            -960.2
# Df Residuals:                     229   BIC:                            -942.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0025      0.002     -1.183      0.237      -0.007       0.002
# mktrf          1.3428      0.065     20.641      0.000       1.215       1.470
# smb            0.7166      0.077      9.263      0.000       0.565       0.868
# hml           -0.2034      0.094     -2.157      0.031      -0.388      -0.019
# umd           -0.1568      0.063     -2.503      0.012      -0.280      -0.034
# ==============================================================================
# Omnibus:                       29.184   Durbin-Watson:                   1.884
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               45.302
# Skew:                           0.732   Prob(JB):                     1.46e-10
# Kurtosis:                       4.582   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.850
# Model:                            OLS   Adj. R-squared:                  0.847
# Method:                 Least Squares   F-statistic:                     198.0
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           4.09e-73
# Time:                        13:35:37   Log-Likelihood:                 485.09
# No. Observations:                 234   AIC:                            -960.2
# Df Residuals:                     229   BIC:                            -942.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0025      0.002     -1.222      0.222      -0.007       0.002
# mktrf          1.3428      0.068     19.889      0.000       1.210       1.475
# smb            0.7166      0.070     10.300      0.000       0.580       0.853
# hml           -0.2034      0.089     -2.282      0.022      -0.378      -0.029
# umd           -0.1568      0.068     -2.300      0.021      -0.290      -0.023
# ==============================================================================
# Omnibus:                       29.184   Durbin-Watson:                   1.884
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               45.302
# Skew:                           0.732   Prob(JB):                     1.46e-10
# Kurtosis:                       4.582   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Pre-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.871
# Model:                            OLS   Adj. R-squared:                  0.866
# Method:                 Least Squares   F-statistic:                     193.5
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           4.31e-50
# Time:                        13:35:37   Log-Likelihood:                 238.47
# No. Observations:                 120   AIC:                            -466.9
# Df Residuals:                     115   BIC:                            -453.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0022      0.003     -0.689      0.492      -0.009       0.004
# mktrf          1.2756      0.087     14.607      0.000       1.103       1.449
# me             0.5130      0.086      5.948      0.000       0.342       0.684
# ia            -0.3732      0.135     -2.763      0.007      -0.641      -0.106
# roe           -0.4353      0.120     -3.641      0.000      -0.672      -0.198
# ==============================================================================
# Omnibus:                       18.094   Durbin-Watson:                   1.975
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               32.695
# Skew:                           0.652   Prob(JB):                     7.95e-08
# Kurtosis:                       5.199   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.871
# Model:                            OLS   Adj. R-squared:                  0.866
# Method:                 Least Squares   F-statistic:                     170.7
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           2.16e-47
# Time:                        13:35:37   Log-Likelihood:                 238.47
# No. Observations:                 120   AIC:                            -466.9
# Df Residuals:                     115   BIC:                            -453.0
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0022      0.004     -0.512      0.609      -0.011       0.006
# mktrf          1.2756      0.106     12.082      0.000       1.069       1.483
# me             0.5130      0.095      5.376      0.000       0.326       0.700
# ia            -0.3732      0.190     -1.968      0.049      -0.745      -0.002
# roe           -0.4353      0.201     -2.171      0.030      -0.828      -0.042
# ==============================================================================
# Omnibus:                       18.094   Durbin-Watson:                   1.975
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               32.695
# Skew:                           0.652   Prob(JB):                     7.95e-08
# Kurtosis:                       5.199   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.871
# Model:                            OLS   Adj. R-squared:                  0.866
# Method:                 Least Squares   F-statistic:                     230.0
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           6.99e-54
# Time:                        13:35:37   Log-Likelihood:                 238.47
# No. Observations:                 120   AIC:                            -466.9
# Df Residuals:                     115   BIC:                            -453.0
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0022      0.004     -0.502      0.615      -0.011       0.006
# mktrf          1.2756      0.093     13.738      0.000       1.094       1.458
# me             0.5130      0.089      5.774      0.000       0.339       0.687
# ia            -0.3732      0.191     -1.951      0.051      -0.748       0.002
# roe           -0.4353      0.208     -2.092      0.036      -0.843      -0.028
# ==============================================================================
# Omnibus:                       18.094   Durbin-Watson:                   1.975
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               32.695
# Skew:                           0.652   Prob(JB):                     7.95e-08
# Kurtosis:                       5.199   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.882
# Model:                            OLS   Adj. R-squared:                  0.877
# Method:                 Least Squares   F-statistic:                     214.0
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           2.74e-52
# Time:                        13:35:37   Log-Likelihood:                 243.76
# No. Observations:                 120   AIC:                            -477.5
# Df Residuals:                     115   BIC:                            -463.6
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0026      0.003     -0.855      0.394      -0.009       0.003
# mktrf          1.4490      0.074     19.683      0.000       1.303       1.595
# smb            0.6814      0.084      8.130      0.000       0.515       0.847
# hml           -0.2743      0.084     -3.267      0.001      -0.441      -0.108
# umd           -0.1058      0.052     -2.044      0.043      -0.208      -0.003
# ==============================================================================
# Omnibus:                       11.542   Durbin-Watson:                   1.962
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               13.735
# Skew:                           0.578   Prob(JB):                      0.00104
# Kurtosis:                       4.189   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.882
# Model:                            OLS   Adj. R-squared:                  0.877
# Method:                 Least Squares   F-statistic:                     214.7
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           2.32e-52
# Time:                        13:35:37   Log-Likelihood:                 243.76
# No. Observations:                 120   AIC:                            -477.5
# Df Residuals:                     115   BIC:                            -463.6
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0026      0.003     -0.764      0.445      -0.009       0.004
# mktrf          1.4490      0.069     20.915      0.000       1.313       1.585
# smb            0.6814      0.095      7.197      0.000       0.496       0.867
# hml           -0.2743      0.087     -3.137      0.002      -0.446      -0.103
# umd           -0.1058      0.068     -1.564      0.118      -0.238       0.027
# ==============================================================================
# Omnibus:                       11.542   Durbin-Watson:                   1.962
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               13.735
# Skew:                           0.578   Prob(JB):                      0.00104
# Kurtosis:                       4.189   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.882
# Model:                            OLS   Adj. R-squared:                  0.877
# Method:                 Least Squares   F-statistic:                     369.7
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           1.23e-64
# Time:                        13:35:37   Log-Likelihood:                 243.76
# No. Observations:                 120   AIC:                            -477.5
# Df Residuals:                     115   BIC:                            -463.6
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0026      0.003     -0.809      0.419      -0.009       0.004
# mktrf          1.4490      0.049     29.283      0.000       1.352       1.546
# smb            0.6814      0.093      7.346      0.000       0.500       0.863
# hml           -0.2743      0.070     -3.930      0.000      -0.411      -0.137
# umd           -0.1058      0.069     -1.532      0.126      -0.241       0.030
# ==============================================================================
# Omnibus:                       11.542   Durbin-Watson:                   1.962
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               13.735
# Skew:                           0.578   Prob(JB):                      0.00104
# Kurtosis:                       4.189   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.882
# Model:                            OLS   Adj. R-squared:                  0.877
# Method:                 Least Squares   F-statistic:                     214.0
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           2.74e-52
# Time:                        13:35:37   Log-Likelihood:                 243.76
# No. Observations:                 120   AIC:                            -477.5
# Df Residuals:                     115   BIC:                            -463.6
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0026      0.003     -0.855      0.394      -0.009       0.003
# mktrf          1.4490      0.074     19.683      0.000       1.303       1.595
# smb            0.6814      0.084      8.130      0.000       0.515       0.847
# hml           -0.2743      0.084     -3.267      0.001      -0.441      -0.108
# umd           -0.1058      0.052     -2.044      0.043      -0.208      -0.003
# ==============================================================================
# Omnibus:                       11.542   Durbin-Watson:                   1.962
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               13.735
# Skew:                           0.578   Prob(JB):                      0.00104
# Kurtosis:                       4.189   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.882
# Model:                            OLS   Adj. R-squared:                  0.877
# Method:                 Least Squares   F-statistic:                     214.7
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           2.32e-52
# Time:                        13:35:37   Log-Likelihood:                 243.76
# No. Observations:                 120   AIC:                            -477.5
# Df Residuals:                     115   BIC:                            -463.6
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0026      0.003     -0.764      0.445      -0.009       0.004
# mktrf          1.4490      0.069     20.915      0.000       1.313       1.585
# smb            0.6814      0.095      7.197      0.000       0.496       0.867
# hml           -0.2743      0.087     -3.137      0.002      -0.446      -0.103
# umd           -0.1058      0.068     -1.564      0.118      -0.238       0.027
# ==============================================================================
# Omnibus:                       11.542   Durbin-Watson:                   1.962
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               13.735
# Skew:                           0.578   Prob(JB):                      0.00104
# Kurtosis:                       4.189   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.882
# Model:                            OLS   Adj. R-squared:                  0.877
# Method:                 Least Squares   F-statistic:                     369.7
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           1.23e-64
# Time:                        13:35:37   Log-Likelihood:                 243.76
# No. Observations:                 120   AIC:                            -477.5
# Df Residuals:                     115   BIC:                            -463.6
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0026      0.003     -0.809      0.419      -0.009       0.004
# mktrf          1.4490      0.049     29.283      0.000       1.352       1.546
# smb            0.6814      0.093      7.346      0.000       0.500       0.863
# hml           -0.2743      0.070     -3.930      0.000      -0.411      -0.137
# umd           -0.1058      0.069     -1.532      0.126      -0.241       0.030
# ==============================================================================
# Omnibus:                       11.542   Durbin-Watson:                   1.962
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               13.735
# Skew:                           0.578   Prob(JB):                      0.00104
# Kurtosis:                       4.189   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Post-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.860
# Model:                            OLS   Adj. R-squared:                  0.855
# Method:                 Least Squares   F-statistic:                     167.1
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           1.53e-45
# Time:                        13:35:37   Log-Likelihood:                 271.49
# No. Observations:                 114   AIC:                            -533.0
# Df Residuals:                     109   BIC:                            -519.3
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0034      0.002      1.478      0.142      -0.001       0.008
# mktrf          1.0931      0.067     16.258      0.000       0.960       1.226
# me             0.4248      0.104      4.092      0.000       0.219       0.631
# ia            -0.1117      0.144     -0.775      0.440      -0.397       0.174
# roe           -0.9429      0.127     -7.452      0.000      -1.194      -0.692
# ==============================================================================
# Omnibus:                       14.189   Durbin-Watson:                   1.871
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               19.178
# Skew:                           0.647   Prob(JB):                     6.85e-05
# Kurtosis:                       4.538   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.860
# Model:                            OLS   Adj. R-squared:                  0.855
# Method:                 Least Squares   F-statistic:                     227.4
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           6.28e-52
# Time:                        13:35:37   Log-Likelihood:                 271.49
# No. Observations:                 114   AIC:                            -533.0
# Df Residuals:                     109   BIC:                            -519.3
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0034      0.002      1.925      0.054   -6.04e-05       0.007
# mktrf          1.0931      0.072     15.272      0.000       0.953       1.233
# me             0.4248      0.069      6.180      0.000       0.290       0.560
# ia            -0.1117      0.140     -0.797      0.426      -0.386       0.163
# roe           -0.9429      0.154     -6.127      0.000      -1.244      -0.641
# ==============================================================================
# Omnibus:                       14.189   Durbin-Watson:                   1.871
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               19.178
# Skew:                           0.647   Prob(JB):                     6.85e-05
# Kurtosis:                       4.538   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.860
# Model:                            OLS   Adj. R-squared:                  0.855
# Method:                 Least Squares   F-statistic:                     281.2
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           1.86e-56
# Time:                        13:35:37   Log-Likelihood:                 271.49
# No. Observations:                 114   AIC:                            -533.0
# Df Residuals:                     109   BIC:                            -519.3
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0034      0.002      2.022      0.043       0.000       0.007
# mktrf          1.0931      0.066     16.588      0.000       0.964       1.222
# me             0.4248      0.066      6.420      0.000       0.295       0.555
# ia            -0.1117      0.136     -0.819      0.413      -0.379       0.156
# roe           -0.9429      0.139     -6.784      0.000      -1.215      -0.670
# ==============================================================================
# Omnibus:                       14.189   Durbin-Watson:                   1.871
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               19.178
# Skew:                           0.647   Prob(JB):                     6.85e-05
# Kurtosis:                       4.538   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.798
# Model:                            OLS   Adj. R-squared:                  0.790
# Method:                 Least Squares   F-statistic:                     107.5
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           6.56e-37
# Time:                        13:35:37   Log-Likelihood:                 250.62
# No. Observations:                 114   AIC:                            -491.2
# Df Residuals:                     109   BIC:                            -477.6
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0002      0.003      0.082      0.935      -0.005       0.006
# mktrf          1.1682      0.077     15.269      0.000       1.017       1.320
# smb            0.6616      0.119      5.546      0.000       0.425       0.898
# hml            0.0978      0.123      0.796      0.428      -0.146       0.341
# umd           -0.2085      0.093     -2.249      0.026      -0.392      -0.025
# ==============================================================================
# Omnibus:                       17.137   Durbin-Watson:                   1.804
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.095
# Skew:                           0.777   Prob(JB):                     9.66e-06
# Kurtosis:                       4.565   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.798
# Model:                            OLS   Adj. R-squared:                  0.790
# Method:                 Least Squares   F-statistic:                     128.7
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           2.34e-40
# Time:                        13:35:37   Log-Likelihood:                 250.62
# No. Observations:                 114   AIC:                            -491.2
# Df Residuals:                     109   BIC:                            -477.6
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0002      0.002      0.110      0.913      -0.004       0.004
# mktrf          1.1682      0.084     13.848      0.000       1.003       1.334
# smb            0.6616      0.095      6.935      0.000       0.475       0.849
# hml            0.0978      0.217      0.450      0.653      -0.328       0.524
# umd           -0.2085      0.098     -2.131      0.033      -0.400      -0.017
# ==============================================================================
# Omnibus:                       17.137   Durbin-Watson:                   1.804
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.095
# Skew:                           0.777   Prob(JB):                     9.66e-06
# Kurtosis:                       4.565   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.798
# Model:                            OLS   Adj. R-squared:                  0.790
# Method:                 Least Squares   F-statistic:                     168.8
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           9.40e-46
# Time:                        13:35:37   Log-Likelihood:                 250.62
# No. Observations:                 114   AIC:                            -491.2
# Df Residuals:                     109   BIC:                            -477.6
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0002      0.002      0.119      0.905      -0.003       0.004
# mktrf          1.1682      0.083     14.089      0.000       1.006       1.331
# smb            0.6616      0.078      8.441      0.000       0.508       0.815
# hml            0.0978      0.223      0.438      0.661      -0.340       0.536
# umd           -0.2085      0.085     -2.458      0.014      -0.375      -0.042
# ==============================================================================
# Omnibus:                       17.137   Durbin-Watson:                   1.804
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.095
# Skew:                           0.777   Prob(JB):                     9.66e-06
# Kurtosis:                       4.565   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.798
# Model:                            OLS   Adj. R-squared:                  0.790
# Method:                 Least Squares   F-statistic:                     107.5
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           6.56e-37
# Time:                        13:35:37   Log-Likelihood:                 250.62
# No. Observations:                 114   AIC:                            -491.2
# Df Residuals:                     109   BIC:                            -477.6
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0002      0.003      0.082      0.935      -0.005       0.006
# mktrf          1.1682      0.077     15.269      0.000       1.017       1.320
# smb            0.6616      0.119      5.546      0.000       0.425       0.898
# hml            0.0978      0.123      0.796      0.428      -0.146       0.341
# umd           -0.2085      0.093     -2.249      0.026      -0.392      -0.025
# ==============================================================================
# Omnibus:                       17.137   Durbin-Watson:                   1.804
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.095
# Skew:                           0.777   Prob(JB):                     9.66e-06
# Kurtosis:                       4.565   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.798
# Model:                            OLS   Adj. R-squared:                  0.790
# Method:                 Least Squares   F-statistic:                     128.7
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           2.34e-40
# Time:                        13:35:37   Log-Likelihood:                 250.62
# No. Observations:                 114   AIC:                            -491.2
# Df Residuals:                     109   BIC:                            -477.6
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0002      0.002      0.110      0.913      -0.004       0.004
# mktrf          1.1682      0.084     13.848      0.000       1.003       1.334
# smb            0.6616      0.095      6.935      0.000       0.475       0.849
# hml            0.0978      0.217      0.450      0.653      -0.328       0.524
# umd           -0.2085      0.098     -2.131      0.033      -0.400      -0.017
# ==============================================================================
# Omnibus:                       17.137   Durbin-Watson:                   1.804
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.095
# Skew:                           0.777   Prob(JB):                     9.66e-06
# Kurtosis:                       4.565   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.798
# Model:                            OLS   Adj. R-squared:                  0.790
# Method:                 Least Squares   F-statistic:                     168.8
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           9.40e-46
# Time:                        13:35:37   Log-Likelihood:                 250.62
# No. Observations:                 114   AIC:                            -491.2
# Df Residuals:                     109   BIC:                            -477.6
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0002      0.002      0.119      0.905      -0.003       0.004
# mktrf          1.1682      0.083     14.089      0.000       1.006       1.331
# smb            0.6616      0.078      8.441      0.000       0.508       0.815
# hml            0.0978      0.223      0.438      0.661      -0.340       0.536
# umd           -0.2085      0.085     -2.458      0.014      -0.375      -0.042
# ==============================================================================
# Omnibus:                       17.137   Durbin-Watson:                   1.804
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.095
# Skew:                           0.777   Prob(JB):                     9.66e-06
# Kurtosis:                       4.565   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """
