# %% [markdown]
# # Method 4 - Best Minus Rest

# %%
# %matplotlib inline
import pandas as pd
import warnings
from statsmodels import api as sm

from eptooling import crsp, epd, fs, hfu, crsp, db, bi
from eptooling.bm import bmdb, iso
from epquant.engine import weights, portfolio
from epquant.gen import returns
from epquant.perf import relative_performance

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Fetch Holdings and Benchmark Data

# %%
# Get HFU Data

# %store -r inst_data
inst_data = inst_data[inst_data['datadate'] >= '1999-06-30']

# Count number of positions per manager

inst_data['num_pos'] = inst_data.groupby(['datadate', 'institution_id'])[
    'fsym_id'].transform(lambda s: s.nunique())

# Remove less than 20 holdings and less than $5mm per CSP

valid_data = inst_data[inst_data['num_pos'] >= 20]
valid_data = valid_data[valid_data['public_aum'] >= 5e6]

# Calculate Market Cap Adjusted Target

valid_data['weight'] = valid_data['market_cap_val_cur'] / valid_data.groupby(
    ['datadate', 'institution_id'])['market_cap_val_cur'].transform('sum')

# Grab Idiosyncratic Volatility

capm_var = crsp.get_capm_variance()

# Merge Idiosyncratic Volatility

valid_data = valid_data.merge(capm_var, how='left')

# Calculate Variance Adjusted Intra-Cap Weight Tilt

valid_data['adj_target'] = (valid_data['target'] - valid_data[
    'weight'].fillna(0)) * valid_data['capm_var']

# %% [markdown]
# ## Calculate Best Ideas

# %%
# Extract Best Ideas

valid_data['pos_rank'] = valid_data\
    .groupby(['datadate', 'institution_id'])['adj_target'].rank(ascending=False)

                                                                                         
# Split Long and Short and Filter to Highest Tilts

long_ideas = valid_data[valid_data['pos_rank'] == 1].copy()                                                                           
short_ideas = valid_data[valid_data['pos_rank'] != 1].copy()

# Weight the best ideas equally

long_ideas['target'] = 1 / long_ideas.groupby('datadate')[
    'institution_id'].transform('count')

short_ideas['target'] = - short_ideas['target'] / short_ideas.groupby([
    'datadate', 'institution_id'])['target'].transform('sum') * \
                        (1 / short_ideas.groupby('datadate')['institution_id']
                         .transform(lambda s: s.nunique()))

best_ideas = pd.concat([long_ideas, short_ideas])

# %% [markdown]
# ## Backtest Portfolio

# %%
w = weights.Weights(best_ideas)

# %store -r r

p = portfolio.DailyPortfolio(w, r, end_date='2018-12-31')

monthly_return = p.port_return.loc['1999-07-01':].resample('M').apply(epd.prod_red)
monthly_return.name = 'port_return'

# %% [markdown]
# ## Plot Performance

# %%
epd.nav(monthly_return).plot()

# %%
monthly_return.resample('A').apply(epd.prod_red)
# Out:
# datadate
# 1999-12-31    0.223402
# 2000-12-31   -0.239574
# 2001-12-31   -0.114498
# 2002-12-31   -0.125776
# 2003-12-31    0.341964
# 2004-12-31   -0.002904
# 2005-12-31   -0.037788
# 2006-12-31   -0.002520
# 2007-12-31    0.002645
# 2008-12-31   -0.179042
# 2009-12-31    0.246569
# 2010-12-31    0.006534
# 2011-12-31   -0.095343
# 2012-12-31    0.062845
# 2013-12-31    0.061723
# 2014-12-31   -0.015038
# 2015-12-31   -0.071210
# 2016-12-31    0.060472
# 2017-12-31   -0.007562
# 2018-12-31   -0.042332
# Freq: A-DEC, Name: port_return, dtype: float64

# %% [markdown]
# ## Fetch Factor Models

# %%
# Get Factor Models
q_factor_model = bi.get_q_factor_model()
fama_french_five_factor_model = bi.get_fama_french_five_factor_model()
four_factor_model = bi.get_four_factor_model()

# Concat Portfolio Return
q_factor = pd.concat([monthly_return, q_factor_model], axis=1)
fama_french_five = pd.concat([monthly_return, fama_french_five_factor_model], axis=1)
four_factor = pd.concat([monthly_return, four_factor_model], axis=1)

# Add Constants
q_factor.insert(1, 'const', 1)
fama_french_five.insert(1, 'const', 1)
four_factor.insert(1, 'const', 1)

# Split Period into Pre and Post Crisis
q_factor_pre, q_factor_post = q_factor.loc[:'2009-06-30'], q_factor.loc['2009-07-31':]
fama_french_five_pre, fama_french_five_post = fama_french_five.loc[:'2009-06-30'], fama_french_five.loc['2009-07-31':] 
four_factor_pre, four_factor_post = four_factor.loc[:'2009-06-30'], four_factor.loc['2009-07-31':]

# %% [markdown]
# ## Full Time Period Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.613
# Model:                            OLS   Adj. R-squared:                  0.606
# Method:                 Least Squares   F-statistic:                     90.59
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           4.76e-46
# Time:                        14:23:25   Log-Likelihood:                 556.61
# No. Observations:                 234   AIC:                            -1103.
# Df Residuals:                     229   BIC:                            -1086.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0018      0.002      1.185      0.237      -0.001       0.005
# mktrf          0.0827      0.042      1.956      0.052      -0.001       0.166
# me             0.2289      0.049      4.655      0.000       0.132       0.326
# ia            -0.1845      0.075     -2.469      0.014      -0.332      -0.037
# roe           -0.6885      0.064    -10.761      0.000      -0.815      -0.562
# ==============================================================================
# Omnibus:                       62.319   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              224.516
# Skew:                           1.054   Prob(JB):                     1.77e-49
# Kurtosis:                       7.310   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.613
# Model:                            OLS   Adj. R-squared:                  0.606
# Method:                 Least Squares   F-statistic:                     42.88
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           7.91e-27
# Time:                        14:23:25   Log-Likelihood:                 556.61
# No. Observations:                 234   AIC:                            -1103.
# Df Residuals:                     229   BIC:                            -1086.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0018      0.002      0.982      0.326      -0.002       0.005
# mktrf          0.0827      0.045      1.829      0.067      -0.006       0.171
# me             0.2289      0.068      3.356      0.001       0.095       0.363
# ia            -0.1845      0.122     -1.514      0.130      -0.423       0.054
# roe           -0.6885      0.133     -5.190      0.000      -0.948      -0.428
# ==============================================================================
# Omnibus:                       62.319   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              224.516
# Skew:                           1.054   Prob(JB):                     1.77e-49
# Kurtosis:                       7.310   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.613
# Model:                            OLS   Adj. R-squared:                  0.606
# Method:                 Least Squares   F-statistic:                     58.83
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           4.17e-34
# Time:                        14:23:25   Log-Likelihood:                 556.61
# No. Observations:                 234   AIC:                            -1103.
# Df Residuals:                     229   BIC:                            -1086.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0018      0.002      1.010      0.312      -0.002       0.005
# mktrf          0.0827      0.037      2.227      0.026       0.010       0.155
# me             0.2289      0.068      3.380      0.001       0.096       0.362
# ia            -0.1845      0.114     -1.621      0.105      -0.408       0.039
# roe           -0.6885      0.135     -5.089      0.000      -0.954      -0.423
# ==============================================================================
# Omnibus:                       62.319   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              224.516
# Skew:                           1.054   Prob(JB):                     1.77e-49
# Kurtosis:                       7.310   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.522
# Model:                            OLS   Adj. R-squared:                  0.514
# Method:                 Least Squares   F-statistic:                     62.52
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           1.20e-35
# Time:                        14:23:25   Log-Likelihood:                 531.98
# No. Observations:                 234   AIC:                            -1054.
# Df Residuals:                     229   BIC:                            -1037.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0008      0.002     -0.501      0.617      -0.004       0.002
# mktrf          0.2324      0.043      5.373      0.000       0.147       0.318
# smb            0.4913      0.054      9.101      0.000       0.385       0.598
# hml           -0.2173      0.054     -4.052      0.000      -0.323      -0.112
# umd           -0.1861      0.035     -5.289      0.000      -0.255      -0.117
# ==============================================================================
# Omnibus:                       73.817   Durbin-Watson:                   1.912
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              317.817
# Skew:                           1.201   Prob(JB):                     9.70e-70
# Kurtosis:                       8.179   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.522
# Model:                            OLS   Adj. R-squared:                  0.514
# Method:                 Least Squares   F-statistic:                     20.77
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           1.28e-14
# Time:                        14:23:25   Log-Likelihood:                 531.98
# No. Observations:                 234   AIC:                            -1054.
# Df Residuals:                     229   BIC:                            -1037.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0008      0.002     -0.494      0.621      -0.004       0.002
# mktrf          0.2324      0.052      4.493      0.000       0.131       0.334
# smb            0.4913      0.085      5.811      0.000       0.326       0.657
# hml           -0.2173      0.081     -2.692      0.007      -0.375      -0.059
# umd           -0.1861      0.068     -2.744      0.006      -0.319      -0.053
# ==============================================================================
# Omnibus:                       73.817   Durbin-Watson:                   1.912
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              317.817
# Skew:                           1.201   Prob(JB):                     9.70e-70
# Kurtosis:                       8.179   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.522
# Model:                            OLS   Adj. R-squared:                  0.514
# Method:                 Least Squares   F-statistic:                     18.97
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           1.74e-13
# Time:                        14:23:25   Log-Likelihood:                 531.98
# No. Observations:                 234   AIC:                            -1054.
# Df Residuals:                     229   BIC:                            -1037.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0008      0.002     -0.545      0.586      -0.004       0.002
# mktrf          0.2324      0.052      4.476      0.000       0.131       0.334
# smb            0.4913      0.076      6.435      0.000       0.342       0.641
# hml           -0.2173      0.081     -2.688      0.007      -0.376      -0.059
# umd           -0.1861      0.072     -2.581      0.010      -0.327      -0.045
# ==============================================================================
# Omnibus:                       73.817   Durbin-Watson:                   1.912
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              317.817
# Skew:                           1.201   Prob(JB):                     9.70e-70
# Kurtosis:                       8.179   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.522
# Model:                            OLS   Adj. R-squared:                  0.514
# Method:                 Least Squares   F-statistic:                     62.52
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           1.20e-35
# Time:                        14:23:25   Log-Likelihood:                 531.98
# No. Observations:                 234   AIC:                            -1054.
# Df Residuals:                     229   BIC:                            -1037.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0008      0.002     -0.501      0.617      -0.004       0.002
# mktrf          0.2324      0.043      5.373      0.000       0.147       0.318
# smb            0.4913      0.054      9.101      0.000       0.385       0.598
# hml           -0.2173      0.054     -4.052      0.000      -0.323      -0.112
# umd           -0.1861      0.035     -5.289      0.000      -0.255      -0.117
# ==============================================================================
# Omnibus:                       73.817   Durbin-Watson:                   1.912
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              317.817
# Skew:                           1.201   Prob(JB):                     9.70e-70
# Kurtosis:                       8.179   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.522
# Model:                            OLS   Adj. R-squared:                  0.514
# Method:                 Least Squares   F-statistic:                     20.77
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           1.28e-14
# Time:                        14:23:25   Log-Likelihood:                 531.98
# No. Observations:                 234   AIC:                            -1054.
# Df Residuals:                     229   BIC:                            -1037.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0008      0.002     -0.494      0.621      -0.004       0.002
# mktrf          0.2324      0.052      4.493      0.000       0.131       0.334
# smb            0.4913      0.085      5.811      0.000       0.326       0.657
# hml           -0.2173      0.081     -2.692      0.007      -0.375      -0.059
# umd           -0.1861      0.068     -2.744      0.006      -0.319      -0.053
# ==============================================================================
# Omnibus:                       73.817   Durbin-Watson:                   1.912
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              317.817
# Skew:                           1.201   Prob(JB):                     9.70e-70
# Kurtosis:                       8.179   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.522
# Model:                            OLS   Adj. R-squared:                  0.514
# Method:                 Least Squares   F-statistic:                     18.97
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           1.74e-13
# Time:                        14:23:25   Log-Likelihood:                 531.98
# No. Observations:                 234   AIC:                            -1054.
# Df Residuals:                     229   BIC:                            -1037.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0008      0.002     -0.545      0.586      -0.004       0.002
# mktrf          0.2324      0.052      4.476      0.000       0.131       0.334
# smb            0.4913      0.076      6.435      0.000       0.342       0.641
# hml           -0.2173      0.081     -2.688      0.007      -0.376      -0.059
# umd           -0.1861      0.072     -2.581      0.010      -0.327      -0.045
# ==============================================================================
# Omnibus:                       73.817   Durbin-Watson:                   1.912
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              317.817
# Skew:                           1.201   Prob(JB):                     9.70e-70
# Kurtosis:                       8.179   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Pre-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.636
# Model:                            OLS   Adj. R-squared:                  0.624
# Method:                 Least Squares   F-statistic:                     50.32
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           2.04e-24
# Time:                        14:23:25   Log-Likelihood:                 264.15
# No. Observations:                 120   AIC:                            -518.3
# Df Residuals:                     115   BIC:                            -504.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0020      0.003      0.767      0.445      -0.003       0.007
# mktrf          0.1085      0.071      1.538      0.127      -0.031       0.248
# me             0.2518      0.070      3.616      0.000       0.114       0.390
# ia            -0.2295      0.109     -2.105      0.037      -0.446      -0.014
# roe           -0.6334      0.097     -6.563      0.000      -0.825      -0.442
# ==============================================================================
# Omnibus:                       36.104   Durbin-Watson:                   2.035
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               99.945
# Skew:                           1.098   Prob(JB):                     1.98e-22
# Kurtosis:                       6.894   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.636
# Model:                            OLS   Adj. R-squared:                  0.624
# Method:                 Least Squares   F-statistic:                     32.67
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           3.49e-18
# Time:                        14:23:25   Log-Likelihood:                 264.15
# No. Observations:                 120   AIC:                            -518.3
# Df Residuals:                     115   BIC:                            -504.4
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0020      0.003      0.581      0.561      -0.005       0.009
# mktrf          0.1085      0.072      1.506      0.132      -0.033       0.250
# me             0.2518      0.091      2.766      0.006       0.073       0.430
# ia            -0.2295      0.180     -1.277      0.202      -0.582       0.123
# roe           -0.6334      0.193     -3.284      0.001      -1.011      -0.255
# ==============================================================================
# Omnibus:                       36.104   Durbin-Watson:                   2.035
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               99.945
# Skew:                           1.098   Prob(JB):                     1.98e-22
# Kurtosis:                       6.894   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.636
# Model:                            OLS   Adj. R-squared:                  0.624
# Method:                 Least Squares   F-statistic:                     46.89
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           2.55e-23
# Time:                        14:23:25   Log-Likelihood:                 264.15
# No. Observations:                 120   AIC:                            -518.3
# Df Residuals:                     115   BIC:                            -504.4
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0020      0.003      0.592      0.554      -0.005       0.009
# mktrf          0.1085      0.057      1.917      0.055      -0.002       0.219
# me             0.2518      0.093      2.719      0.007       0.070       0.433
# ia            -0.2295      0.173     -1.327      0.185      -0.569       0.110
# roe           -0.6334      0.197     -3.218      0.001      -1.019      -0.248
# ==============================================================================
# Omnibus:                       36.104   Durbin-Watson:                   2.035
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               99.945
# Skew:                           1.098   Prob(JB):                     1.98e-22
# Kurtosis:                       6.894   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.616
# Model:                            OLS   Adj. R-squared:                  0.603
# Method:                 Least Squares   F-statistic:                     46.20
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           4.31e-23
# Time:                        14:23:25   Log-Likelihood:                 260.93
# No. Observations:                 120   AIC:                            -511.9
# Df Residuals:                     115   BIC:                            -497.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       9.754e-06      0.003      0.004      0.997      -0.005       0.005
# mktrf          0.3048      0.064      4.777      0.000       0.178       0.431
# smb            0.4827      0.073      6.645      0.000       0.339       0.627
# hml           -0.2818      0.073     -3.874      0.000      -0.426      -0.138
# umd           -0.1532      0.045     -3.415      0.001      -0.242      -0.064
# ==============================================================================
# Omnibus:                       44.003   Durbin-Watson:                   2.078
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              164.039
# Skew:                           1.231   Prob(JB):                     2.40e-36
# Kurtosis:                       8.172   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.616
# Model:                            OLS   Adj. R-squared:                  0.603
# Method:                 Least Squares   F-statistic:                     20.53
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           8.75e-13
# Time:                        14:23:25   Log-Likelihood:                 260.93
# No. Observations:                 120   AIC:                            -511.9
# Df Residuals:                     115   BIC:                            -497.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       9.754e-06      0.003      0.004      0.997      -0.005       0.005
# mktrf          0.3048      0.065      4.718      0.000       0.178       0.431
# smb            0.4827      0.097      4.955      0.000       0.292       0.674
# hml           -0.2818      0.077     -3.654      0.000      -0.433      -0.131
# umd           -0.1532      0.074     -2.068      0.039      -0.298      -0.008
# ==============================================================================
# Omnibus:                       44.003   Durbin-Watson:                   2.078
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              164.039
# Skew:                           1.231   Prob(JB):                     2.40e-36
# Kurtosis:                       8.172   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.616
# Model:                            OLS   Adj. R-squared:                  0.603
# Method:                 Least Squares   F-statistic:                     23.75
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           2.48e-14
# Time:                        14:23:25   Log-Likelihood:                 260.93
# No. Observations:                 120   AIC:                            -511.9
# Df Residuals:                     115   BIC:                            -497.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       9.754e-06      0.002      0.004      0.997      -0.005       0.005
# mktrf          0.3048      0.052      5.865      0.000       0.203       0.407
# smb            0.4827      0.089      5.424      0.000       0.308       0.657
# hml           -0.2818      0.062     -4.564      0.000      -0.403      -0.161
# umd           -0.1532      0.075     -2.041      0.041      -0.300      -0.006
# ==============================================================================
# Omnibus:                       44.003   Durbin-Watson:                   2.078
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              164.039
# Skew:                           1.231   Prob(JB):                     2.40e-36
# Kurtosis:                       8.172   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.616
# Model:                            OLS   Adj. R-squared:                  0.603
# Method:                 Least Squares   F-statistic:                     46.20
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           4.31e-23
# Time:                        14:23:25   Log-Likelihood:                 260.93
# No. Observations:                 120   AIC:                            -511.9
# Df Residuals:                     115   BIC:                            -497.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       9.754e-06      0.003      0.004      0.997      -0.005       0.005
# mktrf          0.3048      0.064      4.777      0.000       0.178       0.431
# smb            0.4827      0.073      6.645      0.000       0.339       0.627
# hml           -0.2818      0.073     -3.874      0.000      -0.426      -0.138
# umd           -0.1532      0.045     -3.415      0.001      -0.242      -0.064
# ==============================================================================
# Omnibus:                       44.003   Durbin-Watson:                   2.078
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              164.039
# Skew:                           1.231   Prob(JB):                     2.40e-36
# Kurtosis:                       8.172   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.616
# Model:                            OLS   Adj. R-squared:                  0.603
# Method:                 Least Squares   F-statistic:                     20.53
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           8.75e-13
# Time:                        14:23:25   Log-Likelihood:                 260.93
# No. Observations:                 120   AIC:                            -511.9
# Df Residuals:                     115   BIC:                            -497.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       9.754e-06      0.003      0.004      0.997      -0.005       0.005
# mktrf          0.3048      0.065      4.718      0.000       0.178       0.431
# smb            0.4827      0.097      4.955      0.000       0.292       0.674
# hml           -0.2818      0.077     -3.654      0.000      -0.433      -0.131
# umd           -0.1532      0.074     -2.068      0.039      -0.298      -0.008
# ==============================================================================
# Omnibus:                       44.003   Durbin-Watson:                   2.078
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              164.039
# Skew:                           1.231   Prob(JB):                     2.40e-36
# Kurtosis:                       8.172   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.616
# Model:                            OLS   Adj. R-squared:                  0.603
# Method:                 Least Squares   F-statistic:                     23.75
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           2.48e-14
# Time:                        14:23:25   Log-Likelihood:                 260.93
# No. Observations:                 120   AIC:                            -511.9
# Df Residuals:                     115   BIC:                            -497.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       9.754e-06      0.002      0.004      0.997      -0.005       0.005
# mktrf          0.3048      0.052      5.865      0.000       0.203       0.407
# smb            0.4827      0.089      5.424      0.000       0.308       0.657
# hml           -0.2818      0.062     -4.564      0.000      -0.403      -0.161
# umd           -0.1532      0.075     -2.041      0.041      -0.300      -0.006
# ==============================================================================
# Omnibus:                       44.003   Durbin-Watson:                   2.078
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              164.039
# Skew:                           1.231   Prob(JB):                     2.40e-36
# Kurtosis:                       8.172   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Post-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.544
# Model:                            OLS   Adj. R-squared:                  0.527
# Method:                 Least Squares   F-statistic:                     32.47
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           8.25e-18
# Time:                        14:23:25   Log-Likelihood:                 306.95
# No. Observations:                 114   AIC:                            -603.9
# Df Residuals:                     109   BIC:                            -590.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0017      0.002      1.010      0.315      -0.002       0.005
# mktrf          0.0702      0.049      1.426      0.157      -0.027       0.168
# me             0.1662      0.076      2.185      0.031       0.015       0.317
# ia            -0.0891      0.105     -0.845      0.400      -0.298       0.120
# roe           -0.7775      0.093     -8.388      0.000      -0.961      -0.594
# ==============================================================================
# Omnibus:                       26.079   Durbin-Watson:                   1.848
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               49.878
# Skew:                           0.951   Prob(JB):                     1.48e-11
# Kurtosis:                       5.624   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.544
# Model:                            OLS   Adj. R-squared:                  0.527
# Method:                 Least Squares   F-statistic:                     40.32
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           1.07e-20
# Time:                        14:23:25   Log-Likelihood:                 306.95
# No. Observations:                 114   AIC:                            -603.9
# Df Residuals:                     109   BIC:                            -590.2
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0017      0.001      1.383      0.167      -0.001       0.004
# mktrf          0.0702      0.047      1.487      0.137      -0.022       0.163
# me             0.1662      0.043      3.899      0.000       0.083       0.250
# ia            -0.0891      0.115     -0.776      0.438      -0.314       0.136
# roe           -0.7775      0.113     -6.879      0.000      -0.999      -0.556
# ==============================================================================
# Omnibus:                       26.079   Durbin-Watson:                   1.848
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               49.878
# Skew:                           0.951   Prob(JB):                     1.48e-11
# Kurtosis:                       5.624   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.544
# Model:                            OLS   Adj. R-squared:                  0.527
# Method:                 Least Squares   F-statistic:                     65.62
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           3.76e-28
# Time:                        14:23:25   Log-Likelihood:                 306.95
# No. Observations:                 114   AIC:                            -603.9
# Df Residuals:                     109   BIC:                            -590.2
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0017      0.001      1.614      0.107      -0.000       0.004
# mktrf          0.0702      0.041      1.715      0.086      -0.010       0.150
# me             0.1662      0.040      4.193      0.000       0.089       0.244
# ia            -0.0891      0.117     -0.765      0.444      -0.317       0.139
# roe           -0.7775      0.099     -7.864      0.000      -0.971      -0.584
# ==============================================================================
# Omnibus:                       26.079   Durbin-Watson:                   1.848
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               49.878
# Skew:                           0.951   Prob(JB):                     1.48e-11
# Kurtosis:                       5.624   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.332
# Model:                            OLS   Adj. R-squared:                  0.308
# Method:                 Least Squares   F-statistic:                     13.57
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           5.18e-09
# Time:                        14:23:25   Log-Likelihood:                 285.27
# No. Observations:                 114   AIC:                            -560.5
# Df Residuals:                     109   BIC:                            -546.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        3.47e-06      0.002      0.002      0.999      -0.004       0.004
# mktrf          0.1263      0.056      2.238      0.027       0.014       0.238
# smb            0.3628      0.088      4.121      0.000       0.188       0.537
# hml            0.0605      0.091      0.668      0.506      -0.119       0.240
# umd           -0.2075      0.068     -3.034      0.003      -0.343      -0.072
# ==============================================================================
# Omnibus:                       23.767   Durbin-Watson:                   1.758
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               42.621
# Skew:                           0.895   Prob(JB):                     5.56e-10
# Kurtosis:                       5.402   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.332
# Model:                            OLS   Adj. R-squared:                  0.308
# Method:                 Least Squares   F-statistic:                     14.04
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           2.84e-09
# Time:                        14:23:25   Log-Likelihood:                 285.27
# No. Observations:                 114   AIC:                            -560.5
# Df Residuals:                     109   BIC:                            -546.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        3.47e-06      0.001      0.002      0.998      -0.003       0.003
# mktrf          0.1263      0.064      1.978      0.048       0.001       0.251
# smb            0.3628      0.070      5.164      0.000       0.225       0.500
# hml            0.0605      0.160      0.379      0.705      -0.253       0.374
# umd           -0.2075      0.071     -2.925      0.003      -0.347      -0.068
# ==============================================================================
# Omnibus:                       23.767   Durbin-Watson:                   1.758
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               42.621
# Skew:                           0.895   Prob(JB):                     5.56e-10
# Kurtosis:                       5.402   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.332
# Model:                            OLS   Adj. R-squared:                  0.308
# Method:                 Least Squares   F-statistic:                     20.94
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           7.88e-13
# Time:                        14:23:25   Log-Likelihood:                 285.27
# No. Observations:                 114   AIC:                            -560.5
# Df Residuals:                     109   BIC:                            -546.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        3.47e-06      0.001      0.003      0.998      -0.002       0.002
# mktrf          0.1263      0.063      2.012      0.044       0.003       0.249
# smb            0.3628      0.053      6.792      0.000       0.258       0.467
# hml            0.0605      0.168      0.361      0.718      -0.268       0.389
# umd           -0.2075      0.065     -3.173      0.002      -0.336      -0.079
# ==============================================================================
# Omnibus:                       23.767   Durbin-Watson:                   1.758
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               42.621
# Skew:                           0.895   Prob(JB):                     5.56e-10
# Kurtosis:                       5.402   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.332
# Model:                            OLS   Adj. R-squared:                  0.308
# Method:                 Least Squares   F-statistic:                     13.57
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           5.18e-09
# Time:                        14:23:25   Log-Likelihood:                 285.27
# No. Observations:                 114   AIC:                            -560.5
# Df Residuals:                     109   BIC:                            -546.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        3.47e-06      0.002      0.002      0.999      -0.004       0.004
# mktrf          0.1263      0.056      2.238      0.027       0.014       0.238
# smb            0.3628      0.088      4.121      0.000       0.188       0.537
# hml            0.0605      0.091      0.668      0.506      -0.119       0.240
# umd           -0.2075      0.068     -3.034      0.003      -0.343      -0.072
# ==============================================================================
# Omnibus:                       23.767   Durbin-Watson:                   1.758
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               42.621
# Skew:                           0.895   Prob(JB):                     5.56e-10
# Kurtosis:                       5.402   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.332
# Model:                            OLS   Adj. R-squared:                  0.308
# Method:                 Least Squares   F-statistic:                     14.04
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           2.84e-09
# Time:                        14:23:25   Log-Likelihood:                 285.27
# No. Observations:                 114   AIC:                            -560.5
# Df Residuals:                     109   BIC:                            -546.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        3.47e-06      0.001      0.002      0.998      -0.003       0.003
# mktrf          0.1263      0.064      1.978      0.048       0.001       0.251
# smb            0.3628      0.070      5.164      0.000       0.225       0.500
# hml            0.0605      0.160      0.379      0.705      -0.253       0.374
# umd           -0.2075      0.071     -2.925      0.003      -0.347      -0.068
# ==============================================================================
# Omnibus:                       23.767   Durbin-Watson:                   1.758
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               42.621
# Skew:                           0.895   Prob(JB):                     5.56e-10
# Kurtosis:                       5.402   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.332
# Model:                            OLS   Adj. R-squared:                  0.308
# Method:                 Least Squares   F-statistic:                     20.94
# Date:                Fri, 24 Apr 2020   Prob (F-statistic):           7.88e-13
# Time:                        14:23:25   Log-Likelihood:                 285.27
# No. Observations:                 114   AIC:                            -560.5
# Df Residuals:                     109   BIC:                            -546.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        3.47e-06      0.001      0.003      0.998      -0.002       0.002
# mktrf          0.1263      0.063      2.012      0.044       0.003       0.249
# smb            0.3628      0.053      6.792      0.000       0.258       0.467
# hml            0.0605      0.168      0.361      0.718      -0.268       0.389
# umd           -0.2075      0.065     -3.173      0.002      -0.336      -0.079
# ==============================================================================
# Omnibus:                       23.767   Durbin-Watson:                   1.758
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               42.621
# Skew:                           0.895   Prob(JB):                     5.56e-10
# Kurtosis:                       5.402   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """
