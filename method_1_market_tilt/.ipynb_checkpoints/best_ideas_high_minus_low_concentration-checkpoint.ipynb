# %% [markdown]
# # Method 1 - Best Ideas High Minus Low Concentration

# %%
# %matplotlib inline
import pandas as pd
import warnings
from statsmodels import api as sm

from eptooling import crsp, epd, fs, hfu, crsp, db, bi
from eptooling.bm import bmdb, iso
from epquant.engine import weights, portfolio
from epquant.gen import returns
from epquant.perf import relative_performance

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Fetch Holdings and Benchmark Data

# %%
# Get HFU Data

# %store -r inst_data
inst_data = inst_data[inst_data['datadate'] >= '1999-06-30']

# Herfindahl

inst_data['target_sq'] = inst_data['target'] ** 2
herf = inst_data.groupby(['datadate', 'institution_id'])['target_sq'].sum().rename('herf').reset_index()

# Count number of positions per manager

inst_data['num_pos'] = inst_data.groupby(['datadate', 'institution_id'])[
    'fsym_id'].transform(lambda s: s.nunique())

# Remove less than 20 holdings and less than $5mm per CSP

valid_data = inst_data[inst_data['num_pos'] >= 20]
valid_data = valid_data[valid_data['public_aum'] >= 5e6]

# Get Benchmark Weights

bm = crsp.get_crsp_market_portfolio()

# Merge Benchmark Weights onto Holdings

valid_data = valid_data.merge(bm, how='left', on=['datadate', 'fsym_id'])

# Market Tilt

valid_data['adj_target'] = valid_data['target'] - valid_data['weight'].fillna(0)

# %% [markdown]
# ## Calculate Best Ideas

# %%
# Extract Best Ideas

valid_data['pos_rank'] = valid_data\
    .groupby(['datadate', 'institution_id'])['adj_target'].rank(ascending=False)

best_ideas = valid_data[valid_data['pos_rank'] == 1].copy()

# Add Herf

best_ideas = best_ideas.merge(herf)
best_ideas['herf_pct'] = best_ideas.groupby('datadate')['herf'].rank(pct=True)
low_ideas = best_ideas[best_ideas['herf_pct'] < (1 / 3)]
high_ideas = best_ideas[best_ideas['herf_pct'] > (2 / 3)]

# Weight the best ideas equally

low_ideas['target'] = 1 / low_ideas.groupby('datadate')['institution_id'].transform('count')
high_ideas['target'] = 1 / high_ideas.groupby('datadate')['institution_id'].transform('count')

# %% [markdown]
# ## Backtest Portfolio

# %%
low_w = weights.Weights(low_ideas)
high_w = weights.Weights(high_ideas)

# %store -r r

low_p = portfolio.DailyPortfolio(low_w, r, end_date='2018-12-31')
high_p = portfolio.DailyPortfolio(high_w, r, end_date='2018-12-31')

monthly_return = (high_p.port_return - low_p.port_return).loc['1999-07-01':].resample('M').apply(epd.prod_red)
monthly_return.name = 'port_return'

# %% [markdown]
# ## Plot Performance

# %%
epd.nav(monthly_return).plot()

# %%
monthly_return.resample('A').apply(epd.prod_red)
# Out:
# datadate
# 1999-12-31   -0.116788
# 2000-12-31    0.174067
# 2001-12-31    0.128946
# 2002-12-31   -0.027983
# 2003-12-31   -0.008664
# 2004-12-31    0.100415
# 2005-12-31    0.085107
# 2006-12-31    0.076228
# 2007-12-31   -0.018167
# 2008-12-31    0.007410
# 2009-12-31    0.001659
# 2010-12-31   -0.008091
# 2011-12-31    0.031135
# 2012-12-31    0.044033
# 2013-12-31    0.035018
# 2014-12-31   -0.000054
# 2015-12-31    0.011865
# 2016-12-31   -0.031409
# 2017-12-31    0.057850
# 2018-12-31    0.071199
# Freq: A-DEC, Name: port_return, dtype: float64

# %% [markdown]
# ## Fetch Factor Models

# %%
# Get Factor Models
q_factor_model = bi.get_q_factor_model()
fama_french_five_factor_model = bi.get_fama_french_five_factor_model()
four_factor_model = bi.get_four_factor_model()

# Concat Portfolio Return
q_factor = pd.concat([monthly_return, q_factor_model], axis=1)
fama_french_five = pd.concat([monthly_return, fama_french_five_factor_model], axis=1)
four_factor = pd.concat([monthly_return, four_factor_model], axis=1)

# Add Constants
q_factor.insert(1, 'const', 1)
fama_french_five.insert(1, 'const', 1)
four_factor.insert(1, 'const', 1)

# Split Period into Pre and Post Crisis
q_factor_pre, q_factor_post = q_factor.loc[:'2009-06-30'], q_factor.loc['2009-07-31':]
fama_french_five_pre, fama_french_five_post = fama_french_five.loc[:'2009-06-30'], fama_french_five.loc['2009-07-31':] 
four_factor_pre, four_factor_post = four_factor.loc[:'2009-06-30'], four_factor.loc['2009-07-31':]

# %% [markdown]
# ## Full Time Period Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.070
# Model:                            OLS   Adj. R-squared:                  0.054
# Method:                 Least Squares   F-statistic:                     4.302
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):            0.00224
# Time:                        12:16:19   Log-Likelihood:                 659.44
# No. Observations:                 234   AIC:                            -1309.
# Df Residuals:                     229   BIC:                            -1292.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0033      0.001      3.270      0.001       0.001       0.005
# mktrf         -0.0942      0.027     -3.459      0.001      -0.148      -0.041
# me             0.0341      0.032      1.077      0.283      -0.028       0.097
# ia             0.0037      0.048      0.076      0.939      -0.091       0.099
# roe           -0.1325      0.041     -3.214      0.001      -0.214      -0.051
# ==============================================================================
# Omnibus:                        5.393   Durbin-Watson:                   1.825
# Prob(Omnibus):                  0.067   Jarque-Bera (JB):                7.664
# Skew:                          -0.058   Prob(JB):                       0.0217
# Kurtosis:                       3.879   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.070
# Model:                            OLS   Adj. R-squared:                  0.054
# Method:                 Least Squares   F-statistic:                     2.180
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):             0.0720
# Time:                        12:16:19   Log-Likelihood:                 659.44
# No. Observations:                 234   AIC:                            -1309.
# Df Residuals:                     229   BIC:                            -1292.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0033      0.001      2.926      0.003       0.001       0.005
# mktrf         -0.0942      0.036     -2.626      0.009      -0.165      -0.024
# me             0.0341      0.033      1.033      0.301      -0.031       0.099
# ia             0.0037      0.060      0.061      0.951      -0.113       0.120
# roe           -0.1325      0.060     -2.206      0.027      -0.250      -0.015
# ==============================================================================
# Omnibus:                        5.393   Durbin-Watson:                   1.825
# Prob(Omnibus):                  0.067   Jarque-Bera (JB):                7.664
# Skew:                          -0.058   Prob(JB):                       0.0217
# Kurtosis:                       3.879   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.070
# Model:                            OLS   Adj. R-squared:                  0.054
# Method:                 Least Squares   F-statistic:                     3.577
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):            0.00749
# Time:                        12:16:19   Log-Likelihood:                 659.44
# No. Observations:                 234   AIC:                            -1309.
# Df Residuals:                     229   BIC:                            -1292.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0033      0.001      3.095      0.002       0.001       0.005
# mktrf         -0.0942      0.033     -2.815      0.005      -0.160      -0.029
# me             0.0341      0.036      0.953      0.341      -0.036       0.104
# ia             0.0037      0.063      0.058      0.954      -0.120       0.127
# roe           -0.1325      0.051     -2.602      0.009      -0.232      -0.033
# ==============================================================================
# Omnibus:                        5.393   Durbin-Watson:                   1.825
# Prob(Omnibus):                  0.067   Jarque-Bera (JB):                7.664
# Skew:                          -0.058   Prob(JB):                       0.0217
# Kurtosis:                       3.879   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.051
# Model:                            OLS   Adj. R-squared:                  0.035
# Method:                 Least Squares   F-statistic:                     3.090
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):             0.0167
# Time:                        12:16:19   Log-Likelihood:                 657.11
# No. Observations:                 234   AIC:                            -1304.
# Df Residuals:                     229   BIC:                            -1287.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0029      0.001      2.983      0.003       0.001       0.005
# mktrf         -0.0698      0.025     -2.754      0.006      -0.120      -0.020
# smb            0.0709      0.032      2.243      0.026       0.009       0.133
# hml           -0.0178      0.031     -0.567      0.571      -0.080       0.044
# umd           -0.0561      0.021     -2.720      0.007      -0.097      -0.015
# ==============================================================================
# Omnibus:                        5.009   Durbin-Watson:                   1.835
# Prob(Omnibus):                  0.082   Jarque-Bera (JB):                6.743
# Skew:                          -0.076   Prob(JB):                       0.0343
# Kurtosis:                       3.817   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.051
# Model:                            OLS   Adj. R-squared:                  0.035
# Method:                 Least Squares   F-statistic:                     1.651
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):              0.162
# Time:                        12:16:19   Log-Likelihood:                 657.11
# No. Observations:                 234   AIC:                            -1304.
# Df Residuals:                     229   BIC:                            -1287.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0029      0.001      2.844      0.004       0.001       0.005
# mktrf         -0.0698      0.034     -2.064      0.039      -0.136      -0.004
# smb            0.0709      0.051      1.382      0.167      -0.030       0.172
# hml           -0.0178      0.031     -0.575      0.565      -0.079       0.043
# umd           -0.0561      0.034     -1.654      0.098      -0.123       0.010
# ==============================================================================
# Omnibus:                        5.009   Durbin-Watson:                   1.835
# Prob(Omnibus):                  0.082   Jarque-Bera (JB):                6.743
# Skew:                          -0.076   Prob(JB):                       0.0343
# Kurtosis:                       3.817   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.051
# Model:                            OLS   Adj. R-squared:                  0.035
# Method:                 Least Squares   F-statistic:                     2.407
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):             0.0503
# Time:                        12:16:19   Log-Likelihood:                 657.11
# No. Observations:                 234   AIC:                            -1304.
# Df Residuals:                     229   BIC:                            -1287.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0029      0.001      2.893      0.004       0.001       0.005
# mktrf         -0.0698      0.034     -2.056      0.040      -0.136      -0.003
# smb            0.0709      0.048      1.465      0.143      -0.024       0.166
# hml           -0.0178      0.032     -0.549      0.583      -0.081       0.046
# umd           -0.0561      0.029     -1.924      0.054      -0.113       0.001
# ==============================================================================
# Omnibus:                        5.009   Durbin-Watson:                   1.835
# Prob(Omnibus):                  0.082   Jarque-Bera (JB):                6.743
# Skew:                          -0.076   Prob(JB):                       0.0343
# Kurtosis:                       3.817   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.051
# Model:                            OLS   Adj. R-squared:                  0.035
# Method:                 Least Squares   F-statistic:                     3.090
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):             0.0167
# Time:                        12:16:19   Log-Likelihood:                 657.11
# No. Observations:                 234   AIC:                            -1304.
# Df Residuals:                     229   BIC:                            -1287.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0029      0.001      2.983      0.003       0.001       0.005
# mktrf         -0.0698      0.025     -2.754      0.006      -0.120      -0.020
# smb            0.0709      0.032      2.243      0.026       0.009       0.133
# hml           -0.0178      0.031     -0.567      0.571      -0.080       0.044
# umd           -0.0561      0.021     -2.720      0.007      -0.097      -0.015
# ==============================================================================
# Omnibus:                        5.009   Durbin-Watson:                   1.835
# Prob(Omnibus):                  0.082   Jarque-Bera (JB):                6.743
# Skew:                          -0.076   Prob(JB):                       0.0343
# Kurtosis:                       3.817   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.051
# Model:                            OLS   Adj. R-squared:                  0.035
# Method:                 Least Squares   F-statistic:                     1.651
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):              0.162
# Time:                        12:16:19   Log-Likelihood:                 657.11
# No. Observations:                 234   AIC:                            -1304.
# Df Residuals:                     229   BIC:                            -1287.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0029      0.001      2.844      0.004       0.001       0.005
# mktrf         -0.0698      0.034     -2.064      0.039      -0.136      -0.004
# smb            0.0709      0.051      1.382      0.167      -0.030       0.172
# hml           -0.0178      0.031     -0.575      0.565      -0.079       0.043
# umd           -0.0561      0.034     -1.654      0.098      -0.123       0.010
# ==============================================================================
# Omnibus:                        5.009   Durbin-Watson:                   1.835
# Prob(Omnibus):                  0.082   Jarque-Bera (JB):                6.743
# Skew:                          -0.076   Prob(JB):                       0.0343
# Kurtosis:                       3.817   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.051
# Model:                            OLS   Adj. R-squared:                  0.035
# Method:                 Least Squares   F-statistic:                     2.407
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):             0.0503
# Time:                        12:16:19   Log-Likelihood:                 657.11
# No. Observations:                 234   AIC:                            -1304.
# Df Residuals:                     229   BIC:                            -1287.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0029      0.001      2.893      0.004       0.001       0.005
# mktrf         -0.0698      0.034     -2.056      0.040      -0.136      -0.003
# smb            0.0709      0.048      1.465      0.143      -0.024       0.166
# hml           -0.0178      0.032     -0.549      0.583      -0.081       0.046
# umd           -0.0561      0.029     -1.924      0.054      -0.113       0.001
# ==============================================================================
# Omnibus:                        5.009   Durbin-Watson:                   1.835
# Prob(Omnibus):                  0.082   Jarque-Bera (JB):                6.743
# Skew:                          -0.076   Prob(JB):                       0.0343
# Kurtosis:                       3.817   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Pre-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.073
# Model:                            OLS   Adj. R-squared:                  0.041
# Method:                 Least Squares   F-statistic:                     2.269
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):             0.0660
# Time:                        12:16:19   Log-Likelihood:                 315.55
# No. Observations:                 120   AIC:                            -621.1
# Df Residuals:                     115   BIC:                            -607.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0033      0.002      1.949      0.054   -5.47e-05       0.007
# mktrf         -0.0952      0.046     -2.073      0.040      -0.186      -0.004
# me             0.0279      0.045      0.616      0.539      -0.062       0.118
# ia             0.0800      0.071      1.126      0.263      -0.061       0.221
# roe           -0.1546      0.063     -2.458      0.015      -0.279      -0.030
# ==============================================================================
# Omnibus:                        0.408   Durbin-Watson:                   1.751
# Prob(Omnibus):                  0.815   Jarque-Bera (JB):                0.117
# Skew:                          -0.015   Prob(JB):                        0.943
# Kurtosis:                       3.150   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.073
# Model:                            OLS   Adj. R-squared:                  0.041
# Method:                 Least Squares   F-statistic:                    0.8877
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):              0.474
# Time:                        12:16:19   Log-Likelihood:                 315.55
# No. Observations:                 120   AIC:                            -621.1
# Df Residuals:                     115   BIC:                            -607.2
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0033      0.002      1.787      0.074      -0.000       0.007
# mktrf         -0.0952      0.059     -1.621      0.105      -0.210       0.020
# me             0.0279      0.042      0.661      0.509      -0.055       0.111
# ia             0.0800      0.077      1.044      0.296      -0.070       0.230
# roe           -0.1546      0.084     -1.840      0.066      -0.319       0.010
# ==============================================================================
# Omnibus:                        0.408   Durbin-Watson:                   1.751
# Prob(Omnibus):                  0.815   Jarque-Bera (JB):                0.117
# Skew:                          -0.015   Prob(JB):                        0.943
# Kurtosis:                       3.150   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.073
# Model:                            OLS   Adj. R-squared:                  0.041
# Method:                 Least Squares   F-statistic:                     1.477
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):              0.214
# Time:                        12:16:19   Log-Likelihood:                 315.55
# No. Observations:                 120   AIC:                            -621.1
# Df Residuals:                     115   BIC:                            -607.2
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0033      0.002      1.844      0.065      -0.000       0.007
# mktrf         -0.0952      0.052     -1.831      0.067      -0.197       0.007
# me             0.0279      0.046      0.613      0.540      -0.061       0.117
# ia             0.0800      0.077      1.042      0.298      -0.071       0.230
# roe           -0.1546      0.067     -2.294      0.022      -0.287      -0.023
# ==============================================================================
# Omnibus:                        0.408   Durbin-Watson:                   1.751
# Prob(Omnibus):                  0.815   Jarque-Bera (JB):                0.117
# Skew:                          -0.015   Prob(JB):                        0.943
# Kurtosis:                       3.150   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.075
# Model:                            OLS   Adj. R-squared:                  0.043
# Method:                 Least Squares   F-statistic:                     2.339
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):             0.0594
# Time:                        12:16:19   Log-Likelihood:                 315.68
# No. Observations:                 120   AIC:                            -621.4
# Df Residuals:                     115   BIC:                            -607.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0029      0.002      1.766      0.080      -0.000       0.006
# mktrf         -0.0820      0.040     -2.028      0.045      -0.162      -0.002
# smb            0.0922      0.046      2.002      0.048       0.001       0.183
# hml            0.0129      0.046      0.280      0.780      -0.078       0.104
# umd           -0.0771      0.028     -2.712      0.008      -0.133      -0.021
# ==============================================================================
# Omnibus:                        0.849   Durbin-Watson:                   1.752
# Prob(Omnibus):                  0.654   Jarque-Bera (JB):                0.452
# Skew:                          -0.096   Prob(JB):                        0.798
# Kurtosis:                       3.231   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.075
# Model:                            OLS   Adj. R-squared:                  0.043
# Method:                 Least Squares   F-statistic:                     1.219
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):              0.307
# Time:                        12:16:19   Log-Likelihood:                 315.68
# No. Observations:                 120   AIC:                            -621.4
# Df Residuals:                     115   BIC:                            -607.4
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0029      0.002      1.673      0.094      -0.001       0.006
# mktrf         -0.0820      0.047     -1.757      0.079      -0.173       0.009
# smb            0.0922      0.076      1.213      0.225      -0.057       0.241
# hml            0.0129      0.036      0.354      0.723      -0.058       0.084
# umd           -0.0771      0.043     -1.792      0.073      -0.161       0.007
# ==============================================================================
# Omnibus:                        0.849   Durbin-Watson:                   1.752
# Prob(Omnibus):                  0.654   Jarque-Bera (JB):                0.452
# Skew:                          -0.096   Prob(JB):                        0.798
# Kurtosis:                       3.231   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.075
# Model:                            OLS   Adj. R-squared:                  0.043
# Method:                 Least Squares   F-statistic:                     1.832
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):              0.127
# Time:                        12:16:19   Log-Likelihood:                 315.68
# No. Observations:                 120   AIC:                            -621.4
# Df Residuals:                     115   BIC:                            -607.4
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0029      0.002      1.657      0.098      -0.001       0.006
# mktrf         -0.0820      0.043     -1.902      0.057      -0.166       0.002
# smb            0.0922      0.073      1.270      0.204      -0.050       0.234
# hml            0.0129      0.038      0.342      0.732      -0.061       0.087
# umd           -0.0771      0.036     -2.125      0.034      -0.148      -0.006
# ==============================================================================
# Omnibus:                        0.849   Durbin-Watson:                   1.752
# Prob(Omnibus):                  0.654   Jarque-Bera (JB):                0.452
# Skew:                          -0.096   Prob(JB):                        0.798
# Kurtosis:                       3.231   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.075
# Model:                            OLS   Adj. R-squared:                  0.043
# Method:                 Least Squares   F-statistic:                     2.339
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):             0.0594
# Time:                        12:16:19   Log-Likelihood:                 315.68
# No. Observations:                 120   AIC:                            -621.4
# Df Residuals:                     115   BIC:                            -607.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0029      0.002      1.766      0.080      -0.000       0.006
# mktrf         -0.0820      0.040     -2.028      0.045      -0.162      -0.002
# smb            0.0922      0.046      2.002      0.048       0.001       0.183
# hml            0.0129      0.046      0.280      0.780      -0.078       0.104
# umd           -0.0771      0.028     -2.712      0.008      -0.133      -0.021
# ==============================================================================
# Omnibus:                        0.849   Durbin-Watson:                   1.752
# Prob(Omnibus):                  0.654   Jarque-Bera (JB):                0.452
# Skew:                          -0.096   Prob(JB):                        0.798
# Kurtosis:                       3.231   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.075
# Model:                            OLS   Adj. R-squared:                  0.043
# Method:                 Least Squares   F-statistic:                     1.219
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):              0.307
# Time:                        12:16:19   Log-Likelihood:                 315.68
# No. Observations:                 120   AIC:                            -621.4
# Df Residuals:                     115   BIC:                            -607.4
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0029      0.002      1.673      0.094      -0.001       0.006
# mktrf         -0.0820      0.047     -1.757      0.079      -0.173       0.009
# smb            0.0922      0.076      1.213      0.225      -0.057       0.241
# hml            0.0129      0.036      0.354      0.723      -0.058       0.084
# umd           -0.0771      0.043     -1.792      0.073      -0.161       0.007
# ==============================================================================
# Omnibus:                        0.849   Durbin-Watson:                   1.752
# Prob(Omnibus):                  0.654   Jarque-Bera (JB):                0.452
# Skew:                          -0.096   Prob(JB):                        0.798
# Kurtosis:                       3.231   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.075
# Model:                            OLS   Adj. R-squared:                  0.043
# Method:                 Least Squares   F-statistic:                     1.832
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):              0.127
# Time:                        12:16:19   Log-Likelihood:                 315.68
# No. Observations:                 120   AIC:                            -621.4
# Df Residuals:                     115   BIC:                            -607.4
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0029      0.002      1.657      0.098      -0.001       0.006
# mktrf         -0.0820      0.043     -1.902      0.057      -0.166       0.002
# smb            0.0922      0.073      1.270      0.204      -0.050       0.234
# hml            0.0129      0.038      0.342      0.732      -0.061       0.087
# umd           -0.0771      0.036     -2.125      0.034      -0.148      -0.006
# ==============================================================================
# Omnibus:                        0.849   Durbin-Watson:                   1.752
# Prob(Omnibus):                  0.654   Jarque-Bera (JB):                0.452
# Skew:                          -0.096   Prob(JB):                        0.798
# Kurtosis:                       3.231   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Post-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.161
# Model:                            OLS   Adj. R-squared:                  0.130
# Method:                 Least Squares   F-statistic:                     5.233
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           0.000680
# Time:                        12:16:19   Log-Likelihood:                 365.66
# No. Observations:                 114   AIC:                            -721.3
# Df Residuals:                     109   BIC:                            -707.6
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0031      0.001      3.115      0.002       0.001       0.005
# mktrf         -0.0860      0.029     -2.923      0.004      -0.144      -0.028
# me             0.0424      0.045      0.934      0.353      -0.048       0.132
# ia            -0.1955      0.063     -3.101      0.002      -0.320      -0.071
# roe           -0.1419      0.055     -2.562      0.012      -0.252      -0.032
# ==============================================================================
# Omnibus:                        0.868   Durbin-Watson:                   2.050
# Prob(Omnibus):                  0.648   Jarque-Bera (JB):                0.618
# Skew:                          -0.177   Prob(JB):                        0.734
# Kurtosis:                       3.068   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.161
# Model:                            OLS   Adj. R-squared:                  0.130
# Method:                 Least Squares   F-statistic:                     6.885
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           5.59e-05
# Time:                        12:16:19   Log-Likelihood:                 365.66
# No. Observations:                 114   AIC:                            -721.3
# Df Residuals:                     109   BIC:                            -707.6
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0031      0.001      2.425      0.015       0.001       0.006
# mktrf         -0.0860      0.033     -2.619      0.009      -0.150      -0.022
# me             0.0424      0.041      1.044      0.297      -0.037       0.122
# ia            -0.1955      0.070     -2.778      0.005      -0.333      -0.058
# roe           -0.1419      0.051     -2.769      0.006      -0.242      -0.041
# ==============================================================================
# Omnibus:                        0.868   Durbin-Watson:                   2.050
# Prob(Omnibus):                  0.648   Jarque-Bera (JB):                0.618
# Skew:                          -0.177   Prob(JB):                        0.734
# Kurtosis:                       3.068   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.161
# Model:                            OLS   Adj. R-squared:                  0.130
# Method:                 Least Squares   F-statistic:                     14.13
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):           2.55e-09
# Time:                        12:16:19   Log-Likelihood:                 365.66
# No. Observations:                 114   AIC:                            -721.3
# Df Residuals:                     109   BIC:                            -707.6
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0031      0.001      2.316      0.021       0.000       0.006
# mktrf         -0.0860      0.034     -2.567      0.010      -0.152      -0.020
# me             0.0424      0.040      1.066      0.287      -0.036       0.120
# ia            -0.1955      0.069     -2.853      0.004      -0.330      -0.061
# roe           -0.1419      0.054     -2.632      0.008      -0.248      -0.036
# ==============================================================================
# Omnibus:                        0.868   Durbin-Watson:                   2.050
# Prob(Omnibus):                  0.648   Jarque-Bera (JB):                0.618
# Skew:                          -0.177   Prob(JB):                        0.734
# Kurtosis:                       3.068   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.070
# Model:                            OLS   Adj. R-squared:                  0.036
# Method:                 Least Squares   F-statistic:                     2.044
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):             0.0932
# Time:                        12:16:19   Log-Likelihood:                 359.77
# No. Observations:                 114   AIC:                            -709.5
# Df Residuals:                     109   BIC:                            -695.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0023      0.001      2.210      0.029       0.000       0.004
# mktrf         -0.0487      0.029     -1.656      0.101      -0.107       0.010
# smb            0.0692      0.046      1.512      0.134      -0.022       0.160
# hml           -0.0709      0.047     -1.503      0.136      -0.164       0.023
# umd            0.0157      0.036      0.441      0.660      -0.055       0.086
# ==============================================================================
# Omnibus:                        4.246   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.120   Jarque-Bera (JB):                3.665
# Skew:                          -0.355   Prob(JB):                        0.160
# Kurtosis:                       3.518   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.070
# Model:                            OLS   Adj. R-squared:                  0.036
# Method:                 Least Squares   F-statistic:                     2.225
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):             0.0709
# Time:                        12:16:19   Log-Likelihood:                 359.77
# No. Observations:                 114   AIC:                            -709.5
# Df Residuals:                     109   BIC:                            -695.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0023      0.001      1.923      0.054   -4.39e-05       0.005
# mktrf         -0.0487      0.033     -1.467      0.142      -0.114       0.016
# smb            0.0692      0.048      1.428      0.153      -0.026       0.164
# hml           -0.0709      0.045     -1.583      0.113      -0.159       0.017
# umd            0.0157      0.040      0.389      0.697      -0.063       0.095
# ==============================================================================
# Omnibus:                        4.246   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.120   Jarque-Bera (JB):                3.665
# Skew:                          -0.355   Prob(JB):                        0.160
# Kurtosis:                       3.518   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.070
# Model:                            OLS   Adj. R-squared:                  0.036
# Method:                 Least Squares   F-statistic:                     4.595
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):            0.00182
# Time:                        12:16:19   Log-Likelihood:                 359.77
# No. Observations:                 114   AIC:                            -709.5
# Df Residuals:                     109   BIC:                            -695.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0023      0.001      1.957      0.050    -3.2e-06       0.005
# mktrf         -0.0487      0.036     -1.347      0.178      -0.119       0.022
# smb            0.0692      0.048      1.428      0.153      -0.026       0.164
# hml           -0.0709      0.040     -1.792      0.073      -0.148       0.007
# umd            0.0157      0.040      0.387      0.699      -0.064       0.095
# ==============================================================================
# Omnibus:                        4.246   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.120   Jarque-Bera (JB):                3.665
# Skew:                          -0.355   Prob(JB):                        0.160
# Kurtosis:                       3.518   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.070
# Model:                            OLS   Adj. R-squared:                  0.036
# Method:                 Least Squares   F-statistic:                     2.044
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):             0.0932
# Time:                        12:16:19   Log-Likelihood:                 359.77
# No. Observations:                 114   AIC:                            -709.5
# Df Residuals:                     109   BIC:                            -695.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0023      0.001      2.210      0.029       0.000       0.004
# mktrf         -0.0487      0.029     -1.656      0.101      -0.107       0.010
# smb            0.0692      0.046      1.512      0.134      -0.022       0.160
# hml           -0.0709      0.047     -1.503      0.136      -0.164       0.023
# umd            0.0157      0.036      0.441      0.660      -0.055       0.086
# ==============================================================================
# Omnibus:                        4.246   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.120   Jarque-Bera (JB):                3.665
# Skew:                          -0.355   Prob(JB):                        0.160
# Kurtosis:                       3.518   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.070
# Model:                            OLS   Adj. R-squared:                  0.036
# Method:                 Least Squares   F-statistic:                     2.225
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):             0.0709
# Time:                        12:16:19   Log-Likelihood:                 359.77
# No. Observations:                 114   AIC:                            -709.5
# Df Residuals:                     109   BIC:                            -695.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0023      0.001      1.923      0.054   -4.39e-05       0.005
# mktrf         -0.0487      0.033     -1.467      0.142      -0.114       0.016
# smb            0.0692      0.048      1.428      0.153      -0.026       0.164
# hml           -0.0709      0.045     -1.583      0.113      -0.159       0.017
# umd            0.0157      0.040      0.389      0.697      -0.063       0.095
# ==============================================================================
# Omnibus:                        4.246   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.120   Jarque-Bera (JB):                3.665
# Skew:                          -0.355   Prob(JB):                        0.160
# Kurtosis:                       3.518   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.070
# Model:                            OLS   Adj. R-squared:                  0.036
# Method:                 Least Squares   F-statistic:                     4.595
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):            0.00182
# Time:                        12:16:20   Log-Likelihood:                 359.77
# No. Observations:                 114   AIC:                            -709.5
# Df Residuals:                     109   BIC:                            -695.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0023      0.001      1.957      0.050    -3.2e-06       0.005
# mktrf         -0.0487      0.036     -1.347      0.178      -0.119       0.022
# smb            0.0692      0.048      1.428      0.153      -0.026       0.164
# hml           -0.0709      0.040     -1.792      0.073      -0.148       0.007
# umd            0.0157      0.040      0.387      0.699      -0.064       0.095
# ==============================================================================
# Omnibus:                        4.246   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.120   Jarque-Bera (JB):                3.665
# Skew:                          -0.355   Prob(JB):                        0.160
# Kurtosis:                       3.518   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """
