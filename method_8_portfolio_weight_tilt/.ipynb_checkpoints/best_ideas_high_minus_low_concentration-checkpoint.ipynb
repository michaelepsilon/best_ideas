# %% [markdown]
# # Method 8 - Best Ideas High Minus Low Concentration

# %%
# %matplotlib inline
import pandas as pd
import warnings
from statsmodels import api as sm

from eptooling import crsp, epd, fs, hfu, crsp, db, bi
from eptooling.bm import bmdb, iso
from epquant.engine import weights, portfolio
from epquant.gen import returns
from epquant.perf import relative_performance

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Fetch Holdings and Benchmark Data

# %%
# Get HFU Data

# %store -r inst_data
inst_data = inst_data[inst_data['datadate'] >= '1999-06-30']

# Herfindahl

inst_data['target_sq'] = inst_data['target'] ** 2
herf = inst_data.groupby(['datadate', 'institution_id'])['target_sq'].sum().rename('herf').reset_index()

# Count number of positions per manager

inst_data['num_pos'] = inst_data.groupby(['datadate', 'institution_id'])[
    'fsym_id'].transform(lambda s: s.nunique())

# Remove less than 20 holdings and less than $5mm per CSP

valid_data = inst_data[inst_data['num_pos'] >= 20]
valid_data = valid_data[valid_data['public_aum'] >= 5e6]

# Use Raw Weight

valid_data['adj_target'] = valid_data['target']

# %% [markdown]
# ## Calculate Best Ideas

# %%
# Extract Best Ideas

valid_data['pos_rank'] = valid_data\
    .groupby(['datadate', 'institution_id'])['adj_target'].rank(ascending=False)

best_ideas = valid_data[valid_data['pos_rank'] == 1].copy()

# Add Herf

best_ideas = best_ideas.merge(herf)
best_ideas['herf_pct'] = best_ideas.groupby('datadate')['herf'].rank(pct=True)
low_ideas = best_ideas[best_ideas['herf_pct'] < (1 / 3)]
high_ideas = best_ideas[best_ideas['herf_pct'] > (2 / 3)]

# Weight the best ideas equally

low_ideas['target'] = 1 / low_ideas.groupby('datadate')['institution_id'].transform('count')
high_ideas['target'] = 1 / high_ideas.groupby('datadate')['institution_id'].transform('count')

# %% [markdown]
# ## Backtest Portfolio

# %%
low_w = weights.Weights(low_ideas)
high_w = weights.Weights(high_ideas)

# %store -r r

low_p = portfolio.DailyPortfolio(low_w, r, end_date='2018-12-31')
high_p = portfolio.DailyPortfolio(high_w, r, end_date='2018-12-31')

monthly_return = (high_p.port_return - low_p.port_return).loc['1999-07-01':].resample('M').apply(epd.prod_red)
monthly_return.name = 'port_return'

# %% [markdown]
# ## Plot Performance

# %%
epd.nav(monthly_return).plot()

# %%
monthly_return.resample('A').apply(epd.prod_red)
# Out:
# datadate
# 1999-12-31    0.034953
# 2000-12-31    0.422380
# 2001-12-31    0.328539
# 2002-12-31   -0.003895
# 2003-12-31    0.004109
# 2004-12-31    0.099200
# 2005-12-31    0.004477
# 2006-12-31    0.120437
# 2007-12-31   -0.010688
# 2008-12-31    0.132123
# 2009-12-31   -0.178475
# 2010-12-31    0.015343
# 2011-12-31    0.124772
# 2012-12-31   -0.075192
# 2013-12-31    0.035456
# 2014-12-31   -0.031176
# 2015-12-31    0.099174
# 2016-12-31    0.015016
# 2017-12-31    0.035908
# 2018-12-31    0.031400
# Freq: A-DEC, Name: port_return, dtype: float64

# %% [markdown]
# ## Fetch Factor Models

# %%
# Get Factor Models
q_factor_model = bi.get_q_factor_model()
fama_french_five_factor_model = bi.get_fama_french_five_factor_model()
four_factor_model = bi.get_four_factor_model()

# Concat Portfolio Return
q_factor = pd.concat([monthly_return, q_factor_model], axis=1)
fama_french_five = pd.concat([monthly_return, fama_french_five_factor_model], axis=1)
four_factor = pd.concat([monthly_return, four_factor_model], axis=1)

# Add Constants
q_factor.insert(1, 'const', 1)
fama_french_five.insert(1, 'const', 1)
four_factor.insert(1, 'const', 1)

# Split Period into Pre and Post Crisis
q_factor_pre, q_factor_post = q_factor.loc[:'2009-06-30'], q_factor.loc['2009-07-31':]
fama_french_five_pre, fama_french_five_post = fama_french_five.loc[:'2009-06-30'], fama_french_five.loc['2009-07-31':] 
four_factor_pre, four_factor_post = four_factor.loc[:'2009-06-30'], four_factor.loc['2009-07-31':]

# %% [markdown]
# ## Full Time Period Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.194
# Model:                            OLS   Adj. R-squared:                  0.180
# Method:                 Least Squares   F-statistic:                     13.77
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           4.42e-10
# Time:                        13:05:17   Log-Likelihood:                 535.18
# No. Observations:                 234   AIC:                            -1060.
# Df Residuals:                     229   BIC:                            -1043.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0043      0.002      2.532      0.012       0.001       0.008
# mktrf         -0.1827      0.046     -3.943      0.000      -0.274      -0.091
# me             0.1107      0.054      2.053      0.041       0.004       0.217
# ia             0.2981      0.082      3.639      0.000       0.137       0.459
# roe            0.0587      0.070      0.837      0.404      -0.079       0.197
# ==============================================================================
# Omnibus:                        2.912   Durbin-Watson:                   1.916
# Prob(Omnibus):                  0.233   Jarque-Bera (JB):                3.043
# Skew:                           0.076   Prob(JB):                        0.218
# Kurtosis:                       3.538   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.194
# Model:                            OLS   Adj. R-squared:                  0.180
# Method:                 Least Squares   F-statistic:                     5.315
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           0.000413
# Time:                        13:05:17   Log-Likelihood:                 535.18
# No. Observations:                 234   AIC:                            -1060.
# Df Residuals:                     229   BIC:                            -1043.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0043      0.002      2.539      0.011       0.001       0.008
# mktrf         -0.1827      0.053     -3.447      0.001      -0.287      -0.079
# me             0.1107      0.047      2.376      0.018       0.019       0.202
# ia             0.2981      0.123      2.414      0.016       0.056       0.540
# roe            0.0587      0.105      0.558      0.577      -0.147       0.265
# ==============================================================================
# Omnibus:                        2.912   Durbin-Watson:                   1.916
# Prob(Omnibus):                  0.233   Jarque-Bera (JB):                3.043
# Skew:                           0.076   Prob(JB):                        0.218
# Kurtosis:                       3.538   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.194
# Model:                            OLS   Adj. R-squared:                  0.180
# Method:                 Least Squares   F-statistic:                     6.041
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           0.000123
# Time:                        13:05:17   Log-Likelihood:                 535.18
# No. Observations:                 234   AIC:                            -1060.
# Df Residuals:                     229   BIC:                            -1043.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0043      0.002      2.734      0.006       0.001       0.007
# mktrf         -0.1827      0.057     -3.227      0.001      -0.294      -0.072
# me             0.1107      0.044      2.502      0.012       0.024       0.197
# ia             0.2981      0.141      2.120      0.034       0.023       0.574
# roe            0.0587      0.093      0.628      0.530      -0.125       0.242
# ==============================================================================
# Omnibus:                        2.912   Durbin-Watson:                   1.916
# Prob(Omnibus):                  0.233   Jarque-Bera (JB):                3.043
# Skew:                           0.076   Prob(JB):                        0.218
# Kurtosis:                       3.538   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.192
# Model:                            OLS   Adj. R-squared:                  0.178
# Method:                 Least Squares   F-statistic:                     13.61
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           5.66e-10
# Time:                        13:05:17   Log-Likelihood:                 534.92
# No. Observations:                 234   AIC:                            -1060.
# Df Residuals:                     229   BIC:                            -1043.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0047      0.002      2.828      0.005       0.001       0.008
# mktrf         -0.1854      0.043     -4.341      0.000      -0.270      -0.101
# smb            0.0492      0.053      0.923      0.357      -0.056       0.154
# hml            0.2335      0.053      4.409      0.000       0.129       0.338
# umd            0.0620      0.035      1.785      0.076      -0.006       0.130
# ==============================================================================
# Omnibus:                        1.995   Durbin-Watson:                   1.881
# Prob(Omnibus):                  0.369   Jarque-Bera (JB):                1.847
# Skew:                           0.031   Prob(JB):                        0.397
# Kurtosis:                       3.431   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.192
# Model:                            OLS   Adj. R-squared:                  0.178
# Method:                 Least Squares   F-statistic:                     6.074
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           0.000116
# Time:                        13:05:17   Log-Likelihood:                 534.92
# No. Observations:                 234   AIC:                            -1060.
# Df Residuals:                     229   BIC:                            -1043.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0047      0.001      3.201      0.001       0.002       0.008
# mktrf         -0.1854      0.050     -3.699      0.000      -0.284      -0.087
# smb            0.0492      0.056      0.886      0.376      -0.060       0.158
# hml            0.2335      0.085      2.762      0.006       0.068       0.399
# umd            0.0620      0.054      1.148      0.251      -0.044       0.168
# ==============================================================================
# Omnibus:                        1.995   Durbin-Watson:                   1.881
# Prob(Omnibus):                  0.369   Jarque-Bera (JB):                1.847
# Skew:                           0.031   Prob(JB):                        0.397
# Kurtosis:                       3.431   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.192
# Model:                            OLS   Adj. R-squared:                  0.178
# Method:                 Least Squares   F-statistic:                     5.762
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           0.000195
# Time:                        13:05:17   Log-Likelihood:                 534.92
# No. Observations:                 234   AIC:                            -1060.
# Df Residuals:                     229   BIC:                            -1043.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0047      0.001      3.623      0.000       0.002       0.007
# mktrf         -0.1854      0.056     -3.297      0.001      -0.296      -0.075
# smb            0.0492      0.052      0.945      0.345      -0.053       0.151
# hml            0.2335      0.087      2.672      0.008       0.062       0.405
# umd            0.0620      0.052      1.200      0.230      -0.039       0.163
# ==============================================================================
# Omnibus:                        1.995   Durbin-Watson:                   1.881
# Prob(Omnibus):                  0.369   Jarque-Bera (JB):                1.847
# Skew:                           0.031   Prob(JB):                        0.397
# Kurtosis:                       3.431   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.192
# Model:                            OLS   Adj. R-squared:                  0.178
# Method:                 Least Squares   F-statistic:                     13.61
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           5.66e-10
# Time:                        13:05:17   Log-Likelihood:                 534.92
# No. Observations:                 234   AIC:                            -1060.
# Df Residuals:                     229   BIC:                            -1043.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0047      0.002      2.828      0.005       0.001       0.008
# mktrf         -0.1854      0.043     -4.341      0.000      -0.270      -0.101
# smb            0.0492      0.053      0.923      0.357      -0.056       0.154
# hml            0.2335      0.053      4.409      0.000       0.129       0.338
# umd            0.0620      0.035      1.785      0.076      -0.006       0.130
# ==============================================================================
# Omnibus:                        1.995   Durbin-Watson:                   1.881
# Prob(Omnibus):                  0.369   Jarque-Bera (JB):                1.847
# Skew:                           0.031   Prob(JB):                        0.397
# Kurtosis:                       3.431   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.192
# Model:                            OLS   Adj. R-squared:                  0.178
# Method:                 Least Squares   F-statistic:                     6.074
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           0.000116
# Time:                        13:05:17   Log-Likelihood:                 534.92
# No. Observations:                 234   AIC:                            -1060.
# Df Residuals:                     229   BIC:                            -1043.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0047      0.001      3.201      0.001       0.002       0.008
# mktrf         -0.1854      0.050     -3.699      0.000      -0.284      -0.087
# smb            0.0492      0.056      0.886      0.376      -0.060       0.158
# hml            0.2335      0.085      2.762      0.006       0.068       0.399
# umd            0.0620      0.054      1.148      0.251      -0.044       0.168
# ==============================================================================
# Omnibus:                        1.995   Durbin-Watson:                   1.881
# Prob(Omnibus):                  0.369   Jarque-Bera (JB):                1.847
# Skew:                           0.031   Prob(JB):                        0.397
# Kurtosis:                       3.431   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.192
# Model:                            OLS   Adj. R-squared:                  0.178
# Method:                 Least Squares   F-statistic:                     5.762
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           0.000195
# Time:                        13:05:17   Log-Likelihood:                 534.92
# No. Observations:                 234   AIC:                            -1060.
# Df Residuals:                     229   BIC:                            -1043.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0047      0.001      3.623      0.000       0.002       0.007
# mktrf         -0.1854      0.056     -3.297      0.001      -0.296      -0.075
# smb            0.0492      0.052      0.945      0.345      -0.053       0.151
# hml            0.2335      0.087      2.672      0.008       0.062       0.405
# umd            0.0620      0.052      1.200      0.230      -0.039       0.163
# ==============================================================================
# Omnibus:                        1.995   Durbin-Watson:                   1.881
# Prob(Omnibus):                  0.369   Jarque-Bera (JB):                1.847
# Skew:                           0.031   Prob(JB):                        0.397
# Kurtosis:                       3.431   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Pre-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.298
# Model:                            OLS   Adj. R-squared:                  0.274
# Method:                 Least Squares   F-statistic:                     12.23
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.57e-08
# Time:                        13:05:17   Log-Likelihood:                 261.42
# No. Observations:                 120   AIC:                            -512.8
# Df Residuals:                     115   BIC:                            -498.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0061      0.003      2.294      0.024       0.001       0.011
# mktrf         -0.2326      0.072     -3.224      0.002      -0.375      -0.090
# me             0.0894      0.071      1.255      0.212      -0.052       0.231
# ia             0.5028      0.112      4.508      0.000       0.282       0.724
# roe           -0.0835      0.099     -0.845      0.400      -0.279       0.112
# ==============================================================================
# Omnibus:                        0.525   Durbin-Watson:                   1.860
# Prob(Omnibus):                  0.769   Jarque-Bera (JB):                0.186
# Skew:                           0.006   Prob(JB):                        0.911
# Kurtosis:                       3.192   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.298
# Model:                            OLS   Adj. R-squared:                  0.274
# Method:                 Least Squares   F-statistic:                     8.204
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           7.41e-06
# Time:                        13:05:17   Log-Likelihood:                 261.42
# No. Observations:                 120   AIC:                            -512.8
# Df Residuals:                     115   BIC:                            -498.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0061      0.003      2.419      0.016       0.001       0.011
# mktrf         -0.2326      0.065     -3.560      0.000      -0.361      -0.105
# me             0.0894      0.053      1.683      0.092      -0.015       0.194
# ia             0.5028      0.135      3.733      0.000       0.239       0.767
# roe           -0.0835      0.132     -0.632      0.527      -0.342       0.175
# ==============================================================================
# Omnibus:                        0.525   Durbin-Watson:                   1.860
# Prob(Omnibus):                  0.769   Jarque-Bera (JB):                0.186
# Skew:                           0.006   Prob(JB):                        0.911
# Kurtosis:                       3.192   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.298
# Model:                            OLS   Adj. R-squared:                  0.274
# Method:                 Least Squares   F-statistic:                     8.904
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.67e-06
# Time:                        13:05:17   Log-Likelihood:                 261.42
# No. Observations:                 120   AIC:                            -512.8
# Df Residuals:                     115   BIC:                            -498.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0061      0.002      2.602      0.009       0.002       0.011
# mktrf         -0.2326      0.059     -3.933      0.000      -0.348      -0.117
# me             0.0894      0.047      1.914      0.056      -0.002       0.181
# ia             0.5028      0.152      3.300      0.001       0.204       0.802
# roe           -0.0835      0.109     -0.767      0.443      -0.297       0.130
# ==============================================================================
# Omnibus:                        0.525   Durbin-Watson:                   1.860
# Prob(Omnibus):                  0.769   Jarque-Bera (JB):                0.186
# Skew:                           0.006   Prob(JB):                        0.911
# Kurtosis:                       3.192   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.276
# Model:                            OLS   Adj. R-squared:                  0.251
# Method:                 Least Squares   F-statistic:                     10.96
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.46e-07
# Time:                        13:05:17   Log-Likelihood:                 259.53
# No. Observations:                 120   AIC:                            -509.1
# Df Residuals:                     115   BIC:                            -495.1
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0058      0.003      2.185      0.031       0.001       0.011
# mktrf         -0.2309      0.065     -3.577      0.001      -0.359      -0.103
# smb            0.1083      0.073      1.474      0.143      -0.037       0.254
# hml            0.3184      0.074      4.325      0.000       0.173       0.464
# umd            0.0254      0.045      0.559      0.577      -0.065       0.115
# ==============================================================================
# Omnibus:                        0.505   Durbin-Watson:                   1.839
# Prob(Omnibus):                  0.777   Jarque-Bera (JB):                0.217
# Skew:                           0.079   Prob(JB):                        0.897
# Kurtosis:                       3.137   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.276
# Model:                            OLS   Adj. R-squared:                  0.251
# Method:                 Least Squares   F-statistic:                     15.20
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           5.26e-10
# Time:                        13:05:17   Log-Likelihood:                 259.53
# No. Observations:                 120   AIC:                            -509.1
# Df Residuals:                     115   BIC:                            -495.1
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0058      0.002      2.930      0.003       0.002       0.010
# mktrf         -0.2309      0.055     -4.166      0.000      -0.340      -0.122
# smb            0.1083      0.070      1.543      0.123      -0.029       0.246
# hml            0.3184      0.086      3.718      0.000       0.151       0.486
# umd            0.0254      0.054      0.468      0.640      -0.081       0.132
# ==============================================================================
# Omnibus:                        0.505   Durbin-Watson:                   1.839
# Prob(Omnibus):                  0.777   Jarque-Bera (JB):                0.217
# Skew:                           0.079   Prob(JB):                        0.897
# Kurtosis:                       3.137   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.276
# Model:                            OLS   Adj. R-squared:                  0.251
# Method:                 Least Squares   F-statistic:                     21.94
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.78e-13
# Time:                        13:05:17   Log-Likelihood:                 259.53
# No. Observations:                 120   AIC:                            -509.1
# Df Residuals:                     115   BIC:                            -495.1
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0058      0.002      3.318      0.001       0.002       0.009
# mktrf         -0.2309      0.052     -4.411      0.000      -0.333      -0.128
# smb            0.1083      0.064      1.686      0.092      -0.018       0.234
# hml            0.3184      0.080      3.988      0.000       0.162       0.475
# umd            0.0254      0.052      0.486      0.627      -0.077       0.128
# ==============================================================================
# Omnibus:                        0.505   Durbin-Watson:                   1.839
# Prob(Omnibus):                  0.777   Jarque-Bera (JB):                0.217
# Skew:                           0.079   Prob(JB):                        0.897
# Kurtosis:                       3.137   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.276
# Model:                            OLS   Adj. R-squared:                  0.251
# Method:                 Least Squares   F-statistic:                     10.96
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.46e-07
# Time:                        13:05:17   Log-Likelihood:                 259.53
# No. Observations:                 120   AIC:                            -509.1
# Df Residuals:                     115   BIC:                            -495.1
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0058      0.003      2.185      0.031       0.001       0.011
# mktrf         -0.2309      0.065     -3.577      0.001      -0.359      -0.103
# smb            0.1083      0.073      1.474      0.143      -0.037       0.254
# hml            0.3184      0.074      4.325      0.000       0.173       0.464
# umd            0.0254      0.045      0.559      0.577      -0.065       0.115
# ==============================================================================
# Omnibus:                        0.505   Durbin-Watson:                   1.839
# Prob(Omnibus):                  0.777   Jarque-Bera (JB):                0.217
# Skew:                           0.079   Prob(JB):                        0.897
# Kurtosis:                       3.137   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.276
# Model:                            OLS   Adj. R-squared:                  0.251
# Method:                 Least Squares   F-statistic:                     15.20
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           5.26e-10
# Time:                        13:05:17   Log-Likelihood:                 259.53
# No. Observations:                 120   AIC:                            -509.1
# Df Residuals:                     115   BIC:                            -495.1
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0058      0.002      2.930      0.003       0.002       0.010
# mktrf         -0.2309      0.055     -4.166      0.000      -0.340      -0.122
# smb            0.1083      0.070      1.543      0.123      -0.029       0.246
# hml            0.3184      0.086      3.718      0.000       0.151       0.486
# umd            0.0254      0.054      0.468      0.640      -0.081       0.132
# ==============================================================================
# Omnibus:                        0.505   Durbin-Watson:                   1.839
# Prob(Omnibus):                  0.777   Jarque-Bera (JB):                0.217
# Skew:                           0.079   Prob(JB):                        0.897
# Kurtosis:                       3.137   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.276
# Model:                            OLS   Adj. R-squared:                  0.251
# Method:                 Least Squares   F-statistic:                     21.94
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.78e-13
# Time:                        13:05:17   Log-Likelihood:                 259.53
# No. Observations:                 120   AIC:                            -509.1
# Df Residuals:                     115   BIC:                            -495.1
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0058      0.002      3.318      0.001       0.002       0.009
# mktrf         -0.2309      0.052     -4.411      0.000      -0.333      -0.128
# smb            0.1083      0.064      1.686      0.092      -0.018       0.234
# hml            0.3184      0.080      3.988      0.000       0.162       0.475
# umd            0.0254      0.052      0.486      0.627      -0.077       0.128
# ==============================================================================
# Omnibus:                        0.505   Durbin-Watson:                   1.839
# Prob(Omnibus):                  0.777   Jarque-Bera (JB):                0.217
# Skew:                           0.079   Prob(JB):                        0.897
# Kurtosis:                       3.137   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Post-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.105
# Model:                            OLS   Adj. R-squared:                  0.072
# Method:                 Least Squares   F-statistic:                     3.206
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):             0.0157
# Time:                        13:05:17   Log-Likelihood:                 293.06
# No. Observations:                 114   AIC:                            -576.1
# Df Residuals:                     109   BIC:                            -562.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0015      0.002      0.777      0.439      -0.002       0.005
# mktrf         -0.0929      0.056     -1.669      0.098      -0.203       0.017
# me             0.0912      0.086      1.061      0.291      -0.079       0.261
# ia            -0.1876      0.119     -1.574      0.118      -0.424       0.049
# roe            0.2225      0.105      2.124      0.036       0.015       0.430
# ==============================================================================
# Omnibus:                        1.712   Durbin-Watson:                   1.962
# Prob(Omnibus):                  0.425   Jarque-Bera (JB):                1.762
# Skew:                          -0.278   Prob(JB):                        0.414
# Kurtosis:                       2.753   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.105
# Model:                            OLS   Adj. R-squared:                  0.072
# Method:                 Least Squares   F-statistic:                     4.627
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):            0.00173
# Time:                        13:05:17   Log-Likelihood:                 293.06
# No. Observations:                 114   AIC:                            -576.1
# Df Residuals:                     109   BIC:                            -562.4
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0015      0.002      0.917      0.359      -0.002       0.005
# mktrf         -0.0929      0.064     -1.451      0.147      -0.218       0.033
# me             0.0912      0.078      1.172      0.241      -0.061       0.244
# ia            -0.1876      0.095     -1.970      0.049      -0.374      -0.001
# roe            0.2225      0.117      1.909      0.056      -0.006       0.451
# ==============================================================================
# Omnibus:                        1.712   Durbin-Watson:                   1.962
# Prob(Omnibus):                  0.425   Jarque-Bera (JB):                1.762
# Skew:                          -0.278   Prob(JB):                        0.414
# Kurtosis:                       2.753   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.105
# Model:                            OLS   Adj. R-squared:                  0.072
# Method:                 Least Squares   F-statistic:                     7.910
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.23e-05
# Time:                        13:05:17   Log-Likelihood:                 293.06
# No. Observations:                 114   AIC:                            -576.1
# Df Residuals:                     109   BIC:                            -562.4
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0015      0.001      1.192      0.233      -0.001       0.004
# mktrf         -0.0929      0.065     -1.433      0.152      -0.220       0.034
# me             0.0912      0.077      1.188      0.235      -0.059       0.242
# ia            -0.1876      0.082     -2.277      0.023      -0.349      -0.026
# roe            0.2225      0.127      1.752      0.080      -0.026       0.471
# ==============================================================================
# Omnibus:                        1.712   Durbin-Watson:                   1.962
# Prob(Omnibus):                  0.425   Jarque-Bera (JB):                1.762
# Skew:                          -0.278   Prob(JB):                        0.414
# Kurtosis:                       2.753   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.067
# Model:                            OLS   Adj. R-squared:                  0.033
# Method:                 Least Squares   F-statistic:                     1.950
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):              0.107
# Time:                        13:05:17   Log-Likelihood:                 290.66
# No. Observations:                 114   AIC:                            -571.3
# Df Residuals:                     109   BIC:                            -557.6
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0014      0.002      0.754      0.452      -0.002       0.005
# mktrf         -0.0753      0.054     -1.399      0.165      -0.182       0.031
# smb           -0.0068      0.084     -0.081      0.935      -0.173       0.160
# hml           -0.0093      0.086     -0.108      0.914      -0.181       0.162
# umd            0.1138      0.065      1.744      0.084      -0.016       0.243
# ==============================================================================
# Omnibus:                        2.227   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.328   Jarque-Bera (JB):                1.777
# Skew:                          -0.150   Prob(JB):                        0.411
# Kurtosis:                       2.466   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.067
# Model:                            OLS   Adj. R-squared:                  0.033
# Method:                 Least Squares   F-statistic:                     1.505
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):              0.206
# Time:                        13:05:17   Log-Likelihood:                 290.66
# No. Observations:                 114   AIC:                            -571.3
# Df Residuals:                     109   BIC:                            -557.6
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0014      0.002      0.838      0.402      -0.002       0.005
# mktrf         -0.0753      0.066     -1.142      0.254      -0.205       0.054
# smb           -0.0068      0.076     -0.090      0.929      -0.156       0.143
# hml           -0.0093      0.095     -0.099      0.921      -0.195       0.176
# umd            0.1138      0.100      1.142      0.254      -0.082       0.309
# ==============================================================================
# Omnibus:                        2.227   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.328   Jarque-Bera (JB):                1.777
# Skew:                          -0.150   Prob(JB):                        0.411
# Kurtosis:                       2.466   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.067
# Model:                            OLS   Adj. R-squared:                  0.033
# Method:                 Least Squares   F-statistic:                     2.695
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):             0.0346
# Time:                        13:05:17   Log-Likelihood:                 290.66
# No. Observations:                 114   AIC:                            -571.3
# Df Residuals:                     109   BIC:                            -557.6
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0014      0.001      1.045      0.296      -0.001       0.004
# mktrf         -0.0753      0.069     -1.100      0.271      -0.210       0.059
# smb           -0.0068      0.071     -0.097      0.923      -0.145       0.132
# hml           -0.0093      0.097     -0.096      0.923      -0.200       0.181
# umd            0.1138      0.080      1.415      0.157      -0.044       0.271
# ==============================================================================
# Omnibus:                        2.227   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.328   Jarque-Bera (JB):                1.777
# Skew:                          -0.150   Prob(JB):                        0.411
# Kurtosis:                       2.466   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.067
# Model:                            OLS   Adj. R-squared:                  0.033
# Method:                 Least Squares   F-statistic:                     1.950
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):              0.107
# Time:                        13:05:17   Log-Likelihood:                 290.66
# No. Observations:                 114   AIC:                            -571.3
# Df Residuals:                     109   BIC:                            -557.6
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0014      0.002      0.754      0.452      -0.002       0.005
# mktrf         -0.0753      0.054     -1.399      0.165      -0.182       0.031
# smb           -0.0068      0.084     -0.081      0.935      -0.173       0.160
# hml           -0.0093      0.086     -0.108      0.914      -0.181       0.162
# umd            0.1138      0.065      1.744      0.084      -0.016       0.243
# ==============================================================================
# Omnibus:                        2.227   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.328   Jarque-Bera (JB):                1.777
# Skew:                          -0.150   Prob(JB):                        0.411
# Kurtosis:                       2.466   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.067
# Model:                            OLS   Adj. R-squared:                  0.033
# Method:                 Least Squares   F-statistic:                     1.505
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):              0.206
# Time:                        13:05:17   Log-Likelihood:                 290.66
# No. Observations:                 114   AIC:                            -571.3
# Df Residuals:                     109   BIC:                            -557.6
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0014      0.002      0.838      0.402      -0.002       0.005
# mktrf         -0.0753      0.066     -1.142      0.254      -0.205       0.054
# smb           -0.0068      0.076     -0.090      0.929      -0.156       0.143
# hml           -0.0093      0.095     -0.099      0.921      -0.195       0.176
# umd            0.1138      0.100      1.142      0.254      -0.082       0.309
# ==============================================================================
# Omnibus:                        2.227   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.328   Jarque-Bera (JB):                1.777
# Skew:                          -0.150   Prob(JB):                        0.411
# Kurtosis:                       2.466   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.067
# Model:                            OLS   Adj. R-squared:                  0.033
# Method:                 Least Squares   F-statistic:                     2.695
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):             0.0346
# Time:                        13:05:17   Log-Likelihood:                 290.66
# No. Observations:                 114   AIC:                            -571.3
# Df Residuals:                     109   BIC:                            -557.6
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0014      0.001      1.045      0.296      -0.001       0.004
# mktrf         -0.0753      0.069     -1.100      0.271      -0.210       0.059
# smb           -0.0068      0.071     -0.097      0.923      -0.145       0.132
# hml           -0.0093      0.097     -0.096      0.923      -0.200       0.181
# umd            0.1138      0.080      1.415      0.157      -0.044       0.271
# ==============================================================================
# Omnibus:                        2.227   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.328   Jarque-Bera (JB):                1.777
# Skew:                          -0.150   Prob(JB):                        0.411
# Kurtosis:                       2.466   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """
