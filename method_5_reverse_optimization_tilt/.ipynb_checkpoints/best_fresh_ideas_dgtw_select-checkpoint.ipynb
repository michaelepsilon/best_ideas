# %% [markdown]
# # Method 5 - Best Ideas DGTW Selection

# %%
# %matplotlib inline
import pandas as pd
import warnings
from statsmodels import api as sm

from eptooling import crsp, epd, fs, hfu, crsp, db, bi
from eptooling.bm import bmdb, iso
from epquant.engine import weights, portfolio
from epquant.gen import returns
from epquant.perf import relative_performance

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Fetch Holdings and Benchmark Data

# %%
# Get HFU Data

# %store -r inst_data

# Count number of positions per manager

inst_data['num_pos'] = inst_data.groupby(['datadate', 'institution_id'])[
    'fsym_id'].transform(lambda s: s.nunique())

# Remove less than 20 holdings and less than $5mm per CSP

valid_data = inst_data[inst_data['num_pos'] >= 20]
valid_data = valid_data[valid_data['public_aum'] >= 5e6]

# Get Returns for Fresh Ideas

# %store -r r

# Get Adjusted Quantities

qty_pivot = pd.pivot_table(inst_data, index='datadate', columns=['institution_id', 'fsym_id'], values='quantity',
                           aggfunc='sum')
qty_pivot = qty_pivot.mul(r.splits.reindex(qty_pivot.index), level=1).fillna(0)
qty_pivot = qty_pivot - qty_pivot.shift(1)
flat_qty = pd.melt(qty_pivot.reset_index(), id_vars='datadate', value_name='qty_change')
flat_qty = flat_qty[flat_qty['qty_change'] > 0]

# Get Pos Size Change

pos_size_pivot = pd.pivot_table(inst_data, index='datadate', columns=['institution_id', 'fsym_id'], values='target',
                                aggfunc='sum')
pos_size_pivot = pos_size_pivot - pos_size_pivot.shift(1)
flat_pos_size = pd.melt(pos_size_pivot.reset_index(), id_vars='datadate', value_name='size_change')
flat_pos_size = flat_pos_size[flat_pos_size['size_change'] > 0]

# Add Expected Returns per Shumway, Szefler, Yuan 2009

# %store -r exp_ret

valid_data = valid_data.merge(exp_ret, on=['datadate', 'institution_id', 'fsym_id'], how='left')

# Calculate CSP Weight per Market Tilt

valid_data['adj_target'] = valid_data['expected_return']

# %% [markdown]
# ## Calculate Best Fresh Ideas

# %%
# Extract Best Ideas

valid_data['pos_rank'] = valid_data\
    .groupby(['datadate', 'institution_id'])['adj_target'].rank(ascending=False)

# Get Best
    
best_ideas = valid_data[valid_data['pos_rank'] == 1].copy()

# Filter to Fresh

best_ideas = best_ideas.merge(flat_qty).merge(flat_pos_size)

# Weight the best ideas equally

best_ideas['target'] = 1 / best_ideas.groupby('datadate')[
    'institution_id'].transform('count')

# %% [markdown]
# ## Backtest Portfolio

# %%
w = weights.Weights(best_ideas)

p = portfolio.DailyPortfolio(w, r, end_date='2018-12-31')

monthly_beg_pos = p.beg_port.iloc[1:].resample('M', level=0).apply(epd.take_first)
dgtw = crsp.get_dgtw_returns(list(set(best_ideas['fsym_id'].dropna())),
                    best_ideas['datadate'].min(), pd.datetime(2018, 12, 31))
dgtw_pivot = pd.pivot_table(dgtw, index='datadate', columns='fsym_id', values='total_return')
dgtw_cont = monthly_beg_pos.mul(dgtw_pivot, axis=1, level=0).sum(axis=1)


monthly_return = p.port_return.loc['1999-07-01':].resample('M').apply(epd.prod_red)
monthly_return = (monthly_return - dgtw_cont).dropna()
monthly_return.name = 'port_return'

# %% [markdown]
# ## Plot Performance

# %%
epd.nav(monthly_return).plot()

# %%
monthly_return.resample('A').apply(epd.prod_red)
# Out:
# datadate
# 1999-12-31    0.114994
# 2000-12-31   -0.113513
# 2001-12-31   -0.273280
# 2002-12-31   -0.145441
# 2003-12-31    0.343801
# 2004-12-31    0.030366
# 2005-12-31    0.075952
# 2006-12-31    0.066905
# 2007-12-31    0.052729
# 2008-12-31   -0.122696
# 2009-12-31    0.113122
# 2010-12-31    0.014733
# 2011-12-31   -0.065986
# 2012-12-31    0.111857
# 2013-12-31    0.155078
# 2014-12-31   -0.011154
# 2015-12-31   -0.030364
# 2016-12-31   -0.010438
# 2017-12-31    0.026062
# 2018-12-31   -0.010204
# Freq: A-DEC, Name: port_return, dtype: float64

# %% [markdown]
# ## Fetch Factor Models

# %%
# Get Factor Models
q_factor_model = bi.get_q_factor_model()
fama_french_five_factor_model = bi.get_fama_french_five_factor_model()
four_factor_model = bi.get_four_factor_model()

# Concat Portfolio Return
q_factor = pd.concat([monthly_return, q_factor_model], axis=1)
fama_french_five = pd.concat([monthly_return, fama_french_five_factor_model], axis=1)
four_factor = pd.concat([monthly_return, four_factor_model], axis=1)

# Add Constants
q_factor.insert(1, 'const', 1)
fama_french_five.insert(1, 'const', 1)
four_factor.insert(1, 'const', 1)

# Split Period into Pre and Post Crisis
q_factor_pre, q_factor_post = q_factor.loc[:'2009-06-30'], q_factor.loc['2009-07-31':]
fama_french_five_pre, fama_french_five_post = fama_french_five.loc[:'2009-06-30'], fama_french_five.loc['2009-07-31':] 
four_factor_pre, four_factor_post = four_factor.loc[:'2009-06-30'], four_factor.loc['2009-07-31':]

# %% [markdown]
# ## Full Time Period Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.480
# Model:                            OLS   Adj. R-squared:                  0.470
# Method:                 Least Squares   F-statistic:                     52.76
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.87e-31
# Time:                        12:39:38   Log-Likelihood:                 565.14
# No. Observations:                 234   AIC:                            -1120.
# Df Residuals:                     229   BIC:                            -1103.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0008      0.001      0.528      0.598      -0.002       0.004
# mktrf          0.1707      0.041      4.187      0.000       0.090       0.251
# me             0.2680      0.047      5.653      0.000       0.175       0.361
# ia            -0.1292      0.072     -1.794      0.074      -0.271       0.013
# roe           -0.3074      0.062     -4.983      0.000      -0.429      -0.186
# ==============================================================================
# Omnibus:                       16.666   Durbin-Watson:                   2.082
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               49.175
# Skew:                           0.118   Prob(JB):                     2.10e-11
# Kurtosis:                       5.233   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.480
# Model:                            OLS   Adj. R-squared:                  0.470
# Method:                 Least Squares   F-statistic:                     24.13
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.13e-16
# Time:                        12:39:38   Log-Likelihood:                 565.14
# No. Observations:                 234   AIC:                            -1120.
# Df Residuals:                     229   BIC:                            -1103.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0008      0.002      0.391      0.696      -0.003       0.005
# mktrf          0.1707      0.045      3.779      0.000       0.082       0.259
# me             0.2680      0.078      3.446      0.001       0.116       0.420
# ia            -0.1292      0.128     -1.013      0.311      -0.379       0.121
# roe           -0.3074      0.106     -2.910      0.004      -0.514      -0.100
# ==============================================================================
# Omnibus:                       16.666   Durbin-Watson:                   2.082
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               49.175
# Skew:                           0.118   Prob(JB):                     2.10e-11
# Kurtosis:                       5.233   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.480
# Model:                            OLS   Adj. R-squared:                  0.470
# Method:                 Least Squares   F-statistic:                     29.94
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           4.89e-20
# Time:                        12:39:38   Log-Likelihood:                 565.14
# No. Observations:                 234   AIC:                            -1120.
# Df Residuals:                     229   BIC:                            -1103.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0008      0.002      0.363      0.716      -0.003       0.005
# mktrf          0.1707      0.039      4.380      0.000       0.094       0.247
# me             0.2680      0.080      3.342      0.001       0.111       0.425
# ia            -0.1292      0.103     -1.253      0.210      -0.332       0.073
# roe           -0.3074      0.108     -2.839      0.005      -0.520      -0.095
# ==============================================================================
# Omnibus:                       16.666   Durbin-Watson:                   2.082
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               49.175
# Skew:                           0.118   Prob(JB):                     2.10e-11
# Kurtosis:                       5.233   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.449
# Model:                            OLS   Adj. R-squared:                  0.440
# Method:                 Least Squares   F-statistic:                     46.69
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.16e-28
# Time:                        12:39:38   Log-Likelihood:                 558.50
# No. Observations:                 234   AIC:                            -1107.
# Df Residuals:                     229   BIC:                            -1090.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0009      0.001     -0.587      0.558      -0.004       0.002
# mktrf          0.2966      0.039      7.682      0.000       0.221       0.373
# smb            0.3301      0.048      6.848      0.000       0.235       0.425
# hml           -0.1132      0.048     -2.364      0.019      -0.208      -0.019
# umd            0.0195      0.031      0.622      0.535      -0.042       0.081
# ==============================================================================
# Omnibus:                       19.468   Durbin-Watson:                   2.022
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               35.304
# Skew:                           0.451   Prob(JB):                     2.16e-08
# Kurtosis:                       4.675   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.449
# Model:                            OLS   Adj. R-squared:                  0.440
# Method:                 Least Squares   F-statistic:                     27.85
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           7.43e-19
# Time:                        12:39:38   Log-Likelihood:                 558.50
# No. Observations:                 234   AIC:                            -1107.
# Df Residuals:                     229   BIC:                            -1090.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0009      0.002     -0.474      0.636      -0.005       0.003
# mktrf          0.2966      0.039      7.581      0.000       0.220       0.373
# smb            0.3301      0.068      4.848      0.000       0.197       0.463
# hml           -0.1132      0.060     -1.880      0.060      -0.231       0.005
# umd            0.0195      0.062      0.315      0.753      -0.102       0.141
# ==============================================================================
# Omnibus:                       19.468   Durbin-Watson:                   2.022
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               35.304
# Skew:                           0.451   Prob(JB):                     2.16e-08
# Kurtosis:                       4.675   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.449
# Model:                            OLS   Adj. R-squared:                  0.440
# Method:                 Least Squares   F-statistic:                     27.68
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           9.33e-19
# Time:                        12:39:39   Log-Likelihood:                 558.50
# No. Observations:                 234   AIC:                            -1107.
# Df Residuals:                     229   BIC:                            -1090.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0009      0.002     -0.443      0.658      -0.005       0.003
# mktrf          0.2966      0.039      7.561      0.000       0.220       0.373
# smb            0.3301      0.054      6.156      0.000       0.225       0.435
# hml           -0.1132      0.054     -2.111      0.035      -0.218      -0.008
# umd            0.0195      0.068      0.285      0.775      -0.115       0.154
# ==============================================================================
# Omnibus:                       19.468   Durbin-Watson:                   2.022
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               35.304
# Skew:                           0.451   Prob(JB):                     2.16e-08
# Kurtosis:                       4.675   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.449
# Model:                            OLS   Adj. R-squared:                  0.440
# Method:                 Least Squares   F-statistic:                     46.69
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.16e-28
# Time:                        12:39:39   Log-Likelihood:                 558.50
# No. Observations:                 234   AIC:                            -1107.
# Df Residuals:                     229   BIC:                            -1090.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0009      0.001     -0.587      0.558      -0.004       0.002
# mktrf          0.2966      0.039      7.682      0.000       0.221       0.373
# smb            0.3301      0.048      6.848      0.000       0.235       0.425
# hml           -0.1132      0.048     -2.364      0.019      -0.208      -0.019
# umd            0.0195      0.031      0.622      0.535      -0.042       0.081
# ==============================================================================
# Omnibus:                       19.468   Durbin-Watson:                   2.022
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               35.304
# Skew:                           0.451   Prob(JB):                     2.16e-08
# Kurtosis:                       4.675   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.449
# Model:                            OLS   Adj. R-squared:                  0.440
# Method:                 Least Squares   F-statistic:                     27.85
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           7.43e-19
# Time:                        12:39:39   Log-Likelihood:                 558.50
# No. Observations:                 234   AIC:                            -1107.
# Df Residuals:                     229   BIC:                            -1090.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0009      0.002     -0.474      0.636      -0.005       0.003
# mktrf          0.2966      0.039      7.581      0.000       0.220       0.373
# smb            0.3301      0.068      4.848      0.000       0.197       0.463
# hml           -0.1132      0.060     -1.880      0.060      -0.231       0.005
# umd            0.0195      0.062      0.315      0.753      -0.102       0.141
# ==============================================================================
# Omnibus:                       19.468   Durbin-Watson:                   2.022
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               35.304
# Skew:                           0.451   Prob(JB):                     2.16e-08
# Kurtosis:                       4.675   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.449
# Model:                            OLS   Adj. R-squared:                  0.440
# Method:                 Least Squares   F-statistic:                     27.68
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           9.33e-19
# Time:                        12:39:39   Log-Likelihood:                 558.50
# No. Observations:                 234   AIC:                            -1107.
# Df Residuals:                     229   BIC:                            -1090.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0009      0.002     -0.443      0.658      -0.005       0.003
# mktrf          0.2966      0.039      7.561      0.000       0.220       0.373
# smb            0.3301      0.054      6.156      0.000       0.225       0.435
# hml           -0.1132      0.054     -2.111      0.035      -0.218      -0.008
# umd            0.0195      0.068      0.285      0.775      -0.115       0.154
# ==============================================================================
# Omnibus:                       19.468   Durbin-Watson:                   2.022
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               35.304
# Skew:                           0.451   Prob(JB):                     2.16e-08
# Kurtosis:                       4.675   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Pre-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.491
# Model:                            OLS   Adj. R-squared:                  0.473
# Method:                 Least Squares   F-statistic:                     27.72
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           4.07e-16
# Time:                        12:39:39   Log-Likelihood:                 266.93
# No. Observations:                 120   AIC:                            -523.9
# Df Residuals:                     115   BIC:                            -509.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -7.9e-05      0.003     -0.031      0.975      -0.005       0.005
# mktrf          0.2194      0.069      3.185      0.002       0.083       0.356
# me             0.3257      0.068      4.787      0.000       0.191       0.460
# ia            -0.1284      0.107     -1.205      0.231      -0.339       0.083
# roe           -0.2143      0.094     -2.273      0.025      -0.401      -0.028
# ==============================================================================
# Omnibus:                        7.555   Durbin-Watson:                   2.096
# Prob(Omnibus):                  0.023   Jarque-Bera (JB):               10.236
# Skew:                           0.312   Prob(JB):                      0.00599
# Kurtosis:                       4.288   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.491
# Model:                            OLS   Adj. R-squared:                  0.473
# Method:                 Least Squares   F-statistic:                     13.33
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           5.90e-09
# Time:                        12:39:39   Log-Likelihood:                 266.93
# No. Observations:                 120   AIC:                            -523.9
# Df Residuals:                     115   BIC:                            -509.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -7.9e-05      0.004     -0.021      0.983      -0.007       0.007
# mktrf          0.2194      0.074      2.949      0.003       0.074       0.365
# me             0.3257      0.101      3.210      0.001       0.127       0.525
# ia            -0.1284      0.173     -0.741      0.459      -0.468       0.211
# roe           -0.2143      0.147     -1.463      0.144      -0.502       0.073
# ==============================================================================
# Omnibus:                        7.555   Durbin-Watson:                   2.096
# Prob(Omnibus):                  0.023   Jarque-Bera (JB):               10.236
# Skew:                           0.312   Prob(JB):                      0.00599
# Kurtosis:                       4.288   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.491
# Model:                            OLS   Adj. R-squared:                  0.473
# Method:                 Least Squares   F-statistic:                     16.27
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.37e-10
# Time:                        12:39:39   Log-Likelihood:                 266.93
# No. Observations:                 120   AIC:                            -523.9
# Df Residuals:                     115   BIC:                            -509.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -7.9e-05      0.004     -0.019      0.985      -0.008       0.008
# mktrf          0.2194      0.065      3.378      0.001       0.092       0.347
# me             0.3257      0.106      3.061      0.002       0.117       0.534
# ia            -0.1284      0.147     -0.876      0.381      -0.416       0.159
# roe           -0.2143      0.145     -1.476      0.140      -0.499       0.070
# ==============================================================================
# Omnibus:                        7.555   Durbin-Watson:                   2.096
# Prob(Omnibus):                  0.023   Jarque-Bera (JB):               10.236
# Skew:                           0.312   Prob(JB):                      0.00599
# Kurtosis:                       4.288   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.515
# Model:                            OLS   Adj. R-squared:                  0.499
# Method:                 Least Squares   F-statistic:                     30.58
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.48e-17
# Time:                        12:39:39   Log-Likelihood:                 269.90
# No. Observations:                 120   AIC:                            -529.8
# Df Residuals:                     115   BIC:                            -515.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.002     -0.105      0.917      -0.005       0.005
# mktrf          0.3554      0.059      6.003      0.000       0.238       0.473
# smb            0.3285      0.067      4.873      0.000       0.195       0.462
# hml           -0.1443      0.068     -2.138      0.035      -0.278      -0.011
# umd            0.0489      0.042      1.175      0.243      -0.034       0.131
# ==============================================================================
# Omnibus:                       11.883   Durbin-Watson:                   2.096
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               13.921
# Skew:                           0.603   Prob(JB):                     0.000949
# Kurtosis:                       4.154   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.515
# Model:                            OLS   Adj. R-squared:                  0.499
# Method:                 Least Squares   F-statistic:                     42.70
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           6.53e-22
# Time:                        12:39:39   Log-Likelihood:                 269.90
# No. Observations:                 120   AIC:                            -529.8
# Df Residuals:                     115   BIC:                            -515.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.003     -0.079      0.937      -0.007       0.006
# mktrf          0.3554      0.046      7.807      0.000       0.266       0.445
# smb            0.3285      0.077      4.259      0.000       0.177       0.480
# hml           -0.1443      0.076     -1.911      0.056      -0.292       0.004
# umd            0.0489      0.069      0.709      0.479      -0.086       0.184
# ==============================================================================
# Omnibus:                       11.883   Durbin-Watson:                   2.096
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               13.921
# Skew:                           0.603   Prob(JB):                     0.000949
# Kurtosis:                       4.154   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.515
# Model:                            OLS   Adj. R-squared:                  0.499
# Method:                 Least Squares   F-statistic:                     59.63
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           3.60e-27
# Time:                        12:39:39   Log-Likelihood:                 269.90
# No. Observations:                 120   AIC:                            -529.8
# Df Residuals:                     115   BIC:                            -515.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.003     -0.075      0.940      -0.007       0.006
# mktrf          0.3554      0.039      9.218      0.000       0.280       0.431
# smb            0.3285      0.058      5.677      0.000       0.215       0.442
# hml           -0.1443      0.069     -2.102      0.036      -0.279      -0.010
# umd            0.0489      0.074      0.664      0.506      -0.095       0.193
# ==============================================================================
# Omnibus:                       11.883   Durbin-Watson:                   2.096
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               13.921
# Skew:                           0.603   Prob(JB):                     0.000949
# Kurtosis:                       4.154   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.515
# Model:                            OLS   Adj. R-squared:                  0.499
# Method:                 Least Squares   F-statistic:                     30.58
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.48e-17
# Time:                        12:39:39   Log-Likelihood:                 269.90
# No. Observations:                 120   AIC:                            -529.8
# Df Residuals:                     115   BIC:                            -515.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.002     -0.105      0.917      -0.005       0.005
# mktrf          0.3554      0.059      6.003      0.000       0.238       0.473
# smb            0.3285      0.067      4.873      0.000       0.195       0.462
# hml           -0.1443      0.068     -2.138      0.035      -0.278      -0.011
# umd            0.0489      0.042      1.175      0.243      -0.034       0.131
# ==============================================================================
# Omnibus:                       11.883   Durbin-Watson:                   2.096
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               13.921
# Skew:                           0.603   Prob(JB):                     0.000949
# Kurtosis:                       4.154   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.515
# Model:                            OLS   Adj. R-squared:                  0.499
# Method:                 Least Squares   F-statistic:                     42.70
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           6.53e-22
# Time:                        12:39:39   Log-Likelihood:                 269.90
# No. Observations:                 120   AIC:                            -529.8
# Df Residuals:                     115   BIC:                            -515.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.003     -0.079      0.937      -0.007       0.006
# mktrf          0.3554      0.046      7.807      0.000       0.266       0.445
# smb            0.3285      0.077      4.259      0.000       0.177       0.480
# hml           -0.1443      0.076     -1.911      0.056      -0.292       0.004
# umd            0.0489      0.069      0.709      0.479      -0.086       0.184
# ==============================================================================
# Omnibus:                       11.883   Durbin-Watson:                   2.096
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               13.921
# Skew:                           0.603   Prob(JB):                     0.000949
# Kurtosis:                       4.154   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.515
# Model:                            OLS   Adj. R-squared:                  0.499
# Method:                 Least Squares   F-statistic:                     59.63
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           3.60e-27
# Time:                        12:39:39   Log-Likelihood:                 269.90
# No. Observations:                 120   AIC:                            -529.8
# Df Residuals:                     115   BIC:                            -515.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.003     -0.075      0.940      -0.007       0.006
# mktrf          0.3554      0.039      9.218      0.000       0.280       0.431
# smb            0.3285      0.058      5.677      0.000       0.215       0.442
# hml           -0.1443      0.069     -2.102      0.036      -0.279      -0.010
# umd            0.0489      0.074      0.664      0.506      -0.095       0.193
# ==============================================================================
# Omnibus:                       11.883   Durbin-Watson:                   2.096
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               13.921
# Skew:                           0.603   Prob(JB):                     0.000949
# Kurtosis:                       4.154   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Post-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.504
# Model:                            OLS   Adj. R-squared:                  0.485
# Method:                 Least Squares   F-statistic:                     27.65
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           7.50e-16
# Time:                        12:39:39   Log-Likelihood:                 320.46
# No. Observations:                 114   AIC:                            -630.9
# Df Residuals:                     109   BIC:                            -617.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0015      0.001      1.025      0.308      -0.001       0.004
# mktrf          0.1585      0.044      3.622      0.000       0.072       0.245
# me             0.1147      0.068      1.698      0.092      -0.019       0.249
# ia            -0.1688      0.094     -1.802      0.074      -0.355       0.017
# roe           -0.5160      0.082     -6.267      0.000      -0.679      -0.353
# ==============================================================================
# Omnibus:                        2.556   Durbin-Watson:                   1.882
# Prob(Omnibus):                  0.279   Jarque-Bera (JB):                2.163
# Skew:                           0.333   Prob(JB):                        0.339
# Kurtosis:                       3.110   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.504
# Model:                            OLS   Adj. R-squared:                  0.485
# Method:                 Least Squares   F-statistic:                     50.12
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           7.25e-24
# Time:                        12:39:39   Log-Likelihood:                 320.46
# No. Observations:                 114   AIC:                            -630.9
# Df Residuals:                     109   BIC:                            -617.2
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0015      0.001      1.374      0.170      -0.001       0.004
# mktrf          0.1585      0.040      4.010      0.000       0.081       0.236
# me             0.1147      0.043      2.693      0.007       0.031       0.198
# ia            -0.1688      0.088     -1.916      0.055      -0.342       0.004
# roe           -0.5160      0.068     -7.614      0.000      -0.649      -0.383
# ==============================================================================
# Omnibus:                        2.556   Durbin-Watson:                   1.882
# Prob(Omnibus):                  0.279   Jarque-Bera (JB):                2.163
# Skew:                           0.333   Prob(JB):                        0.339
# Kurtosis:                       3.110   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.504
# Model:                            OLS   Adj. R-squared:                  0.485
# Method:                 Least Squares   F-statistic:                     76.42
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           9.74e-31
# Time:                        12:39:39   Log-Likelihood:                 320.46
# No. Observations:                 114   AIC:                            -630.9
# Df Residuals:                     109   BIC:                            -617.2
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0015      0.001      1.338      0.181      -0.001       0.004
# mktrf          0.1585      0.038      4.179      0.000       0.084       0.233
# me             0.1147      0.039      2.906      0.004       0.037       0.192
# ia            -0.1688      0.088     -1.917      0.055      -0.341       0.004
# roe           -0.5160      0.059     -8.744      0.000      -0.632      -0.400
# ==============================================================================
# Omnibus:                        2.556   Durbin-Watson:                   1.882
# Prob(Omnibus):                  0.279   Jarque-Bera (JB):                2.163
# Skew:                           0.333   Prob(JB):                        0.339
# Kurtosis:                       3.110   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.322
# Model:                            OLS   Adj. R-squared:                  0.297
# Method:                 Least Squares   F-statistic:                     12.96
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.15e-08
# Time:                        12:39:39   Log-Likelihood:                 302.71
# No. Observations:                 114   AIC:                            -595.4
# Df Residuals:                     109   BIC:                            -581.7
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.002     -0.185      0.854      -0.004       0.003
# mktrf          0.2188      0.048      4.516      0.000       0.123       0.315
# smb            0.2331      0.076      3.086      0.003       0.083       0.383
# hml            0.0367      0.078      0.472      0.638      -0.118       0.191
# umd           -0.0287      0.059     -0.490      0.625      -0.145       0.088
# ==============================================================================
# Omnibus:                        3.067   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.216   Jarque-Bera (JB):                3.210
# Skew:                           0.022   Prob(JB):                        0.201
# Kurtosis:                       3.821   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.322
# Model:                            OLS   Adj. R-squared:                  0.297
# Method:                 Least Squares   F-statistic:                     9.623
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.06e-06
# Time:                        12:39:39   Log-Likelihood:                 302.71
# No. Observations:                 114   AIC:                            -595.4
# Df Residuals:                     109   BIC:                            -581.7
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.001     -0.256      0.798      -0.003       0.002
# mktrf          0.2188      0.046      4.755      0.000       0.129       0.309
# smb            0.2331      0.068      3.438      0.001       0.100       0.366
# hml            0.0367      0.091      0.404      0.687      -0.142       0.215
# umd           -0.0287      0.065     -0.443      0.658      -0.156       0.098
# ==============================================================================
# Omnibus:                        3.067   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.216   Jarque-Bera (JB):                3.210
# Skew:                           0.022   Prob(JB):                        0.201
# Kurtosis:                       3.821   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.322
# Model:                            OLS   Adj. R-squared:                  0.297
# Method:                 Least Squares   F-statistic:                     10.45
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           3.33e-07
# Time:                        12:39:39   Log-Likelihood:                 302.71
# No. Observations:                 114   AIC:                            -595.4
# Df Residuals:                     109   BIC:                            -581.7
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.001     -0.266      0.790      -0.003       0.002
# mktrf          0.2188      0.042      5.158      0.000       0.136       0.302
# smb            0.2331      0.065      3.560      0.000       0.105       0.361
# hml            0.0367      0.091      0.403      0.687      -0.142       0.215
# umd           -0.0287      0.060     -0.477      0.634      -0.147       0.089
# ==============================================================================
# Omnibus:                        3.067   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.216   Jarque-Bera (JB):                3.210
# Skew:                           0.022   Prob(JB):                        0.201
# Kurtosis:                       3.821   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.322
# Model:                            OLS   Adj. R-squared:                  0.297
# Method:                 Least Squares   F-statistic:                     12.96
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.15e-08
# Time:                        12:39:39   Log-Likelihood:                 302.71
# No. Observations:                 114   AIC:                            -595.4
# Df Residuals:                     109   BIC:                            -581.7
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.002     -0.185      0.854      -0.004       0.003
# mktrf          0.2188      0.048      4.516      0.000       0.123       0.315
# smb            0.2331      0.076      3.086      0.003       0.083       0.383
# hml            0.0367      0.078      0.472      0.638      -0.118       0.191
# umd           -0.0287      0.059     -0.490      0.625      -0.145       0.088
# ==============================================================================
# Omnibus:                        3.067   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.216   Jarque-Bera (JB):                3.210
# Skew:                           0.022   Prob(JB):                        0.201
# Kurtosis:                       3.821   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.322
# Model:                            OLS   Adj. R-squared:                  0.297
# Method:                 Least Squares   F-statistic:                     9.623
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.06e-06
# Time:                        12:39:39   Log-Likelihood:                 302.71
# No. Observations:                 114   AIC:                            -595.4
# Df Residuals:                     109   BIC:                            -581.7
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.001     -0.256      0.798      -0.003       0.002
# mktrf          0.2188      0.046      4.755      0.000       0.129       0.309
# smb            0.2331      0.068      3.438      0.001       0.100       0.366
# hml            0.0367      0.091      0.404      0.687      -0.142       0.215
# umd           -0.0287      0.065     -0.443      0.658      -0.156       0.098
# ==============================================================================
# Omnibus:                        3.067   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.216   Jarque-Bera (JB):                3.210
# Skew:                           0.022   Prob(JB):                        0.201
# Kurtosis:                       3.821   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.322
# Model:                            OLS   Adj. R-squared:                  0.297
# Method:                 Least Squares   F-statistic:                     10.45
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           3.33e-07
# Time:                        12:39:39   Log-Likelihood:                 302.71
# No. Observations:                 114   AIC:                            -595.4
# Df Residuals:                     109   BIC:                            -581.7
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.001     -0.266      0.790      -0.003       0.002
# mktrf          0.2188      0.042      5.158      0.000       0.136       0.302
# smb            0.2331      0.065      3.560      0.000       0.105       0.361
# hml            0.0367      0.091      0.403      0.687      -0.142       0.215
# umd           -0.0287      0.060     -0.477      0.634      -0.147       0.089
# ==============================================================================
# Omnibus:                        3.067   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.216   Jarque-Bera (JB):                3.210
# Skew:                           0.022   Prob(JB):                        0.201
# Kurtosis:                       3.821   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """
