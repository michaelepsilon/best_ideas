# %% [markdown]
# # Method 6 - Best Ideas Medium Focus

# %%
# %matplotlib inline
import pandas as pd
import warnings
from statsmodels import api as sm

from eptooling import crsp, epd, fs, hfu, crsp, db, bi
from eptooling.bm import bmdb, iso
from epquant.engine import weights, portfolio
from epquant.gen import returns
from epquant.perf import relative_performance

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Fetch Holdings and Benchmark Data

# %%
# Get HFU Data

# %store -r inst_data
inst_data = inst_data[inst_data['datadate'] >= '1999-06-30']

# Focus

focus = inst_data.groupby(['datadate', 'institution_id'])['fsym_id'].count().rename('focus').reset_index()

# Count number of positions per manager

inst_data['num_pos'] = inst_data.groupby(['datadate', 'institution_id'])[
    'fsym_id'].transform(lambda s: s.nunique())

# Remove less than 20 holdings and less than $5mm per CSP

valid_data = inst_data[inst_data['num_pos'] >= 20]
valid_data = valid_data[valid_data['public_aum'] >= 5e6]

# Add Expected Returns from Market Relative Weight per Shumway, Szefler, Yuan 2009

# %store -r mkt_exp_ret

valid_data = valid_data.merge(mkt_exp_ret, on=['datadate', 'institution_id', 'fsym_id'], how='left')

# Calculate CSP Weight per Market Tilt

valid_data['adj_target'] = valid_data['expected_return']

# %% [markdown]
# ## Calculate Best Ideas

# %%
# Extract Best Ideas

valid_data['pos_rank'] = valid_data\
    .groupby(['datadate', 'institution_id'])['adj_target'].rank(ascending=False)

best_ideas = valid_data[valid_data['pos_rank'] == 1].copy()

# Add Focus

best_ideas = best_ideas.merge(focus)
best_ideas['focus_pct'] = best_ideas.groupby('datadate')['focus'].rank(pct=True)
best_ideas = best_ideas[(best_ideas['focus_pct'] > (1 / 3)) & (best_ideas['focus_pct'] < (2 / 3))]

# Weight the best ideas equally

best_ideas['target'] = 1 / best_ideas.groupby('datadate')['institution_id'].transform('count')

# %% [markdown]
# ## Backtest Portfolio

# %%
w = weights.Weights(best_ideas)

# %store -r r

p = portfolio.DailyPortfolio(w, r, end_date='2018-12-31')

rf = bi.get_risk_free_rate()
monthly_return = p.port_return.loc['1999-07-01':].resample('M').apply(epd.prod_red)
monthly_return = (monthly_return - rf).dropna()
monthly_return.name = 'port_return'

# %% [markdown]
# ## Plot Performance

# %%
epd.nav(monthly_return).plot()

# %%
monthly_return.resample('A').apply(epd.prod_red)
# Out:
# datadate
# 1999-12-31    0.345658
# 2000-12-31   -0.281537
# 2001-12-31   -0.082354
# 2002-12-31   -0.356395
# 2003-12-31    0.895357
# 2004-12-31    0.152142
# 2005-12-31    0.066335
# 2006-12-31    0.114321
# 2007-12-31   -0.009327
# 2008-12-31   -0.503109
# 2009-12-31    0.877774
# 2010-12-31    0.298768
# 2011-12-31   -0.136326
# 2012-12-31    0.246847
# 2013-12-31    0.481050
# 2014-12-31    0.106049
# 2015-12-31   -0.094372
# 2016-12-31    0.198321
# 2017-12-31    0.189733
# 2018-12-31   -0.216452
# Freq: A-DEC, Name: port_return, dtype: float64

# %% [markdown]
# ## Fetch Factor Models

# %%
# Get Factor Models
q_factor_model = bi.get_q_factor_model()
fama_french_five_factor_model = bi.get_fama_french_five_factor_model()
four_factor_model = bi.get_four_factor_model()

# Concat Portfolio Return
q_factor = pd.concat([monthly_return, q_factor_model], axis=1)
fama_french_five = pd.concat([monthly_return, fama_french_five_factor_model], axis=1)
four_factor = pd.concat([monthly_return, four_factor_model], axis=1)

# Add Constants
q_factor.insert(1, 'const', 1)
fama_french_five.insert(1, 'const', 1)
four_factor.insert(1, 'const', 1)

# Split Period into Pre and Post Crisis
q_factor_pre, q_factor_post = q_factor.loc[:'2009-06-30'], q_factor.loc['2009-07-31':]
fama_french_five_pre, fama_french_five_post = fama_french_five.loc[:'2009-06-30'], fama_french_five.loc['2009-07-31':] 
four_factor_pre, four_factor_post = four_factor.loc[:'2009-06-30'], four_factor.loc['2009-07-31':]

# %% [markdown]
# ## Full Time Period Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.887
# Model:                            OLS   Adj. R-squared:                  0.885
# Method:                 Least Squares   F-statistic:                     447.4
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):          6.05e-107
# Time:                        12:44:10   Log-Likelihood:                 528.46
# No. Observations:                 234   AIC:                            -1047.
# Df Residuals:                     229   BIC:                            -1030.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0037      0.002      2.114      0.036       0.000       0.007
# mktrf          1.0713      0.048     22.467      0.000       0.977       1.165
# me             0.6056      0.055     10.919      0.000       0.496       0.715
# ia            -0.0469      0.084     -0.556      0.579      -0.213       0.119
# roe           -0.6843      0.072     -9.483      0.000      -0.826      -0.542
# ==============================================================================
# Omnibus:                       49.209   Durbin-Watson:                   2.142
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              171.606
# Skew:                           0.822   Prob(JB):                     5.45e-38
# Kurtosis:                       6.859   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.887
# Model:                            OLS   Adj. R-squared:                  0.885
# Method:                 Least Squares   F-statistic:                     429.8
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):          3.54e-105
# Time:                        12:44:10   Log-Likelihood:                 528.46
# No. Observations:                 234   AIC:                            -1047.
# Df Residuals:                     229   BIC:                            -1030.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0037      0.002      1.816      0.069      -0.000       0.008
# mktrf          1.0713      0.043     24.919      0.000       0.987       1.156
# me             0.6056      0.061      9.856      0.000       0.485       0.726
# ia            -0.0469      0.151     -0.310      0.757      -0.343       0.249
# roe           -0.6843      0.154     -4.455      0.000      -0.985      -0.383
# ==============================================================================
# Omnibus:                       49.209   Durbin-Watson:                   2.142
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              171.606
# Skew:                           0.822   Prob(JB):                     5.45e-38
# Kurtosis:                       6.859   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.887
# Model:                            OLS   Adj. R-squared:                  0.885
# Method:                 Least Squares   F-statistic:                     510.8
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):          8.03e-113
# Time:                        12:44:10   Log-Likelihood:                 528.46
# No. Observations:                 234   AIC:                            -1047.
# Df Residuals:                     229   BIC:                            -1030.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0037      0.002      1.947      0.051   -2.37e-05       0.007
# mktrf          1.0713      0.042     25.502      0.000       0.989       1.154
# me             0.6056      0.069      8.829      0.000       0.471       0.740
# ia            -0.0469      0.125     -0.374      0.708      -0.292       0.199
# roe           -0.6843      0.165     -4.149      0.000      -1.008      -0.361
# ==============================================================================
# Omnibus:                       49.209   Durbin-Watson:                   2.142
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              171.606
# Skew:                           0.822   Prob(JB):                     5.45e-38
# Kurtosis:                       6.859   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.857
# Model:                            OLS   Adj. R-squared:                  0.855
# Method:                 Least Squares   F-statistic:                     344.2
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.41e-95
# Time:                        12:44:10   Log-Likelihood:                 501.68
# No. Observations:                 234   AIC:                            -993.4
# Df Residuals:                     229   BIC:                            -976.1
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0012      0.002      0.642      0.521      -0.003       0.005
# mktrf          1.2170      0.049     24.724      0.000       1.120       1.314
# smb            0.8612      0.061     14.016      0.000       0.740       0.982
# hml           -0.0462      0.061     -0.756      0.450      -0.166       0.074
# umd           -0.1804      0.040     -4.506      0.000      -0.259      -0.102
# ==============================================================================
# Omnibus:                       48.626   Durbin-Watson:                   2.103
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              186.938
# Skew:                           0.777   Prob(JB):                     2.55e-41
# Kurtosis:                       7.094   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.857
# Model:                            OLS   Adj. R-squared:                  0.855
# Method:                 Least Squares   F-statistic:                     284.3
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.48e-87
# Time:                        12:44:10   Log-Likelihood:                 501.68
# No. Observations:                 234   AIC:                            -993.4
# Df Residuals:                     229   BIC:                            -976.1
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0012      0.002      0.631      0.528      -0.003       0.005
# mktrf          1.2170      0.045     26.938      0.000       1.128       1.306
# smb            0.8612      0.082     10.460      0.000       0.700       1.023
# hml           -0.0462      0.102     -0.453      0.651      -0.246       0.154
# umd           -0.1804      0.092     -1.970      0.049      -0.360      -0.001
# ==============================================================================
# Omnibus:                       48.626   Durbin-Watson:                   2.103
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              186.938
# Skew:                           0.777   Prob(JB):                     2.55e-41
# Kurtosis:                       7.094   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.857
# Model:                            OLS   Adj. R-squared:                  0.855
# Method:                 Least Squares   F-statistic:                     271.9
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.02e-85
# Time:                        12:44:10   Log-Likelihood:                 501.68
# No. Observations:                 234   AIC:                            -993.4
# Df Residuals:                     229   BIC:                            -976.1
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0012      0.002      0.726      0.468      -0.002       0.005
# mktrf          1.2170      0.044     27.433      0.000       1.130       1.304
# smb            0.8612      0.077     11.202      0.000       0.710       1.012
# hml           -0.0462      0.093     -0.497      0.619      -0.228       0.136
# umd           -0.1804      0.092     -1.951      0.051      -0.362       0.001
# ==============================================================================
# Omnibus:                       48.626   Durbin-Watson:                   2.103
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              186.938
# Skew:                           0.777   Prob(JB):                     2.55e-41
# Kurtosis:                       7.094   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.857
# Model:                            OLS   Adj. R-squared:                  0.855
# Method:                 Least Squares   F-statistic:                     344.2
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.41e-95
# Time:                        12:44:10   Log-Likelihood:                 501.68
# No. Observations:                 234   AIC:                            -993.4
# Df Residuals:                     229   BIC:                            -976.1
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0012      0.002      0.642      0.521      -0.003       0.005
# mktrf          1.2170      0.049     24.724      0.000       1.120       1.314
# smb            0.8612      0.061     14.016      0.000       0.740       0.982
# hml           -0.0462      0.061     -0.756      0.450      -0.166       0.074
# umd           -0.1804      0.040     -4.506      0.000      -0.259      -0.102
# ==============================================================================
# Omnibus:                       48.626   Durbin-Watson:                   2.103
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              186.938
# Skew:                           0.777   Prob(JB):                     2.55e-41
# Kurtosis:                       7.094   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.857
# Model:                            OLS   Adj. R-squared:                  0.855
# Method:                 Least Squares   F-statistic:                     284.3
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.48e-87
# Time:                        12:44:10   Log-Likelihood:                 501.68
# No. Observations:                 234   AIC:                            -993.4
# Df Residuals:                     229   BIC:                            -976.1
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0012      0.002      0.631      0.528      -0.003       0.005
# mktrf          1.2170      0.045     26.938      0.000       1.128       1.306
# smb            0.8612      0.082     10.460      0.000       0.700       1.023
# hml           -0.0462      0.102     -0.453      0.651      -0.246       0.154
# umd           -0.1804      0.092     -1.970      0.049      -0.360      -0.001
# ==============================================================================
# Omnibus:                       48.626   Durbin-Watson:                   2.103
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              186.938
# Skew:                           0.777   Prob(JB):                     2.55e-41
# Kurtosis:                       7.094   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.857
# Model:                            OLS   Adj. R-squared:                  0.855
# Method:                 Least Squares   F-statistic:                     271.9
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.02e-85
# Time:                        12:44:10   Log-Likelihood:                 501.68
# No. Observations:                 234   AIC:                            -993.4
# Df Residuals:                     229   BIC:                            -976.1
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0012      0.002      0.726      0.468      -0.002       0.005
# mktrf          1.2170      0.044     27.433      0.000       1.130       1.304
# smb            0.8612      0.077     11.202      0.000       0.710       1.012
# hml           -0.0462      0.093     -0.497      0.619      -0.228       0.136
# umd           -0.1804      0.092     -1.951      0.051      -0.362       0.001
# ==============================================================================
# Omnibus:                       48.626   Durbin-Watson:                   2.103
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              186.938
# Skew:                           0.777   Prob(JB):                     2.55e-41
# Kurtosis:                       7.094   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Pre-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.876
# Model:                            OLS   Adj. R-squared:                  0.872
# Method:                 Least Squares   F-statistic:                     203.4
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           3.53e-51
# Time:                        12:44:10   Log-Likelihood:                 246.91
# No. Observations:                 120   AIC:                            -483.8
# Df Residuals:                     115   BIC:                            -469.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0048      0.003      1.605      0.111      -0.001       0.011
# mktrf          1.0960      0.081     13.465      0.000       0.935       1.257
# me             0.6020      0.080      7.489      0.000       0.443       0.761
# ia            -0.0208      0.126     -0.165      0.869      -0.270       0.229
# roe           -0.6398      0.111     -5.742      0.000      -0.860      -0.419
# ==============================================================================
# Omnibus:                       23.584   Durbin-Watson:                   2.217
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               49.724
# Skew:                           0.787   Prob(JB):                     1.59e-11
# Kurtosis:                       5.733   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.876
# Model:                            OLS   Adj. R-squared:                  0.872
# Method:                 Least Squares   F-statistic:                     250.7
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           8.51e-56
# Time:                        12:44:10   Log-Likelihood:                 246.91
# No. Observations:                 120   AIC:                            -483.8
# Df Residuals:                     115   BIC:                            -469.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0048      0.004      1.370      0.171      -0.002       0.012
# mktrf          1.0960      0.069     15.852      0.000       0.960       1.232
# me             0.6020      0.091      6.595      0.000       0.423       0.781
# ia            -0.0208      0.211     -0.099      0.921      -0.435       0.393
# roe           -0.6398      0.215     -2.973      0.003      -1.061      -0.218
# ==============================================================================
# Omnibus:                       23.584   Durbin-Watson:                   2.217
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               49.724
# Skew:                           0.787   Prob(JB):                     1.59e-11
# Kurtosis:                       5.733   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.876
# Model:                            OLS   Adj. R-squared:                  0.872
# Method:                 Least Squares   F-statistic:                     359.3
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           5.56e-64
# Time:                        12:44:10   Log-Likelihood:                 246.91
# No. Observations:                 120   AIC:                            -483.8
# Df Residuals:                     115   BIC:                            -469.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0048      0.003      1.511      0.131      -0.001       0.011
# mktrf          1.0960      0.067     16.271      0.000       0.964       1.228
# me             0.6020      0.103      5.870      0.000       0.401       0.803
# ia            -0.0208      0.174     -0.120      0.905      -0.362       0.321
# roe           -0.6398      0.231     -2.776      0.006      -1.092      -0.188
# ==============================================================================
# Omnibus:                       23.584   Durbin-Watson:                   2.217
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               49.724
# Skew:                           0.787   Prob(JB):                     1.59e-11
# Kurtosis:                       5.733   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.859
# Model:                            OLS   Adj. R-squared:                  0.854
# Method:                 Least Squares   F-statistic:                     174.6
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           7.08e-48
# Time:                        12:44:10   Log-Likelihood:                 238.95
# No. Observations:                 120   AIC:                            -467.9
# Df Residuals:                     115   BIC:                            -454.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0038      0.003      1.200      0.233      -0.002       0.010
# mktrf          1.2842      0.077     16.760      0.000       1.132       1.436
# smb            0.8456      0.087      9.693      0.000       0.673       1.018
# hml           -0.0753      0.087     -0.862      0.390      -0.248       0.098
# umd           -0.1530      0.054     -2.840      0.005      -0.260      -0.046
# ==============================================================================
# Omnibus:                       25.978   Durbin-Watson:                   2.288
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               73.079
# Skew:                           0.749   Prob(JB):                     1.35e-16
# Kurtosis:                       6.517   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.859
# Model:                            OLS   Adj. R-squared:                  0.854
# Method:                 Least Squares   F-statistic:                     301.1
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           6.25e-60
# Time:                        12:44:10   Log-Likelihood:                 238.95
# No. Observations:                 120   AIC:                            -467.9
# Df Residuals:                     115   BIC:                            -454.0
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0038      0.003      1.250      0.211      -0.002       0.010
# mktrf          1.2842      0.052     24.895      0.000       1.183       1.385
# smb            0.8456      0.105      8.022      0.000       0.639       1.052
# hml           -0.0753      0.129     -0.586      0.558      -0.327       0.177
# umd           -0.1530      0.104     -1.468      0.142      -0.357       0.051
# ==============================================================================
# Omnibus:                       25.978   Durbin-Watson:                   2.288
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               73.079
# Skew:                           0.749   Prob(JB):                     1.35e-16
# Kurtosis:                       6.517   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.859
# Model:                            OLS   Adj. R-squared:                  0.854
# Method:                 Least Squares   F-statistic:                     462.1
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           7.60e-70
# Time:                        12:44:10   Log-Likelihood:                 238.95
# No. Observations:                 120   AIC:                            -467.9
# Df Residuals:                     115   BIC:                            -454.0
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0038      0.003      1.511      0.131      -0.001       0.009
# mktrf          1.2842      0.040     31.985      0.000       1.206       1.363
# smb            0.8456      0.100      8.488      0.000       0.650       1.041
# hml           -0.0753      0.121     -0.625      0.532      -0.312       0.161
# umd           -0.1530      0.102     -1.501      0.133      -0.353       0.047
# ==============================================================================
# Omnibus:                       25.978   Durbin-Watson:                   2.288
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               73.079
# Skew:                           0.749   Prob(JB):                     1.35e-16
# Kurtosis:                       6.517   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.859
# Model:                            OLS   Adj. R-squared:                  0.854
# Method:                 Least Squares   F-statistic:                     174.6
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           7.08e-48
# Time:                        12:44:10   Log-Likelihood:                 238.95
# No. Observations:                 120   AIC:                            -467.9
# Df Residuals:                     115   BIC:                            -454.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0038      0.003      1.200      0.233      -0.002       0.010
# mktrf          1.2842      0.077     16.760      0.000       1.132       1.436
# smb            0.8456      0.087      9.693      0.000       0.673       1.018
# hml           -0.0753      0.087     -0.862      0.390      -0.248       0.098
# umd           -0.1530      0.054     -2.840      0.005      -0.260      -0.046
# ==============================================================================
# Omnibus:                       25.978   Durbin-Watson:                   2.288
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               73.079
# Skew:                           0.749   Prob(JB):                     1.35e-16
# Kurtosis:                       6.517   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.859
# Model:                            OLS   Adj. R-squared:                  0.854
# Method:                 Least Squares   F-statistic:                     301.1
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           6.25e-60
# Time:                        12:44:10   Log-Likelihood:                 238.95
# No. Observations:                 120   AIC:                            -467.9
# Df Residuals:                     115   BIC:                            -454.0
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0038      0.003      1.250      0.211      -0.002       0.010
# mktrf          1.2842      0.052     24.895      0.000       1.183       1.385
# smb            0.8456      0.105      8.022      0.000       0.639       1.052
# hml           -0.0753      0.129     -0.586      0.558      -0.327       0.177
# umd           -0.1530      0.104     -1.468      0.142      -0.357       0.051
# ==============================================================================
# Omnibus:                       25.978   Durbin-Watson:                   2.288
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               73.079
# Skew:                           0.749   Prob(JB):                     1.35e-16
# Kurtosis:                       6.517   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.859
# Model:                            OLS   Adj. R-squared:                  0.854
# Method:                 Least Squares   F-statistic:                     462.1
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           7.60e-70
# Time:                        12:44:10   Log-Likelihood:                 238.95
# No. Observations:                 120   AIC:                            -467.9
# Df Residuals:                     115   BIC:                            -454.0
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0038      0.003      1.511      0.131      -0.001       0.009
# mktrf          1.2842      0.040     31.985      0.000       1.206       1.363
# smb            0.8456      0.100      8.488      0.000       0.650       1.041
# hml           -0.0753      0.121     -0.625      0.532      -0.312       0.161
# umd           -0.1530      0.102     -1.501      0.133      -0.353       0.047
# ==============================================================================
# Omnibus:                       25.978   Durbin-Watson:                   2.288
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               73.079
# Skew:                           0.749   Prob(JB):                     1.35e-16
# Kurtosis:                       6.517   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Post-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.916
# Model:                            OLS   Adj. R-squared:                  0.913
# Method:                 Least Squares   F-statistic:                     296.0
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.46e-57
# Time:                        12:44:10   Log-Likelihood:                 303.00
# No. Observations:                 114   AIC:                            -596.0
# Df Residuals:                     109   BIC:                            -582.3
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0026      0.002      1.534      0.128      -0.001       0.006
# mktrf          1.0668      0.051     20.918      0.000       0.966       1.168
# me             0.5898      0.079      7.490      0.000       0.434       0.746
# ia            -0.1883      0.109     -1.724      0.088      -0.405       0.028
# roe           -0.8505      0.096     -8.863      0.000      -1.041      -0.660
# ==============================================================================
# Omnibus:                        0.461   Durbin-Watson:                   1.976
# Prob(Omnibus):                  0.794   Jarque-Bera (JB):                0.286
# Skew:                           0.121   Prob(JB):                        0.867
# Kurtosis:                       3.036   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.916
# Model:                            OLS   Adj. R-squared:                  0.913
# Method:                 Least Squares   F-statistic:                     455.6
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           4.79e-67
# Time:                        12:44:10   Log-Likelihood:                 303.00
# No. Observations:                 114   AIC:                            -596.0
# Df Residuals:                     109   BIC:                            -582.3
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0026      0.001      1.853      0.064      -0.000       0.005
# mktrf          1.0668      0.047     22.679      0.000       0.975       1.159
# me             0.5898      0.049     11.960      0.000       0.493       0.686
# ia            -0.1883      0.097     -1.938      0.053      -0.379       0.002
# roe           -0.8505      0.095     -8.941      0.000      -1.037      -0.664
# ==============================================================================
# Omnibus:                        0.461   Durbin-Watson:                   1.976
# Prob(Omnibus):                  0.794   Jarque-Bera (JB):                0.286
# Skew:                           0.121   Prob(JB):                        0.867
# Kurtosis:                       3.036   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.916
# Model:                            OLS   Adj. R-squared:                  0.913
# Method:                 Least Squares   F-statistic:                     788.9
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.85e-79
# Time:                        12:44:10   Log-Likelihood:                 303.00
# No. Observations:                 114   AIC:                            -596.0
# Df Residuals:                     109   BIC:                            -582.3
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0026      0.001      1.894      0.058   -9.19e-05       0.005
# mktrf          1.0668      0.040     26.361      0.000       0.987       1.146
# me             0.5898      0.039     15.295      0.000       0.514       0.665
# ia            -0.1883      0.100     -1.880      0.060      -0.385       0.008
# roe           -0.8505      0.075    -11.334      0.000      -0.998      -0.703
# ==============================================================================
# Omnibus:                        0.461   Durbin-Watson:                   1.976
# Prob(Omnibus):                  0.794   Jarque-Bera (JB):                0.286
# Skew:                           0.121   Prob(JB):                        0.867
# Kurtosis:                       3.036   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.865
# Model:                            OLS   Adj. R-squared:                  0.860
# Method:                 Least Squares   F-statistic:                     174.7
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.89e-46
# Time:                        12:44:10   Log-Likelihood:                 276.18
# No. Observations:                 114   AIC:                            -542.4
# Df Residuals:                     109   BIC:                            -528.7
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.002     -0.150      0.881      -0.005       0.004
# mktrf          1.1477      0.061     18.771      0.000       1.027       1.269
# smb            0.7893      0.095      8.278      0.000       0.600       0.978
# hml            0.0708      0.098      0.721      0.473      -0.124       0.265
# umd           -0.2125      0.074     -2.869      0.005      -0.359      -0.066
# ==============================================================================
# Omnibus:                        6.690   Durbin-Watson:                   1.869
# Prob(Omnibus):                  0.035   Jarque-Bera (JB):                6.607
# Skew:                           0.437   Prob(JB):                       0.0368
# Kurtosis:                       3.793   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.865
# Model:                            OLS   Adj. R-squared:                  0.860
# Method:                 Least Squares   F-statistic:                     141.4
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           3.37e-42
# Time:                        12:44:10   Log-Likelihood:                 276.18
# No. Observations:                 114   AIC:                            -542.4
# Df Residuals:                     109   BIC:                            -528.7
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.002     -0.187      0.852      -0.004       0.003
# mktrf          1.1477      0.063     18.311      0.000       1.025       1.271
# smb            0.7893      0.080      9.886      0.000       0.633       0.946
# hml            0.0708      0.148      0.478      0.633      -0.219       0.361
# umd           -0.2125      0.091     -2.323      0.020      -0.392      -0.033
# ==============================================================================
# Omnibus:                        6.690   Durbin-Watson:                   1.869
# Prob(Omnibus):                  0.035   Jarque-Bera (JB):                6.607
# Skew:                           0.437   Prob(JB):                       0.0368
# Kurtosis:                       3.793   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.865
# Model:                            OLS   Adj. R-squared:                  0.860
# Method:                 Least Squares   F-statistic:                     148.6
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           3.43e-43
# Time:                        12:44:11   Log-Likelihood:                 276.18
# No. Observations:                 114   AIC:                            -542.4
# Df Residuals:                     109   BIC:                            -528.7
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.002     -0.194      0.846      -0.004       0.003
# mktrf          1.1477      0.059     19.337      0.000       1.031       1.264
# smb            0.7893      0.067     11.843      0.000       0.659       0.920
# hml            0.0708      0.159      0.446      0.656      -0.240       0.382
# umd           -0.2125      0.089     -2.395      0.017      -0.386      -0.039
# ==============================================================================
# Omnibus:                        6.690   Durbin-Watson:                   1.869
# Prob(Omnibus):                  0.035   Jarque-Bera (JB):                6.607
# Skew:                           0.437   Prob(JB):                       0.0368
# Kurtosis:                       3.793   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.865
# Model:                            OLS   Adj. R-squared:                  0.860
# Method:                 Least Squares   F-statistic:                     174.7
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.89e-46
# Time:                        12:44:11   Log-Likelihood:                 276.18
# No. Observations:                 114   AIC:                            -542.4
# Df Residuals:                     109   BIC:                            -528.7
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.002     -0.150      0.881      -0.005       0.004
# mktrf          1.1477      0.061     18.771      0.000       1.027       1.269
# smb            0.7893      0.095      8.278      0.000       0.600       0.978
# hml            0.0708      0.098      0.721      0.473      -0.124       0.265
# umd           -0.2125      0.074     -2.869      0.005      -0.359      -0.066
# ==============================================================================
# Omnibus:                        6.690   Durbin-Watson:                   1.869
# Prob(Omnibus):                  0.035   Jarque-Bera (JB):                6.607
# Skew:                           0.437   Prob(JB):                       0.0368
# Kurtosis:                       3.793   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.865
# Model:                            OLS   Adj. R-squared:                  0.860
# Method:                 Least Squares   F-statistic:                     141.4
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           3.37e-42
# Time:                        12:44:11   Log-Likelihood:                 276.18
# No. Observations:                 114   AIC:                            -542.4
# Df Residuals:                     109   BIC:                            -528.7
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.002     -0.187      0.852      -0.004       0.003
# mktrf          1.1477      0.063     18.311      0.000       1.025       1.271
# smb            0.7893      0.080      9.886      0.000       0.633       0.946
# hml            0.0708      0.148      0.478      0.633      -0.219       0.361
# umd           -0.2125      0.091     -2.323      0.020      -0.392      -0.033
# ==============================================================================
# Omnibus:                        6.690   Durbin-Watson:                   1.869
# Prob(Omnibus):                  0.035   Jarque-Bera (JB):                6.607
# Skew:                           0.437   Prob(JB):                       0.0368
# Kurtosis:                       3.793   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.865
# Model:                            OLS   Adj. R-squared:                  0.860
# Method:                 Least Squares   F-statistic:                     148.6
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           3.43e-43
# Time:                        12:44:11   Log-Likelihood:                 276.18
# No. Observations:                 114   AIC:                            -542.4
# Df Residuals:                     109   BIC:                            -528.7
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.002     -0.194      0.846      -0.004       0.003
# mktrf          1.1477      0.059     19.337      0.000       1.031       1.264
# smb            0.7893      0.067     11.843      0.000       0.659       0.920
# hml            0.0708      0.159      0.446      0.656      -0.240       0.382
# umd           -0.2125      0.089     -2.395      0.017      -0.386      -0.039
# ==============================================================================
# Omnibus:                        6.690   Durbin-Watson:                   1.869
# Prob(Omnibus):                  0.035   Jarque-Bera (JB):                6.607
# Skew:                           0.437   Prob(JB):                       0.0368
# Kurtosis:                       3.793   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """
