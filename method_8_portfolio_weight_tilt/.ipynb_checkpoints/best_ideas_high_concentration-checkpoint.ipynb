# %% [markdown]
# # Method 8 - Best Ideas High Concentration

# %%
# %matplotlib inline
import pandas as pd
import warnings
from statsmodels import api as sm

from eptooling import crsp, epd, fs, hfu, crsp, db, bi
from eptooling.bm import bmdb, iso
from epquant.engine import weights, portfolio
from epquant.gen import returns
from epquant.perf import relative_performance

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Fetch Holdings and Benchmark Data

# %%
# Get HFU Data

# %store -r inst_data
inst_data = inst_data[inst_data['datadate'] >= '1999-06-30']

# Herfindahl

inst_data['target_sq'] = inst_data['target'] ** 2
herf = inst_data.groupby(['datadate', 'institution_id'])['target_sq'].sum().rename('herf').reset_index()

# Count number of positions per manager

inst_data['num_pos'] = inst_data.groupby(['datadate', 'institution_id'])[
    'fsym_id'].transform(lambda s: s.nunique())

# Remove less than 20 holdings and less than $5mm per CSP

valid_data = inst_data[inst_data['num_pos'] >= 20]
valid_data = valid_data[valid_data['public_aum'] >= 5e6]

# Use Raw Weight

valid_data['adj_target'] = valid_data['target']

# %% [markdown]
# ## Calculate Best Ideas

# %%
# Extract Best Ideas

valid_data['pos_rank'] = valid_data\
    .groupby(['datadate', 'institution_id'])['adj_target'].rank(ascending=False)

best_ideas = valid_data[valid_data['pos_rank'] == 1].copy()

# Add Herf

best_ideas = best_ideas.merge(herf)
best_ideas['herf_pct'] = best_ideas.groupby('datadate')['herf'].rank(pct=True)
best_ideas = best_ideas[best_ideas['herf_pct'] > (2 / 3)]

# Weight the best ideas equally

best_ideas['target'] = 1 / best_ideas.groupby('datadate')['institution_id'].transform('count')

# %% [markdown]
# ## Backtest Portfolio

# %%
w = weights.Weights(best_ideas)

# %store -r r

p = portfolio.DailyPortfolio(w, r, end_date='2018-12-31')

rf = bi.get_risk_free_rate()
monthly_return = p.port_return.loc['1999-07-01':].resample('M').apply(epd.prod_red)
monthly_return = (monthly_return - rf).dropna()
monthly_return.name = 'port_return'

# %% [markdown]
# ## Plot Performance

# %%
epd.nav(monthly_return).plot()

# %%
monthly_return.resample('A').apply(epd.prod_red)
# Out:
# datadate
# 1999-12-31    0.272399
# 2000-12-31   -0.081017
# 2001-12-31   -0.117263
# 2002-12-31   -0.328838
# 2003-12-31    0.854297
# 2004-12-31    0.248270
# 2005-12-31    0.051139
# 2006-12-31    0.183236
# 2007-12-31   -0.037134
# 2008-12-31   -0.468816
# 2009-12-31    0.584859
# 2010-12-31    0.224900
# 2011-12-31   -0.056234
# 2012-12-31    0.180847
# 2013-12-31    0.543513
# 2014-12-31    0.055310
# 2015-12-31   -0.085856
# 2016-12-31    0.165870
# 2017-12-31    0.240005
# 2018-12-31   -0.112866
# Freq: A-DEC, Name: port_return, dtype: float64

# %% [markdown]
# ## Fetch Factor Models

# %%
# Get Factor Models
q_factor_model = bi.get_q_factor_model()
fama_french_five_factor_model = bi.get_fama_french_five_factor_model()
four_factor_model = bi.get_four_factor_model()

# Concat Portfolio Return
q_factor = pd.concat([monthly_return, q_factor_model], axis=1)
fama_french_five = pd.concat([monthly_return, fama_french_five_factor_model], axis=1)
four_factor = pd.concat([monthly_return, four_factor_model], axis=1)

# Add Constants
q_factor.insert(1, 'const', 1)
fama_french_five.insert(1, 'const', 1)
four_factor.insert(1, 'const', 1)

# Split Period into Pre and Post Crisis
q_factor_pre, q_factor_post = q_factor.loc[:'2009-06-30'], q_factor.loc['2009-07-31':]
fama_french_five_pre, fama_french_five_post = fama_french_five.loc[:'2009-06-30'], fama_french_five.loc['2009-07-31':] 
four_factor_pre, four_factor_post = four_factor.loc[:'2009-06-30'], four_factor.loc['2009-07-31':]

# %% [markdown]
# ## Full Time Period Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.903
# Model:                            OLS   Adj. R-squared:                  0.901
# Method:                 Least Squares   F-statistic:                     533.2
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):          9.54e-115
# Time:                        13:28:06   Log-Likelihood:                 564.37
# No. Observations:                 234   AIC:                            -1119.
# Df Residuals:                     229   BIC:                            -1101.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0043      0.001      2.899      0.004       0.001       0.007
# mktrf          1.0144      0.041     24.805      0.000       0.934       1.095
# me             0.5963      0.048     12.535      0.000       0.503       0.690
# ia             0.0814      0.072      1.125      0.262      -0.061       0.224
# roe           -0.6279      0.062    -10.146      0.000      -0.750      -0.506
# ==============================================================================
# Omnibus:                       16.587   Durbin-Watson:                   1.912
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               48.665
# Skew:                           0.119   Prob(JB):                     2.71e-11
# Kurtosis:                       5.221   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.903
# Model:                            OLS   Adj. R-squared:                  0.901
# Method:                 Least Squares   F-statistic:                     527.3
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):          3.06e-114
# Time:                        13:28:06   Log-Likelihood:                 564.37
# No. Observations:                 234   AIC:                            -1119.
# Df Residuals:                     229   BIC:                            -1101.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0043      0.002      2.620      0.009       0.001       0.008
# mktrf          1.0144      0.038     26.537      0.000       0.940       1.089
# me             0.5963      0.049     12.190      0.000       0.500       0.692
# ia             0.0814      0.131      0.623      0.533      -0.175       0.337
# roe           -0.6279      0.112     -5.626      0.000      -0.847      -0.409
# ==============================================================================
# Omnibus:                       16.587   Durbin-Watson:                   1.912
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               48.665
# Skew:                           0.119   Prob(JB):                     2.71e-11
# Kurtosis:                       5.221   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.903
# Model:                            OLS   Adj. R-squared:                  0.901
# Method:                 Least Squares   F-statistic:                     495.4
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):          1.85e-111
# Time:                        13:28:07   Log-Likelihood:                 564.37
# No. Observations:                 234   AIC:                            -1119.
# Df Residuals:                     229   BIC:                            -1101.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0043      0.002      2.860      0.004       0.001       0.007
# mktrf          1.0144      0.032     31.601      0.000       0.952       1.077
# me             0.5963      0.051     11.765      0.000       0.497       0.696
# ia             0.0814      0.120      0.677      0.498      -0.154       0.317
# roe           -0.6279      0.112     -5.620      0.000      -0.847      -0.409
# ==============================================================================
# Omnibus:                       16.587   Durbin-Watson:                   1.912
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               48.665
# Skew:                           0.119   Prob(JB):                     2.71e-11
# Kurtosis:                       5.221   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.869
# Model:                            OLS   Adj. R-squared:                  0.867
# Method:                 Least Squares   F-statistic:                     379.2
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):          9.87e-100
# Time:                        13:28:07   Log-Likelihood:                 529.01
# No. Observations:                 234   AIC:                            -1048.
# Df Residuals:                     229   BIC:                            -1031.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0021      0.002      1.207      0.229      -0.001       0.005
# mktrf          1.1603      0.044     26.493      0.000       1.074       1.247
# smb            0.8089      0.055     14.796      0.000       0.701       0.917
# hml            0.0521      0.054      0.959      0.339      -0.055       0.159
# umd           -0.1358      0.036     -3.811      0.000      -0.206      -0.066
# ==============================================================================
# Omnibus:                       31.967   Durbin-Watson:                   1.916
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              112.337
# Skew:                           0.479   Prob(JB):                     4.04e-25
# Kurtosis:                       6.256   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.869
# Model:                            OLS   Adj. R-squared:                  0.867
# Method:                 Least Squares   F-statistic:                     450.5
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):          2.99e-107
# Time:                        13:28:07   Log-Likelihood:                 529.01
# No. Observations:                 234   AIC:                            -1048.
# Df Residuals:                     229   BIC:                            -1031.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0021      0.002      1.226      0.220      -0.001       0.005
# mktrf          1.1603      0.041     28.443      0.000       1.080       1.240
# smb            0.8089      0.075     10.781      0.000       0.662       0.956
# hml            0.0521      0.096      0.541      0.588      -0.137       0.241
# umd           -0.1358      0.081     -1.672      0.094      -0.295       0.023
# ==============================================================================
# Omnibus:                       31.967   Durbin-Watson:                   1.916
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              112.337
# Skew:                           0.479   Prob(JB):                     4.04e-25
# Kurtosis:                       6.256   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.869
# Model:                            OLS   Adj. R-squared:                  0.867
# Method:                 Least Squares   F-statistic:                     394.7
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):          1.81e-101
# Time:                        13:28:07   Log-Likelihood:                 529.01
# No. Observations:                 234   AIC:                            -1048.
# Df Residuals:                     229   BIC:                            -1031.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0021      0.002      1.322      0.186      -0.001       0.005
# mktrf          1.1603      0.039     29.626      0.000       1.084       1.237
# smb            0.8089      0.058     13.922      0.000       0.695       0.923
# hml            0.0521      0.089      0.587      0.557      -0.122       0.226
# umd           -0.1358      0.083     -1.631      0.103      -0.299       0.027
# ==============================================================================
# Omnibus:                       31.967   Durbin-Watson:                   1.916
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              112.337
# Skew:                           0.479   Prob(JB):                     4.04e-25
# Kurtosis:                       6.256   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.869
# Model:                            OLS   Adj. R-squared:                  0.867
# Method:                 Least Squares   F-statistic:                     379.2
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):          9.87e-100
# Time:                        13:28:07   Log-Likelihood:                 529.01
# No. Observations:                 234   AIC:                            -1048.
# Df Residuals:                     229   BIC:                            -1031.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0021      0.002      1.207      0.229      -0.001       0.005
# mktrf          1.1603      0.044     26.493      0.000       1.074       1.247
# smb            0.8089      0.055     14.796      0.000       0.701       0.917
# hml            0.0521      0.054      0.959      0.339      -0.055       0.159
# umd           -0.1358      0.036     -3.811      0.000      -0.206      -0.066
# ==============================================================================
# Omnibus:                       31.967   Durbin-Watson:                   1.916
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              112.337
# Skew:                           0.479   Prob(JB):                     4.04e-25
# Kurtosis:                       6.256   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.869
# Model:                            OLS   Adj. R-squared:                  0.867
# Method:                 Least Squares   F-statistic:                     450.5
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):          2.99e-107
# Time:                        13:28:07   Log-Likelihood:                 529.01
# No. Observations:                 234   AIC:                            -1048.
# Df Residuals:                     229   BIC:                            -1031.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0021      0.002      1.226      0.220      -0.001       0.005
# mktrf          1.1603      0.041     28.443      0.000       1.080       1.240
# smb            0.8089      0.075     10.781      0.000       0.662       0.956
# hml            0.0521      0.096      0.541      0.588      -0.137       0.241
# umd           -0.1358      0.081     -1.672      0.094      -0.295       0.023
# ==============================================================================
# Omnibus:                       31.967   Durbin-Watson:                   1.916
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              112.337
# Skew:                           0.479   Prob(JB):                     4.04e-25
# Kurtosis:                       6.256   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.869
# Model:                            OLS   Adj. R-squared:                  0.867
# Method:                 Least Squares   F-statistic:                     394.7
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):          1.81e-101
# Time:                        13:28:07   Log-Likelihood:                 529.01
# No. Observations:                 234   AIC:                            -1048.
# Df Residuals:                     229   BIC:                            -1031.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0021      0.002      1.322      0.186      -0.001       0.005
# mktrf          1.1603      0.039     29.626      0.000       1.084       1.237
# smb            0.8089      0.058     13.922      0.000       0.695       0.923
# hml            0.0521      0.089      0.587      0.557      -0.122       0.226
# umd           -0.1358      0.083     -1.631      0.103      -0.299       0.027
# ==============================================================================
# Omnibus:                       31.967   Durbin-Watson:                   1.916
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              112.337
# Skew:                           0.479   Prob(JB):                     4.04e-25
# Kurtosis:                       6.256   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Pre-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.894
# Model:                            OLS   Adj. R-squared:                  0.890
# Method:                 Least Squares   F-statistic:                     241.2
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           6.14e-55
# Time:                        13:28:07   Log-Likelihood:                 265.74
# No. Observations:                 120   AIC:                            -521.5
# Df Residuals:                     115   BIC:                            -507.5
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0056      0.003      2.175      0.032       0.001       0.011
# mktrf          1.0301      0.070     14.806      0.000       0.892       1.168
# me             0.5777      0.069      8.406      0.000       0.442       0.714
# ia             0.1854      0.108      1.723      0.088      -0.028       0.399
# roe           -0.6288      0.095     -6.602      0.000      -0.817      -0.440
# ==============================================================================
# Omnibus:                        4.937   Durbin-Watson:                   1.952
# Prob(Omnibus):                  0.085   Jarque-Bera (JB):                6.820
# Skew:                          -0.072   Prob(JB):                       0.0330
# Kurtosis:                       4.159   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.894
# Model:                            OLS   Adj. R-squared:                  0.890
# Method:                 Least Squares   F-statistic:                     283.9
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.35e-58
# Time:                        13:28:07   Log-Likelihood:                 265.74
# No. Observations:                 120   AIC:                            -521.5
# Df Residuals:                     115   BIC:                            -507.5
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0056      0.003      2.038      0.042       0.000       0.011
# mktrf          1.0301      0.068     15.086      0.000       0.896       1.164
# me             0.5777      0.072      8.012      0.000       0.436       0.719
# ia             0.1854      0.158      1.172      0.241      -0.125       0.495
# roe           -0.6288      0.144     -4.377      0.000      -0.910      -0.347
# ==============================================================================
# Omnibus:                        4.937   Durbin-Watson:                   1.952
# Prob(Omnibus):                  0.085   Jarque-Bera (JB):                6.820
# Skew:                          -0.072   Prob(JB):                       0.0330
# Kurtosis:                       4.159   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.894
# Model:                            OLS   Adj. R-squared:                  0.890
# Method:                 Least Squares   F-statistic:                     276.0
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           5.85e-58
# Time:                        13:28:07   Log-Likelihood:                 265.74
# No. Observations:                 120   AIC:                            -521.5
# Df Residuals:                     115   BIC:                            -507.5
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0056      0.002      2.258      0.024       0.001       0.010
# mktrf          1.0301      0.055     18.734      0.000       0.922       1.138
# me             0.5777      0.077      7.545      0.000       0.428       0.728
# ia             0.1854      0.134      1.388      0.165      -0.076       0.447
# roe           -0.6288      0.142     -4.421      0.000      -0.908      -0.350
# ==============================================================================
# Omnibus:                        4.937   Durbin-Watson:                   1.952
# Prob(Omnibus):                  0.085   Jarque-Bera (JB):                6.820
# Skew:                          -0.072   Prob(JB):                       0.0330
# Kurtosis:                       4.159   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.862
# Model:                            OLS   Adj. R-squared:                  0.857
# Method:                 Least Squares   F-statistic:                     178.9
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.14e-48
# Time:                        13:28:07   Log-Likelihood:                 249.98
# No. Observations:                 120   AIC:                            -490.0
# Df Residuals:                     115   BIC:                            -476.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0045      0.003      1.575      0.118      -0.001       0.010
# mktrf          1.2213      0.070     17.473      0.000       1.083       1.360
# smb            0.8008      0.080     10.063      0.000       0.643       0.958
# hml            0.0571      0.080      0.716      0.475      -0.101       0.215
# umd           -0.1178      0.049     -2.398      0.018      -0.215      -0.020
# ==============================================================================
# Omnibus:                       11.955   Durbin-Watson:                   1.991
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               24.995
# Skew:                           0.328   Prob(JB):                     3.74e-06
# Kurtosis:                       5.137   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.862
# Model:                            OLS   Adj. R-squared:                  0.857
# Method:                 Least Squares   F-statistic:                     381.1
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.41e-65
# Time:                        13:28:07   Log-Likelihood:                 249.98
# No. Observations:                 120   AIC:                            -490.0
# Df Residuals:                     115   BIC:                            -476.0
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0045      0.003      1.662      0.097      -0.001       0.010
# mktrf          1.2213      0.060     20.223      0.000       1.103       1.340
# smb            0.8008      0.096      8.322      0.000       0.612       0.989
# hml            0.0571      0.121      0.474      0.636      -0.179       0.293
# umd           -0.1178      0.092     -1.280      0.201      -0.298       0.063
# ==============================================================================
# Omnibus:                       11.955   Durbin-Watson:                   1.991
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               24.995
# Skew:                           0.328   Prob(JB):                     3.74e-06
# Kurtosis:                       5.137   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.862
# Model:                            OLS   Adj. R-squared:                  0.857
# Method:                 Least Squares   F-statistic:                     439.4
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.16e-68
# Time:                        13:28:07   Log-Likelihood:                 249.98
# No. Observations:                 120   AIC:                            -490.0
# Df Residuals:                     115   BIC:                            -476.0
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0045      0.002      1.860      0.063      -0.000       0.009
# mktrf          1.2213      0.051     23.787      0.000       1.121       1.322
# smb            0.8008      0.075     10.698      0.000       0.654       0.948
# hml            0.0571      0.119      0.480      0.631      -0.176       0.290
# umd           -0.1178      0.089     -1.322      0.186      -0.293       0.057
# ==============================================================================
# Omnibus:                       11.955   Durbin-Watson:                   1.991
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               24.995
# Skew:                           0.328   Prob(JB):                     3.74e-06
# Kurtosis:                       5.137   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.862
# Model:                            OLS   Adj. R-squared:                  0.857
# Method:                 Least Squares   F-statistic:                     178.9
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.14e-48
# Time:                        13:28:07   Log-Likelihood:                 249.98
# No. Observations:                 120   AIC:                            -490.0
# Df Residuals:                     115   BIC:                            -476.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0045      0.003      1.575      0.118      -0.001       0.010
# mktrf          1.2213      0.070     17.473      0.000       1.083       1.360
# smb            0.8008      0.080     10.063      0.000       0.643       0.958
# hml            0.0571      0.080      0.716      0.475      -0.101       0.215
# umd           -0.1178      0.049     -2.398      0.018      -0.215      -0.020
# ==============================================================================
# Omnibus:                       11.955   Durbin-Watson:                   1.991
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               24.995
# Skew:                           0.328   Prob(JB):                     3.74e-06
# Kurtosis:                       5.137   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.862
# Model:                            OLS   Adj. R-squared:                  0.857
# Method:                 Least Squares   F-statistic:                     381.1
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.41e-65
# Time:                        13:28:07   Log-Likelihood:                 249.98
# No. Observations:                 120   AIC:                            -490.0
# Df Residuals:                     115   BIC:                            -476.0
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0045      0.003      1.662      0.097      -0.001       0.010
# mktrf          1.2213      0.060     20.223      0.000       1.103       1.340
# smb            0.8008      0.096      8.322      0.000       0.612       0.989
# hml            0.0571      0.121      0.474      0.636      -0.179       0.293
# umd           -0.1178      0.092     -1.280      0.201      -0.298       0.063
# ==============================================================================
# Omnibus:                       11.955   Durbin-Watson:                   1.991
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               24.995
# Skew:                           0.328   Prob(JB):                     3.74e-06
# Kurtosis:                       5.137   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.862
# Model:                            OLS   Adj. R-squared:                  0.857
# Method:                 Least Squares   F-statistic:                     439.4
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.16e-68
# Time:                        13:28:07   Log-Likelihood:                 249.98
# No. Observations:                 120   AIC:                            -490.0
# Df Residuals:                     115   BIC:                            -476.0
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0045      0.002      1.860      0.063      -0.000       0.009
# mktrf          1.2213      0.051     23.787      0.000       1.121       1.322
# smb            0.8008      0.075     10.698      0.000       0.654       0.948
# hml            0.0571      0.119      0.480      0.631      -0.176       0.290
# umd           -0.1178      0.089     -1.322      0.186      -0.293       0.057
# ==============================================================================
# Omnibus:                       11.955   Durbin-Watson:                   1.991
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               24.995
# Skew:                           0.328   Prob(JB):                     3.74e-06
# Kurtosis:                       5.137   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Post-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.936
# Model:                            OLS   Adj. R-squared:                  0.934
# Method:                 Least Squares   F-statistic:                     401.4
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           3.13e-64
# Time:                        13:28:07   Log-Likelihood:                 325.80
# No. Observations:                 114   AIC:                            -641.6
# Df Residuals:                     109   BIC:                            -627.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0031      0.001      2.198      0.030       0.000       0.006
# mktrf          1.0170      0.042     24.358      0.000       0.934       1.100
# me             0.6180      0.064      9.587      0.000       0.490       0.746
# ia            -0.2388      0.089     -2.671      0.009      -0.416      -0.062
# roe           -0.7348      0.079     -9.352      0.000      -0.891      -0.579
# ==============================================================================
# Omnibus:                        0.300   Durbin-Watson:                   1.894
# Prob(Omnibus):                  0.861   Jarque-Bera (JB):                0.471
# Skew:                           0.000   Prob(JB):                        0.790
# Kurtosis:                       2.685   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.936
# Model:                            OLS   Adj. R-squared:                  0.934
# Method:                 Least Squares   F-statistic:                     1060.
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           3.02e-86
# Time:                        13:28:07   Log-Likelihood:                 325.80
# No. Observations:                 114   AIC:                            -641.6
# Df Residuals:                     109   BIC:                            -627.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0031      0.001      2.427      0.015       0.001       0.006
# mktrf          1.0170      0.036     28.404      0.000       0.947       1.087
# me             0.6180      0.045     13.655      0.000       0.529       0.707
# ia            -0.2388      0.072     -3.323      0.001      -0.380      -0.098
# roe           -0.7348      0.086     -8.562      0.000      -0.903      -0.567
# ==============================================================================
# Omnibus:                        0.300   Durbin-Watson:                   1.894
# Prob(Omnibus):                  0.861   Jarque-Bera (JB):                0.471
# Skew:                           0.000   Prob(JB):                        0.790
# Kurtosis:                       2.685   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.936
# Model:                            OLS   Adj. R-squared:                  0.934
# Method:                 Least Squares   F-statistic:                     1359.
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           5.51e-92
# Time:                        13:28:07   Log-Likelihood:                 325.80
# No. Observations:                 114   AIC:                            -641.6
# Df Residuals:                     109   BIC:                            -627.9
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0031      0.001      2.725      0.006       0.001       0.005
# mktrf          1.0170      0.033     30.417      0.000       0.951       1.083
# me             0.6180      0.041     15.020      0.000       0.537       0.699
# ia            -0.2388      0.069     -3.469      0.001      -0.374      -0.104
# roe           -0.7348      0.074     -9.929      0.000      -0.880      -0.590
# ==============================================================================
# Omnibus:                        0.300   Durbin-Watson:                   1.894
# Prob(Omnibus):                  0.861   Jarque-Bera (JB):                0.471
# Skew:                           0.000   Prob(JB):                        0.790
# Kurtosis:                       2.685   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.893
# Model:                            OLS   Adj. R-squared:                  0.889
# Method:                 Least Squares   F-statistic:                     226.6
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           7.46e-52
# Time:                        13:28:07   Log-Likelihood:                 295.94
# No. Observations:                 114   AIC:                            -581.9
# Df Residuals:                     109   BIC:                            -568.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0002      0.002      0.083      0.934      -0.003       0.004
# mktrf          1.1053      0.051     21.499      0.000       1.003       1.207
# smb            0.7742      0.080      9.657      0.000       0.615       0.933
# hml            0.0677      0.083      0.820      0.414      -0.096       0.231
# umd           -0.1503      0.062     -2.413      0.018      -0.274      -0.027
# ==============================================================================
# Omnibus:                        4.489   Durbin-Watson:                   1.775
# Prob(Omnibus):                  0.106   Jarque-Bera (JB):                5.637
# Skew:                           0.110   Prob(JB):                       0.0597
# Kurtosis:                       4.067   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.893
# Model:                            OLS   Adj. R-squared:                  0.889
# Method:                 Least Squares   F-statistic:                     181.6
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           3.02e-47
# Time:                        13:28:07   Log-Likelihood:                 295.94
# No. Observations:                 114   AIC:                            -581.9
# Df Residuals:                     109   BIC:                            -568.2
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0002      0.001      0.101      0.919      -0.003       0.003
# mktrf          1.1053      0.046     23.839      0.000       1.014       1.196
# smb            0.7742      0.083      9.288      0.000       0.611       0.938
# hml            0.0677      0.108      0.625      0.532      -0.145       0.280
# umd           -0.1503      0.063     -2.401      0.016      -0.273      -0.028
# ==============================================================================
# Omnibus:                        4.489   Durbin-Watson:                   1.775
# Prob(Omnibus):                  0.106   Jarque-Bera (JB):                5.637
# Skew:                           0.110   Prob(JB):                       0.0597
# Kurtosis:                       4.067   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.893
# Model:                            OLS   Adj. R-squared:                  0.889
# Method:                 Least Squares   F-statistic:                     159.6
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.30e-44
# Time:                        13:28:07   Log-Likelihood:                 295.94
# No. Observations:                 114   AIC:                            -581.9
# Df Residuals:                     109   BIC:                            -568.2
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0002      0.001      0.107      0.915      -0.003       0.003
# mktrf          1.1053      0.048     23.203      0.000       1.012       1.199
# smb            0.7742      0.065     11.987      0.000       0.648       0.901
# hml            0.0677      0.110      0.615      0.539      -0.148       0.284
# umd           -0.1503      0.060     -2.503      0.012      -0.268      -0.033
# ==============================================================================
# Omnibus:                        4.489   Durbin-Watson:                   1.775
# Prob(Omnibus):                  0.106   Jarque-Bera (JB):                5.637
# Skew:                           0.110   Prob(JB):                       0.0597
# Kurtosis:                       4.067   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.893
# Model:                            OLS   Adj. R-squared:                  0.889
# Method:                 Least Squares   F-statistic:                     226.6
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           7.46e-52
# Time:                        13:28:07   Log-Likelihood:                 295.94
# No. Observations:                 114   AIC:                            -581.9
# Df Residuals:                     109   BIC:                            -568.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0002      0.002      0.083      0.934      -0.003       0.004
# mktrf          1.1053      0.051     21.499      0.000       1.003       1.207
# smb            0.7742      0.080      9.657      0.000       0.615       0.933
# hml            0.0677      0.083      0.820      0.414      -0.096       0.231
# umd           -0.1503      0.062     -2.413      0.018      -0.274      -0.027
# ==============================================================================
# Omnibus:                        4.489   Durbin-Watson:                   1.775
# Prob(Omnibus):                  0.106   Jarque-Bera (JB):                5.637
# Skew:                           0.110   Prob(JB):                       0.0597
# Kurtosis:                       4.067   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.893
# Model:                            OLS   Adj. R-squared:                  0.889
# Method:                 Least Squares   F-statistic:                     181.6
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           3.02e-47
# Time:                        13:28:07   Log-Likelihood:                 295.94
# No. Observations:                 114   AIC:                            -581.9
# Df Residuals:                     109   BIC:                            -568.2
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0002      0.001      0.101      0.919      -0.003       0.003
# mktrf          1.1053      0.046     23.839      0.000       1.014       1.196
# smb            0.7742      0.083      9.288      0.000       0.611       0.938
# hml            0.0677      0.108      0.625      0.532      -0.145       0.280
# umd           -0.1503      0.063     -2.401      0.016      -0.273      -0.028
# ==============================================================================
# Omnibus:                        4.489   Durbin-Watson:                   1.775
# Prob(Omnibus):                  0.106   Jarque-Bera (JB):                5.637
# Skew:                           0.110   Prob(JB):                       0.0597
# Kurtosis:                       4.067   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.893
# Model:                            OLS   Adj. R-squared:                  0.889
# Method:                 Least Squares   F-statistic:                     159.6
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.30e-44
# Time:                        13:28:07   Log-Likelihood:                 295.94
# No. Observations:                 114   AIC:                            -581.9
# Df Residuals:                     109   BIC:                            -568.2
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0002      0.001      0.107      0.915      -0.003       0.003
# mktrf          1.1053      0.048     23.203      0.000       1.012       1.199
# smb            0.7742      0.065     11.987      0.000       0.648       0.901
# hml            0.0677      0.110      0.615      0.539      -0.148       0.284
# umd           -0.1503      0.060     -2.503      0.012      -0.268      -0.033
# ==============================================================================
# Omnibus:                        4.489   Durbin-Watson:                   1.775
# Prob(Omnibus):                  0.106   Jarque-Bera (JB):                5.637
# Skew:                           0.110   Prob(JB):                       0.0597
# Kurtosis:                       4.067   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """
