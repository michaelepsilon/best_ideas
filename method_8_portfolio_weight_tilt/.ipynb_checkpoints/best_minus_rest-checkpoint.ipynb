# %% [markdown]
# # Method 8 - Best Minus Rest

# %%
# %matplotlib inline
import pandas as pd
import warnings
from statsmodels import api as sm

from eptooling import crsp, epd, fs, hfu, crsp, db, bi
from eptooling.bm import bmdb, iso
from epquant.engine import weights, portfolio
from epquant.gen import returns
from epquant.perf import relative_performance

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Fetch Holdings and Benchmark Data

# %%
# Get HFU Data

# %store -r inst_data
inst_data = inst_data[inst_data['datadate'] >= '1999-06-30']

# Count number of positions per manager

inst_data['num_pos'] = inst_data.groupby(['datadate', 'institution_id'])[
    'fsym_id'].transform(lambda s: s.nunique())

# Remove less than 20 holdings and less than $5mm per CSP

valid_data = inst_data[inst_data['num_pos'] >= 20]
valid_data = valid_data[valid_data['public_aum'] >= 5e6]

# Use Raw Weight

valid_data['adj_target'] = valid_data['target']

# %% [markdown]
# ## Calculate Best Ideas

# %%
# Extract Best Ideas

valid_data['pos_rank'] = valid_data\
    .groupby(['datadate', 'institution_id'])['adj_target'].rank(ascending=False)

                                                                                         
# Split Long and Short and Filter to Highest Tilts

long_ideas = valid_data[valid_data['pos_rank'] == 1].copy()                                                                           
short_ideas = valid_data[valid_data['pos_rank'] != 1].copy()

# Weight the best ideas equally

long_ideas['target'] = 1 / long_ideas.groupby('datadate')[
    'institution_id'].transform('count')

short_ideas['target'] = - short_ideas['target'] / short_ideas.groupby([
    'datadate', 'institution_id'])['target'].transform('sum') * \
                        (1 / short_ideas.groupby('datadate')['institution_id']
                         .transform(lambda s: s.nunique()))

best_ideas = pd.concat([long_ideas, short_ideas])

# %% [markdown]
# ## Backtest Portfolio

# %%
w = weights.Weights(best_ideas)

# %store -r r

p = portfolio.DailyPortfolio(w, r, end_date='2018-12-31')

monthly_return = p.port_return.loc['1999-07-01':].resample('M').apply(epd.prod_red)
monthly_return.name = 'port_return'

# %% [markdown]
# ## Plot Performance

# %%
epd.nav(monthly_return).plot()

# %%
monthly_return.resample('A').apply(epd.prod_red)
# Out:
# datadate
# 1999-12-31    0.158129
# 2000-12-31   -0.190829
# 2001-12-31   -0.085237
# 2002-12-31   -0.139311
# 2003-12-31    0.306194
# 2004-12-31   -0.000464
# 2005-12-31   -0.038531
# 2006-12-31   -0.003364
# 2007-12-31   -0.038279
# 2008-12-31   -0.163495
# 2009-12-31    0.329188
# 2010-12-31    0.021180
# 2011-12-31   -0.104776
# 2012-12-31    0.042429
# 2013-12-31    0.066885
# 2014-12-31   -0.034297
# 2015-12-31   -0.090662
# 2016-12-31    0.037725
# 2017-12-31   -0.022466
# 2018-12-31   -0.052769
# Freq: A-DEC, Name: port_return, dtype: float64

# %% [markdown]
# ## Fetch Factor Models

# %%
# Get Factor Models
q_factor_model = bi.get_q_factor_model()
fama_french_five_factor_model = bi.get_fama_french_five_factor_model()
four_factor_model = bi.get_four_factor_model()

# Concat Portfolio Return
q_factor = pd.concat([monthly_return, q_factor_model], axis=1)
fama_french_five = pd.concat([monthly_return, fama_french_five_factor_model], axis=1)
four_factor = pd.concat([monthly_return, four_factor_model], axis=1)

# Add Constants
q_factor.insert(1, 'const', 1)
fama_french_five.insert(1, 'const', 1)
four_factor.insert(1, 'const', 1)

# Split Period into Pre and Post Crisis
q_factor_pre, q_factor_post = q_factor.loc[:'2009-06-30'], q_factor.loc['2009-07-31':]
fama_french_five_pre, fama_french_five_post = fama_french_five.loc[:'2009-06-30'], fama_french_five.loc['2009-07-31':] 
four_factor_pre, four_factor_post = four_factor.loc[:'2009-06-30'], four_factor.loc['2009-07-31':]

# %% [markdown]
# ## Full Time Period Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.659
# Model:                            OLS   Adj. R-squared:                  0.653
# Method:                 Least Squares   F-statistic:                     110.4
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.80e-52
# Time:                        12:52:20   Log-Likelihood:                 585.72
# No. Observations:                 234   AIC:                            -1161.
# Df Residuals:                     229   BIC:                            -1144.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0011      0.001      0.781      0.436      -0.002       0.004
# mktrf          0.0885      0.037      2.370      0.019       0.015       0.162
# me             0.2603      0.043      5.995      0.000       0.175       0.346
# ia            -0.0891      0.066     -1.349      0.179      -0.219       0.041
# roe           -0.6622      0.056    -11.722      0.000      -0.774      -0.551
# ==============================================================================
# Omnibus:                       77.977   Durbin-Watson:                   2.053
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              347.176
# Skew:                           1.266   Prob(JB):                     4.09e-76
# Kurtosis:                       8.403   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.659
# Model:                            OLS   Adj. R-squared:                  0.653
# Method:                 Least Squares   F-statistic:                     62.97
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           7.84e-36
# Time:                        12:52:20   Log-Likelihood:                 585.72
# No. Observations:                 234   AIC:                            -1161.
# Df Residuals:                     229   BIC:                            -1144.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0011      0.002      0.654      0.513      -0.002       0.004
# mktrf          0.0885      0.037      2.385      0.017       0.016       0.161
# me             0.2603      0.043      6.056      0.000       0.176       0.345
# ia            -0.0891      0.108     -0.828      0.408      -0.300       0.122
# roe           -0.6622      0.121     -5.492      0.000      -0.899      -0.426
# ==============================================================================
# Omnibus:                       77.977   Durbin-Watson:                   2.053
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              347.176
# Skew:                           1.266   Prob(JB):                     4.09e-76
# Kurtosis:                       8.403   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.659
# Model:                            OLS   Adj. R-squared:                  0.653
# Method:                 Least Squares   F-statistic:                     83.63
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.15e-43
# Time:                        12:52:20   Log-Likelihood:                 585.72
# No. Observations:                 234   AIC:                            -1161.
# Df Residuals:                     229   BIC:                            -1144.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0011      0.002      0.682      0.495      -0.002       0.004
# mktrf          0.0885      0.034      2.592      0.010       0.022       0.155
# me             0.2603      0.044      5.931      0.000       0.174       0.346
# ia            -0.0891      0.096     -0.931      0.352      -0.277       0.098
# roe           -0.6622      0.123     -5.381      0.000      -0.903      -0.421
# ==============================================================================
# Omnibus:                       77.977   Durbin-Watson:                   2.053
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              347.176
# Skew:                           1.266   Prob(JB):                     4.09e-76
# Kurtosis:                       8.403   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.565
# Model:                            OLS   Adj. R-squared:                  0.558
# Method:                 Least Squares   F-statistic:                     74.50
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.35e-40
# Time:                        12:52:20   Log-Likelihood:                 557.51
# No. Observations:                 234   AIC:                            -1105.
# Df Residuals:                     229   BIC:                            -1088.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0013      0.002     -0.882      0.379      -0.004       0.002
# mktrf          0.2194      0.039      5.659      0.000       0.143       0.296
# smb            0.5180      0.048     10.702      0.000       0.423       0.613
# hml           -0.1408      0.048     -2.929      0.004      -0.236      -0.046
# umd           -0.1895      0.032     -6.007      0.000      -0.252      -0.127
# ==============================================================================
# Omnibus:                       86.464   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              446.413
# Skew:                           1.368   Prob(JB):                     1.16e-97
# Kurtosis:                       9.189   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.565
# Model:                            OLS   Adj. R-squared:                  0.558
# Method:                 Least Squares   F-statistic:                     26.18
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           6.95e-18
# Time:                        12:52:20   Log-Likelihood:                 557.51
# No. Observations:                 234   AIC:                            -1105.
# Df Residuals:                     229   BIC:                            -1088.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0013      0.002     -0.874      0.382      -0.004       0.002
# mktrf          0.2194      0.042      5.193      0.000       0.137       0.302
# smb            0.5180      0.065      7.935      0.000       0.390       0.646
# hml           -0.1408      0.070     -2.016      0.044      -0.278      -0.004
# umd           -0.1895      0.067     -2.847      0.004      -0.320      -0.059
# ==============================================================================
# Omnibus:                       86.464   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              446.413
# Skew:                           1.368   Prob(JB):                     1.16e-97
# Kurtosis:                       9.189   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.565
# Model:                            OLS   Adj. R-squared:                  0.558
# Method:                 Least Squares   F-statistic:                     25.87
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.05e-17
# Time:                        12:52:20   Log-Likelihood:                 557.51
# No. Observations:                 234   AIC:                            -1105.
# Df Residuals:                     229   BIC:                            -1088.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0013      0.001     -0.960      0.337      -0.004       0.001
# mktrf          0.2194      0.044      4.949      0.000       0.133       0.306
# smb            0.5180      0.059      8.794      0.000       0.403       0.633
# hml           -0.1408      0.066     -2.126      0.034      -0.271      -0.011
# umd           -0.1895      0.071     -2.658      0.008      -0.329      -0.050
# ==============================================================================
# Omnibus:                       86.464   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              446.413
# Skew:                           1.368   Prob(JB):                     1.16e-97
# Kurtosis:                       9.189   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.565
# Model:                            OLS   Adj. R-squared:                  0.558
# Method:                 Least Squares   F-statistic:                     74.50
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.35e-40
# Time:                        12:52:20   Log-Likelihood:                 557.51
# No. Observations:                 234   AIC:                            -1105.
# Df Residuals:                     229   BIC:                            -1088.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0013      0.002     -0.882      0.379      -0.004       0.002
# mktrf          0.2194      0.039      5.659      0.000       0.143       0.296
# smb            0.5180      0.048     10.702      0.000       0.423       0.613
# hml           -0.1408      0.048     -2.929      0.004      -0.236      -0.046
# umd           -0.1895      0.032     -6.007      0.000      -0.252      -0.127
# ==============================================================================
# Omnibus:                       86.464   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              446.413
# Skew:                           1.368   Prob(JB):                     1.16e-97
# Kurtosis:                       9.189   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.565
# Model:                            OLS   Adj. R-squared:                  0.558
# Method:                 Least Squares   F-statistic:                     26.18
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           6.95e-18
# Time:                        12:52:20   Log-Likelihood:                 557.51
# No. Observations:                 234   AIC:                            -1105.
# Df Residuals:                     229   BIC:                            -1088.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0013      0.002     -0.874      0.382      -0.004       0.002
# mktrf          0.2194      0.042      5.193      0.000       0.137       0.302
# smb            0.5180      0.065      7.935      0.000       0.390       0.646
# hml           -0.1408      0.070     -2.016      0.044      -0.278      -0.004
# umd           -0.1895      0.067     -2.847      0.004      -0.320      -0.059
# ==============================================================================
# Omnibus:                       86.464   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              446.413
# Skew:                           1.368   Prob(JB):                     1.16e-97
# Kurtosis:                       9.189   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.565
# Model:                            OLS   Adj. R-squared:                  0.558
# Method:                 Least Squares   F-statistic:                     25.87
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.05e-17
# Time:                        12:52:20   Log-Likelihood:                 557.51
# No. Observations:                 234   AIC:                            -1105.
# Df Residuals:                     229   BIC:                            -1088.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0013      0.001     -0.960      0.337      -0.004       0.001
# mktrf          0.2194      0.044      4.949      0.000       0.133       0.306
# smb            0.5180      0.059      8.794      0.000       0.403       0.633
# hml           -0.1408      0.066     -2.126      0.034      -0.271      -0.011
# umd           -0.1895      0.071     -2.658      0.008      -0.329      -0.050
# ==============================================================================
# Omnibus:                       86.464   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              446.413
# Skew:                           1.368   Prob(JB):                     1.16e-97
# Kurtosis:                       9.189   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Pre-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.674
# Model:                            OLS   Adj. R-squared:                  0.662
# Method:                 Least Squares   F-statistic:                     59.35
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           4.31e-27
# Time:                        12:52:20   Log-Likelihood:                 279.51
# No. Observations:                 120   AIC:                            -549.0
# Df Residuals:                     115   BIC:                            -535.1
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0015      0.002      0.642      0.522      -0.003       0.006
# mktrf          0.1157      0.062      1.865      0.065      -0.007       0.239
# me             0.2657      0.061      4.336      0.000       0.144       0.387
# ia            -0.1220      0.096     -1.272      0.206      -0.312       0.068
# roe           -0.6104      0.085     -7.188      0.000      -0.779      -0.442
# ==============================================================================
# Omnibus:                       47.611   Durbin-Watson:                   2.156
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              167.439
# Skew:                           1.379   Prob(JB):                     4.38e-37
# Kurtosis:                       8.088   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.674
# Model:                            OLS   Adj. R-squared:                  0.662
# Method:                 Least Squares   F-statistic:                     44.42
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.68e-22
# Time:                        12:52:20   Log-Likelihood:                 279.51
# No. Observations:                 120   AIC:                            -549.0
# Df Residuals:                     115   BIC:                            -535.1
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0015      0.003      0.509      0.611      -0.004       0.007
# mktrf          0.1157      0.059      1.964      0.049       0.000       0.231
# me             0.2657      0.064      4.179      0.000       0.141       0.390
# ia            -0.1220      0.161     -0.756      0.449      -0.438       0.194
# roe           -0.6104      0.174     -3.503      0.000      -0.952      -0.269
# ==============================================================================
# Omnibus:                       47.611   Durbin-Watson:                   2.156
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              167.439
# Skew:                           1.379   Prob(JB):                     4.38e-37
# Kurtosis:                       8.088   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.674
# Model:                            OLS   Adj. R-squared:                  0.662
# Method:                 Least Squares   F-statistic:                     63.49
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           3.13e-28
# Time:                        12:52:20   Log-Likelihood:                 279.51
# No. Observations:                 120   AIC:                            -549.0
# Df Residuals:                     115   BIC:                            -535.1
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0015      0.003      0.525      0.600      -0.004       0.007
# mktrf          0.1157      0.054      2.160      0.031       0.011       0.221
# me             0.2657      0.067      3.973      0.000       0.135       0.397
# ia            -0.1220      0.149     -0.820      0.412      -0.414       0.170
# roe           -0.6104      0.178     -3.428      0.001      -0.959      -0.261
# ==============================================================================
# Omnibus:                       47.611   Durbin-Watson:                   2.156
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              167.439
# Skew:                           1.379   Prob(JB):                     4.38e-37
# Kurtosis:                       8.088   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.644
# Model:                            OLS   Adj. R-squared:                  0.631
# Method:                 Least Squares   F-statistic:                     51.93
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           6.50e-25
# Time:                        12:52:20   Log-Likelihood:                 274.23
# No. Observations:                 120   AIC:                            -538.5
# Df Residuals:                     115   BIC:                            -524.5
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0004      0.002     -0.153      0.879      -0.005       0.004
# mktrf          0.2833      0.057      4.960      0.000       0.170       0.396
# smb            0.4984      0.065      7.665      0.000       0.370       0.627
# hml           -0.2022      0.065     -3.105      0.002      -0.331      -0.073
# umd           -0.1629      0.040     -4.058      0.000      -0.242      -0.083
# ==============================================================================
# Omnibus:                       59.225   Durbin-Watson:                   2.160
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              276.418
# Skew:                           1.645   Prob(JB):                     9.48e-61
# Kurtosis:                       9.668   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.644
# Model:                            OLS   Adj. R-squared:                  0.631
# Method:                 Least Squares   F-statistic:                     31.88
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           7.28e-18
# Time:                        12:52:20   Log-Likelihood:                 274.23
# No. Observations:                 120   AIC:                            -538.5
# Df Residuals:                     115   BIC:                            -524.5
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0004      0.002     -0.153      0.879      -0.005       0.004
# mktrf          0.2833      0.044      6.434      0.000       0.197       0.370
# smb            0.4984      0.078      6.410      0.000       0.346       0.651
# hml           -0.2022      0.070     -2.875      0.004      -0.340      -0.064
# umd           -0.1629      0.074     -2.208      0.027      -0.308      -0.018
# ==============================================================================
# Omnibus:                       59.225   Durbin-Watson:                   2.160
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              276.418
# Skew:                           1.645   Prob(JB):                     9.48e-61
# Kurtosis:                       9.668   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.644
# Model:                            OLS   Adj. R-squared:                  0.631
# Method:                 Least Squares   F-statistic:                     33.82
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.22e-18
# Time:                        12:52:20   Log-Likelihood:                 274.23
# No. Observations:                 120   AIC:                            -538.5
# Df Residuals:                     115   BIC:                            -524.5
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0004      0.002     -0.169      0.866      -0.005       0.004
# mktrf          0.2833      0.037      7.664      0.000       0.211       0.356
# smb            0.4984      0.074      6.777      0.000       0.354       0.643
# hml           -0.2022      0.058     -3.470      0.001      -0.316      -0.088
# umd           -0.1629      0.077     -2.108      0.035      -0.314      -0.011
# ==============================================================================
# Omnibus:                       59.225   Durbin-Watson:                   2.160
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              276.418
# Skew:                           1.645   Prob(JB):                     9.48e-61
# Kurtosis:                       9.668   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.644
# Model:                            OLS   Adj. R-squared:                  0.631
# Method:                 Least Squares   F-statistic:                     51.93
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           6.50e-25
# Time:                        12:52:20   Log-Likelihood:                 274.23
# No. Observations:                 120   AIC:                            -538.5
# Df Residuals:                     115   BIC:                            -524.5
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0004      0.002     -0.153      0.879      -0.005       0.004
# mktrf          0.2833      0.057      4.960      0.000       0.170       0.396
# smb            0.4984      0.065      7.665      0.000       0.370       0.627
# hml           -0.2022      0.065     -3.105      0.002      -0.331      -0.073
# umd           -0.1629      0.040     -4.058      0.000      -0.242      -0.083
# ==============================================================================
# Omnibus:                       59.225   Durbin-Watson:                   2.160
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              276.418
# Skew:                           1.645   Prob(JB):                     9.48e-61
# Kurtosis:                       9.668   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.644
# Model:                            OLS   Adj. R-squared:                  0.631
# Method:                 Least Squares   F-statistic:                     31.88
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           7.28e-18
# Time:                        12:52:20   Log-Likelihood:                 274.23
# No. Observations:                 120   AIC:                            -538.5
# Df Residuals:                     115   BIC:                            -524.5
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0004      0.002     -0.153      0.879      -0.005       0.004
# mktrf          0.2833      0.044      6.434      0.000       0.197       0.370
# smb            0.4984      0.078      6.410      0.000       0.346       0.651
# hml           -0.2022      0.070     -2.875      0.004      -0.340      -0.064
# umd           -0.1629      0.074     -2.208      0.027      -0.308      -0.018
# ==============================================================================
# Omnibus:                       59.225   Durbin-Watson:                   2.160
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              276.418
# Skew:                           1.645   Prob(JB):                     9.48e-61
# Kurtosis:                       9.668   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.644
# Model:                            OLS   Adj. R-squared:                  0.631
# Method:                 Least Squares   F-statistic:                     33.82
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.22e-18
# Time:                        12:52:20   Log-Likelihood:                 274.23
# No. Observations:                 120   AIC:                            -538.5
# Df Residuals:                     115   BIC:                            -524.5
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0004      0.002     -0.169      0.866      -0.005       0.004
# mktrf          0.2833      0.037      7.664      0.000       0.211       0.356
# smb            0.4984      0.074      6.777      0.000       0.354       0.643
# hml           -0.2022      0.058     -3.470      0.001      -0.316      -0.088
# umd           -0.1629      0.077     -2.108      0.035      -0.314      -0.011
# ==============================================================================
# Omnibus:                       59.225   Durbin-Watson:                   2.160
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              276.418
# Skew:                           1.645   Prob(JB):                     9.48e-61
# Kurtosis:                       9.668   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Post-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.622
# Model:                            OLS   Adj. R-squared:                  0.609
# Method:                 Least Squares   F-statistic:                     44.93
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           3.06e-22
# Time:                        12:52:20   Log-Likelihood:                 319.92
# No. Observations:                 114   AIC:                            -629.8
# Df Residuals:                     109   BIC:                            -616.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0009      0.001      0.602      0.548      -0.002       0.004
# mktrf          0.0646      0.044      1.470      0.144      -0.023       0.152
# me             0.2492      0.068      3.672      0.000       0.115       0.384
# ia            -0.0380      0.094     -0.403      0.688      -0.225       0.149
# roe           -0.7613      0.083     -9.203      0.000      -0.925      -0.597
# ==============================================================================
# Omnibus:                       23.934   Durbin-Watson:                   1.795
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               48.814
# Skew:                           0.841   Prob(JB):                     2.51e-11
# Kurtosis:                       5.729   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.622
# Model:                            OLS   Adj. R-squared:                  0.609
# Method:                 Least Squares   F-statistic:                     54.37
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           4.03e-25
# Time:                        12:52:20   Log-Likelihood:                 319.92
# No. Observations:                 114   AIC:                            -629.8
# Df Residuals:                     109   BIC:                            -616.2
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0009      0.001      0.840      0.401      -0.001       0.003
# mktrf          0.0646      0.038      1.688      0.091      -0.010       0.140
# me             0.2492      0.036      6.985      0.000       0.179       0.319
# ia            -0.0380      0.101     -0.376      0.707      -0.236       0.160
# roe           -0.7613      0.098     -7.750      0.000      -0.954      -0.569
# ==============================================================================
# Omnibus:                       23.934   Durbin-Watson:                   1.795
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               48.814
# Skew:                           0.841   Prob(JB):                     2.51e-11
# Kurtosis:                       5.729   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.622
# Model:                            OLS   Adj. R-squared:                  0.609
# Method:                 Least Squares   F-statistic:                     82.81
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           3.83e-32
# Time:                        12:52:20   Log-Likelihood:                 319.92
# No. Observations:                 114   AIC:                            -629.8
# Df Residuals:                     109   BIC:                            -616.2
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0009      0.001      1.039      0.299      -0.001       0.003
# mktrf          0.0646      0.032      2.014      0.044       0.002       0.128
# me             0.2492      0.032      7.898      0.000       0.187       0.311
# ia            -0.0380      0.103     -0.368      0.713      -0.240       0.164
# roe           -0.7613      0.087     -8.744      0.000      -0.932      -0.591
# ==============================================================================
# Omnibus:                       23.934   Durbin-Watson:                   1.795
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               48.814
# Skew:                           0.841   Prob(JB):                     2.51e-11
# Kurtosis:                       5.729   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.424
# Model:                            OLS   Adj. R-squared:                  0.403
# Method:                 Least Squares   F-statistic:                     20.08
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.07e-12
# Time:                        12:52:20   Log-Likelihood:                 295.87
# No. Observations:                 114   AIC:                            -581.7
# Df Residuals:                     109   BIC:                            -568.1
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0007      0.002     -0.400      0.690      -0.004       0.003
# mktrf          0.1221      0.051      2.372      0.019       0.020       0.224
# smb            0.4426      0.080      5.518      0.000       0.284       0.602
# hml            0.1063      0.083      1.286      0.201      -0.057       0.270
# umd           -0.1901      0.062     -3.051      0.003      -0.314      -0.067
# ==============================================================================
# Omnibus:                       13.708   Durbin-Watson:                   1.791
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               19.191
# Skew:                           0.608   Prob(JB):                     6.80e-05
# Kurtosis:                       4.600   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.424
# Model:                            OLS   Adj. R-squared:                  0.403
# Method:                 Least Squares   F-statistic:                     16.48
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.37e-10
# Time:                        12:52:20   Log-Likelihood:                 295.87
# No. Observations:                 114   AIC:                            -581.7
# Df Residuals:                     109   BIC:                            -568.1
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0007      0.001     -0.549      0.583      -0.003       0.002
# mktrf          0.1221      0.056      2.172      0.030       0.012       0.232
# smb            0.4426      0.066      6.662      0.000       0.312       0.573
# hml            0.1063      0.147      0.725      0.469      -0.181       0.394
# umd           -0.1901      0.067     -2.839      0.005      -0.321      -0.059
# ==============================================================================
# Omnibus:                       13.708   Durbin-Watson:                   1.791
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               19.191
# Skew:                           0.608   Prob(JB):                     6.80e-05
# Kurtosis:                       4.600   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.424
# Model:                            OLS   Adj. R-squared:                  0.403
# Method:                 Least Squares   F-statistic:                     25.20
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           8.65e-15
# Time:                        12:52:20   Log-Likelihood:                 295.87
# No. Observations:                 114   AIC:                            -581.7
# Df Residuals:                     109   BIC:                            -568.1
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0007      0.001     -0.625      0.532      -0.003       0.002
# mktrf          0.1221      0.056      2.192      0.028       0.013       0.231
# smb            0.4426      0.049      9.018      0.000       0.346       0.539
# hml            0.1063      0.155      0.685      0.493      -0.198       0.410
# umd           -0.1901      0.060     -3.169      0.002      -0.308      -0.073
# ==============================================================================
# Omnibus:                       13.708   Durbin-Watson:                   1.791
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               19.191
# Skew:                           0.608   Prob(JB):                     6.80e-05
# Kurtosis:                       4.600   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.424
# Model:                            OLS   Adj. R-squared:                  0.403
# Method:                 Least Squares   F-statistic:                     20.08
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           2.07e-12
# Time:                        12:52:20   Log-Likelihood:                 295.87
# No. Observations:                 114   AIC:                            -581.7
# Df Residuals:                     109   BIC:                            -568.1
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0007      0.002     -0.400      0.690      -0.004       0.003
# mktrf          0.1221      0.051      2.372      0.019       0.020       0.224
# smb            0.4426      0.080      5.518      0.000       0.284       0.602
# hml            0.1063      0.083      1.286      0.201      -0.057       0.270
# umd           -0.1901      0.062     -3.051      0.003      -0.314      -0.067
# ==============================================================================
# Omnibus:                       13.708   Durbin-Watson:                   1.791
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               19.191
# Skew:                           0.608   Prob(JB):                     6.80e-05
# Kurtosis:                       4.600   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.424
# Model:                            OLS   Adj. R-squared:                  0.403
# Method:                 Least Squares   F-statistic:                     16.48
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.37e-10
# Time:                        12:52:20   Log-Likelihood:                 295.87
# No. Observations:                 114   AIC:                            -581.7
# Df Residuals:                     109   BIC:                            -568.1
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0007      0.001     -0.549      0.583      -0.003       0.002
# mktrf          0.1221      0.056      2.172      0.030       0.012       0.232
# smb            0.4426      0.066      6.662      0.000       0.312       0.573
# hml            0.1063      0.147      0.725      0.469      -0.181       0.394
# umd           -0.1901      0.067     -2.839      0.005      -0.321      -0.059
# ==============================================================================
# Omnibus:                       13.708   Durbin-Watson:                   1.791
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               19.191
# Skew:                           0.608   Prob(JB):                     6.80e-05
# Kurtosis:                       4.600   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.424
# Model:                            OLS   Adj. R-squared:                  0.403
# Method:                 Least Squares   F-statistic:                     25.20
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           8.65e-15
# Time:                        12:52:21   Log-Likelihood:                 295.87
# No. Observations:                 114   AIC:                            -581.7
# Df Residuals:                     109   BIC:                            -568.1
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0007      0.001     -0.625      0.532      -0.003       0.002
# mktrf          0.1221      0.056      2.192      0.028       0.013       0.231
# smb            0.4426      0.049      9.018      0.000       0.346       0.539
# hml            0.1063      0.155      0.685      0.493      -0.198       0.410
# umd           -0.1901      0.060     -3.169      0.002      -0.308      -0.073
# ==============================================================================
# Omnibus:                       13.708   Durbin-Watson:                   1.791
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               19.191
# Skew:                           0.608   Prob(JB):                     6.80e-05
# Kurtosis:                       4.600   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """
