# %% [markdown]
# # Method 8 - Best Fresh Ideas DGTW Timing

# %%
# %matplotlib inline
import pandas as pd
import warnings
from statsmodels import api as sm

from eptooling import crsp, epd, fs, hfu, crsp, db, bi
from eptooling.bm import bmdb, iso
from epquant.engine import weights, portfolio
from epquant.gen import returns
from epquant.perf import relative_performance

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Fetch Holdings and Benchmark Data

# %%
# Novus HFU

novus_hfu = hfu.get_novus_hfu()

# Get HFU Data

# %store -r inst_data

# Count number of positions per manager

inst_data['num_pos'] = inst_data.groupby(['datadate', 'institution_id'])[
    'fsym_id'].transform(lambda s: s.nunique())

# Remove less than 20 holdings and less than $5mm per CSP

valid_data = inst_data[inst_data['num_pos'] >= 20]
valid_data = valid_data[valid_data['public_aum'] >= 5e6]

# Get Returns for Fresh Ideas

# %store -r r

# Get Adjusted Quantities

qty_pivot = pd.pivot_table(inst_data, index='datadate', columns=['institution_id', 'fsym_id'], values='quantity',
                           aggfunc='sum')
qty_pivot = qty_pivot.mul(r.splits.reindex(qty_pivot.index), level=1).fillna(0)
qty_pivot = qty_pivot - qty_pivot.shift(1)
flat_qty = pd.melt(qty_pivot.reset_index(), id_vars='datadate', value_name='qty_change')
flat_qty = flat_qty[flat_qty['qty_change'] > 0]

# Get Pos Size Change

pos_size_pivot = pd.pivot_table(inst_data, index='datadate', columns=['institution_id', 'fsym_id'], values='target',
                                aggfunc='sum')
pos_size_pivot = pos_size_pivot - pos_size_pivot.shift(1)
flat_pos_size = pd.melt(pos_size_pivot.reset_index(), id_vars='datadate', value_name='size_change')
flat_pos_size = flat_pos_size[flat_pos_size['size_change'] > 0]

# Use Raw Weight

valid_data['adj_target'] = valid_data['target']

# %% [markdown]
# ## Calculate Best Fresh Ideas

# %%
# Extract Best Ideas

valid_data['pos_rank'] = valid_data\
    .groupby(['datadate', 'institution_id'])['adj_target'].rank(ascending=False)

# Get Best
    
best_ideas = valid_data[valid_data['pos_rank'] == 1].copy()

# Filter to Fresh

best_ideas = best_ideas.merge(flat_qty).merge(flat_pos_size)

# Weight the best ideas equally

best_ideas['target'] = 1 / best_ideas.groupby('datadate')[
    'institution_id'].transform('count')

# %% [markdown]
# ## Backtest Portfolio

# %%
w = weights.Weights(best_ideas)

p = portfolio.DailyPortfolio(w, r, end_date='2018-12-31')

monthly_beg_pos = p.beg_port.iloc[1:].resample('M', level=0).apply(epd.take_first)
dgtw = crsp.get_dgtw_returns(list(set(best_ideas['fsym_id'].dropna())),
                    best_ideas['datadate'].min(), pd.datetime(2018, 12, 31))
dgtw_pivot = pd.pivot_table(dgtw, index='datadate', columns='fsym_id', values='total_return')
dgtw_cont = monthly_beg_pos.mul(dgtw_pivot, axis=1, level=0).sum(axis=1)
dgtw_cont = dgtw_cont[dgtw_cont != 0]

rf = bi.get_risk_free_rate()
monthly_return = dgtw_cont.loc['1999-07-01':]
monthly_return = (monthly_return - rf).dropna()
monthly_return.name = 'port_return'

# %% [markdown]
# ## Plot Performance

# %%
epd.nav(monthly_return).plot()

# %%
monthly_return.resample('A').apply(epd.prod_red)
# Out:
# datadate
# 1999-12-31    0.118099
# 2000-12-31   -0.103163
# 2001-12-31   -0.059254
# 2002-12-31   -0.201721
# 2003-12-31    0.515497
# 2004-12-31    0.135934
# 2005-12-31    0.030337
# 2006-12-31    0.062092
# 2007-12-31   -0.029229
# 2008-12-31   -0.446743
# 2009-12-31    0.556358
# 2010-12-31    0.268206
# 2011-12-31   -0.042524
# 2012-12-31    0.169171
# 2013-12-31    0.371711
# 2014-12-31    0.057250
# 2015-12-31   -0.065609
# 2016-12-31    0.171770
# 2017-12-31    0.155936
# 2018-12-31   -0.077405
# Freq: A-DEC, Name: port_return, dtype: float64

# %% [markdown]
# ## Fetch Factor Models

# %%
# Get Factor Models
q_factor_model = bi.get_q_factor_model()
fama_french_five_factor_model = bi.get_fama_french_five_factor_model()
four_factor_model = bi.get_four_factor_model()

# Concat Portfolio Return
q_factor = pd.concat([monthly_return, q_factor_model], axis=1)
fama_french_five = pd.concat([monthly_return, fama_french_five_factor_model], axis=1)
four_factor = pd.concat([monthly_return, four_factor_model], axis=1)

# Add Constants
q_factor.insert(1, 'const', 1)
fama_french_five.insert(1, 'const', 1)
four_factor.insert(1, 'const', 1)

# Split Period into Pre and Post Crisis
q_factor_pre, q_factor_post = q_factor.loc[:'2009-06-30'], q_factor.loc['2009-07-31':]
fama_french_five_pre, fama_french_five_post = fama_french_five.loc[:'2009-06-30'], fama_french_five.loc['2009-07-31':] 
four_factor_pre, four_factor_post = four_factor.loc[:'2009-06-30'], four_factor.loc['2009-07-31':]

# %% [markdown]
# ## Full Time Period Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.946
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     1009.
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):          4.08e-144
# Time:                        13:43:04   Log-Likelihood:                 691.98
# No. Observations:                 234   AIC:                            -1374.
# Df Residuals:                     229   BIC:                            -1357.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0017      0.001      1.985      0.048    1.26e-05       0.003
# mktrf          1.0095      0.024     42.583      0.000       0.963       1.056
# me             0.2695      0.028      9.775      0.000       0.215       0.324
# ia             0.1380      0.042      3.292      0.001       0.055       0.221
# roe           -0.3049      0.036     -8.498      0.000      -0.376      -0.234
# ==============================================================================
# Omnibus:                       56.187   Durbin-Watson:                   1.932
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              384.510
# Skew:                           0.708   Prob(JB):                     3.20e-84
# Kurtosis:                       9.118   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.946
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     820.2
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):          1.99e-134
# Time:                        13:43:04   Log-Likelihood:                 691.98
# No. Observations:                 234   AIC:                            -1374.
# Df Residuals:                     229   BIC:                            -1357.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0017      0.001      1.949      0.051   -9.85e-06       0.003
# mktrf          1.0095      0.038     26.286      0.000       0.934       1.085
# me             0.2695      0.099      2.728      0.006       0.076       0.463
# ia             0.1380      0.084      1.636      0.102      -0.027       0.303
# roe           -0.3049      0.070     -4.347      0.000      -0.442      -0.167
# ==============================================================================
# Omnibus:                       56.187   Durbin-Watson:                   1.932
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              384.510
# Skew:                           0.708   Prob(JB):                     3.20e-84
# Kurtosis:                       9.118   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor.iloc[:, :1], q_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.946
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     1176.
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):          2.42e-151
# Time:                        13:43:04   Log-Likelihood:                 691.98
# No. Observations:                 234   AIC:                            -1374.
# Df Residuals:                     229   BIC:                            -1357.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0017      0.001      2.026      0.043    5.59e-05       0.003
# mktrf          1.0095      0.034     29.649      0.000       0.943       1.076
# me             0.2695      0.103      2.610      0.009       0.067       0.472
# ia             0.1380      0.075      1.836      0.066      -0.009       0.285
# roe           -0.3049      0.066     -4.604      0.000      -0.435      -0.175
# ==============================================================================
# Omnibus:                       56.187   Durbin-Watson:                   1.932
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              384.510
# Skew:                           0.708   Prob(JB):                     3.20e-84
# Kurtosis:                       9.118   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.960
# Model:                            OLS   Adj. R-squared:                  0.960
# Method:                 Least Squares   F-statistic:                     1387.
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):          3.52e-159
# Time:                        13:43:04   Log-Likelihood:                 727.44
# No. Observations:                 234   AIC:                            -1445.
# Df Residuals:                     229   BIC:                            -1428.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0012      0.001      1.644      0.102      -0.000       0.003
# mktrf          1.0050      0.019     53.580      0.000       0.968       1.042
# smb            0.4480      0.023     19.133      0.000       0.402       0.494
# hml            0.1404      0.023      6.038      0.000       0.095       0.186
# umd           -0.1984      0.015    -13.004      0.000      -0.229      -0.168
# ==============================================================================
# Omnibus:                       11.011   Durbin-Watson:                   1.786
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               23.327
# Skew:                          -0.102   Prob(JB):                     8.60e-06
# Kurtosis:                       4.533   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.960
# Model:                            OLS   Adj. R-squared:                  0.960
# Method:                 Least Squares   F-statistic:                     1786.
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):          2.48e-171
# Time:                        13:43:04   Log-Likelihood:                 727.44
# No. Observations:                 234   AIC:                            -1445.
# Df Residuals:                     229   BIC:                            -1428.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0012      0.001      1.321      0.187      -0.001       0.003
# mktrf          1.0050      0.019     52.325      0.000       0.967       1.043
# smb            0.4480      0.066      6.796      0.000       0.319       0.577
# hml            0.1404      0.032      4.458      0.000       0.079       0.202
# umd           -0.1984      0.028     -7.066      0.000      -0.253      -0.143
# ==============================================================================
# Omnibus:                       11.011   Durbin-Watson:                   1.786
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               23.327
# Skew:                          -0.102   Prob(JB):                     8.60e-06
# Kurtosis:                       4.533   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five.iloc[:, :1], fama_french_five.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.960
# Model:                            OLS   Adj. R-squared:                  0.960
# Method:                 Least Squares   F-statistic:                     1570.
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):          3.91e-165
# Time:                        13:43:04   Log-Likelihood:                 727.44
# No. Observations:                 234   AIC:                            -1445.
# Df Residuals:                     229   BIC:                            -1428.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0012      0.001      1.332      0.183      -0.001       0.003
# mktrf          1.0050      0.019     52.429      0.000       0.967       1.043
# smb            0.4480      0.067      6.724      0.000       0.317       0.579
# hml            0.1404      0.032      4.421      0.000       0.078       0.203
# umd           -0.1984      0.026     -7.632      0.000      -0.249      -0.147
# ==============================================================================
# Omnibus:                       11.011   Durbin-Watson:                   1.786
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               23.327
# Skew:                          -0.102   Prob(JB):                     8.60e-06
# Kurtosis:                       4.533   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.960
# Model:                            OLS   Adj. R-squared:                  0.960
# Method:                 Least Squares   F-statistic:                     1387.
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):          3.52e-159
# Time:                        13:43:04   Log-Likelihood:                 727.44
# No. Observations:                 234   AIC:                            -1445.
# Df Residuals:                     229   BIC:                            -1428.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0012      0.001      1.644      0.102      -0.000       0.003
# mktrf          1.0050      0.019     53.580      0.000       0.968       1.042
# smb            0.4480      0.023     19.133      0.000       0.402       0.494
# hml            0.1404      0.023      6.038      0.000       0.095       0.186
# umd           -0.1984      0.015    -13.004      0.000      -0.229      -0.168
# ==============================================================================
# Omnibus:                       11.011   Durbin-Watson:                   1.786
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               23.327
# Skew:                          -0.102   Prob(JB):                     8.60e-06
# Kurtosis:                       4.533   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.960
# Model:                            OLS   Adj. R-squared:                  0.960
# Method:                 Least Squares   F-statistic:                     1786.
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):          2.48e-171
# Time:                        13:43:04   Log-Likelihood:                 727.44
# No. Observations:                 234   AIC:                            -1445.
# Df Residuals:                     229   BIC:                            -1428.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0012      0.001      1.321      0.187      -0.001       0.003
# mktrf          1.0050      0.019     52.325      0.000       0.967       1.043
# smb            0.4480      0.066      6.796      0.000       0.319       0.577
# hml            0.1404      0.032      4.458      0.000       0.079       0.202
# umd           -0.1984      0.028     -7.066      0.000      -0.253      -0.143
# ==============================================================================
# Omnibus:                       11.011   Durbin-Watson:                   1.786
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               23.327
# Skew:                          -0.102   Prob(JB):                     8.60e-06
# Kurtosis:                       4.533   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor.iloc[:, :1], four_factor.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.960
# Model:                            OLS   Adj. R-squared:                  0.960
# Method:                 Least Squares   F-statistic:                     1570.
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):          3.91e-165
# Time:                        13:43:04   Log-Likelihood:                 727.44
# No. Observations:                 234   AIC:                            -1445.
# Df Residuals:                     229   BIC:                            -1428.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0012      0.001      1.332      0.183      -0.001       0.003
# mktrf          1.0050      0.019     52.429      0.000       0.967       1.043
# smb            0.4480      0.067      6.724      0.000       0.317       0.579
# hml            0.1404      0.032      4.421      0.000       0.078       0.203
# umd           -0.1984      0.026     -7.632      0.000      -0.249      -0.147
# ==============================================================================
# Omnibus:                       11.011   Durbin-Watson:                   1.786
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               23.327
# Skew:                          -0.102   Prob(JB):                     8.60e-06
# Kurtosis:                       4.533   Cond. No.                         36.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Pre-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.940
# Model:                            OLS   Adj. R-squared:                  0.938
# Method:                 Least Squares   F-statistic:                     449.0
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           3.63e-69
# Time:                        13:43:04   Log-Likelihood:                 332.69
# No. Observations:                 120   AIC:                            -655.4
# Df Residuals:                     115   BIC:                            -641.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0027      0.001      1.811      0.073      -0.000       0.006
# mktrf          1.0366      0.040     26.029      0.000       0.958       1.116
# me             0.1913      0.039      4.864      0.000       0.113       0.269
# ia             0.1560      0.062      2.532      0.013       0.034       0.278
# roe           -0.2978      0.055     -5.462      0.000      -0.406      -0.190
# ==============================================================================
# Omnibus:                       21.615   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               52.135
# Skew:                           0.660   Prob(JB):                     4.78e-12
# Kurtosis:                       5.947   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.940
# Model:                            OLS   Adj. R-squared:                  0.938
# Method:                 Least Squares   F-statistic:                     408.2
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           6.10e-67
# Time:                        13:43:04   Log-Likelihood:                 332.69
# No. Observations:                 120   AIC:                            -655.4
# Df Residuals:                     115   BIC:                            -641.4
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0027      0.002      1.670      0.095      -0.000       0.006
# mktrf          1.0366      0.047     21.873      0.000       0.944       1.130
# me             0.1913      0.099      1.941      0.052      -0.002       0.385
# ia             0.1560      0.091      1.705      0.088      -0.023       0.335
# roe           -0.2978      0.078     -3.826      0.000      -0.450      -0.145
# ==============================================================================
# Omnibus:                       21.615   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               52.135
# Skew:                           0.660   Prob(JB):                     4.78e-12
# Kurtosis:                       5.947   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_pre.iloc[:, :1], q_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.940
# Model:                            OLS   Adj. R-squared:                  0.938
# Method:                 Least Squares   F-statistic:                     519.3
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.36e-72
# Time:                        13:43:04   Log-Likelihood:                 332.69
# No. Observations:                 120   AIC:                            -655.4
# Df Residuals:                     115   BIC:                            -641.4
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0027      0.002      1.579      0.114      -0.001       0.006
# mktrf          1.0366      0.040     26.205      0.000       0.959       1.114
# me             0.1913      0.103      1.855      0.064      -0.011       0.394
# ia             0.1560      0.079      1.964      0.050       0.000       0.312
# roe           -0.2978      0.066     -4.538      0.000      -0.426      -0.169
# ==============================================================================
# Omnibus:                       21.615   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               52.135
# Skew:                           0.660   Prob(JB):                     4.78e-12
# Kurtosis:                       5.947   Cond. No.                         47.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.956
# Method:                 Least Squares   F-statistic:                     646.9
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           8.19e-78
# Time:                        13:43:04   Log-Likelihood:                 353.49
# No. Observations:                 120   AIC:                            -697.0
# Df Residuals:                     115   BIC:                            -683.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0022      0.001      1.840      0.068      -0.000       0.005
# mktrf          1.0392      0.030     35.222      0.000       0.981       1.098
# smb            0.4045      0.034     12.041      0.000       0.338       0.471
# hml            0.1401      0.034      4.163      0.000       0.073       0.207
# umd           -0.1977      0.021     -9.532      0.000      -0.239      -0.157
# ==============================================================================
# Omnibus:                        3.248   Durbin-Watson:                   1.802
# Prob(Omnibus):                  0.197   Jarque-Bera (JB):                2.683
# Skew:                          -0.286   Prob(JB):                        0.261
# Kurtosis:                       3.458   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.956
# Method:                 Least Squares   F-statistic:                     1768.
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):          3.14e-102
# Time:                        13:43:04   Log-Likelihood:                 353.49
# No. Observations:                 120   AIC:                            -697.0
# Df Residuals:                     115   BIC:                            -683.0
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0022      0.001      1.497      0.134      -0.001       0.005
# mktrf          1.0392      0.024     42.883      0.000       0.992       1.087
# smb            0.4045      0.072      5.602      0.000       0.263       0.546
# hml            0.1401      0.040      3.461      0.001       0.061       0.219
# umd           -0.1977      0.033     -6.056      0.000      -0.262      -0.134
# ==============================================================================
# Omnibus:                        3.248   Durbin-Watson:                   1.802
# Prob(Omnibus):                  0.197   Jarque-Bera (JB):                2.683
# Skew:                          -0.286   Prob(JB):                        0.261
# Kurtosis:                       3.458   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_pre.iloc[:, :1], fama_french_five_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.956
# Method:                 Least Squares   F-statistic:                     2540.
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):          3.78e-111
# Time:                        13:43:04   Log-Likelihood:                 353.49
# No. Observations:                 120   AIC:                            -697.0
# Df Residuals:                     115   BIC:                            -683.0
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0022      0.001      1.506      0.132      -0.001       0.005
# mktrf          1.0392      0.023     44.573      0.000       0.993       1.085
# smb            0.4045      0.073      5.579      0.000       0.262       0.547
# hml            0.1401      0.044      3.188      0.001       0.054       0.226
# umd           -0.1977      0.031     -6.296      0.000      -0.259      -0.136
# ==============================================================================
# Omnibus:                        3.248   Durbin-Watson:                   1.802
# Prob(Omnibus):                  0.197   Jarque-Bera (JB):                2.683
# Skew:                          -0.286   Prob(JB):                        0.261
# Kurtosis:                       3.458   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.956
# Method:                 Least Squares   F-statistic:                     646.9
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           8.19e-78
# Time:                        13:43:04   Log-Likelihood:                 353.49
# No. Observations:                 120   AIC:                            -697.0
# Df Residuals:                     115   BIC:                            -683.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0022      0.001      1.840      0.068      -0.000       0.005
# mktrf          1.0392      0.030     35.222      0.000       0.981       1.098
# smb            0.4045      0.034     12.041      0.000       0.338       0.471
# hml            0.1401      0.034      4.163      0.000       0.073       0.207
# umd           -0.1977      0.021     -9.532      0.000      -0.239      -0.157
# ==============================================================================
# Omnibus:                        3.248   Durbin-Watson:                   1.802
# Prob(Omnibus):                  0.197   Jarque-Bera (JB):                2.683
# Skew:                          -0.286   Prob(JB):                        0.261
# Kurtosis:                       3.458   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.956
# Method:                 Least Squares   F-statistic:                     1768.
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):          3.14e-102
# Time:                        13:43:04   Log-Likelihood:                 353.49
# No. Observations:                 120   AIC:                            -697.0
# Df Residuals:                     115   BIC:                            -683.0
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0022      0.001      1.497      0.134      -0.001       0.005
# mktrf          1.0392      0.024     42.883      0.000       0.992       1.087
# smb            0.4045      0.072      5.602      0.000       0.263       0.546
# hml            0.1401      0.040      3.461      0.001       0.061       0.219
# umd           -0.1977      0.033     -6.056      0.000      -0.262      -0.134
# ==============================================================================
# Omnibus:                        3.248   Durbin-Watson:                   1.802
# Prob(Omnibus):                  0.197   Jarque-Bera (JB):                2.683
# Skew:                          -0.286   Prob(JB):                        0.261
# Kurtosis:                       3.458   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_pre.iloc[:, :1], four_factor_pre.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.956
# Method:                 Least Squares   F-statistic:                     2540.
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):          3.78e-111
# Time:                        13:43:04   Log-Likelihood:                 353.49
# No. Observations:                 120   AIC:                            -697.0
# Df Residuals:                     115   BIC:                            -683.0
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0022      0.001      1.506      0.132      -0.001       0.005
# mktrf          1.0392      0.023     44.573      0.000       0.993       1.085
# smb            0.4045      0.073      5.579      0.000       0.262       0.547
# hml            0.1401      0.044      3.188      0.001       0.054       0.226
# umd           -0.1977      0.031     -6.296      0.000      -0.259      -0.136
# ==============================================================================
# Omnibus:                        3.248   Durbin-Watson:                   1.802
# Prob(Omnibus):                  0.197   Jarque-Bera (JB):                2.683
# Skew:                          -0.286   Prob(JB):                        0.261
# Kurtosis:                       3.458   Cond. No.                         33.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ## Post-Crisis Regressions

# %% [markdown]
# ### Q Factor Model

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.979
# Model:                            OLS   Adj. R-squared:                  0.979
# Method:                 Least Squares   F-statistic:                     1296.
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           6.91e-91
# Time:                        13:43:04   Log-Likelihood:                 414.01
# No. Observations:                 114   AIC:                            -818.0
# Df Residuals:                     109   BIC:                            -804.3
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0020      0.001      3.095      0.002       0.001       0.003
# mktrf          0.9225      0.019     47.899      0.000       0.884       0.961
# me             0.5263      0.030     17.700      0.000       0.467       0.585
# ia             0.0569      0.041      1.380      0.170      -0.025       0.139
# roe           -0.3280      0.036     -9.051      0.000      -0.400      -0.256
# ==============================================================================
# Omnibus:                       43.843   Durbin-Watson:                   1.934
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              200.165
# Skew:                           1.189   Prob(JB):                     3.43e-44
# Kurtosis:                       9.040   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Q Factor Model - Newey West (9 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.979
# Model:                            OLS   Adj. R-squared:                  0.979
# Method:                 Least Squares   F-statistic:                     1607.
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           6.93e-96
# Time:                        13:43:04   Log-Likelihood:                 414.01
# No. Observations:                 114   AIC:                            -818.0
# Df Residuals:                     109   BIC:                            -804.3
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0020      0.001      3.078      0.002       0.001       0.003
# mktrf          0.9225      0.017     54.331      0.000       0.889       0.956
# me             0.5263      0.036     14.537      0.000       0.455       0.597
# ia             0.0569      0.045      1.258      0.208      -0.032       0.146
# roe           -0.3280      0.048     -6.854      0.000      -0.422      -0.234
# ==============================================================================
# Omnibus:                       43.843   Durbin-Watson:                   1.934
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              200.165
# Skew:                           1.189   Prob(JB):                     3.43e-44
# Kurtosis:                       9.040   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Q Factor Model - Newey West (18 Lag)

# %%
sm.OLS(q_factor_post.iloc[:, :1], q_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.979
# Model:                            OLS   Adj. R-squared:                  0.979
# Method:                 Least Squares   F-statistic:                     2506.
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):          2.95e-106
# Time:                        13:43:04   Log-Likelihood:                 414.01
# No. Observations:                 114   AIC:                            -818.0
# Df Residuals:                     109   BIC:                            -804.3
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0020      0.001      3.447      0.001       0.001       0.003
# mktrf          0.9225      0.017     55.047      0.000       0.890       0.955
# me             0.5263      0.040     13.132      0.000       0.448       0.605
# ia             0.0569      0.046      1.225      0.221      -0.034       0.148
# roe           -0.3280      0.051     -6.484      0.000      -0.427      -0.229
# ==============================================================================
# Omnibus:                       43.843   Durbin-Watson:                   1.934
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              200.165
# Skew:                           1.189   Prob(JB):                     3.43e-44
# Kurtosis:                       9.040   Cond. No.                         67.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.975
# Model:                            OLS   Adj. R-squared:                  0.974
# Method:                 Least Squares   F-statistic:                     1071.
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.71e-86
# Time:                        13:43:04   Log-Likelihood:                 403.43
# No. Observations:                 114   AIC:                            -796.9
# Df Residuals:                     109   BIC:                            -783.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0008      0.001      1.156      0.250      -0.001       0.002
# mktrf          0.9479      0.020     47.332      0.000       0.908       0.988
# smb            0.5868      0.031     18.791      0.000       0.525       0.649
# hml            0.1348      0.032      4.190      0.000       0.071       0.198
# umd           -0.1414      0.024     -5.830      0.000      -0.190      -0.093
# ==============================================================================
# Omnibus:                       15.679   Durbin-Watson:                   1.922
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               26.475
# Skew:                           0.606   Prob(JB):                     1.78e-06
# Kurtosis:                       5.026   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (9 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.975
# Model:                            OLS   Adj. R-squared:                  0.974
# Method:                 Least Squares   F-statistic:                     952.4
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           8.84e-84
# Time:                        13:43:05   Log-Likelihood:                 403.43
# No. Observations:                 114   AIC:                            -796.9
# Df Residuals:                     109   BIC:                            -783.2
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0008      0.001      1.044      0.296      -0.001       0.002
# mktrf          0.9479      0.017     55.572      0.000       0.914       0.981
# smb            0.5868      0.034     17.163      0.000       0.520       0.654
# hml            0.1348      0.052      2.613      0.009       0.034       0.236
# umd           -0.1414      0.027     -5.315      0.000      -0.194      -0.089
# ==============================================================================
# Omnibus:                       15.679   Durbin-Watson:                   1.922
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               26.475
# Skew:                           0.606   Prob(JB):                     1.78e-06
# Kurtosis:                       5.026   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Fama French Five Factor Model - Newey West (18 Lag)

# %%
sm.OLS(fama_french_five_post.iloc[:, :1], fama_french_five_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.975
# Model:                            OLS   Adj. R-squared:                  0.974
# Method:                 Least Squares   F-statistic:                     1149.
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           4.15e-88
# Time:                        13:43:05   Log-Likelihood:                 403.43
# No. Observations:                 114   AIC:                            -796.9
# Df Residuals:                     109   BIC:                            -783.2
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0008      0.001      0.942      0.346      -0.001       0.003
# mktrf          0.9479      0.016     59.504      0.000       0.917       0.979
# smb            0.5868      0.034     17.370      0.000       0.521       0.653
# hml            0.1348      0.053      2.519      0.012       0.030       0.240
# umd           -0.1414      0.023     -6.069      0.000      -0.187      -0.096
# ==============================================================================
# Omnibus:                       15.679   Durbin-Watson:                   1.922
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               26.475
# Skew:                           0.606   Prob(JB):                     1.78e-06
# Kurtosis:                       5.026   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.975
# Model:                            OLS   Adj. R-squared:                  0.974
# Method:                 Least Squares   F-statistic:                     1071.
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           1.71e-86
# Time:                        13:43:05   Log-Likelihood:                 403.43
# No. Observations:                 114   AIC:                            -796.9
# Df Residuals:                     109   BIC:                            -783.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0008      0.001      1.156      0.250      -0.001       0.002
# mktrf          0.9479      0.020     47.332      0.000       0.908       0.988
# smb            0.5868      0.031     18.791      0.000       0.525       0.649
# hml            0.1348      0.032      4.190      0.000       0.071       0.198
# umd           -0.1414      0.024     -5.830      0.000      -0.190      -0.093
# ==============================================================================
# Omnibus:                       15.679   Durbin-Watson:                   1.922
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               26.475
# Skew:                           0.606   Prob(JB):                     1.78e-06
# Kurtosis:                       5.026   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (9 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':9}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.975
# Model:                            OLS   Adj. R-squared:                  0.974
# Method:                 Least Squares   F-statistic:                     952.4
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           8.84e-84
# Time:                        13:43:05   Log-Likelihood:                 403.43
# No. Observations:                 114   AIC:                            -796.9
# Df Residuals:                     109   BIC:                            -783.2
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0008      0.001      1.044      0.296      -0.001       0.002
# mktrf          0.9479      0.017     55.572      0.000       0.914       0.981
# smb            0.5868      0.034     17.163      0.000       0.520       0.654
# hml            0.1348      0.052      2.613      0.009       0.034       0.236
# umd           -0.1414      0.027     -5.315      0.000      -0.194      -0.089
# ==============================================================================
# Omnibus:                       15.679   Durbin-Watson:                   1.922
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               26.475
# Skew:                           0.606   Prob(JB):                     1.78e-06
# Kurtosis:                       5.026   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 9 lags and without small sample correction
# """

# %% [markdown]
# ### Carhart Four Factor Model - Newey West (18 Lag)

# %%
sm.OLS(four_factor_post.iloc[:, :1], four_factor_post.iloc[:, 1:]).fit(
    cov_type='HAC', cov_kwds={'maxlags':18}).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            port_return   R-squared:                       0.975
# Model:                            OLS   Adj. R-squared:                  0.974
# Method:                 Least Squares   F-statistic:                     1149.
# Date:                Sat, 25 Apr 2020   Prob (F-statistic):           4.15e-88
# Time:                        13:43:05   Log-Likelihood:                 403.43
# No. Observations:                 114   AIC:                            -796.9
# Df Residuals:                     109   BIC:                            -783.2
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0008      0.001      0.942      0.346      -0.001       0.003
# mktrf          0.9479      0.016     59.504      0.000       0.917       0.979
# smb            0.5868      0.034     17.370      0.000       0.521       0.653
# hml            0.1348      0.053      2.519      0.012       0.030       0.240
# umd           -0.1414      0.023     -6.069      0.000      -0.187      -0.096
# ==============================================================================
# Omnibus:                       15.679   Durbin-Watson:                   1.922
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               26.475
# Skew:                           0.606   Prob(JB):                     1.78e-06
# Kurtosis:                       5.026   Cond. No.                         52.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 18 lags and without small sample correction
# """
